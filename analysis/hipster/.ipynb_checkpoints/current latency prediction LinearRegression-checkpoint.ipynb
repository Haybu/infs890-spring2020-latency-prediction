# %% [markdown]
# # Linear Regression
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import seaborn as sns
from sklearn import preprocessing, metrics, feature_selection
from datetime import datetime
from scipy import stats
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.3f}'.format

# %% [markdown]
# Set this flag to True if you're using reduction feature using FCA, otherwise set it to False

# %%
# 1- read data file
# 1- read processed file
file_dir = '../data/processed-data/'


#data_file = 'factored_dataset.csv'
data_file = 'normalized_dataset.csv'
#data_file = 'standardized_normalized_dataset.csv'

data = pd.read_csv(file_dir + data_file)

# %%
data.head(5)
# Out:
#    ltcy  svc_cpu_use  svc_cpu_thr  svc_net_use  svc_disk_use  system_cpu_use  \
# 0 0.332        0.557        0.332        0.325         0.037          16.982
# 1 0.400        0.616        0.300        0.351         0.047          20.583
# 2 0.469        0.608        0.316        0.362         0.039          19.448
# 3 0.490        0.624        0.300        0.362         0.108          17.319
# 4 0.500        0.608        0.316        0.374         0.133          16.650
#
#    system_cpu_sat  system_net_use  svc_req_size  svc_resp_size  svc_pods  \
# 0           1.591           3.206         0.002          0.012     7.000
# 1           1.608           3.552         0.003          0.019     7.000
# 2           1.390           3.586         0.003          0.024     7.000
# 3           1.730           3.512         0.003          0.022     6.000
# 4           1.917           3.449         0.003          0.023     3.000
#
#    svc_req_rate
# 0         0.980
# 1         1.620
# 2         2.180
# 3         2.130
# 4         2.220

# %%
data.shape
# Out:
# (1584, 12)

# %%
targets = data['ltcy']
inputs = data.drop(['ltcy'], axis=1)

n_features = inputs.values.shape[1]

#inputs_scaled = scaler.fit_transform(inputs)
#x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=0.1, shuffle=False, random_state=365)

# for better convergence and result scale target to values between 0 - 1
y_train_max = y_train.max()
y_test_max = y_test.max()

y_train = y_train / y_train_max
y_test = y_test / y_test_max

print("there are {} features".format(n_features))
# Out:
# there are 11 features

# %% [markdown]
# # Regression with Feature Selection

# %%
# -- trying
#selector = feature_selection.SelectKBest(feature_selection.f_regression).fit(x_train, y_train)
#selectedFeatures = selector.transform(x_train)
#print('{} features selected'.format(selectedFeatures[1].shape[0]))

# %%
#clf = LassoCV()
#sfm = SelectFromModel(clf) #(clf, threshold=0.01)
#selectedFeatures = sfm.fit(x_train, y_train).transform(x_train)
#print('{} features selected'.format(selectedFeatures[1].shape[0]))

# %%
clf = RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15)
sfm = SelectFromModel(clf,threshold='0.8*mean')

# %%
# start:  search grid

reg = LinearRegression(normalize=False) # normalize false bacause we are going to use the scaler

# standardize the features
scaler = StandardScaler()
#scaler.fit(x_train.values.reshape(-1,n_features))

pipe = Pipeline(steps=[
    ('scaler', scaler),
    ('selector', sfm), 
    ('clf', reg)
])

kfold = KFold(n_splits=10, shuffle=False)

param_grid = {
    'selector__threshold': [.1, .05, .02, .01, .005, 0.001]
}

search = GridSearchCV(pipe, param_grid,scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=0, n_jobs=-1)

search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('selector',
#                                         SelectFromModel(estimator=RandomForestRegressor(bootstrap=True,
#                                                                                         ccp_alpha=0.0,
#                                                                                         criterion='mse',
#                                                                                         max_depth=10,
#                                                                                         max_features='auto',
#                                                                                         max_leaf_nodes=None,
#                                                                                         max_s...
#                                                         max_features=None,
#                                                         norm_order=1,
#                                                         prefit=False,
#                                                         threshold='0.8*mean')),
#                                        ('clf',
#                                         LinearRegression(copy_X=True,
#                                                          fit_intercept=True,
#                                                          n_jobs=None,
#                                                          normalize=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'selector__threshold': [0.1, 0.05, 0.02, 0.01, 0.005,
#                                                  0.001]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
estimator = search.best_estimator_
params = search.best_params_
score = search.best_score_

print("Best CV score = %0.3f:" % score)
print("Best CV params = {}".format(params))

print("")
all_training_scores = search.cv_results_
#print("\ncross_validation:\n", all_training_scores , "\n")
print(all_training_scores['mean_train_score'])
# Out:
# Best CV score = -0.018:
# Best CV params = {'selector__threshold': 0.1}
#
# [-0.01669387 -0.01644171 -0.01594819 -0.01594819 -0.01594819 -0.01594819]

# %%
pdf = pd.DataFrame(all_training_scores['mean_train_score'], columns=['training mse'])
pdf.plot()

# %% [markdown]
# # Training R2

# %%
y_hat = search.predict(x_train)

r2_train = metrics.r2_score(y_train, y_hat)
print('R2 (training) = {}'.format(r2_train))

#print("score ", search.score(x_test, y_test))
# or also R-Squared could be obtain via
#pline.score(x_train, y_train)
# Out:
# R2 (training) = 0.2954470942721602

# %%
print('R2 (training) = {}'.format(search.score(x_train,y_train)))
# Out:
# R2 (training) = -0.016775959422640978

# %%
pline.named_steps.regression.intercept_
# Out:
# 0.6261804592123861

# %%
pline.named_steps.regression.coef_
# Out:
# array([ 0.02370634, -0.01899422,  0.07377199])

# %%
# validation mean_absolute_percentage_error
train_error =  np.abs(y_train - y_hat)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)


print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.11 (0.07) 0.00 0.50 MSE

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
#plt.xlim(-2,3)
#plt.ylim(-3,1)
plt.show()

# %%
sns.distplot(y_train - y_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %% [markdown]
# # Testing

# %%
y_hat_test = search.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_hat_test, color='g')

# %%
perf = pd.DataFrame(np.exp(y_hat_test), columns=['prediction'])
y_test = y_test.reset_index(drop=True)
perf['target'] = np.exp(y_test)
perf.head()
# Out:
#    prediction  target
# 0       2.067   1.788
# 1       2.237   2.256
# 2       2.055   2.018
# 3       2.208   2.018
# 4       2.226   2.219

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0         2.067   1.788     0.279       15.602
# 1         2.237   2.256    -0.019        0.855
# 2         2.055   2.018     0.036        1.795
# 3         2.208   2.018     0.189        9.376
# 4         2.226   2.219     0.007        0.320
# ..          ...     ...       ...          ...
# 154       2.230   1.999     0.231       11.571
# 155       2.191   2.181     0.010        0.444
# 156       2.084   2.181    -0.097        4.432
# 157       2.241   2.134     0.107        5.032
# 158       2.258   2.228     0.030        1.326
#
# [159 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction  target  residual  difference%
# count
# 78         2.19    2.28     -0.08         3.73
# 53         2.23    2.14      0.09         4.03
# 36         2.17    2.27     -0.09         4.04
# 30         2.26    2.17      0.09         4.07
# 41         2.08    2.17     -0.09         4.25
# 26         2.25    2.15      0.09         4.35
# 156        2.08    2.18     -0.10         4.43
# 101        1.77    1.85     -0.08         4.48
# 51         2.10    2.20     -0.10         4.66
# 8          2.07    2.17     -0.10         4.68
# 130        2.13    2.24     -0.11         4.72
# 100        1.76    1.85     -0.09         4.73
# 15         2.22    2.11      0.10         4.82
# 134        2.12    2.23     -0.11         4.88
# 157        2.24    2.13      0.11         5.03
# 135        2.16    2.06      0.10         5.10
# 120        2.04    2.15     -0.11         5.16
# 50         2.07    2.18     -0.11         5.22
# 40         2.08    2.20     -0.12         5.30
# 33         2.07    2.19     -0.12         5.35
# 14         2.25    2.13      0.12         5.52
# 103        1.77    1.87     -0.10         5.59
# 95         1.60    1.50      0.10         6.93
# 66         2.09    2.25     -0.16         7.14
# 146        2.06    1.92      0.14         7.37
# 65         2.08    2.25     -0.17         7.44
# 116        2.02    2.18     -0.16         7.50
# 109        1.90    1.77      0.14         7.66
# 12         2.24    2.08      0.16         7.74
# 83         2.29    2.49     -0.20         8.14
# 124        2.08    2.27     -0.18         8.14
# 115        2.01    2.19     -0.18         8.20
# 17         2.08    2.27     -0.19         8.33
# 143        2.21    2.04      0.17         8.35
# 5          2.23    2.43     -0.21         8.46
# 142        2.21    2.04      0.17         8.47
# 77         2.18    2.38     -0.20         8.49
# 136        2.16    1.99      0.17         8.54
# 90         2.03    2.22     -0.19         8.68
# 56         2.01    2.21     -0.20         9.09
# 98         1.65    1.51      0.14         9.25
# 59         1.99    2.20     -0.21         9.32
# 3          2.21    2.02      0.19         9.38
# 75         2.02    2.23     -0.21         9.42
# 108        1.94    1.77      0.17         9.51
# 89         1.99    2.21     -0.22         9.78
# 133        2.01    2.23     -0.22         9.79
# 149        2.08    1.89      0.19         9.87
# 104        1.69    1.88     -0.19        10.04
# 16         2.06    2.30     -0.24        10.59
# 60         1.99    2.23     -0.24        10.74
# 122        1.95    2.19     -0.24        10.75
# 110        1.94    1.75      0.19        10.81
# 117        2.06    1.86      0.20        10.82
# 93         2.22    2.49     -0.27        10.88
# 118        2.04    1.84      0.20        11.00
# 80         2.05    2.31     -0.26        11.31
# 45         2.24    2.53     -0.29        11.56
# 154        2.23    2.00      0.23        11.57
# 11         2.24    2.01      0.24        11.70
# 123        2.09    2.37     -0.28        11.71
# 145        2.21    1.96      0.25        12.75
# 10         2.01    1.78      0.23        12.81
# 119        2.03    1.80      0.23        12.83
# 121        1.92    2.20     -0.28        12.88
# 144        2.22    1.97      0.25        12.89
# 105        1.71    1.51      0.20        13.35
# 96         1.68    1.48      0.20        13.35
# 125        1.97    1.74      0.23        13.51
# 9          2.21    1.95      0.26        13.59
# 70         2.26    2.64     -0.38        14.27
# 82         2.11    2.49     -0.38        15.16
# 141        2.18    1.89      0.29        15.23
# 0          2.07    1.79      0.28        15.60
# 97         1.73    1.50      0.24        15.76
# 147        2.22    1.92      0.30        15.77
# 151        2.06    1.78      0.28        15.98
# 150        2.05    1.77      0.29        16.15
# 44         2.23    2.67     -0.44        16.41
# 126        1.98    1.69      0.28        16.68
# 92         2.25    2.70     -0.45        16.72
# 137        2.16    1.85      0.31        16.82
# 6          2.15    2.61     -0.45        17.38
# 140        2.21    1.88      0.33        17.59
# 69         2.22    2.72     -0.50        18.33
# 106        1.79    1.51      0.28        18.86
# 131        2.13    2.69     -0.56        20.88
# 84         2.12    2.71     -0.59        21.82
# 81         2.09    2.67     -0.59        21.92
# 85         2.10    2.71     -0.61        22.63
# 99         1.72    2.24     -0.51        22.99
# 127        2.11    1.70      0.40        23.76
# 112        1.86    1.50      0.37        24.55
# 129        1.99    2.64     -0.65        24.57
# 107        1.86    1.50      0.37        24.67
# 132        1.96    2.69     -0.73        27.18
# 111        1.94    1.51      0.43        28.48
# 113        1.94    1.50      0.44        29.70

# %% [markdown]
# # Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_hat_test)
print('R2 (testing) = {}'.format(r2_test))

# also: R-Squared could obtain with
# pline.score(x_test, y_test)
# Out:
# R2 (testing) = 0.38161929199691336

# %%
print(np.sqrt(mean_squared_error(y_test,y_hat_test)))
# Out:
# 0.10524162934853167

# %% [markdown]
# # Trying with Polynomial features

# %%
if False:
    from sklearn.preprocessing import PolynomialFeatures

    # covert input data to polynomial form of some degree
    inputs_poly = PolynomialFeatures(degree=2).fit_transform(inputs).astype(float)

    x_train, x_test, y_train, y_test = \
        train_test_split(inputs_poly, targets, test_size=0.1, shuffle=False, random_state=365)

    # for better convergence and result scale target to values between 0 - 1
    y_train_max = y_train.max()
    y_test_max = y_test.max()

    y_train = y_train / y_train_max
    y_test = y_test / y_test_max


    reg = LinearRegression(normalize=False) # normalize false bacause we are going to use the scaler

    scaler = StandardScaler()

    pipe = Pipeline(steps=[
        ('scaler', scaler),
        ('selector', sfm), 
        ('clf', reg)
    ])

    kfold = KFold(n_splits=10, shuffle=False)

    param_grid = {
        'selector__threshold': [.1, .05, .02, .01, .005, 0.001]
    }

    search = GridSearchCV(pipe, param_grid,scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=0, n_jobs=-1)

    search.fit(x_train, y_train)

    y_hat_test = search.predict(x_test)

    r2_test = metrics.r2_score(y_test, y_hat_test)
    print('R2 (testing) = {}'.format(r2_test))

# %% [markdown]
# # What features to select

# %%
x_train.shape
# Out:
# (1425, 11)

# %%
#clf = LassoCV()
#sfm = SelectFromModel(clf, threshold=0.001)

sfm = SelectFromModel(
                RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15),
                threshold='0.8*mean')

selectedFeatures = sfm.fit(inputs, targets).transform(inputs)
print('{} features selected'.format(selectedFeatures[1].shape[0]))

feature_list = x_train.columns[sfm.get_support()]
features = ''
features = ', '.join(feature_list)
#features

reduced_x_train = x_train[feature_list]
reduced_x_train.head(2)
# Out:
# 4 features selected
#    svc_cpu_thr  system_cpu_use  system_cpu_sat  svc_req_rate
# 0         0.33           16.98            1.59          0.98
# 1         0.30           20.58            1.61          1.62

# %% [markdown]
# # Robust Linear Model

# %%
# RANSAC is an iterative algorithm for the robust estimation of parameters from a subset 
# of inliers from the complete data set.
# you can use this with all dataset including outliers
if False:    
    from sklearn.linear_model import RANSACRegressor

    ransac = RANSACRegressor(estimator)
    ransac.fit(x_train, y_train)
    inlier_mask = ransac.inlier_mask_
    outlier_mask = np.logical_not(inlier_mask)

    y_hat_test = ransac.predict(x_test)

    r2_test = metrics.r2_score(y_test, y_hat_test)
    print('R2 (testing) = {}'.format(r2_test))
