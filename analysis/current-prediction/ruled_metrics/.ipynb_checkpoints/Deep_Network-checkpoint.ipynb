# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.3f}'.format

# %%
# network structure. First layer number should be = number of features
net_layers = (11,16,8,4)

epochs=100
patience=80

# trials
# (11,16,8,4)   -> 0.712
# 11 -> 11 -> 6 
# 11 -> 8 -> 6   -> 0.704
# 11 -> 11 -> 8 -> 4  -> 0.709

# %%
# 1- read data file
# 1- read processed file
file_dir = '../../data/processed-data/'
data_file = 'standardized_normalized_dataset.csv'
data = pd.read_csv(file_dir + data_file)

# %%
data.head(5)
# Out:
#    svc_cpu_use  svc_cpu_thr  svc_net_use  svc_disk_use  system_cpu_use  \
# 0       -2.397       -1.146       -2.165        -2.248          -1.571
# 1       -2.193       -1.270       -2.052        -2.129          -1.570
# 2       -2.221       -1.206       -2.008        -2.227          -1.571
# 3       -2.165       -1.270       -2.007        -1.404          -1.571
# 4       -2.221       -1.206       -1.955        -1.105          -1.571
#
#    system_cpu_sat  system_net_use  svc_req_size  svc_resp_size  svc_pods  \
# 0          -1.348          -2.094        -1.754         -1.289    -1.485
# 1          -1.347          -2.030        -1.672         -1.230    -1.485
# 2          -1.365          -2.023        -1.607         -1.181    -1.485
# 3          -1.337          -2.037        -1.624         -1.198    -1.709
# 4          -1.321          -2.049        -1.616         -1.192    -2.379
#
#    svc_req_rate  ltcy
# 0        -1.998 0.332
# 1        -1.928 0.400
# 2        -1.866 0.469
# 3        -1.872 0.490
# 4        -1.862 0.500

# %% [markdown]
# ## Function to build a model

# %%
targets = data['ltcy']
inputs = data.drop(['ltcy'], axis=1)

x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=0.2, random_state=365)

# for better convergence and result scale target to values between 0 - 1
maxltcy = targets.max()
y_train = y_train / maxltcy
y_test = y_test / maxltcy

# %%
def build_model(nodes = net_layers):   # this does not work with KerasRegressor. interesting
    # create model
    model = Sequential()  
    model.add(Dense(nodes[1], input_dim=nodes[0], kernel_initializer='normal', activation='relu'))
    
    layer = 1
    while layer < len(nodes):
        model.add(Dense(nodes[layer], kernel_initializer='normal', activation='relu'))
        layer = layer + 1
        
    model.add(Dense(1, kernel_initializer='normal', activation='linear'))
    # Compile model
    opt = Adam(lr=1e-3, decay=1e-3 / 200)
    # or loss= 'mean_absolute_percentage_error'
    model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse'])
    return model

# %%
model = build_model()

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=patience)

# save the best model only
mc = ModelCheckpoint('../models/best_mlp_model.h5', monitor='val_loss', mode='min' \
                     , verbose=1, save_best_only=True)

history = model.fit(x_train, y_train, epochs=epochs, verbose=1, validation_split=0.1, \
                    shuffle=False, callbacks=[es, mc])

print ("Done..!")
# Out:
# Train on 1140 samples, validate on 127 samples
# Epoch 1/100
# 1140/1140 [==============================] - 2s 2ms/step - loss: 0.4090 - mean_squared_error: 0.4090 - val_loss: 0.3853 - val_mean_squared_error: 0.3853
#
# Epoch 00001: val_loss improved from inf to 0.38534, saving model to ../models/best_mlp_model.h5
# Epoch 2/100
# 1140/1140 [==============================] - 0s 70us/step - loss: 0.3542 - mean_squared_error: 0.3542 - val_loss: 0.3132 - val_mean_squared_error: 0.3132
#
# Epoch 00002: val_loss improved from 0.38534 to 0.31320, saving model to ../models/best_mlp_model.h5
# Epoch 3/100
# 1140/1140 [==============================] - 0s 71us/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.1112 - val_mean_squared_error: 0.1112
#
# Epoch 00003: val_loss improved from 0.31320 to 0.11121, saving model to ../models/best_mlp_model.h5
# Epoch 4/100
# 1140/1140 [==============================] - 0s 73us/step - loss: 0.0681 - mean_squared_error: 0.0681 - val_loss: 0.0649 - val_mean_squared_error: 0.0649
#
# Epoch 00004: val_loss improved from 0.11121 to 0.06494, saving model to ../models/best_mlp_model.h5
# Epoch 5/100
# 1140/1140 [==============================] - 0s 73us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0531 - val_mean_squared_error: 0.0531
#
# Epoch 00005: val_loss improved from 0.06494 to 0.05306, saving model to ../models/best_mlp_model.h5
# Epoch 6/100
# 1140/1140 [==============================] - 0s 71us/step - loss: 0.0408 - mean_squared_error: 0.0408 - val_loss: 0.0436 - val_mean_squared_error: 0.0436
#
# Epoch 00006: val_loss improved from 0.05306 to 0.04364, saving model to ../models/best_mlp_model.h5
# Epoch 7/100
# 1140/1140 [==============================] - 0s 81us/step - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
#
# Epoch 00007: val_loss improved from 0.04364 to 0.03579, saving model to ../models/best_mlp_model.h5
# Epoch 8/100
# 1140/1140 [==============================] - 0s 87us/step - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0294 - val_mean_squared_error: 0.0294
#
# Epoch 00008: val_loss improved from 0.03579 to 0.02942, saving model to ../models/best_mlp_model.h5
# Epoch 9/100
# 1140/1140 [==============================] - 0s 81us/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
#
# Epoch 00009: val_loss improved from 0.02942 to 0.02431, saving model to ../models/best_mlp_model.h5
# Epoch 10/100
# 1140/1140 [==============================] - 0s 79us/step - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
#
# Epoch 00010: val_loss improved from 0.02431 to 0.02052, saving model to ../models/best_mlp_model.h5
# Epoch 11/100
# 1140/1140 [==============================] - 0s 91us/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
#
# Epoch 00011: val_loss improved from 0.02052 to 0.01815, saving model to ../models/best_mlp_model.h5
# Epoch 12/100
# 1140/1140 [==============================] - 0s 85us/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
#
# Epoch 00012: val_loss improved from 0.01815 to 0.01674, saving model to ../models/best_mlp_model.h5
# Epoch 13/100
# 1140/1140 [==============================] - 0s 87us/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
#
# Epoch 00013: val_loss improved from 0.01674 to 0.01584, saving model to ../models/best_mlp_model.h5
# Epoch 14/100
# 1140/1140 [==============================] - 0s 83us/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
#
# Epoch 00014: val_loss improved from 0.01584 to 0.01525, saving model to ../models/best_mlp_model.h5
# Epoch 15/100
# 1140/1140 [==============================] - 0s 81us/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
#
# Epoch 00015: val_loss improved from 0.01525 to 0.01480, saving model to ../models/best_mlp_model.h5
# Epoch 16/100
# 1140/1140 [==============================] - 0s 83us/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
#
# Epoch 00016: val_loss improved from 0.01480 to 0.01457, saving model to ../models/best_mlp_model.h5
# Epoch 17/100
# 1140/1140 [==============================] - 0s 83us/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
#
# Epoch 00017: val_loss improved from 0.01457 to 0.01440, saving model to ../models/best_mlp_model.h5
# Epoch 18/100
# 1140/1140 [==============================] - 0s 83us/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
#
# Epoch 00018: val_loss improved from 0.01440 to 0.01428, saving model to ../models/best_mlp_model.h5
# Epoch 19/100
# 1140/1140 [==============================] - 0s 76us/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
#
# Epoch 00019: val_loss improved from 0.01428 to 0.01418, saving model to ../models/best_mlp_model.h5
# Epoch 20/100
# 1140/1140 [==============================] - 0s 81us/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
#
# Epoch 00020: val_loss improved from 0.01418 to 0.01410, saving model to ../models/best_mlp_model.h5
# Epoch 21/100
# 1140/1140 [==============================] - 0s 79us/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
#
# Epoch 00021: val_loss improved from 0.01410 to 0.01405, saving model to ../models/best_mlp_model.h5
# Epoch 22/100
# 1140/1140 [==============================] - 0s 78us/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
#
# Epoch 00022: val_loss improved from 0.01405 to 0.01402, saving model to ../models/best_mlp_model.h5
# Epoch 23/100
# 1140/1140 [==============================] - 0s 78us/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
#
# Epoch 00023: val_loss improved from 0.01402 to 0.01400, saving model to ../models/best_mlp_model.h5
# Epoch 24/100
# 1140/1140 [==============================] - 0s 80us/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
#
# Epoch 00024: val_loss improved from 0.01400 to 0.01398, saving model to ../models/best_mlp_model.h5
# Epoch 25/100
# 1140/1140 [==============================] - 0s 83us/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
#
# Epoch 00025: val_loss improved from 0.01398 to 0.01396, saving model to ../models/best_mlp_model.h5
# Epoch 26/100
# 1140/1140 [==============================] - 0s 77us/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00026: val_loss improved from 0.01396 to 0.01395, saving model to ../models/best_mlp_model.h5
# Epoch 27/100
# 1140/1140 [==============================] - 0s 80us/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00027: val_loss improved from 0.01395 to 0.01394, saving model to ../models/best_mlp_model.h5
# Epoch 28/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00028: val_loss improved from 0.01394 to 0.01392, saving model to ../models/best_mlp_model.h5
# Epoch 29/100
# 1140/1140 [==============================] - 0s 69us/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00029: val_loss improved from 0.01392 to 0.01391, saving model to ../models/best_mlp_model.h5
# Epoch 30/100
# 1140/1140 [==============================] - 0s 70us/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00030: val_loss improved from 0.01391 to 0.01391, saving model to ../models/best_mlp_model.h5
# Epoch 31/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 00031: val_loss improved from 0.01391 to 0.01389, saving model to ../models/best_mlp_model.h5
# Epoch 32/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00032: val_loss improved from 0.01389 to 0.01387, saving model to ../models/best_mlp_model.h5
# Epoch 33/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00033: val_loss improved from 0.01387 to 0.01387, saving model to ../models/best_mlp_model.h5
# Epoch 34/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00034: val_loss did not improve from 0.01387
# Epoch 35/100
# 1140/1140 [==============================] - 0s 76us/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00035: val_loss improved from 0.01387 to 0.01386, saving model to ../models/best_mlp_model.h5
# Epoch 36/100
# 1140/1140 [==============================] - 0s 86us/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00036: val_loss improved from 0.01386 to 0.01386, saving model to ../models/best_mlp_model.h5
# Epoch 37/100
# 1140/1140 [==============================] - 0s 71us/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00037: val_loss improved from 0.01386 to 0.01384, saving model to ../models/best_mlp_model.h5
# Epoch 38/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00038: val_loss improved from 0.01384 to 0.01384, saving model to ../models/best_mlp_model.h5
# Epoch 39/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00039: val_loss improved from 0.01384 to 0.01383, saving model to ../models/best_mlp_model.h5
# Epoch 40/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00040: val_loss improved from 0.01383 to 0.01382, saving model to ../models/best_mlp_model.h5
# Epoch 41/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00041: val_loss improved from 0.01382 to 0.01382, saving model to ../models/best_mlp_model.h5
# Epoch 42/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00042: val_loss improved from 0.01382 to 0.01382, saving model to ../models/best_mlp_model.h5
# Epoch 43/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00043: val_loss improved from 0.01382 to 0.01380, saving model to ../models/best_mlp_model.h5
# Epoch 44/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00044: val_loss improved from 0.01380 to 0.01380, saving model to ../models/best_mlp_model.h5
# Epoch 45/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00045: val_loss improved from 0.01380 to 0.01379, saving model to ../models/best_mlp_model.h5
# Epoch 46/100
# 1140/1140 [==============================] - 0s 68us/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00046: val_loss improved from 0.01379 to 0.01377, saving model to ../models/best_mlp_model.h5
# Epoch 47/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00047: val_loss improved from 0.01377 to 0.01377, saving model to ../models/best_mlp_model.h5
# Epoch 48/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
#
# Epoch 00048: val_loss improved from 0.01377 to 0.01375, saving model to ../models/best_mlp_model.h5
# Epoch 49/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00049: val_loss improved from 0.01375 to 0.01375, saving model to ../models/best_mlp_model.h5
# Epoch 50/100
# 1140/1140 [==============================] - 0s 69us/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00050: val_loss improved from 0.01375 to 0.01375, saving model to ../models/best_mlp_model.h5
# Epoch 51/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00051: val_loss improved from 0.01375 to 0.01373, saving model to ../models/best_mlp_model.h5
# Epoch 52/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00052: val_loss improved from 0.01373 to 0.01372, saving model to ../models/best_mlp_model.h5
# Epoch 53/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00053: val_loss improved from 0.01372 to 0.01372, saving model to ../models/best_mlp_model.h5
# Epoch 54/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00054: val_loss improved from 0.01372 to 0.01372, saving model to ../models/best_mlp_model.h5
# Epoch 55/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00055: val_loss improved from 0.01372 to 0.01371, saving model to ../models/best_mlp_model.h5
# Epoch 56/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00056: val_loss improved from 0.01371 to 0.01371, saving model to ../models/best_mlp_model.h5
# Epoch 57/100
# 1140/1140 [==============================] - 0s 64us/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00057: val_loss improved from 0.01371 to 0.01370, saving model to ../models/best_mlp_model.h5
# Epoch 58/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00058: val_loss did not improve from 0.01370
# Epoch 59/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00059: val_loss did not improve from 0.01370
# Epoch 60/100
# 1140/1140 [==============================] - 0s 75us/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00060: val_loss improved from 0.01370 to 0.01369, saving model to ../models/best_mlp_model.h5
# Epoch 61/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00061: val_loss did not improve from 0.01369
# Epoch 62/100
# 1140/1140 [==============================] - 0s 68us/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00062: val_loss did not improve from 0.01369
# Epoch 63/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00063: val_loss did not improve from 0.01369
# Epoch 64/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00064: val_loss did not improve from 0.01369
# Epoch 65/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00065: val_loss did not improve from 0.01369
# Epoch 66/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00066: val_loss did not improve from 0.01369
# Epoch 67/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00067: val_loss did not improve from 0.01369
# Epoch 68/100
# 1140/1140 [==============================] - 0s 75us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00068: val_loss did not improve from 0.01369
# Epoch 69/100
# 1140/1140 [==============================] - 0s 78us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00069: val_loss did not improve from 0.01369
# Epoch 70/100
# 1140/1140 [==============================] - 0s 75us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00070: val_loss did not improve from 0.01369
# Epoch 71/100
# 1140/1140 [==============================] - 0s 80us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00071: val_loss did not improve from 0.01369
# Epoch 72/100
# 1140/1140 [==============================] - 0s 81us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00072: val_loss did not improve from 0.01369
# Epoch 73/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00073: val_loss did not improve from 0.01369
# Epoch 74/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00074: val_loss did not improve from 0.01369
# Epoch 75/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00075: val_loss improved from 0.01369 to 0.01369, saving model to ../models/best_mlp_model.h5
# Epoch 76/100
# 1140/1140 [==============================] - 0s 80us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00076: val_loss did not improve from 0.01369
# Epoch 77/100
# 1140/1140 [==============================] - 0s 94us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00077: val_loss did not improve from 0.01369
# Epoch 78/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00078: val_loss did not improve from 0.01369
# Epoch 79/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00079: val_loss did not improve from 0.01369
# Epoch 80/100
# 1140/1140 [==============================] - 0s 69us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00080: val_loss did not improve from 0.01369
# Epoch 81/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00081: val_loss did not improve from 0.01369
# Epoch 82/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00082: val_loss did not improve from 0.01369
# Epoch 83/100
# 1140/1140 [==============================] - 0s 72us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00083: val_loss did not improve from 0.01369
# Epoch 84/100
# 1140/1140 [==============================] - 0s 71us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00084: val_loss did not improve from 0.01369
# Epoch 85/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00085: val_loss did not improve from 0.01369
# Epoch 86/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00086: val_loss did not improve from 0.01369
# Epoch 87/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00087: val_loss did not improve from 0.01369
# Epoch 88/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00088: val_loss did not improve from 0.01369
# Epoch 89/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00089: val_loss did not improve from 0.01369
# Epoch 90/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00090: val_loss did not improve from 0.01369
# Epoch 91/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00091: val_loss did not improve from 0.01369
# Epoch 92/100
# 1140/1140 [==============================] - 0s 66us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00092: val_loss did not improve from 0.01369
# Epoch 93/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00093: val_loss did not improve from 0.01369
# Epoch 94/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00094: val_loss did not improve from 0.01369
# Epoch 95/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00095: val_loss did not improve from 0.01369
# Epoch 96/100
# 1140/1140 [==============================] - 0s 70us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00096: val_loss did not improve from 0.01369
# Epoch 97/100
# 1140/1140 [==============================] - 0s 65us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00097: val_loss did not improve from 0.01369
# Epoch 98/100
# 1140/1140 [==============================] - 0s 68us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00098: val_loss did not improve from 0.01369
# Epoch 99/100
# 1140/1140 [==============================] - 0s 67us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00099: val_loss did not improve from 0.01369
# Epoch 100/100
# 1140/1140 [==============================] - 0s 68us/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
#
# Epoch 00100: val_loss did not improve from 0.01369
# Done..!

# %%
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
val_loss = history.history['val_loss']
val_loss_df = pd.DataFrame(val_loss)

print("Model Result (mean and std of error): %.2f (%.2f) MSE" % \
      (val_loss_df.mean(), val_loss_df.std()))
# Out:
# Model Result (mean and std of error): 0.02 (0.05) MSE

# %%
# load the saved model
try:
    saved_model.load_weights('../models/best_mlp_model.h5')
except Exception as error:
    print("Error trying to load checkpoint.")
    print(error)

#saved_model = load_model('../models/best_mlp_model.h5')
# evaluate the model
_, train_acc = saved_model.evaluate(x_train, y_train, verbose=0)
_, test_acc = saved_model.evaluate(x_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.014, Test: 0.014

# %%
#regressor.fit(x_train, y_train)
y_hat = saved_model.predict(x_train)
y_hat
# Out:
# array([[0.68281686],
#        [0.5064577 ],
#        [0.4535513 ],
#        ...,
#        [0.70452917],
#        [0.62264234],
#        [0.5624937 ]], dtype=float32)

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
#plt.xlim(-2,3)
#plt.ylim(-3,1)
plt.show()

# %%
y_train = y_train.values
sns.distplot(y_train - y_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %%
# evaluation mean_absolute_percentage_error
train_error =  y_train - y_hat
train_error

mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)

print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.00 (0.19) -0.63 0.57 MSE

# %% [markdown]
# ### Testing

# %%
y_hat_test = saved_model.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test, alpha=0.2)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
perf = pd.DataFrame(np.exp(y_hat_test), columns=['prediction'])
y_test = y_test.reset_index(drop=True)
perf['target'] = np.exp(y_test)
perf.head()
# Out:
#    prediction  target
# 0       2.022   1.767
# 1       1.972   1.778
# 2       1.630   1.682
# 3       2.057   2.266
# 4       2.183   1.819

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0         2.022   1.767     0.255       14.424
# 1         1.972   1.778     0.195       10.943
# 2         1.630   1.682    -0.052        3.068
# 3         2.057   2.266    -0.209        9.209
# 4         2.183   1.819     0.364       19.983
# ..          ...     ...       ...          ...
# 312       2.204   2.700    -0.496       18.370
# 313       1.950   2.134    -0.184        8.625
# 314       2.166   2.266    -0.100        4.396
# 315       1.886   2.238    -0.352       15.731
# 316       2.087   2.219    -0.132        5.945
#
# [317 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction  target  residual  difference%
# count     317.000 317.000   317.000      317.000
# mean        1.905   1.921    -0.016        9.093
# std         0.203   0.292     0.228        6.820
# min         1.536   1.457    -0.977        0.072
# 25%         1.705   1.704    -0.143        3.587
# 50%         1.952   1.940     0.014        7.775
# 75%         2.053   2.143     0.137       13.509
# max         2.509   2.700     0.430       37.452

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 218        1.96    1.96     -0.00         0.07
# 145        2.08    2.08      0.00         0.08
# 112        2.11    2.11      0.00         0.08
# 152        2.04    2.05     -0.00         0.21
# 96         2.05    2.05      0.01         0.28
# 88         2.15    2.14      0.01         0.33
# 146        2.23    2.22      0.01         0.34
# 220        1.64    1.65     -0.01         0.35
# 308        2.05    2.06     -0.01         0.39
# 113        2.08    2.07      0.01         0.44
# 87         2.00    1.99      0.01         0.44
# 202        2.00    1.99      0.01         0.47
# 74         2.02    2.01      0.01         0.59
# 144        2.21    2.20      0.01         0.63
# 45         1.56    1.57     -0.01         0.67
# 77         1.76    1.75      0.01         0.74
# 103        2.17    2.15      0.02         0.76
# 94         1.95    1.97     -0.02         0.87
# 262        2.05    2.07     -0.02         0.90
# 276        1.98    1.96      0.02         0.91
# 295        1.96    1.98     -0.02         1.00
# 249        2.06    2.04      0.02         1.00
# 171        2.06    2.04      0.02         1.09
# 307        1.96    1.98     -0.02         1.09
# 117        1.70    1.68      0.02         1.12
# 158        2.18    2.20     -0.02         1.13
# 138        2.01    2.04     -0.02         1.17
# 238        1.81    1.79      0.02         1.17
# 279        2.13    2.15     -0.03         1.21
# 132        1.96    1.94      0.02         1.22
# 235        1.70    1.68      0.02         1.29
# 242        2.12    2.14     -0.03         1.29
# 166        2.03    2.06     -0.03         1.30
# 287        2.20    2.23     -0.03         1.30
# 201        2.03    2.00      0.03         1.31
# 260        2.14    2.17     -0.03         1.41
# 182        2.10    2.13     -0.03         1.45
# 141        2.12    2.09      0.03         1.55
# 161        1.80    1.77      0.03         1.58
# 187        2.18    2.14      0.03         1.63
# 28         1.92    1.89      0.03         1.64
# 176        2.06    2.10     -0.04         1.76
# 47         2.08    2.05      0.04         1.76
# 143        2.09    2.06      0.04         1.77
# 233        2.19    2.23     -0.04         1.81
# 8          1.54    1.51      0.03         1.86
# 115        1.72    1.76     -0.03         1.88
# 253        1.94    1.90      0.04         1.92
# 116        2.11    2.07      0.04         1.98
# 150        2.15    2.19     -0.05         2.06
# 196        2.05    2.10     -0.04         2.12
# 73         1.94    1.90      0.04         2.16
# 289        2.14    2.19     -0.05         2.21
# 128        1.98    1.94      0.04         2.26
# 186        1.54    1.58     -0.04         2.30
# 162        1.94    1.99     -0.05         2.30
# 292        1.83    1.79      0.04         2.32
# 184        1.67    1.71     -0.04         2.33
# 270        1.98    2.03     -0.05         2.36
# 142        1.66    1.70     -0.04         2.50
# 118        1.87    1.92     -0.05         2.56
# 304        2.02    2.08     -0.05         2.58
# 212        2.02    1.97      0.05         2.59
# 190        2.20    2.26     -0.06         2.64
# 130        2.12    2.18     -0.06         2.70
# 278        2.14    2.09      0.06         2.81
# 241        1.95    1.90      0.05         2.86
# 291        2.18    2.25     -0.06         2.88
# 53         1.71    1.76     -0.05         2.88
# 40         1.69    1.75     -0.05         2.99
# 286        2.03    2.10     -0.06         2.99
# 2          1.63    1.68     -0.05         3.07
# 303        2.18    2.26     -0.07         3.21
# 154        2.31    2.24      0.07         3.22
# 192        1.86    1.80      0.06         3.33
# 252        1.64    1.69     -0.06         3.40
# 199        1.68    1.74     -0.06         3.44
# 170        1.82    1.89     -0.07         3.47
# 231        2.15    2.23     -0.08         3.51
# 109        2.14    2.07      0.07         3.59
# 126        2.06    1.99      0.07         3.62
# 239        1.99    1.92      0.07         3.63
# 105        2.04    1.97      0.07         3.77
# 248        1.73    1.80     -0.07         3.79
# 282        2.14    2.06      0.08         3.82
# 18         1.55    1.50      0.06         3.86
# 232        2.02    1.94      0.08         3.96
# 213        2.07    1.99      0.08         4.04
# 81         2.03    1.95      0.08         4.05
# 9          1.62    1.69     -0.07         4.08
# 299        1.57    1.51      0.06         4.20
# 33         2.07    2.16     -0.09         4.35
# 178        1.99    2.08     -0.09         4.38
# 314        2.17    2.27     -0.10         4.40
# 224        1.57    1.64     -0.07         4.42
# 85         1.96    2.06     -0.09         4.48
# 200        2.00    2.10     -0.09         4.49
# 264        2.13    2.04      0.09         4.50
# 137        2.11    2.02      0.09         4.58
# 298        1.58    1.51      0.07         4.62
# 204        2.04    2.14     -0.10         4.62
# 219        1.95    1.86      0.09         4.67
# 310        2.12    2.23     -0.10         4.71
# 151        1.57    1.50      0.07         4.82
# 38         1.84    1.76      0.08         4.82
# 244        1.58    1.51      0.07         4.93
# 189        1.92    2.02     -0.10         5.02
# 164        2.03    2.14     -0.11         5.06
# 274        1.78    1.88     -0.10         5.18
# 10         2.09    1.99      0.10         5.18
# 271        1.59    1.51      0.08         5.19
# 36         1.59    1.51      0.08         5.32
# 272        2.29    2.17      0.12         5.34
# 95         1.56    1.48      0.08         5.42
# 285        1.59    1.51      0.08         5.43
# 114        2.02    1.92      0.10         5.45
# 209        1.59    1.51      0.08         5.53
# 37         1.58    1.68     -0.10         5.79
# 31         2.00    2.12     -0.12         5.85
# 139        2.05    2.18     -0.13         5.88
# 32         2.07    2.20     -0.13         5.89
# 316        2.09    2.22     -0.13         5.95
# 296        1.86    1.98     -0.12         6.07
# 236        2.05    1.93      0.12         6.12
# 90         2.27    2.42     -0.15         6.21
# 67         1.62    1.73     -0.11         6.21
# 153        1.61    1.71     -0.11         6.22
# 127        1.90    2.03     -0.13         6.38
# 195        1.58    1.48      0.10         6.42
# 75         2.22    2.09      0.13         6.43
# 193        1.59    1.50      0.10         6.43
# 168        2.12    2.27     -0.15         6.50
# 62         1.97    2.11     -0.14         6.60
# 306        2.05    1.92      0.13         6.68
# 106        2.10    2.25     -0.15         6.68
# 78         1.61    1.51      0.10         6.71
# 101        2.04    2.19     -0.15         6.71
# 84         2.40    2.25      0.15         6.72
# 266        2.00    1.87      0.13         6.98
# 257        1.89    2.04     -0.14         7.03
# 206        1.80    1.94     -0.14         7.08
# 107        1.88    1.76      0.12         7.09
# 259        1.64    1.53      0.11         7.12
# 80         1.99    2.14     -0.15         7.17
# 191        2.14    2.00      0.14         7.17
# 237        1.84    1.98     -0.14         7.20
# 54         1.60    1.50      0.11         7.25
# 157        2.01    1.87      0.14         7.31
# 24         1.61    1.50      0.11         7.31
# 26         2.05    2.21     -0.16         7.34
# 52         1.62    1.51      0.11         7.44
# 301        1.98    2.14     -0.16         7.44
# 134        2.07    1.92      0.15         7.56
# 23         2.02    1.88      0.14         7.58
# 277        1.61    1.50      0.11         7.59
# 66         1.61    1.50      0.11         7.63
# 111        1.84    1.99     -0.15         7.66
# 125        1.61    1.50      0.12         7.75
# 110        1.99    2.16     -0.17         7.77
# 181        1.92    1.78      0.14         7.81
# 156        2.18    2.02      0.16         7.95
# 71         1.61    1.50      0.12         7.96
# 102        1.63    1.51      0.12         8.09
# 258        1.88    1.74      0.14         8.12
# 15         2.05    2.24     -0.19         8.27
# 34         1.61    1.48      0.12         8.33
# 60         1.70    1.86     -0.16         8.33
# 21         1.62    1.50      0.13         8.49
# 49         1.54    1.68     -0.14         8.51
# 19         1.60    1.47      0.13         8.53
# 222        1.97    1.82      0.16         8.56
# 185        2.03    2.22     -0.19         8.57
# 214        1.94    2.12     -0.18         8.59
# 133        2.11    2.31     -0.20         8.61
# 173        1.62    1.50      0.13         8.62
# 313        1.95    2.13     -0.18         8.62
# 172        1.64    1.51      0.13         8.63
# 155        1.62    1.50      0.13         8.63
# 72         2.42    2.23      0.19         8.64
# 163        2.01    1.85      0.16         8.65
# 97         2.01    2.20     -0.19         8.71
# 179        1.63    1.50      0.13         8.71
# 225        2.03    2.23     -0.19         8.73
# 27         1.64    1.51      0.13         8.84
# 188        1.96    1.80      0.16         8.96
# 227        2.00    2.20     -0.20         9.06
# 79         1.62    1.48      0.13         9.07
# 275        2.07    1.90      0.17         9.13
# 3          2.06    2.27     -0.21         9.21
# 311        1.61    1.47      0.14         9.22
# 149        1.95    2.15     -0.21         9.60
# 210        1.63    1.48      0.14         9.61
# 177        1.96    1.79      0.17         9.70
# 48         1.98    2.19     -0.21         9.71
# 56         1.94    1.77      0.17         9.81
# 14         1.64    1.50      0.15         9.87
# 86         1.64    1.50      0.15         9.91
# 35         1.66    1.51      0.15         9.98
# 246        1.77    1.97     -0.20        10.13
# 215        1.74    1.94     -0.20        10.18
# 129        1.76    1.97     -0.21        10.49
# 91         1.95    1.77      0.19        10.53
# 300        2.26    2.53     -0.27        10.57
# 165        1.93    2.16     -0.23        10.73
# 68         1.89    1.70      0.19        10.92
# 1          1.97    1.78      0.19        10.94
# 11         2.15    2.41     -0.27        10.98
# 174        2.01    1.81      0.20        11.10
# 83         1.67    1.88     -0.21        11.32
# 203        1.89    1.69      0.19        11.44
# 230        1.67    1.50      0.17        11.48
# 256        1.71    1.93     -0.22        11.52
# 76         1.63    1.46      0.17        11.60
# 122        2.51    2.25      0.26        11.66
# 305        1.73    1.96     -0.23        11.71
# 216        1.80    2.04     -0.24        11.79
# 136        1.98    1.77      0.21        11.92
# 124        1.95    2.21     -0.26        11.96
# 93         2.07    1.85      0.22        11.97
# 69         1.66    1.48      0.18        12.10
# 58         1.97    2.24     -0.27        12.10
# 39         1.97    2.25     -0.28        12.27
# 61         1.99    2.27     -0.28        12.29
# 89         1.70    1.51      0.19        12.39
# 12         2.00    1.78      0.22        12.51
# 7          1.67    1.48      0.19        12.67
# 250        2.22    2.54     -0.33        12.82
# 208        2.02    1.79      0.23        12.88
# 273        1.92    2.21     -0.29        12.99
# 140        1.97    2.27     -0.29        13.02
# 92         2.02    1.79      0.23        13.09
# 268        1.69    1.50      0.20        13.14
# 108        1.78    2.06     -0.27        13.24
# 254        2.00    1.77      0.23        13.27
# 290        1.91    2.21     -0.30        13.36
# 243        1.70    1.50      0.20        13.38
# 160        1.91    2.21     -0.30        13.39
# 197        1.70    1.50      0.20        13.51
# 283        1.90    1.67      0.23        13.54
# 6          1.71    1.51      0.21        13.68
# 167        1.69    1.48      0.20        13.69
# 180        1.90    2.20     -0.30        13.86
# 104        1.68    1.95     -0.27        13.87
# 255        1.75    2.03     -0.28        13.92
# 63         2.04    1.79      0.25        13.94
# 263        1.70    1.50      0.21        13.96
# 284        1.85    1.63      0.23        14.02
# 217        2.00    1.76      0.25        14.04
# 288        2.02    1.77      0.25        14.21
# 5          1.98    1.74      0.25        14.24
# 0          2.02    1.77      0.25        14.42
# 229        2.05    1.79      0.26        14.46
# 55         1.96    1.71      0.25        14.58
# 294        1.77    1.54      0.23        14.59
# 13         1.79    1.56      0.23        14.70
# 240        1.70    2.00     -0.29        14.72
# 51         1.96    1.70      0.25        14.84
# 17         1.65    1.94     -0.29        14.99
# 135        2.03    1.77      0.27        15.07
# 70         1.86    2.19     -0.33        15.09
# 245        1.56    1.84     -0.28        15.19
# 147        1.61    1.90     -0.29        15.22
# 100        1.80    2.12     -0.33        15.38
# 131        2.06    1.79      0.28        15.45
# 119        2.18    1.89      0.29        15.58
# 42         2.09    2.48     -0.39        15.60
# 315        1.89    2.24     -0.35        15.73
# 175        1.69    2.01     -0.32        15.79
# 59         2.03    2.41     -0.38        15.94
# 309        1.61    1.92     -0.31        16.01
# 50         1.58    1.88     -0.31        16.23
# 267        1.85    1.59      0.26        16.27
# 20         1.94    1.67      0.27        16.29
# 265        2.20    2.64     -0.43        16.46
# 57         1.81    1.56      0.26        16.47
# 251        1.82    2.18     -0.36        16.73
# 234        1.73    2.08     -0.35        16.84
# 226        1.79    2.15     -0.37        17.04
# 148        1.79    2.16     -0.37        17.19
# 281        2.10    1.79      0.31        17.27
# 159        1.65    2.00     -0.35        17.38
# 99         2.07    1.76      0.31        17.62
# 198        2.09    2.54     -0.45        17.71
# 65         2.10    1.78      0.32        18.08
# 22         1.68    2.06     -0.37        18.12
# 312        2.20    2.70     -0.50        18.37
# 120        2.12    1.79      0.33        18.37
# 43         2.06    1.74      0.32        18.53
# 247        2.11    1.78      0.33        18.64
# 44         1.86    2.29     -0.43        18.87
# 211        1.76    2.17     -0.41        19.04
# 121        1.78    1.50      0.29        19.28
# 169        2.11    1.77      0.34        19.49
# 221        1.79    1.50      0.30        19.96
# 261        2.13    1.78      0.36        19.97
# 4          2.18    1.82      0.36        19.98
# 280        2.13    1.78      0.36        20.08
# 82         1.99    1.66      0.33        20.09
# 205        1.56    1.98     -0.42        21.05
# 25         2.11    2.67     -0.56        21.07
# 194        1.86    1.52      0.34        22.33
# 293        1.84    1.50      0.35        23.07
# 30         2.04    2.65     -0.61        23.07
# 183        1.64    2.15     -0.51        23.70
# 29         1.87    1.51      0.36        23.94
# 228        2.03    2.67     -0.64        24.06
# 123        1.92    2.54     -0.62        24.35
# 16         1.88    1.51      0.37        24.38
# 297        1.89    2.51     -0.61        24.53
# 98         1.91    1.53      0.38        24.68
# 64         1.82    2.44     -0.63        25.66
# 302        1.69    2.29     -0.60        26.30
# 207        1.90    1.50      0.41        27.14
# 41         1.94    1.51      0.43        28.53
# 269        1.74    2.53     -0.79        31.21
# 223        1.71    2.52     -0.80        31.88
# 46         1.63    2.61     -0.98        37.45

# %% [markdown]
# # Prediction Accuracy

# %%
# validation mean_absolute_percentage_error (MAPE)
test_error = np.absolute(perf['residual'] / perf['target'])
mean_error = np.mean(test_error)
min_error = np.min(test_error)
max_error = np.max(test_error)
std_error = np.std(test_error)

print("Mean Absolute Percentate Error std of error (MAPE): [mean: %.2f std: %.2f max: %.2f min: %.2f]" \
      % (mean_error, std_error, max_error, min_error))
# Out:
# Mean Absolute Percentate Error std of error (MAPE): [mean: 0.09 std: 0.07 max: 0.37 min: 0.00]

# %%
# validation mean_squared_error  (MSE)
test_error =  np.power(perf['residual'] , 2)
mean_error = np.mean(test_error)
min_error = np.min(test_error)
max_error = np.max(test_error)
std_error = np.std(test_error)

print("Mean Squared Error (MSE): [mean: %.2f std: %.2f max: %.2f min: %.2f]" \
      % (mean_error, std_error, max_error, min_error))
# Out:
# Mean Squared Error (MSE): [mean: 0.05 std: 0.10 max: 0.95 min: 0.00]

# %% [markdown]
# R2 is a statistic that will give some information about the goodness of fit of a model. In regression, the R2 coefficient of determination is a statistical measure of how well the regression predictions approximate the real data points. An R2 of 1 indicates that the regression predictions perfectly fit the data.

# %%
# R-Squared 
# = 1 -  ( sum of squared residual  / sum of squared variance )
# sum of variance squared = sum (( y - y-mean ) ** 2)
# sum of residual squared = sum (( y-hat - y-mean ) ** 2)
# where y is the observed target, y-mean is the mean of observed target, y-hat is a predicted value

y_mean = np.mean(targets)
sum_squared_residual = np.sum(np.power(perf['residual'] , 2))
sum_squared_variance = np.sum(np.power(targets - y_mean , 2))

R_squared = 1 - ( sum_squared_residual / sum_squared_variance )

R_squared
# Out:
# 0.7121296070807219
