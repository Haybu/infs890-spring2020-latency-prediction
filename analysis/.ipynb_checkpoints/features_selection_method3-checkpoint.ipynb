# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn import preprocessing
from datetime import datetime
from scipy import stats
from sklearn.decomposition import PCA

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.3f}'.format

# %%
# 1- read processed file
file_dir = '../data/processed-data/'
data_file = 'normalized_dataset.csv'

normalized_data = pd.read_csv(file_dir + data_file)
normalized_data.shape
# Out:
# (1584, 12)

# %%
targets = normalized_data['ltcy']
inputs = normalized_data.drop(['ltcy'], axis=1)


# Standardize the features (mean 0 and std 1)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
standarized_inputs = scaler.fit_transform(inputs)

standarized_inputs = pd.DataFrame(standarized_inputs, columns=inputs.columns)

# %%
standarized_inputs.describe()
# Out:
#            ltcy  svc_cpu_use  svc_cpu_thr  svc_net_use  svc_disk_use  \
# count 1,584.000    1,584.000    1,584.000    1,584.000     1,584.000
# mean      0.777        1.256        0.623        0.828         0.225
# std       0.191        0.292        0.255        0.232         0.083
# min       0.332        0.332        0.000        0.190         0.000
# 25%       0.648        1.068        0.436        0.659         0.165
# 50%       0.794        1.288        0.632        0.841         0.224
# 75%       0.927        1.473        0.794        1.017         0.283
# max       1.217        1.822        1.245        1.290         0.440
#
#        system_cpu_use  system_cpu_sat  system_net_use  svc_req_size  \
# count       1,584.000       1,584.000       1,584.000     1,584.000
# mean        4,759.075          17.579          14.493         0.023
# std         3,018.836          11.862           5.392         0.012
# min            14.165           0.699           2.864         0.000
# 25%         2,060.612           6.428          10.329         0.014
# 50%         4,814.819          17.424          15.167         0.023
# 75%         7,545.077          26.365          18.156         0.031
# max         9,683.820          51.619          24.698         0.055
#
#        svc_resp_size  svc_pods  svc_req_rate
# count      1,584.000 1,584.000     1,584.000
# mean           0.158    13.646        19.221
# std            0.113     4.475         9.134
# min            0.001     2.000         0.200
# 25%            0.038    10.000        11.775
# 50%            0.163    14.000        20.470
# 75%            0.254    18.000        25.980
# max            0.382    21.000        35.110

# %% [markdown]
# # Multicollinearity

# %% [markdown]
# Use Variance Inflation Factor (VIF) from the statmodels. VIF measures how big is the square root of the standard error is compared to the case there is no multicollinearity between the variables.
# Conventionally:
#
# $VIF = 1$ means no multicollinearity
#
# $1< VIF < 5$ perfectly okay
#
# $10 < VIF$ unacceptable range (some times < 6 or 8)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = standarized_inputs[['svc_cpu_use'
            ,'svc_cpu_thr'
            ,'svc_net_use'
            ,'svc_disk_use'
            ,'system_cpu_use'
            ,'system_cpu_sat'
            ,'system_net_use'
            ,'svc_req_size'
            ,'svc_resp_size'
            ,'svc_pods']]
vif = pd.DataFrame()
vif['features'] = variables.columns
vif['VIF'] = [variance_inflation_factor(variables.values,i) for i in range(variables.shape[1])]
vif
# Out:
#          features    VIF
# 0     svc_cpu_use 32.969
# 1     svc_cpu_thr 10.759
# 2     svc_net_use 29.844
# 3    svc_disk_use 14.469
# 4  system_cpu_use 11.120
# 5  system_cpu_sat  7.730
# 6  system_net_use 72.605
# 7    svc_req_size 16.373
# 8   svc_resp_size  4.755
# 9        svc_pods 10.987

# %% [markdown]
# vif values are high. Consider using PCA or apply feature selection method to reduce dimentionality when using a ML model.
#
# # Correlation Matrix

# %%
corr = standarized_inputs.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# <style  type="text/css" >
#     #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col1 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col2 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col3 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col4 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col5 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col6 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col7 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col8 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col9 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col10 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row0_col11 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col0 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col2 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col3 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col4 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col5 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col6 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col7 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col8 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col9 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col10 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row1_col11 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col0 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col1 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col3 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col4 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col7 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col8 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col9 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row2_col11 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col0 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col2 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col4 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col5 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col6 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col7 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col8 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col9 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col10 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row3_col11 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col0 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col1 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col2 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col3 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col5 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col6 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col7 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col8 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col9 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col10 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_71af2a48_5751_11ea_a0d9_dca9048b6fd0row4_col11 {
#             background-color:  #dedcdb;
#             color:  #0

# %%
def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);
    
#plot_corr(standarized_inputs,20)

# %% [markdown]
# The function most_highly_correlated() will print out the linear correlation coefficients for each pair of variables in your data set, in order of the correlation coefficient. This lets you see very easily which pair of variables are most highly correlated.

# %%
def most_highly_correlated(mydataframe, numtoreport):
    # find the correlations
    cormatrix = mydataframe.corr()
    # set the correlations on the diagonal or lower triangle to zero,
    # so they will not be reported as the highest ones:
    cormatrix *= np.tri(*cormatrix.values.shape, k=-1).T
    # find the top n correlations
    cormatrix = cormatrix.stack()
    cormatrix = cormatrix.reindex(cormatrix.abs().sort_values(ascending=False).index).reset_index()
    # assign human-friendly names
    cormatrix.columns = ["FirstVariable", "SecondVariable", "Correlation"]
    return cormatrix.head(numtoreport)

mcdf = most_highly_correlated(standarized_inputs, 30)
mcdf = mcdf[mcdf.Correlation > 0.5]

mcdf
# Out:
#      FirstVariable  SecondVariable  Correlation
# 0   system_net_use    svc_req_rate        0.985
# 1     svc_req_size    svc_req_rate        0.855
# 2   system_net_use    svc_req_size        0.848
# 3      svc_net_use  system_net_use        0.752
# 4      svc_net_use    svc_req_rate        0.749
# ..             ...             ...          ...
# 25    svc_req_size   svc_resp_size        0.540
# 26            ltcy  system_net_use        0.532
# 27     svc_net_use    svc_disk_use        0.527
# 28     svc_cpu_thr    svc_req_rate        0.510
# 29     svc_net_use  system_cpu_use        0.506
#
# [30 rows x 3 columns]

# %% [markdown]
# # Features Selection

# %% [markdown]
# ## SelectFromModel Meta-Transformer Method
# sklearn doc: https://scikit-learn.org/stable/modules/feature_selection.html
#
# example with regression case: https://scikit-learn.org/stable/auto_examples/feature_selection/plot_select_from_model_boston.html

# %%
# using SelectFromModel metatransformer to select features
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV

clf = LassoCV(normalize=False, random_state=365, cv=10, verbose=0) # normalize=False because data already scaled 

sfm = SelectFromModel(clf, threshold=-np.inf, max_features=3)  
#sfm = SelectFromModel(clf, threshold=0.001)  
sfm.fit(standarized_inputs, targets)

transformed_inputs = sfm.transform(standarized_inputs)

print('shape of transformed inputs %', transformed_inputs.shape)

transformed_inputs
# Out:
# shape of inputs % (1584, 11)
# shape of standardized inputs % (1584, 11)
# shape of transformed inputs % (1584, 3)
# array([[-1.14575563, -1.48543676, -1.99771431],
#        [-1.27010889, -1.48543676, -1.92762278],
#        [-1.20637492, -1.48543676, -1.8662927 ],
#        ...,
#        [-0.52429145, -0.36786678,  1.60871363],
#        [ 1.88967803,  0.3026752 ,  1.54300283],
#        [ 1.97767941,  0.3026752 ,  1.60871363]])

# %%
# features selected

indices = sfm.get_support(indices=True)
all_features = inputs.columns

selected_features = []
for i in indices:
    selected_features.append(all_features[i])
    
selected_features
# Out:
# ['svc_cpu_thr', 'svc_pods', 'svc_req_rate']
