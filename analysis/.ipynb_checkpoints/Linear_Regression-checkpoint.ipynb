# %% [markdown]
# # Linear Regression
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import seaborn as sns
from sklearn import preprocessing, metrics, feature_selection
from datetime import datetime
from scipy import stats
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.3f}'.format

# %% [markdown]
# Set this flag to True if you're using reduction feature using FCA, otherwise set it to False

# %%
# 1- read data file
# 1- read processed file
file_dir = '../data/processed-data/'


#data_file = 'factored_dataset.csv'
data_file = 'normalized_dataset.csv'
#data_file = 'standardized_normalized_dataset.csv'

data = pd.read_csv(file_dir + data_file)

# %%
data.head(5)
# Out:
#    ltcy  svc_cpu_use  svc_cpu_thr  svc_net_use  svc_disk_use  system_cpu_use  \
# 0 0.332        0.557        0.332        0.325         0.037          16.982
# 1 0.400        0.616        0.300        0.351         0.047          20.583
# 2 0.469        0.608        0.316        0.362         0.039          19.448
# 3 0.490        0.624        0.300        0.362         0.108          17.319
# 4 0.500        0.608        0.316        0.374         0.133          16.650
#
#    system_cpu_sat  system_net_use  svc_req_size  svc_resp_size  svc_pods  \
# 0           1.591           3.206         0.002          0.012     7.000
# 1           1.608           3.552         0.003          0.019     7.000
# 2           1.390           3.586         0.003          0.024     7.000
# 3           1.730           3.512         0.003          0.022     6.000
# 4           1.917           3.449         0.003          0.023     3.000
#
#    svc_req_rate
# 0         0.980
# 1         1.620
# 2         2.180
# 3         2.130
# 4         2.220

# %%
data.shape
# Out:
# (1584, 12)

# %%
targets = data['ltcy']
inputs = data.drop(['ltcy'], axis=1)

n_features = inputs.values.shape[1]

#inputs_scaled = scaler.fit_transform(inputs)
#x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=0.1, shuffle=False, random_state=365)

# for better convergence and result scale target to values between 0 - 1
y_train_max = y_train.max()
y_test_max = y_test.max()

y_train = y_train / y_train_max
y_test = y_test / y_test_max

print("there are {} features".format(n_features))
# Out:
# there are 11 features

# %% [markdown]
# # Regression with Feature Selection

# %%
# -- trying
#selector = feature_selection.SelectKBest(feature_selection.f_regression).fit(x_train, y_train)
#selectedFeatures = selector.transform(x_train)
#print('{} features selected'.format(selectedFeatures[1].shape[0]))

# %%
#clf = LassoCV()
#sfm = SelectFromModel(clf) #(clf, threshold=0.01)
#selectedFeatures = sfm.fit(x_train, y_train).transform(x_train)
#print('{} features selected'.format(selectedFeatures[1].shape[0]))

# %%
clf = RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15)
sfm = SelectFromModel(clf,threshold='0.8*mean')

# %%
# start:  search grid

reg = LinearRegression(normalize=False) # normalize false bacause we are going to use the scaler

# standardize the features
scaler = StandardScaler()
#scaler.fit(x_train.values.reshape(-1,n_features))

pipe = Pipeline(steps=[
    ('scaler', scaler),
    ('selector', sfm), 
    ('clf', reg)
])

kfold = KFold(n_splits=10, shuffle=False)

param_grid = {
    'selector__threshold': [.1, .05, .02, .01, .005, 0.001]
}

search = GridSearchCV(pipe, param_grid,scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=0, n_jobs=-1)

search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('selector',
#                                         SelectFromModel(estimator=RandomForestRegressor(bootstrap=True,
#                                                                                         ccp_alpha=0.0,
#                                                                                         criterion='mse',
#                                                                                         max_depth=10,
#                                                                                         max_features='auto',
#                                                                                         max_leaf_nodes=None,
#                                                                                         max_s...
#                                                         max_features=None,
#                                                         norm_order=1,
#                                                         prefit=False,
#                                                         threshold='0.8*mean')),
#                                        ('clf',
#                                         LinearRegression(copy_X=True,
#                                                          fit_intercept=True,
#                                                          n_jobs=None,
#                                                          normalize=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'selector__threshold': [0.1, 0.05, 0.02, 0.01, 0.005,
#                                                  0.001]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
estimator = search.best_estimator_
params = search.best_params_
score = search.best_score_

print("Best CV score = %0.3f:" % score)
print("Best CV params = {}".format(params))

print("")
all_training_scores = search.cv_results_
#print("\ncross_validation:\n", all_training_scores , "\n")
print(all_training_scores['mean_train_score'])
# Out:
# Best CV score = -0.018:
# Best CV params = {'selector__threshold': 0.1}
#
# [-0.01669852 -0.01633479 -0.01596509 -0.01594819 -0.01594819 -0.01594819]

# %% [markdown]
# # Training R2

# %%
y_hat = search.predict(x_train)

r2_train = metrics.r2_score(y_train, y_hat)
print('R2 (training) = {}'.format(r2_train))

#print("score ", search.score(x_test, y_test))
# or also R-Squared could be obtain via
#pline.score(x_train, y_train)
# Out:
# R2 (training) = 0.2959540207750059

# %%
print('R2 (training) = {}'.format(search.score(x_train,y_train)))
# Out:
# R2 (training) = -0.016763889103474223

# %%
pline.named_steps.regression.intercept_
# Out:
# 0.6261804592123861

# %%
pline.named_steps.regression.coef_
# Out:
# array([ 0.02370634, -0.01899422,  0.07377199])

# %%
# validation mean_absolute_percentage_error
train_error =  np.abs(y_train - y_hat)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)


print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.11 (0.07) 0.00 0.50 MSE

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
#plt.xlim(-2,3)
#plt.ylim(-3,1)
plt.show()

# %%
sns.distplot(y_train - y_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %% [markdown]
# # Testing

# %%
y_hat_test = search.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
perf = pd.DataFrame(np.exp(y_hat_test), columns=['prediction'])
y_test = y_test.reset_index(drop=True)
perf['target'] = np.exp(y_test)
perf.head()
# Out:
#    prediction  target
# 0       2.056   1.788
# 1       2.231   2.256
# 2       2.040   2.018
# 3       2.199   2.018
# 4       2.217   2.219

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0         2.056   1.788     0.267       14.959
# 1         2.231   2.256    -0.026        1.143
# 2         2.040   2.018     0.022        1.088
# 3         2.199   2.018     0.180        8.928
# 4         2.217   2.219    -0.002        0.082
# ..          ...     ...       ...          ...
# 154       2.227   1.999     0.228       11.404
# 155       2.186   2.181     0.005        0.227
# 156       2.071   2.181    -0.110        5.045
# 157       2.238   2.134     0.104        4.867
# 158       2.254   2.228     0.026        1.159
#
# [159 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction  target  residual  difference%
# count     159.000 159.000   159.000      159.000
# mean        2.109   2.130    -0.021        7.784
# std         0.157   0.272     0.223        6.952
# min         1.596   1.483    -0.748        0.058
# 25%         2.035   2.004    -0.121        1.927
# 50%         2.175   2.200     0.006        5.724
# 75%         2.226   2.247     0.102       11.568
# max         2.298   2.718     0.436       29.121

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 46         2.22    2.22      0.00         0.06
# 71         2.25    2.25      0.00         0.08
# 4          2.22    2.22     -0.00         0.08
# 91         2.27    2.27      0.00         0.16
# 32         2.21    2.22     -0.00         0.18
# 155        2.19    2.18      0.00         0.23
# 24         2.22    2.22      0.01         0.23
# 37         2.26    2.26      0.01         0.24
# 58         2.21    2.20      0.01         0.25
# 74         2.26    2.26      0.01         0.34
# 88         2.21    2.20      0.01         0.36
# 79         2.25    2.26     -0.01         0.38
# 38         2.26    2.27     -0.01         0.45
# 68         2.28    2.27      0.01         0.48
# 34         2.20    2.21     -0.01         0.56
# 57         2.21    2.23     -0.01         0.65
# 13         2.18    2.19     -0.01         0.66
# 67         2.28    2.27      0.02         0.78
# 94         2.26    2.24      0.02         0.81
# 138        2.04    2.02      0.02         0.83
# 22         2.22    2.20      0.02         0.91
# 86         2.24    2.27     -0.02         1.01
# 2          2.04    2.02      0.02         1.09
# 72         2.27    2.25      0.02         1.09
# 1          2.23    2.26     -0.03         1.14
# 25         2.24    2.22      0.03         1.15
# 39         2.23    2.20      0.03         1.16
# 158        2.25    2.23      0.03         1.16
# 64         2.25    2.23      0.03         1.20
# 148        2.21    2.24     -0.03         1.20
# 62         2.22    2.25     -0.03         1.23
# 73         2.24    2.27     -0.03         1.23
# 43         2.21    2.24     -0.03         1.29
# 152        2.07    2.11     -0.03         1.47
# 42         2.26    2.23      0.03         1.54
# 7          2.19    2.23     -0.04         1.69
# 20         2.26    2.22      0.04         1.75
# 35         2.26    2.22      0.04         1.87
# 54         2.23    2.28     -0.04         1.90
# 23         2.24    2.20      0.04         1.92
# 48         2.19    2.15      0.04         1.94
# 27         2.23    2.18      0.04         2.04
# 18         2.22    2.27     -0.05         2.14
# 139        2.03    2.08     -0.04         2.14
# 114        1.83    1.79      0.04         2.14
# 21         2.22    2.17      0.05         2.18
# 87         2.30    2.25      0.05         2.27
# 63         2.28    2.23      0.05         2.39
# 52         2.22    2.17      0.05         2.41
# 28         2.24    2.19      0.05         2.43
# 76         2.26    2.20      0.06         2.64
# 29         2.24    2.18      0.06         2.82
# 55         2.21    2.28     -0.06         2.83
# 128        2.10    2.04      0.07         3.22
# 47         2.26    2.19      0.07         3.28
# 49         2.22    2.15      0.07         3.29
# 31         2.24    2.17      0.07         3.30
# 61         2.22    2.15      0.07         3.33
# 102        1.77    1.71      0.06         3.39
# 153        2.08    2.16     -0.08         3.58
# 53         2.22    2.14      0.08         3.72
# 78         2.19    2.28     -0.08         3.72
# 19         2.18    2.27     -0.09         3.82
# 30         2.26    2.17      0.08         3.85
# 36         2.17    2.27     -0.09         4.17
# 26         2.24    2.15      0.09         4.26
# 15         2.21    2.11      0.10         4.59
# 41         2.07    2.17     -0.10         4.72
# 135        2.15    2.06      0.10         4.74
# 101        1.76    1.85     -0.09         4.78
# 157        2.24    2.13      0.10         4.87
# 130        2.13    2.24     -0.11         4.92
# 134        2.12    2.23     -0.11         4.98
# 156        2.07    2.18     -0.11         5.04
# 100        1.76    1.85     -0.09         5.06
# 14         2.24    2.13      0.11         5.17
# 51         2.08    2.20     -0.12         5.25
# 8          2.05    2.17     -0.12         5.39
# 120        2.04    2.15     -0.12         5.45
# 50         2.06    2.18     -0.12         5.72
# 40         2.07    2.20     -0.13         5.86
# 103        1.76    1.87     -0.11         5.88
# 33         2.06    2.19     -0.13         6.00
# 95         1.60    1.50      0.10         6.67
# 146        2.05    1.92      0.13         6.70
# 109        1.90    1.77      0.13         7.28
# 12         2.23    2.08      0.15         7.42
# 66         2.07    2.25     -0.17         7.67
# 116        2.01    2.18     -0.17         7.97
# 65         2.07    2.25     -0.18         8.02
# 136        2.15    1.99      0.16         8.24
# 143        2.21    2.04      0.17         8.24
# 83         2.28    2.49     -0.21         8.27
# 142        2.21    2.04      0.17         8.33
# 124        2.08    2.27     -0.19         8.36
# 77         2.17    2.38     -0.20         8.54
# 115        2.00    2.19     -0.19         8.62
# 5          2.22    2.43     -0.22         8.85
# 17         2.06    2.27     -0.20         8.88
# 3          2.20    2.02      0.18         8.93
# 98         1.65    1.51      0.14         9.12
# 108        1.93    1.77      0.16         9.25
# 149        2.07    1.89      0.18         9.32
# 90         2.01    2.22     -0.21         9.39
# 59         1.99    2.20     -0.21         9.64
# 56         1.99    2.21     -0.21         9.73
# 75         2.00    2.23     -0.23        10.15
# 110        1.93    1.75      0.18        10.35
# 133        2.00    2.23     -0.23        10.35
# 89         1.98    2.21     -0.23        10.47
# 117        2.06    1.86      0.20        10.49
# 104        1.68    1.88     -0.20        10.59
# 118        2.04    1.84      0.20        10.62
# 93         2.22    2.49     -0.27        10.89
# 16         2.05    2.30     -0.26        11.09
# 122        1.94    2.19     -0.25        11.33
# 154        2.23    2.00      0.23        11.40
# 60         1.97    2.23     -0.25        11.42
# 11         2.24    2.01      0.23        11.42
# 45         2.24    2.53     -0.30        11.72
# 80         2.04    2.31     -0.27        11.81
# 10         1.99    1.78      0.21        11.82
# 123        2.08    2.37     -0.28        11.97
# 145        2.20    1.96      0.24        12.45
# 119        2.03    1.80      0.23        12.59
# 144        2.22    1.97      0.25        12.69
# 105        1.70    1.51      0.19        12.70
# 125        1.96    1.74      0.22        12.88
# 9          2.20    1.95      0.25        13.05
# 96         1.68    1.48      0.19        13.06
# 121        1.91    2.20     -0.29        13.34
# 70         2.26    2.64     -0.38        14.44
# 0          2.06    1.79      0.27        14.96
# 141        2.17    1.89      0.28        15.05
# 151        2.05    1.78      0.27        15.34
# 150        2.04    1.77      0.27        15.53
# 147        2.22    1.92      0.30        15.55
# 82         2.10    2.49     -0.39        15.61
# 97         1.73    1.50      0.23        15.67
# 126        1.97    1.69      0.27        16.10
# 137        2.16    1.85      0.31        16.54
# 44         2.23    2.67     -0.44        16.60
# 92         2.24    2.70     -0.46        16.90
# 140        2.21    1.88      0.33        17.31
# 6          2.15    2.61     -0.46        17.55
# 69         2.22    2.72     -0.50        18.46
# 106        1.79    1.51      0.28        18.55
# 131        2.13    2.69     -0.57        21.02
# 84         2.11    2.71     -0.60        22.23
# 81         2.07    2.67     -0.60        22.35
# 99         1.72    2.24     -0.51        23.01
# 85         2.09    2.71     -0.62        23.03
# 127        2.10    1.70      0.40        23.50
# 112        1.85    1.50      0.35        23.67
# 107        1.86    1.50      0.36        24.23
# 129        1.98    2.64     -0.66        24.97
# 132        1.94    2.69     -0.75        27.81
# 111        1.93    1.51      0.42        27.96
# 113        1.93    1.50      0.44        29.12

# %% [markdown]
# # Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_hat_test)
print('R2 (testing) = {}'.format(r2_test))

# also: R-Squared could obtain with
# pline.score(x_test, y_test)
# Out:
# R2 (testing) = 0.37633204810112664

# %% [markdown]
# # Trying with Polynomial features

# %%
if False:
    from sklearn.preprocessing import PolynomialFeatures

    # covert input data to polynomial form of some degree
    inputs_poly = PolynomialFeatures(degree=2).fit_transform(inputs).astype(float)

    x_train, x_test, y_train, y_test = \
        train_test_split(inputs_poly, targets, test_size=0.1, shuffle=False, random_state=365)

    # for better convergence and result scale target to values between 0 - 1
    y_train_max = y_train.max()
    y_test_max = y_test.max()

    y_train = y_train / y_train_max
    y_test = y_test / y_test_max


    reg = LinearRegression(normalize=False) # normalize false bacause we are going to use the scaler

    scaler = StandardScaler()

    pipe = Pipeline(steps=[
        ('scaler', scaler),
        ('selector', sfm), 
        ('clf', reg)
    ])

    kfold = KFold(n_splits=10, shuffle=False)

    param_grid = {
        'selector__threshold': [.1, .05, .02, .01, .005, 0.001]
    }

    search = GridSearchCV(pipe, param_grid,scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=0, n_jobs=-1)

    search.fit(x_train, y_train)

    y_hat_test = search.predict(x_test)

    r2_test = metrics.r2_score(y_test, y_hat_test)
    print('R2 (testing) = {}'.format(r2_test))

# %% [markdown]
# # What features to select

# %%
x_train.shape
# Out:
# (1425, 11)

# %%
#clf = LassoCV()
#sfm = SelectFromModel(clf, threshold=0.001)

sfm = SelectFromModel(
                RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15),
                threshold='0.8*mean')

selectedFeatures = sfm.fit(inputs, targets).transform(inputs)
print('{} features selected'.format(selectedFeatures[1].shape[0]))

feature_list = x_train.columns[sfm.get_support()]
features = ''
features = ', '.join(feature_list)
#features

reduced_x_train = x_train[feature_list]
reduced_x_train.head(2)
# Out:
# 4 features selected
#    svc_cpu_thr  system_cpu_use  system_cpu_sat  svc_req_rate
# 0         0.33           16.98            1.59          0.98
# 1         0.30           20.58            1.61          1.62

# %% [markdown]
# # Robust Linear Model

# %%
# RANSAC is an iterative algorithm for the robust estimation of parameters from a subset 
# of inliers from the complete data set.
# you can use this with all dataset including outliers
if False:    
    from sklearn.linear_model import RANSACRegressor

    ransac = RANSACRegressor(estimator)
    ransac.fit(x_train, y_train)
    inlier_mask = ransac.inlier_mask_
    outlier_mask = np.logical_not(inlier_mask)

    y_hat_test = ransac.predict(x_test)

    r2_test = metrics.r2_score(y_test, y_hat_test)
    print('R2 (testing) = {}'.format(r2_test))
# Out:
# R2 (testing) = 0.26399875560838515
