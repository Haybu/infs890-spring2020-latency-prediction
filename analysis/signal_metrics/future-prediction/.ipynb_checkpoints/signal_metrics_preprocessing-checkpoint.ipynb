# %% [markdown]
# # 2- Time-series Signal Metrics
#
# This file to be executed second
#
# Haytham Mohamed - INFS890 - Spring 2020
#
# Using metrics as time-series data to predict future latency. The data collected from prometheus metrics output directly. Treated as raw observations signals from the application without apply transformation rules processing.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(color_codes=True)

pd.set_option("display.precision", 2)
pd.options.display.float_format = '{:.2f}'.format

# %%
input_dir = '../../../data/raw-data-linode-run3/merged/'     # this is prepared raw metrics signals
input_file = 'all_data.csv'

output_dir = input_dir                 # output dir for raw signal metrics data
output_file = 'raw_timeseries_data.csv'

target = 'service_ltcy_200'

features = ['service_cpu_use'
            , 'service_memory_use'
            , 'service_cpu_sat'
            , 'service_net_usage'
            , 'service_disk_usage'
            , 'service_req_total'
            , 'service_errors'
            , 'service_request_size'
            , 'service_response_size'
            , 'containers_count'
            , 'system_cpu_usage'
           ]


time_window='S'

# %%
data_df = pd.read_csv(input_dir + input_file, header=None, skiprows=1, names=['date', 'value', 'metric'])
data_df.head(5)
# Out:
#                   date    value           metric
# 0  2020-02-27 22:49:53  4601.79  service_cpu_use
# 1  2020-02-27 22:49:54  9273.33  service_cpu_use
# 2  2020-02-27 22:49:55  9273.33  service_cpu_use
# 3  2020-02-27 22:49:56 11312.63  service_cpu_use
# 4  2020-02-27 22:49:57 11761.99  service_cpu_use

# %%
def extractMetricSeries(df, name):
    metric = df.loc[df['metric'] == name].drop(['metric'], axis=1).rename(index=str, columns={"value": name})
    metric.date = pd.to_datetime(metric.date)
    metric[name] = pd.to_numeric(metric[name])
    metric.set_index('date', inplace=True)
    metric.sort_index()
    return metric

# T for minutes, S for seconds
def resample(df, frequency = time_window, interpolate = True, interpolate_method = 'linear', base=6):
    # fill in missing interval (upsample)
    resampled = df.resample(frequency, kind='timestamp', base=base).bfill()
    if interpolate:
        resampled = resampled.interpolate(method=interpolate_method)
    return resampled

def plot_series(df):
    df.plot(figsize=(20,10), linewidth=2, fontsize=20)
    plt.xlabel('Time', fontsize=20);
    plt.show()
    
def diff_series(df):
    # eliminate seasonality, taking first diff
    return df.diff()[1:]       

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('15 second')).bfill()    
    
def clear_null(df):
    return df[df[target].notna()]  

def eliminate_zeros(df, col):
    return df[df[col] > 0.00]

# %%
print("Processing metric: %", target)
metrics_df = extractMetricSeries(data_df, target)
metrics_df = resample(metrics_df, interpolate=False)   
metrics_df.head(3)
# Out:
# Processing metric: % service_ltcy_200
#                      service_ltcy_200
# date
# 2020-02-27 22:50:53             -0.01
# 2020-02-27 22:50:54             -0.09
# 2020-02-27 22:50:55             -0.09

# %%
# check number of nulls
null = metrics_df.isnull().sum()
null
# Out:
# service_ltcy_200    0
# dtype: int64

# %%
# check zero values
null = metrics_df[metrics_df[target] == 0].sum()
null
# Out:
# service_ltcy_200   0.00
# dtype: float64

# %%
plot_series(metrics_df)

# %%
rows = len(features)
i = 1

plt.figure(figsize=(20, 40), dpi=80, facecolor='w', edgecolor='k')

for feature in features:
    print("Processing metric: %", feature)
    feature_series = extractMetricSeries(data_df, feature)
    feature_series = resample(feature_series)    
    feature_series = diff_series(feature_series)    
    metrics_df = merge(metrics_df, feature_series)
    plt.subplot(rows, 1, i)
    plt.plot(feature_series)
    plt.title(feature, y=0.5, loc='right', fontsize=20)
    plt.xlabel('Time', fontsize=20)
    i += 1
    
plt.show()
# Out:
# Processing metric: % service_cpu_use
# Processing metric: % service_memory_use
# Processing metric: % service_cpu_sat
# Processing metric: % service_net_usage
# Processing metric: % service_disk_usage
# Processing metric: % service_req_total
# Processing metric: % service_errors
# Processing metric: % service_request_size
# Processing metric: % service_response_size
# Processing metric: % containers_count
# Processing metric: % system_cpu_usage

# %%
# drop system_net_sat and system_disk_sat and system_disk_io
#metrics_df = metrics_df.drop('system_net_sat', 1)
#metrics_df = metrics_df.drop('system_disk_sat', 1)
#metrics_df = metrics_df.drop('system_disk_io', 1)

metrics_df.shape
# Out:
# (78781, 12)

# %%
# check any null
metrics_df.isnull().sum() * 100 / metrics_df.shape[0]
# Out:
# service_ltcy_200        0.00
# service_cpu_use         0.00
# service_memory_use      0.00
# service_cpu_sat         0.00
# service_net_usage       0.00
# service_disk_usage      0.00
# service_req_total       0.00
# service_errors          0.00
# service_request_size    0.00
# service_response_size   0.00
# containers_count        0.00
# system_cpu_usage        0.00
# dtype: float64

# %% [markdown]
# # Add Data
#
# Let's a signal to indicate day and time of the the metric

# %%
#metrics_df['Hour'] = metrics_df.index.hour 
metrics_df['time'] = (metrics_df.index.values - metrics_df.index.values.astype('datetime64[D]'))/np.timedelta64(1,'s')
metrics_df.head(100)
# Out:
#                      service_ltcy_200  service_cpu_use  service_memory_use  \
# date
# 2020-02-27 22:50:53             -0.01         -1567.59        -63164416.00
# 2020-02-27 22:50:54             -0.09          2698.26         78835712.00
# 2020-02-27 22:50:55             -0.09           -45.34         50089984.00
# 2020-02-27 22:50:56             -0.09         -3178.54        -21082112.00
# 2020-02-27 22:50:57             -0.09          -923.45        -37556224.00
# ...                               ...              ...                 ...
# 2020-02-27 22:52:28             -0.01            72.88         85590016.00
# 2020-02-27 22:52:29             -0.01          -747.88        -36116480.00
# 2020-02-27 22:52:30             -0.01           500.38         34959360.00
# 2020-02-27 22:52:31             -0.01          5368.23         -4321280.00
# 2020-02-27 22:52:32             -0.01          6569.41        161202176.00
#
#                      service_cpu_sat  service_net_usage  service_disk_usage  \
# date
# 2020-02-27 22:50:53         -6732.49       -37926900.50       -101511168.00
# 2020-02-27 22:50:54             0.00               0.00            14336.00
# 2020-02-27 22:50:55          -223.98        53967680.00            45056.00
# 2020-02-27 22:50:56         -2053.77        23957588.00       -257785856.00
# 2020-02-27 22:50:57          -738.31         -501578.00            23893.33
# ...                              ...                ...                 ...
# 2020-02-27 22:52:28         -2771.79               0.00        -71774208.00
# 2020-02-27 22:52:29           244.88        74719173.00       -256245760.00
# 2020-02-27 22:52:30          3372.51      -404162689.00         52080640.00
# 2020-02-27 22:52:31         -2739.14       -15437624.50            61440.00
# 2020-02-27 22:52:32          -511.02       -71509329.17        -52162560.00
#
#                      service_req_total  service_errors  service_request_size  \
# date
# 2020-02-27 22:50:53               0.00            0.00                  0.00
# 2020-02-27 22:50:54           10515.47           -3.50            7225066.55
# 2020-02-27 22:50:55               0.00            0.00                  0.00
# 2020-02-27 22:50:56               0.00            0.00                  0.00
# 2020-02-27 22:50:57               0.00            0.00                  0.00
# ...                                ...             ...                   ...
# 2020-02-27 22:52:28               0.00            0.00                  0.00
# 2020-02-27 22:52:29               0.00            0.00                  0.00
# 2020-02-27 22:52:30               0.00            0.00                  0.00
# 2020-02-27 22:52:31               0.00            0.00                  0.00
# 2020-02-27 22:52:32               0.00            0.00                  0.00
#
#                      service_response_size  containers_count  \
# date
# 2020-02-27 22:50:53                   0.00              0.00
# 2020-02-27 22:50:54            56320481.10              0.00
# 2020-02-27 22:50:55                   0.00              0.00
# 2020-02-27 22:50:56                   0.00              0.00
# 2020-02-27 22:50:57                   0.00              0.00
# ...                                    ...               ...
# 2020-02-27 22:52:28                   0.00              0.00
# 2020-02-27 22:52:29                   0.00              0.00
# 2020-02-27 22:52:30                   0.00              0.00
# 2020-02-27 22:52:31                   0.00              0.00
# 2020-02-27 22:52:32                   0.00              0.00
#
#                      system_cpu_usage     time
# date
# 2020-02-27 22:50:53              0.00 82253.00
# 2020-02-27 22:50:54              0.00 82254.00
# 2020-02-27 22:50:55              0.00 82255.00
# 2020-02-27 22:50:56            485.07 82256.00
# 2020-02-27 22:50:57              0.00 82257.00
# ...                               ...      ...
# 2020-02-27 22:52:28             74.95 82348.00
# 2020-02-27 22:52:29             21.01 82349.00
# 2020-02-27 22:52:30              0.00 82350.00
# 2020-02-27 22:52:31              0.00 82351.00
# 2020-02-27 22:52:32              0.00 82352.00
#
# [100 rows x 13 columns]

# %% [markdown]
# ## Save Metrics TimeSeries Data

# %%
if True:
    metrics_df.sort_index()
    metrics_df.to_csv(output_dir + output_file)

# %% [markdown]
# ### ----------- Below are REPEATED ON OTHER NOTEBOOK --------------

# %% [markdown]
# # Target Data for Prediction
#
# Assuming a 1 minute ahead prediction.
#
# The following is the number of time-steps that we will shift the target-data. Our data-set is resampled to have an observation every 15 seconds, so there are 4 observations for every minute.
#
# If we want to predict the latency 1 minute into the future, we shift the data 4 time-steps. If we want to predict the weather 2 minutes into the future, we shift the data 2 * 4 time-steps, and so on

# %%
shift_minutes = 1

shift_steps = shift_minutes * 4

# %% [markdown]
# Create new dataframe with the time-shifted data (note the negative time-shift value)

# %%
df_targets = metrics_df[target].shift(-shift_steps)
df_targets.head(5)
# Out:
# date
# 2020-02-27 22:50:53   -0.09
# 2020-02-27 22:50:54   -0.09
# 2020-02-27 22:50:55   -0.09
# 2020-02-27 22:50:56   -0.09
# 2020-02-27 22:50:57   -0.09
# Freq: S, Name: service_ltcy_200, dtype: float64

# %%
# double checking the shifted data
metrics_df[target].head(shift_steps + 5)  # before shifting. Note the 5th record shifted first
# Out:
# date
# 2020-02-27 22:50:53   -0.01
# 2020-02-27 22:50:54   -0.09
# 2020-02-27 22:50:55   -0.09
# 2020-02-27 22:50:56   -0.09
# 2020-02-27 22:50:57   -0.09
# 2020-02-27 22:50:58   -0.09
# 2020-02-27 22:50:59   -0.09
# 2020-02-27 22:51:00   -0.09
# 2020-02-27 22:51:01   -0.09
# Freq: S, Name: service_ltcy_200, dtype: float64

# %%
df_targets.tail()  # note last recrods are shifted up and no more values on them
# Out:
# date
# 2020-02-28 20:43:49   -0.44
# 2020-02-28 20:43:50     nan
# 2020-02-28 20:43:51     nan
# 2020-02-28 20:43:52     nan
# 2020-02-28 20:43:53     nan
# Freq: S, Name: service_ltcy_200, dtype: float64

# %% [markdown]
# # Data as Numpy Arrays

# %%
x_data = metrics_df[0:-shift_steps]
print(type(x_data))
print("Shape: ", x_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Shape:  (78777, 13)

# %%
num_data = len(x_data)
num_data
# Out:
# 78777

# %%
y_data = df_targets.values[:-shift_steps]
y_data = pd.DataFrame(y_data)
y_data.shape
# Out:
# (78777, 1)

# %%
train_split = 0.9

# %%
num_train = int(train_split * num_data)
num_train
# Out:
# 70899

# %%
num_test = num_data - num_train
num_test
# Out:
# 7878

# %%
x_train = x_data[0:num_train]
x_test = x_data[num_train:]
len(x_train) + len(x_test)
# Out:
# 78777

# %%
y_train = y_data[0:num_train]
y_test = y_data[num_train:]
len(y_train) + len(y_test)
# Out:
# 78777

# %%
num_x_signals = x_data.shape[1]
num_x_signals
# Out:
# 13

# %%
num_y_signals = y_data.shape[1]
num_y_signals
# Out:
# 1

# %% [markdown]
# ## Scaled Data

# %%
print("Min:", np.min(x_train))
print("Max:", np.max(x_train))
# Out:
# Min: service_ltcy_200                 -1.00
# service_cpu_use              -34191.02
# service_memory_use       -489172992.00
# service_cpu_sat              -22742.64
# service_net_usage       -6707571855.00
# service_disk_usage      -4980259498.67
# service_req_total           -393531.00
# service_errors                 -294.00
# service_request_size     -245802579.67
# service_response_size   -1162582841.67
# containers_count                 -1.00
# system_cpu_usage             -17082.83
# time                              0.00
# dtype: float64
# Max: service_ltcy_200                12.21
# service_cpu_use              32594.07
# service_memory_use       457145617.07
# service_cpu_sat              22224.74
# service_net_usage       7074885570.00
# service_disk_usage      5080296106.67
# service_req_total           327405.33
# service_errors                 409.00
# service_request_size     305838600.76
# service_response_size   1682572537.86
# containers_count                 1.00
# system_cpu_usage             13734.83
# time                         86399.00
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

x_scaler = StandardScaler()
x_train_scaled = x_scaler.fit_transform(x_train)

# %%
print("Min:", np.min(x_train_scaled))
print("Max:", np.max(x_train_scaled))
# Out:
# Min: -44.939485892877535
# Max: 56.929266834337

# %%
x_test_scaled = x_scaler.transform(x_test)
x_test_scaled
# Out:
# array([[ 8.69580168e-01,  8.26566424e-01,  1.83533899e+00, ...,
#          0.00000000e+00, -7.88936509e-04,  1.36947594e+00],
#        [ 8.69580168e-01, -4.34113294e-01, -2.33605056e+00, ...,
#          0.00000000e+00, -7.88936509e-04,  1.36952099e+00],
#        [ 8.69580168e-01, -1.09258372e+00, -1.24278908e-01, ...,
#          0.00000000e+00, -1.10153094e+00,  1.36956605e+00],
#        ...,
#        [-1.37591926e+00, -7.82212632e-01,  5.62783157e-02, ...,
#          0.00000000e+00, -7.88936509e-04,  1.72427622e+00],
#        [-1.37591926e+00,  8.74327377e-02, -1.07453305e+00, ...,
#          0.00000000e+00, -7.88936509e-04,  1.72432127e+00],
#        [-1.37591926e+00, -2.41960089e-01, -2.62899066e-01, ...,
#          0.00000000e+00, -7.88936509e-04,  1.72436632e+00]])

# %%
y_scaler = StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
