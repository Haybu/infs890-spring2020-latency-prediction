# %% [markdown]
# # Multi-Layer Perceptron
#
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from keras.models import Sequential
from keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
from keras.layers import Dense, GaussianNoise, Dropout
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from keras.callbacks import EarlyStopping , ReduceLROnPlateau , ModelCheckpoint
from keras.models import load_model
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.4f}'.format

import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
# network structure. 
# not to include the input layer
#net_layers = (8, 5)  # (11,9,8,4)

epochs=1000
batch_size=500

learning_rate = 1e-3
decay = learning_rate / epochs

patience=80

test_split = 0.1
validation_split = 0.1


SCALE_TARGET = True
SCALE_FEATURES = True

select_features = False

TRAIN_MODEL = True

# trials
# 11 R2-> -0.12
# 11,16,8,4 R2-> 0.37
# 11,11,6 R2-> -0.2
# 11,8,6 R2->   0.316
# 11,11,8,4 R2->  0.37
# 11, 6 R2-> 0.37

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'
models_dir = home_dir + "/models/"

data_file = 'orders_flow_data.csv'   # raw data as is
#data_file = 'order_flow_cleanup_data.csv'
#data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, True)
data = data.reset_index(drop=True)
data.head(5)
# Out:
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0             0.0300          0.0100             0.0100        0.0100
# 1             0.0600          0.0200             0.0200        0.0200
# 2             0.0700          0.0300             0.0200        0.0300
# 3             0.0700          0.0300             0.0200        0.0200
# 4             0.0700          0.0200             0.0100        0.0200
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0           0.0100            0.0100           0.0100         0.0300
# 1           0.0200            0.0100           0.0100         0.1800
# 2           0.0200            0.0100           0.0100         0.4400
# 3           0.0200            0.0100           0.0100         0.2300
# 4           0.0200            0.0100           0.0100         0.2400
#
#    carts-db_cpu_use  front-end_pods  ...  user-db_net_use  shipping_net_use  \
# 0            0.0700          1.0000  ...           2.2044            2.6585
# 1            0.1800          1.0000  ...           2.2044            2.6585
# 2            0.2000          1.0000  ...          16.0739           13.5708
# 3            0.1700          1.0000  ...          19.9869           14.4342
# 4            0.1400          1.0000  ...          10.4490            3.7392
#
#    payment_net_use  carts_net_use  carts-db_net_use  nodes_cpu_use  \
# 0           8.9654        22.0117            4.7995         2.5000
# 1           8.9654        22.0117            4.7995         1.8900
# 2          16.9964        27.3438           16.6522         1.3500
# 3           9.5804         9.4313           17.1768         1.2600
# 4           2.7970         9.1791            6.2516         1.2800
#
#    nodes_disk_io  nodes_net_use  orders_req  orders_ltcy
# 0         1.6700         2.7617      0.1500       0.2400
# 1         1.0100         2.7617      0.1500       0.2400
# 2         0.0500         2.5880      0.1500       0.2400
# 3         0.0400         2.1487      0.1300       0.2400
# 4         0.2600         1.8080      0.3600       0.2400
#
# [5 rows x 29 columns]

# %%
data.shape
# Out:
# (6766, 29)

# %%
targets = data['orders_ltcy']
inputs = data.drop(['orders_ltcy'], axis=1)

n_features = inputs.values.shape[1]
print("there are {} features".format(n_features))
# Out:
# there are 28 features

# %% [markdown]
# # Network Architecture

# %%
#net_layers = (11, 8, 5, 2)  # (11,9,8,4)
net_layers = (19, 7)

# %% [markdown]
# # Scale Target Variable

# %%
# scale targets for better convergence
if SCALE_TARGET:
    y_scaler =  MinMaxScaler()
    targets = y_scaler.fit_transform(targets.values.reshape(-1,1))

# %%
x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=test_split, shuffle=True, random_state=365)

print("y_train {} , y_test {}".format(y_train.shape, y_test.shape))
# Out:
# y_train (6089, 1) , y_test (677, 1)

# %% [markdown]
# # Scaling Features

# %%
if SCALE_FEATURES:
    x_scaler = StandardScaler()
    x_train = x_scaler.fit_transform(x_train)  # fit on training data only
    x_test = x_scaler.transform(x_test)

# %% [markdown]
# # Feature Selection

# %%
feature_list = inputs.columns.values
if 1 == 0:  # disabled
    clf = RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15)
    sfm = SelectFromModel(clf, threshold='0.02*mean')

    selectedFeatures = sfm.fit(inputs, targets).transform(inputs)
    print('{} features selected'.format(selectedFeatures[1].shape[0]))

    feature_list = inputs.columns[sfm.get_support()]
    features = ''
    features = ', '.join(feature_list)
    
    print("columns selected are {}".format(features))

    inputs = inputs[feature_list]
    inputs.head(2)

# %%
if select_features:
    PCA_N_COMPONENTS = 15
    pca = PCA(n_components=PCA_N_COMPONENTS)
    x_train = pca.fit_transform(x_train)
    x_test = pca.transform(x_test)
    pca_std = np.std(x_train)

# %%
n_inputs = len(feature_list)

if select_features:
    n_inputs = PCA_N_COMPONENTS
    
n_inputs
# Out:
# 28

# %% [markdown]
# ## Function to build a model

# %%
def build_keras_model(nodes = net_layers):   # this does not work with KerasRegressor. interesting
    # create model
    model = Sequential()  
    
    if isinstance(nodes, int) or not nodes:
        model.add(Dense(1, input_dim=n_inputs, kernel_initializer='normal'))
    
    else:
        model.add(Dense(nodes[1], input_dim=n_inputs, kernel_initializer='normal', activation='relu'))
    
        layer = 0
        while layer < len(nodes):
            model.add(Dense(nodes[layer], kernel_initializer='normal', activation='relu'))
            layer = layer + 1
        
        #model.add(Dense(1, kernel_initializer='normal', activation='linear')) 
        model.add(Dense(1, kernel_initializer='normal', activation='linear'))  
    
    adam = Adam(lr=learning_rate, decay=decay)
    
    # or loss= 'mean_absolute_percentage_error'
    model.compile(loss='mean_squared_error', optimizer=adam, metrics=['mse'])
    
    return model

# %%
model = build_keras_model()

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=patience)

# save the best model only
mc = ModelCheckpoint(models_dir + 'best_mlp_model.h5'
                     , monitor='val_loss'
                     , mode='min' 
                     , verbose=1
                     #, save_weights_only=True
                     , save_best_only=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.1,
                                       min_lr=1e-4,
                                       patience=0,
                                       verbose=1)

callbacks = [es, mc, reduce_lr]

if TRAIN_MODEL:
    history = model.fit(x_train, y_train
                    , epochs=epochs
                    , batch_size=batch_size
                    , verbose=1
                    , validation_split=validation_split
                    , shuffle=False
                    , callbacks=callbacks)

print ("Done..!")
# Out:
# Train on 5480 samples, validate on 609 samples
# Epoch 1/1000
# 5480/5480 [==============================] - 5s 885us/step - loss: 0.2194 - mean_squared_error: 0.2194 - val_loss: 0.2005 - val_mean_squared_error: 0.2005
#
# Epoch 00001: val_loss improved from inf to 0.20046, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 2/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.2111 - mean_squared_error: 0.2111 - val_loss: 0.1916 - val_mean_squared_error: 0.1916
#
# Epoch 00002: val_loss improved from 0.20046 to 0.19164, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 3/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.2006 - mean_squared_error: 0.2006 - val_loss: 0.1795 - val_mean_squared_error: 0.1795
#
# Epoch 00003: val_loss improved from 0.19164 to 0.17948, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 4/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.1851 - mean_squared_error: 0.1851 - val_loss: 0.1601 - val_mean_squared_error: 0.1601
#
# Epoch 00004: val_loss improved from 0.17948 to 0.16014, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 5/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.1598 - mean_squared_error: 0.1598 - val_loss: 0.1293 - val_mean_squared_error: 0.1293
#
# Epoch 00005: val_loss improved from 0.16014 to 0.12930, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 6/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.1248 - mean_squared_error: 0.1248 - val_loss: 0.0970 - val_mean_squared_error: 0.0970
#
# Epoch 00006: val_loss improved from 0.12930 to 0.09699, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 7/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.1035 - mean_squared_error: 0.1035 - val_loss: 0.0918 - val_mean_squared_error: 0.0918
#
# Epoch 00007: val_loss improved from 0.09699 to 0.09183, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 8/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.1005 - mean_squared_error: 0.1005 - val_loss: 0.0872 - val_mean_squared_error: 0.0872
#
# Epoch 00008: val_loss improved from 0.09183 to 0.08722, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 9/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0961 - mean_squared_error: 0.0961 - val_loss: 0.0850 - val_mean_squared_error: 0.0850
#
# Epoch 00009: val_loss improved from 0.08722 to 0.08497, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 10/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0929 - mean_squared_error: 0.0929 - val_loss: 0.0821 - val_mean_squared_error: 0.0821
#
# Epoch 00010: val_loss improved from 0.08497 to 0.08207, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 11/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0898 - mean_squared_error: 0.0898 - val_loss: 0.0794 - val_mean_squared_error: 0.0794
#
# Epoch 00011: val_loss improved from 0.08207 to 0.07943, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 12/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0866 - mean_squared_error: 0.0866 - val_loss: 0.0767 - val_mean_squared_error: 0.0767
#
# Epoch 00012: val_loss improved from 0.07943 to 0.07668, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 13/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0831 - mean_squared_error: 0.0831 - val_loss: 0.0737 - val_mean_squared_error: 0.0737
#
# Epoch 00013: val_loss improved from 0.07668 to 0.07374, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 14/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0793 - mean_squared_error: 0.0793 - val_loss: 0.0705 - val_mean_squared_error: 0.0705
#
# Epoch 00014: val_loss improved from 0.07374 to 0.07055, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 15/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0752 - mean_squared_error: 0.0752 - val_loss: 0.0672 - val_mean_squared_error: 0.0672
#
# Epoch 00015: val_loss improved from 0.07055 to 0.06721, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 16/1000
# 5480/5480 [==============================] - 0s 11us/step - loss: 0.0709 - mean_squared_error: 0.0709 - val_loss: 0.0639 - val_mean_squared_error: 0.0639
#
# Epoch 00016: val_loss improved from 0.06721 to 0.06386, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 17/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0669 - mean_squared_error: 0.0669 - val_loss: 0.0607 - val_mean_squared_error: 0.0607
#
# Epoch 00017: val_loss improved from 0.06386 to 0.06065, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 18/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0633 - mean_squared_error: 0.0633 - val_loss: 0.0579 - val_mean_squared_error: 0.0579
#
# Epoch 00018: val_loss improved from 0.06065 to 0.05787, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 19/1000
# 5480/5480 [==============================] - 0s 11us/step - loss: 0.0602 - mean_squared_error: 0.0602 - val_loss: 0.0556 - val_mean_squared_error: 0.0556
#
# Epoch 00019: val_loss improved from 0.05787 to 0.05557, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 20/1000
# 5480/5480 [==============================] - 0s 11us/step - loss: 0.0576 - mean_squared_error: 0.0576 - val_loss: 0.0537 - val_mean_squared_error: 0.0537
#
# Epoch 00020: val_loss improved from 0.05557 to 0.05366, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 21/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0553 - mean_squared_error: 0.0553 - val_loss: 0.0521 - val_mean_squared_error: 0.0521
#
# Epoch 00021: val_loss improved from 0.05366 to 0.05206, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 22/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0533 - mean_squared_error: 0.0533 - val_loss: 0.0508 - val_mean_squared_error: 0.0508
#
# Epoch 00022: val_loss improved from 0.05206 to 0.05079, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 23/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0517 - mean_squared_error: 0.0517 - val_loss: 0.0498 - val_mean_squared_error: 0.0498
#
# Epoch 00023: val_loss improved from 0.05079 to 0.04979, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 24/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0503 - mean_squared_error: 0.0503 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00024: val_loss improved from 0.04979 to 0.04905, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 25/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0485 - val_mean_squared_error: 0.0485
#
# Epoch 00025: val_loss improved from 0.04905 to 0.04848, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 26/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0484 - mean_squared_error: 0.0484 - val_loss: 0.0480 - val_mean_squared_error: 0.0480
#
# Epoch 00026: val_loss improved from 0.04848 to 0.04799, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 27/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0477 - mean_squared_error: 0.0477 - val_loss: 0.0475 - val_mean_squared_error: 0.0475
#
# Epoch 00027: val_loss improved from 0.04799 to 0.04746, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 28/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0471 - mean_squared_error: 0.0471 - val_loss: 0.0470 - val_mean_squared_error: 0.0470
#
# Epoch 00028: val_loss improved from 0.04746 to 0.04699, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 29/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0465 - mean_squared_error: 0.0465 - val_loss: 0.0465 - val_mean_squared_error: 0.0465
#
# Epoch 00029: val_loss improved from 0.04699 to 0.04652, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 30/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0459 - mean_squared_error: 0.0459 - val_loss: 0.0461 - val_mean_squared_error: 0.0461
#
# Epoch 00030: val_loss improved from 0.04652 to 0.04611, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 31/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0455 - mean_squared_error: 0.0455 - val_loss: 0.0457 - val_mean_squared_error: 0.0457
#
# Epoch 00031: val_loss improved from 0.04611 to 0.04568, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 32/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0450 - mean_squared_error: 0.0450 - val_loss: 0.0453 - val_mean_squared_error: 0.0453
#
# Epoch 00032: val_loss improved from 0.04568 to 0.04529, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 33/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0445 - mean_squared_error: 0.0445 - val_loss: 0.0449 - val_mean_squared_error: 0.0449
#
# Epoch 00033: val_loss improved from 0.04529 to 0.04491, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 34/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0441 - mean_squared_error: 0.0441 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00034: val_loss improved from 0.04491 to 0.04454, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 35/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0437 - mean_squared_error: 0.0437 - val_loss: 0.0442 - val_mean_squared_error: 0.0442
#
# Epoch 00035: val_loss improved from 0.04454 to 0.04421, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 36/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0432 - mean_squared_error: 0.0432 - val_loss: 0.0439 - val_mean_squared_error: 0.0439
#
# Epoch 00036: val_loss improved from 0.04421 to 0.04390, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 37/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0428 - mean_squared_error: 0.0428 - val_loss: 0.0435 - val_mean_squared_error: 0.0435
#
# Epoch 00037: val_loss improved from 0.04390 to 0.04354, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 38/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0424 - mean_squared_error: 0.0424 - val_loss: 0.0433 - val_mean_squared_error: 0.0433
#
# Epoch 00038: val_loss improved from 0.04354 to 0.04327, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 39/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0420 - mean_squared_error: 0.0420 - val_loss: 0.0430 - val_mean_squared_error: 0.0430
#
# Epoch 00039: val_loss improved from 0.04327 to 0.04298, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 40/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0416 - mean_squared_error: 0.0416 - val_loss: 0.0428 - val_mean_squared_error: 0.0428
#
# Epoch 00040: val_loss improved from 0.04298 to 0.04278, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 41/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.0426 - val_mean_squared_error: 0.0426
#
# Epoch 00041: val_loss improved from 0.04278 to 0.04255, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 42/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0407 - mean_squared_error: 0.0407 - val_loss: 0.0423 - val_mean_squared_error: 0.0423
#
# Epoch 00042: val_loss improved from 0.04255 to 0.04228, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 43/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0404 - mean_squared_error: 0.0404 - val_loss: 0.0424 - val_mean_squared_error: 0.0424
#
# Epoch 00043: val_loss did not improve from 0.04228
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 44/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0401 - mean_squared_error: 0.0401 - val_loss: 0.0422 - val_mean_squared_error: 0.0422
#
# Epoch 00044: val_loss improved from 0.04228 to 0.04216, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 45/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0400 - mean_squared_error: 0.0400 - val_loss: 0.0420 - val_mean_squared_error: 0.0420
#
# Epoch 00045: val_loss improved from 0.04216 to 0.04199, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 46/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.0420 - val_mean_squared_error: 0.0420
#
# Epoch 00046: val_loss did not improve from 0.04199
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 47/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.0420 - val_mean_squared_error: 0.0420
#
# Epoch 00047: val_loss did not improve from 0.04199
# Epoch 48/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.0420 - val_mean_squared_error: 0.0420
#
# Epoch 00048: val_loss improved from 0.04199 to 0.04197, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 49/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
#
# Epoch 00049: val_loss improved from 0.04197 to 0.04194, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 50/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
#
# Epoch 00050: val_loss improved from 0.04194 to 0.04192, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 51/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
#
# Epoch 00051: val_loss improved from 0.04192 to 0.04189, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 52/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0397 - mean_squared_error: 0.0397 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
#
# Epoch 00052: val_loss improved from 0.04189 to 0.04187, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 53/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0397 - mean_squared_error: 0.0397 - val_loss: 0.0418 - val_mean_squared_error: 0.0418
#
# Epoch 00053: val_loss improved from 0.04187 to 0.04184, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 54/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0397 - mean_squared_error: 0.0397 - val_loss: 0.0418 - val_mean_squared_error: 0.0418
#
# Epoch 00054: val_loss improved from 0.04184 to 0.04182, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 55/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0396 - mean_squared_error: 0.0396 - val_loss: 0.0418 - val_mean_squared_error: 0.0418
#
# Epoch 00055: val_loss improved from 0.04182 to 0.04180, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 56/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0396 - mean_squared_error: 0.0396 - val_loss: 0.0418 - val_mean_squared_error: 0.0418
#
# Epoch 00056: val_loss improved from 0.04180 to 0.04177, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 57/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0396 - mean_squared_error: 0.0396 - val_loss: 0.0417 - val_mean_squared_error: 0.0417
#
# Epoch 00057: val_loss improved from 0.04177 to 0.04174, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 58/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0395 - mean_squared_error: 0.0395 - val_loss: 0.0417 - val_mean_squared_error: 0.0417
#
# Epoch 00058: val_loss improved from 0.04174 to 0.04172, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 59/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0395 - mean_squared_error: 0.0395 - val_loss: 0.0417 - val_mean_squared_error: 0.0417
#
# Epoch 00059: val_loss improved from 0.04172 to 0.04169, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 60/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0395 - mean_squared_error: 0.0395 - val_loss: 0.0417 - val_mean_squared_error: 0.0417
#
# Epoch 00060: val_loss improved from 0.04169 to 0.04167, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 61/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0394 - mean_squared_error: 0.0394 - val_loss: 0.0416 - val_mean_squared_error: 0.0416
#
# Epoch 00061: val_loss improved from 0.04167 to 0.04164, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 62/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0394 - mean_squared_error: 0.0394 - val_loss: 0.0416 - val_mean_squared_error: 0.0416
#
# Epoch 00062: val_loss improved from 0.04164 to 0.04162, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 63/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0394 - mean_squared_error: 0.0394 - val_loss: 0.0416 - val_mean_squared_error: 0.0416
#
# Epoch 00063: val_loss improved from 0.04162 to 0.04159, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 64/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0393 - mean_squared_error: 0.0393 - val_loss: 0.0416 - val_mean_squared_error: 0.0416
#
# Epoch 00064: val_loss improved from 0.04159 to 0.04157, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 65/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0393 - mean_squared_error: 0.0393 - val_loss: 0.0415 - val_mean_squared_error: 0.0415
#
# Epoch 00065: val_loss improved from 0.04157 to 0.04155, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 66/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0393 - mean_squared_error: 0.0393 - val_loss: 0.0415 - val_mean_squared_error: 0.0415
#
# Epoch 00066: val_loss improved from 0.04155 to 0.04153, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 67/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0393 - mean_squared_error: 0.0393 - val_loss: 0.0415 - val_mean_squared_error: 0.0415
#
# Epoch 00067: val_loss improved from 0.04153 to 0.04150, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 68/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0392 - mean_squared_error: 0.0392 - val_loss: 0.0415 - val_mean_squared_error: 0.0415
#
# Epoch 00068: val_loss improved from 0.04150 to 0.04148, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 69/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0392 - mean_squared_error: 0.0392 - val_loss: 0.0415 - val_mean_squared_error: 0.0415
#
# Epoch 00069: val_loss improved from 0.04148 to 0.04146, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 70/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0392 - mean_squared_error: 0.0392 - val_loss: 0.0414 - val_mean_squared_error: 0.0414
#
# Epoch 00070: val_loss improved from 0.04146 to 0.04143, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 71/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0414 - val_mean_squared_error: 0.0414
#
# Epoch 00071: val_loss improved from 0.04143 to 0.04141, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 72/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0414 - val_mean_squared_error: 0.0414
#
# Epoch 00072: val_loss improved from 0.04141 to 0.04139, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 73/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0414 - val_mean_squared_error: 0.0414
#
# Epoch 00073: val_loss improved from 0.04139 to 0.04137, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 74/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0414 - val_mean_squared_error: 0.0414
#
# Epoch 00074: val_loss improved from 0.04137 to 0.04135, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 75/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0413 - val_mean_squared_error: 0.0413
#
# Epoch 00075: val_loss improved from 0.04135 to 0.04133, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 76/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0413 - val_mean_squared_error: 0.0413
#
# Epoch 00076: val_loss improved from 0.04133 to 0.04130, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 77/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0413 - val_mean_squared_error: 0.0413
# Epoch 00077: val_loss improved from 0.04130 to 0.04128, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 78/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0413 - val_mean_squared_error: 0.0413
#
# Epoch 00078: val_loss improved from 0.04128 to 0.04126, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 79/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0412 - val_mean_squared_error: 0.0412
#
# Epoch 00079: val_loss improved from 0.04126 to 0.04123, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 80/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0412 - val_mean_squared_error: 0.0412
#
# Epoch 00080: val_loss improved from 0.04123 to 0.04121, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 81/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0412 - val_mean_squared_error: 0.0412
#
# Epoch 00081: val_loss improved from 0.04121 to 0.04119, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 82/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0412 - val_mean_squared_error: 0.0412
#
# Epoch 00082: val_loss improved from 0.04119 to 0.04116, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 83/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
#
# Epoch 00083: val_loss improved from 0.04116 to 0.04114, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 84/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
#
# Epoch 00084: val_loss improved from 0.04114 to 0.04112, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 85/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
#
# Epoch 00085: val_loss improved from 0.04112 to 0.04110, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 86/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
#
# Epoch 00086: val_loss improved from 0.04110 to 0.04108, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 87/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
#
# Epoch 00087: val_loss improved from 0.04108 to 0.04105, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 88/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0410 - val_mean_squared_error: 0.0410
#
# Epoch 00088: val_loss improved from 0.04105 to 0.04103, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 89/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0410 - val_mean_squared_error: 0.0410
#
# Epoch 00089: val_loss improved from 0.04103 to 0.04100, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 90/1000
# 5480/5480 [==============================] - 0s 11us/step - loss: 0.0386 - mean_squared_error: 0.0386 - val_loss: 0.0410 - val_mean_squared_error: 0.0410
#
# Epoch 00090: val_loss improved from 0.04100 to 0.04098, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 91/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0386 - mean_squared_error: 0.0386 - val_loss: 0.0410 - val_mean_squared_error: 0.0410
#
# Epoch 00091: val_loss improved from 0.04098 to 0.04096, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 92/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0386 - mean_squared_error: 0.0386 - val_loss: 0.0409 - val_mean_squared_error: 0.0409
#
# Epoch 00092: val_loss improved from 0.04096 to 0.04093, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 93/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0386 - mean_squared_error: 0.0386 - val_loss: 0.0409 - val_mean_squared_error: 0.0409
#
# Epoch 00093: val_loss improved from 0.04093 to 0.04090, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 94/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0409 - val_mean_squared_error: 0.0409
#
# Epoch 00094: val_loss improved from 0.04090 to 0.04088, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 95/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0409 - val_mean_squared_error: 0.0409
#
# Epoch 00095: val_loss improved from 0.04088 to 0.04086, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 96/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0408 - val_mean_squared_error: 0.0408
#
# Epoch 00096: val_loss improved from 0.04086 to 0.04084, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 97/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0408 - val_mean_squared_error: 0.0408
#
# Epoch 00097: val_loss improved from 0.04084 to 0.04082, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 98/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.0408 - val_mean_squared_error: 0.0408
#
# Epoch 00098: val_loss improved from 0.04082 to 0.04080, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 99/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.0408 - val_mean_squared_error: 0.0408
#
# Epoch 00099: val_loss improved from 0.04080 to 0.04077, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 100/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.0408 - val_mean_squared_error: 0.0408
#
# Epoch 00100: val_loss improved from 0.04077 to 0.04075, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 101/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0383 - mean_squared_error: 0.0383 - val_loss: 0.0407 - val_mean_squared_error: 0.0407
#
# Epoch 00101: val_loss improved from 0.04075 to 0.04073, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 102/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0383 - mean_squared_error: 0.0383 - val_loss: 0.0407 - val_mean_squared_error: 0.0407
#
# Epoch 00102: val_loss improved from 0.04073 to 0.04071, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 103/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0383 - mean_squared_error: 0.0383 - val_loss: 0.0407 - val_mean_squared_error: 0.0407
#
# Epoch 00103: val_loss improved from 0.04071 to 0.04069, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 104/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0383 - mean_squared_error: 0.0383 - val_loss: 0.0407 - val_mean_squared_error: 0.0407
#
# Epoch 00104: val_loss improved from 0.04069 to 0.04067, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 105/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.0406 - val_mean_squared_error: 0.0406
#
# Epoch 00105: val_loss improved from 0.04067 to 0.04064, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 106/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.0406 - val_mean_squared_error: 0.0406
#
# Epoch 00106: val_loss improved from 0.04064 to 0.04062, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 107/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.0406 - val_mean_squared_error: 0.0406
#
# Epoch 00107: val_loss improved from 0.04062 to 0.04060, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 108/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.0406 - val_mean_squared_error: 0.0406
#
# Epoch 00108: val_loss improved from 0.04060 to 0.04058, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 109/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0381 - mean_squared_error: 0.0381 - val_loss: 0.0406 - val_mean_squared_error: 0.0406
#
# Epoch 00109: val_loss improved from 0.04058 to 0.04056, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 110/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0381 - mean_squared_error: 0.0381 - val_loss: 0.0405 - val_mean_squared_error: 0.0405
#
# Epoch 00110: val_loss improved from 0.04056 to 0.04054, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 111/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0381 - mean_squared_error: 0.0381 - val_loss: 0.0405 - val_mean_squared_error: 0.0405
#
# Epoch 00111: val_loss improved from 0.04054 to 0.04052, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 112/1000
# 5480/5480 [==============================] - 0s 11us/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0405 - val_mean_squared_error: 0.0405
#
# Epoch 00112: val_loss improved from 0.04052 to 0.04049, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 113/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0405 - val_mean_squared_error: 0.0405
#
# Epoch 00113: val_loss improved from 0.04049 to 0.04047, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 114/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
#
# Epoch 00114: val_loss improved from 0.04047 to 0.04045, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 115/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
#
# Epoch 00115: val_loss improved from 0.04045 to 0.04043, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 116/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
#
# Epoch 00116: val_loss improved from 0.04043 to 0.04041, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 117/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
#
# Epoch 00117: val_loss improved from 0.04041 to 0.04039, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 118/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
#
# Epoch 00118: val_loss improved from 0.04039 to 0.04037, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 119/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
#
# Epoch 00119: val_loss improved from 0.04037 to 0.04035, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 120/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
#
# Epoch 00120: val_loss improved from 0.04035 to 0.04033, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 121/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
#
# Epoch 00121: val_loss improved from 0.04033 to 0.04031, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 122/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
#
# Epoch 00122: val_loss improved from 0.04031 to 0.04030, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 123/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
#
# Epoch 00123: val_loss improved from 0.04030 to 0.04028, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 124/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0377 - mean_squared_error: 0.0377 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
#
# Epoch 00124: val_loss improved from 0.04028 to 0.04026, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 125/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0377 - mean_squared_error: 0.0377 - val_loss: 0.0402 - val_mean_squared_error: 0.0402
#
# Epoch 00125: val_loss improved from 0.04026 to 0.04024, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 126/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0377 - mean_squared_error: 0.0377 - val_loss: 0.0402 - val_mean_squared_error: 0.0402
#
# Epoch 00126: val_loss improved from 0.04024 to 0.04022, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 127/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0377 - mean_squared_error: 0.0377 - val_loss: 0.0402 - val_mean_squared_error: 0.0402
#
# Epoch 00127: val_loss improved from 0.04022 to 0.04021, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 128/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.0402 - val_mean_squared_error: 0.0402
#
# Epoch 00128: val_loss improved from 0.04021 to 0.04019, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 129/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.0402 - val_mean_squared_error: 0.0402
#
# Epoch 00129: val_loss improved from 0.04019 to 0.04017, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 130/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.0401 - val_mean_squared_error: 0.0401
#
# Epoch 00130: val_loss improved from 0.04017 to 0.04014, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 131/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.0401 - val_mean_squared_error: 0.0401
#
# Epoch 00131: val_loss improved from 0.04014 to 0.04012, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 132/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0401 - val_mean_squared_error: 0.0401
#
# Epoch 00132: val_loss improved from 0.04012 to 0.04010, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 133/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0401 - val_mean_squared_error: 0.0401
#
# Epoch 00133: val_loss improved from 0.04010 to 0.04007, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 134/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0400 - val_mean_squared_error: 0.0400
#
# Epoch 00134: val_loss improved from 0.04007 to 0.04005, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 135/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0400 - val_mean_squared_error: 0.0400
#
# Epoch 00135: val_loss improved from 0.04005 to 0.04002, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 136/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0400 - val_mean_squared_error: 0.0400
#
# Epoch 00136: val_loss improved from 0.04002 to 0.04000, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 137/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0400 - val_mean_squared_error: 0.0400
#
# Epoch 00137: val_loss improved from 0.04000 to 0.03997, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 138/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0399 - val_mean_squared_error: 0.0399
#
# Epoch 00138: val_loss improved from 0.03997 to 0.03995, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 139/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0399 - val_mean_squared_error: 0.0399
#
# Epoch 00139: val_loss improved from 0.03995 to 0.03993, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 140/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.0399 - val_mean_squared_error: 0.0399
#
# Epoch 00140: val_loss improved from 0.03993 to 0.03990, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 141/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.0399 - val_mean_squared_error: 0.0399
#
# Epoch 00141: val_loss improved from 0.03990 to 0.03988, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 142/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.0399 - val_mean_squared_error: 0.0399
#
# Epoch 00142: val_loss improved from 0.03988 to 0.03986, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 143/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.0398 - val_mean_squared_error: 0.0398
#
# Epoch 00143: val_loss improved from 0.03986 to 0.03984, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 144/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0398 - val_mean_squared_error: 0.0398
#
# Epoch 00144: val_loss improved from 0.03984 to 0.03982, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 145/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0398 - val_mean_squared_error: 0.0398
#
# Epoch 00145: val_loss improved from 0.03982 to 0.03980, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 146/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0398 - val_mean_squared_error: 0.0398
#
# Epoch 00146: val_loss improved from 0.03980 to 0.03978, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 147/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0398 - val_mean_squared_error: 0.0398
#
# Epoch 00147: val_loss improved from 0.03978 to 0.03976, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 148/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0397 - val_mean_squared_error: 0.0397
#
# Epoch 00148: val_loss improved from 0.03976 to 0.03974, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 149/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0371 - mean_squared_error: 0.0371 - val_loss: 0.0397 - val_mean_squared_error: 0.0397
#
# ...
#
# Epoch 00941: val_loss improved from 0.03173 to 0.03173, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 942/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00942: val_loss did not improve from 0.03173
# Epoch 943/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00943: val_loss improved from 0.03173 to 0.03172, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 944/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00944: val_loss did not improve from 0.03172
# Epoch 945/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00945: val_loss improved from 0.03172 to 0.03171, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 946/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00946: val_loss did not improve from 0.03171
# Epoch 947/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00947: val_loss improved from 0.03171 to 0.03171, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 948/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00948: val_loss improved from 0.03171 to 0.03171, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 949/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00949: val_loss improved from 0.03171 to 0.03171, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 950/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00950: val_loss improved from 0.03171 to 0.03170, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 951/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00951: val_loss improved from 0.03170 to 0.03169, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 952/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00952: val_loss did not improve from 0.03169
# Epoch 953/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00953: val_loss improved from 0.03169 to 0.03169, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 954/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00954: val_loss did not improve from 0.03169
# Epoch 955/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00955: val_loss improved from 0.03169 to 0.03167, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 956/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00956: val_loss did not improve from 0.03167
# Epoch 957/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00957: val_loss improved from 0.03167 to 0.03167, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 958/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00958: val_loss improved from 0.03167 to 0.03166, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 959/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00959: val_loss did not improve from 0.03166
# Epoch 960/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00960: val_loss improved from 0.03166 to 0.03166, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 961/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00961: val_loss improved from 0.03166 to 0.03166, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 962/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00962: val_loss did not improve from 0.03166
# Epoch 963/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00963: val_loss improved from 0.03166 to 0.03165, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 964/1000
# 5480/5480 [==============================] - 0s 11us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00964: val_loss improved from 0.03165 to 0.03164, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 965/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00965: val_loss did not improve from 0.03164
# Epoch 966/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00966: val_loss did not improve from 0.03164
# Epoch 967/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00967: val_loss did not improve from 0.03164
# Epoch 968/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00968: val_loss did not improve from 0.03164
# Epoch 969/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00969: val_loss did not improve from 0.03164
# Epoch 970/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00970: val_loss did not improve from 0.03164
# Epoch 971/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00971: val_loss did not improve from 0.03164
# Epoch 972/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00972: val_loss did not improve from 0.03164
# Epoch 973/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00973: val_loss did not improve from 0.03164
# Epoch 974/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
#
# Epoch 00974: val_loss did not improve from 0.03164
# Epoch 975/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00975: val_loss did not improve from 0.03164
# Epoch 976/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00976: val_loss improved from 0.03164 to 0.03164, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 977/1000
# 5480/5480 [==============================] - 0s 11us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00977: val_loss did not improve from 0.03164
# Epoch 978/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00978: val_loss did not improve from 0.03164
# Epoch 979/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00979: val_loss did not improve from 0.03164
# Epoch 980/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00980: val_loss did not improve from 0.03164
# Epoch 981/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00981: val_loss improved from 0.03164 to 0.03163, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 982/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00982: val_loss improved from 0.03163 to 0.03163, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 983/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00983: val_loss did not improve from 0.03163
# Epoch 984/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00984: val_loss improved from 0.03163 to 0.03163, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 985/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00985: val_loss did not improve from 0.03163
# Epoch 986/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00986: val_loss improved from 0.03163 to 0.03162, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 987/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00987: val_loss improved from 0.03162 to 0.03162, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 988/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00988: val_loss improved from 0.03162 to 0.03162, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 989/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
# Epoch 00989: val_loss did not improve from 0.03162
# Epoch 990/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00990: val_loss improved from 0.03162 to 0.03161, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 991/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00991: val_loss did not improve from 0.03161
# Epoch 992/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00992: val_loss improved from 0.03161 to 0.03161, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 993/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00993: val_loss improved from 0.03161 to 0.03160, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 994/1000
# 5480/5480 [==============================] - 0s 8us/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00994: val_loss did not improve from 0.03160
# Epoch 995/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00995: val_loss did not improve from 0.03160
# Epoch 996/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00996: val_loss did not improve from 0.03160
# Epoch 997/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00997: val_loss did not improve from 0.03160
# Epoch 998/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00998: val_loss did not improve from 0.03160
# Epoch 999/1000
# 5480/5480 [==============================] - 0s 10us/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 00999: val_loss improved from 0.03160 to 0.03160, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 1000/1000
# 5480/5480 [==============================] - 0s 9us/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
#
# Epoch 01000: val_loss did not improve from 0.03160
# Done..!

# %%
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
val_loss = history.history['val_loss']
val_loss_df = pd.DataFrame(val_loss)

print("Model Validation MSE mean: %.2f  std: (%.2f)" % \
      (val_loss_df.mean(), val_loss_df.std()))
# Out:
# Model Validation MSE mean: 0.04  std: (0.01)

# %%
# load the saved model
saved_model = load_model(models_dir + 'best_mlp_model.h5')

# %%
# evaluate the model
train_loss, train_mse = saved_model.evaluate(x_train, y_train, verbose=0)
test_loss, test_mse = saved_model.evaluate(x_test, y_test, verbose=0)
print('Train MSE: %.3f, Test MSE: %.3f' % (train_mse, test_mse))
# Out:
# Train MSE: 0.028, Test MSE: 0.030

# %%
#regressor.fit(x_train, y_train)
y_hat = saved_model.predict(x_train)

#y_train = y_scaler.inverse_transform(y_train.reshape(-1,1))
#y_hat = y_scaler.inverse_transform(y_hat.reshape(-1,1))

# %%
y_train = y_train.reshape(-1)

# %%
y_train_together = pd.DataFrame(y_train, columns=['y_train_true'])
y_train_together['y_train_pred'] = y_hat
#y_train_together = y_train_together.reshape(-1,2)
y_train_together.head(5)
# Out:
#    y_train_true  y_train_pred
# 0        0.0226        0.0020
# 1        0.6702        0.4862
# 2        0.2022        0.4862
# 3        0.0226        0.0147
# 4        0.9753        0.9751

# %%
r2_train = metrics.r2_score(y_train, y_hat)
print('R2 (training) = {}'.format(r2_train))
# Out:
# R2 (training) = 0.7839329499654227

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
#plt.xlim(-2,3)
#plt.ylim(-3,1)
plt.show()

# %%
#y_train = y_train.values
sns.distplot(y_train - y_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %%
# evaluation mean_absolute_percentage_error
train_error =  y_train - y_hat
train_error

mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)

print("Train Residual mean: %.2f std: %.2f  min; %.2f max: %.2f" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Train Residual mean: 0.00 std: 0.48  min; -1.28 max: 1.04

# %% [markdown]
# ### Testing

# %%
y_hat_test = saved_model.predict(x_test)

#y_test = y_scaler.inverse_transform(y_test.reshape(-1,1))
#y_hat_test = y_scaler.inverse_transform(y_hat_test.reshape(-1,1))

# %%
y_test = y_test.reshape(-1)

# %%
y_test_together = pd.DataFrame(y_test, columns=['y_test_true'])
y_test_together['y_test_pred'] = y_hat_test
y_test_together.head(5)
# Out:
#    y_test_true  y_test_pred
# 0       0.9599       1.0326
# 1       0.0781       0.0633
# 2       0.3936       0.0340
# 3       0.0216       0.0207
# 4       0.2950       0.3346

# %%
plt.scatter(y_test, y_hat_test)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_hat_test, color='g')

# %%
perf = pd.DataFrame(y_hat_test, columns=['prediction'])
#y_test = y_test.reset_index(drop=True)
perf['target'] = y_test
perf.head()
# Out:
#    prediction  target
# 0      1.0326  0.9599
# 1      0.0633  0.0781
# 2      0.0340  0.3936
# 3      0.0207  0.0216
# 4      0.3346  0.2950

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0        1.0326  0.9599    0.0727       7.5695
# 1        0.0633  0.0781   -0.0149      19.0186
# 2        0.0340  0.3936   -0.3597      91.3739
# 3        0.0207  0.0216   -0.0009       4.1270
# 4        0.3346  0.2950    0.0397      13.4501
# ..          ...     ...       ...          ...
# 672      0.0378  0.0226    0.0152      67.3668
# 673      0.4862  0.1879    0.2983     158.7535
# 674      0.0398  0.0206    0.0192      93.5565
# 675      0.0341  0.0226    0.0115      50.6885
# 676      0.4862  0.4665    0.0198       4.2397
#
# [677 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction   target  residual  difference%
# count    677.0000 677.0000  677.0000     677.0000
# mean       0.3202   0.3182    0.0019     142.0153
# std        0.3261   0.3624    0.1735     447.0004
# min       -0.0090   0.0051   -0.8030       0.0722
# 25%        0.0341   0.0226   -0.0277      14.6265
# 50%        0.1890   0.0606    0.0071      40.2423
# 75%        0.4862   0.6259    0.0492      93.7985
# max        1.2335   0.9959    0.7008   8,522.9521

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 87         0.02    0.02     -0.00         0.07
# 160        0.97    0.97      0.00         0.07
# 600        0.97    0.97      0.00         0.08
# 656        0.95    0.95     -0.00         0.11
# 364        0.02    0.02     -0.00         0.11
# 664        0.98    0.98     -0.00         0.14
# 487        0.96    0.96     -0.00         0.32
# 449        0.98    0.98      0.00         0.45
# 336        0.96    0.97     -0.01         0.53
# 213        0.92    0.92      0.00         0.54
# 562        0.49    0.48      0.00         0.59
# 500        1.00    0.99      0.01         0.71
# 50         0.92    0.91      0.01         0.72
# 587        0.98    0.98     -0.01         0.83
# 379        0.49    0.49     -0.00         0.88
# 86         0.96    0.96      0.01         0.96
# 153        0.99    0.98      0.01         1.07
# 188        0.98    0.99     -0.01         1.10
# 259        0.49    0.48      0.01         1.27
# 107        0.49    0.49     -0.01         1.32
# 171        0.49    0.49     -0.01         1.53
# 181        0.92    0.94     -0.02         1.75
# 318        0.03    0.03      0.00         1.75
# 399        0.94    0.96     -0.02         1.80
# 94         0.43    0.44     -0.01         1.80
# 527        0.03    0.03     -0.00         1.84
# 18         0.35    0.34      0.01         1.89
# 38         0.98    0.97      0.02         1.89
# 497        0.02    0.02      0.00         2.09
# 21         0.94    0.96     -0.02         2.09
# 472        0.89    0.87      0.02         2.66
# 270        0.92    0.95     -0.03         2.72
# 464        0.49    0.47      0.01         2.81
# 411        0.96    0.99     -0.03         2.81
# 143        0.98    0.95      0.03         2.83
# 102        0.90    0.93     -0.03         2.86
# 277        0.95    0.98     -0.03         2.95
# 478        0.99    0.96      0.03         2.99
# 145        0.49    0.50     -0.02         3.19
# 209        1.01    0.98      0.03         3.27
# 262        0.92    0.95     -0.03         3.40
# 135        0.49    0.50     -0.02         3.44
# 607        1.02    0.99      0.03         3.45
# 331        0.94    0.97     -0.03         3.47
# 494        1.03    1.00      0.04         3.56
# 13         0.95    0.98     -0.04         3.60
# 130        1.01    0.97      0.04         3.74
# 594        0.02    0.02      0.00         3.74
# 604        0.49    0.47      0.02         3.81
# 200        1.00    0.96      0.04         3.81
# 518        0.02    0.02     -0.00         3.83
# 292        0.95    0.99     -0.04         3.91
# 457        1.01    0.98      0.04         4.06
# 3          0.02    0.02     -0.00         4.13
# 144        0.95    0.91      0.04         4.21
# 676        0.49    0.47      0.02         4.24
# 289        1.01    0.97      0.04         4.24
# 133        0.93    0.97     -0.04         4.40
# 150        1.01    0.97      0.04         4.41
# 405        0.49    0.51     -0.02         4.43
# 484        0.94    0.98     -0.04         4.46
# 567        0.99    0.95      0.04         4.66
# 66         0.37    0.39     -0.02         4.76
# 27         0.49    0.51     -0.02         4.79
# 197        0.90    0.95     -0.05         5.08
# 470        0.02    0.03     -0.00         5.13
# 64         0.02    0.02      0.00         5.29
# 558        0.49    0.51     -0.03         5.40
# 540        0.98    0.92      0.05         5.50
# 214        0.02    0.02      0.00         5.58
# 563        0.47    0.50     -0.03         5.80
# 402        0.41    0.39      0.02         5.81
# 109        0.03    0.03      0.00         5.90
# 311        0.37    0.39     -0.02         5.94
# 210        1.02    0.96      0.06         5.95
# 63         0.49    0.52     -0.03         5.99
# 308        0.92    0.98     -0.06         6.17
# 176        0.49    0.46      0.03         6.32
# 396        0.02    0.02      0.00         6.50
# 339        0.93    1.00     -0.07         6.56
# 413        0.02    0.02     -0.00         6.61
# 235        0.90    0.97     -0.06         6.63
# 95         0.02    0.02      0.00         6.80
# 116        0.44    0.47     -0.03         6.93
# 613        0.66    0.71     -0.05         6.94
# 502        0.67    0.63      0.04         7.04
# 39         0.87    0.93     -0.07         7.08
# 585        0.88    0.95     -0.07         7.08
# 599        0.91    0.98     -0.07         7.11
# 237        0.02    0.02      0.00         7.21
# 546        0.89    0.96     -0.07         7.39
# 125        0.68    0.74     -0.05         7.40
# 659        0.49    0.45      0.03         7.54
# 0          1.03    0.96      0.07         7.57
# 284        0.80    0.86     -0.07         7.58
# 240        0.02    0.02      0.00         7.73
# 373        0.89    0.96     -0.07         7.77
# 11         0.90    0.98     -0.08         7.85
# 380        0.02    0.02      0.00         7.87
# 128        0.49    0.45      0.04         8.01
# 167        0.02    0.02     -0.00         8.02
# 412        1.07    0.99      0.08         8.11
# 228        1.05    0.97      0.08         8.12
# 615        0.02    0.02     -0.00         8.23
# 12         0.49    0.45      0.04         8.32
# 554        0.03    0.03     -0.00         8.48
# 421        0.04    0.04     -0.00         8.60
# 163        0.02    0.02     -0.00         8.60
# 57         0.02    0.02      0.00         8.62
# 9          0.02    0.02      0.00         8.75
# 112        0.03    0.03      0.00         9.03
# 385        0.49    0.53     -0.05         9.08
# 661        0.04    0.04     -0.00         9.17
# 570        0.02    0.02      0.00         9.28
# 59         0.47    0.43      0.04         9.36
# 349        0.88    0.97     -0.09         9.37
# 36         1.08    0.99      0.09         9.51
# 178        0.49    0.54     -0.05         9.52
# 460        1.08    0.98      0.09         9.59
# 164        1.01    0.92      0.09         9.79
# 161        0.86    0.95     -0.09         9.80
# 452        0.03    0.03      0.00         9.98
# 55         0.02    0.02      0.00        10.18
# 43         0.76    0.84     -0.09        10.20
# 32         0.47    0.52     -0.05        10.23
# 372        0.49    0.54     -0.06        10.28
# 267        0.26    0.24      0.02        10.42
# 620        0.39    0.44     -0.05        10.49
# 427        0.49    0.54     -0.06        10.60
# 633        0.82    0.92     -0.10        10.67
# 124        0.79    0.88     -0.10        10.86
# 35         1.09    0.98      0.11        11.17
# 184        0.86    0.97     -0.11        11.21
# 369        0.49    0.44      0.05        11.22
# 246        0.04    0.04      0.00        11.23
# 646        0.87    0.99     -0.11        11.25
# 569        1.09    0.98      0.11        11.28
# 229        1.10    0.99      0.11        11.54
# 602        0.86    0.97     -0.11        11.60
# 586        0.02    0.02     -0.00        11.69
# 632        0.04    0.04      0.00        11.70
# 425        0.02    0.02     -0.00        11.75
# 44         0.47    0.42      0.05        11.76
# 466        0.49    0.55     -0.07        11.97
# 590        0.02    0.02     -0.00        12.04
# 612        0.82    0.93     -0.12        12.32
# 147        0.49    0.43      0.05        12.39
# 306        0.84    0.96     -0.12        12.48
# 22         0.43    0.49     -0.06        12.49
# 319        0.82    0.93     -0.12        12.65
# 272        0.02    0.02     -0.00        12.71
# 224        0.02    0.02     -0.00        12.78
# 663        0.22    0.25     -0.03        12.81
# 282        0.84    0.97     -0.13        12.96
# 501        0.02    0.02      0.00        13.18
# 173        0.86    0.99     -0.13        13.23
# 443        0.03    0.02      0.00        13.23
# 201        0.02    0.02      0.00        13.26
# 305        0.44    0.50     -0.07        13.39
# 4          0.33    0.29      0.04        13.45
# 538        0.03    0.02      0.00        13.64
# 553        0.29    0.25      0.03        13.67
# 611        0.49    0.43      0.06        13.76
# 320        0.42    0.49     -0.07        14.08
# 90         0.02    0.02      0.00        14.15
# 662        0.02    0.02      0.00        14.26
# 322        0.49    0.43      0.06        14.29
# 89         0.84    0.98     -0.14        14.31
# 644        0.49    0.42      0.06        14.46
# 155        0.04    0.04      0.01        14.63
# 583        0.49    0.57     -0.09        14.98
# 248        0.45    0.54     -0.08        15.32
# 635        0.49    0.42      0.06        15.34
# 113        0.49    0.57     -0.09        15.36
# 273        0.02    0.02     -0.00        15.38
# 407        0.03    0.04     -0.01        15.43
# 254        0.04    0.04      0.01        15.88
# 222        0.02    0.02     -0.00        15.90
# 471        0.05    0.06     -0.01        16.04
# 481        0.02    0.02     -0.00        16.21
# 230        0.48    0.41      0.07        16.24
# 526        0.49    0.42      0.07        16.24
# 75         0.03    0.03     -0.01        16.57
# 249        0.54    0.65     -0.11        16.76
# 352        0.42    0.50     -0.08        16.78
# 520        1.16    0.99      0.17        16.79
# 640        0.49    0.59     -0.10        16.96
# 245        0.49    0.42      0.07        16.97
# 641        0.49    0.59     -0.10        17.05
# 574        0.49    0.59     -0.10        17.33
# 491        0.02    0.02     -0.00        17.34
# 195        0.84    0.71      0.12        17.47
# 67         0.49    0.41      0.07        17.52
# 106        0.80    0.97     -0.17        17.59
# 198        0.03    0.04     -0.01        17.66
# 314        0.49    0.59     -0.11        17.87
# 496        1.00    0.85      0.15        17.90
# 499        0.39    0.48     -0.09        17.93
# 668        0.02    0.02     -0.00        17.97
# 482        0.03    0.02      0.00        18.01
# 88         0.03    0.02      0.00        18.64
# 389        0.02    0.02     -0.00        18.65
# 1          0.06    0.08     -0.01        19.02
# 645        0.05    0.04      0.01        19.14
# 26         0.03    0.04     -0.01        19.23
# 474        1.06    0.89      0.17        19.33
# 156        0.49    0.60     -0.12        19.38
# 138        0.02    0.03     -0.01        19.66
# 175        0.02    0.02     -0.00        20.05
# 132        0.04    0.04     -0.01        20.24
# 556        0.03    0.02      0.00        20.69
# 260        1.03    0.85      0.18        20.74
# 541        0.03    0.04     -0.01        20.92
# 148        0.95    0.78      0.16        20.95
# 323        0.49    0.62     -0.13        21.00
# 335        0.36    0.45     -0.09        21.00
# 414        0.92    0.76      0.16        21.03
# 347        0.49    0.62     -0.13        21.08
# 649        0.96    0.79      0.17        21.25
# 91         0.49    0.62     -0.13        21.42
# 388        0.05    0.04      0.01        21.73
# 660        0.03    0.04     -0.01        22.02
# 608        0.03    0.02      0.01        22.23
# 287        0.40    0.33      0.07        22.40
# 521        0.75    0.97     -0.22        22.49
# 510        1.02    0.83      0.19        22.56
# 451        0.03    0.02      0.01        22.60
# 517        0.02    0.02     -0.01        22.65
# 537        0.02    0.02     -0.01        22.76
# 598        0.77    0.63      0.14        23.00
# 391        0.61    0.80     -0.18        23.03
# 187        0.49    0.63     -0.15        23.11
# 669        0.49    0.63     -0.15        23.35
# 634        0.66    0.87     -0.20        23.38
# 180        0.02    0.02     -0.01        23.66
# 356        0.49    0.39      0.09        23.75
# 442        0.73    0.95     -0.23        23.93
# 251        0.49    0.64     -0.15        24.13
# 53         0.65    0.86     -0.21        24.28
# 193        0.03    0.02      0.01        24.53
# 595        0.48    0.39      0.09        24.55
# 423        0.49    0.39      0.10        24.58
# 78         0.49    0.64     -0.16        24.59
# 196        0.61    0.82     -0.20        24.61
# 459        0.05    0.04      0.01        24.63
# 535        0.17    0.23     -0.06        24.72
# 162        0.20    0.16      0.04        24.91
# 658        1.23    0.99      0.25        25.15
# 16         0.04    0.03      0.01        25.27
# 285        0.37    0.49     -0.12        25.42
# 217        0.49    0.65     -0.17        25.57
# 445        0.03    0.02      0.01        25.64
# 65         0.02    0.02     -0.01        25.65
# 653        0.62    0.49      0.13        25.83
# 46         0.49    0.66     -0.17        26.08
# 395        0.64    0.50      0.13        26.17
# 99         0.02    0.02     -0.01        26.23
# 492        0.63    0.86     -0.23        26.27
# 392        0.03    0.02      0.01        26.31
# 469        0.49    0.66     -0.17        26.44
# 441        0.91    0.72      0.19        26.49
# 294        0.02    0.02     -0.01        26.58
# 104        0.05    0.04      0.01        26.61
# 624        0.72    0.98     -0.27        26.97
# 424        0.07    0.06      0.02        26.97
# 365        0.60    0.47      0.13        27.20
# 280        0.49    0.67     -0.18        27.23
# 539        0.49    0.67     -0.18        27.52
# 651        0.45    0.62     -0.17        27.53
# 588        0.60    0.47      0.13        27.65
# 597        0.03    0.02      0.01        27.79
# 626        0.03    0.04     -0.01        27.83
# 516        0.71    0.99     -0.28        28.32
# 504        0.02    0.02     -0.01        28.34
# 465        0.03    0.02      0.01        28.37
# 473        0.49    0.38      0.11        28.43
# 549        0.49    0.68     -0.20        28.83
# 422        0.49    0.68     -0.20        28.90
# 33         0.02    0.02     -0.01        29.75
# 121        0.48    0.69     -0.21        30.16
# 288        0.03    0.02      0.01        30.25
# 366        0.02    0.02     -0.01        30.31
# 117        0.66    0.95     -0.29        30.32
# 670        0.02    0.02     -0.01        30.67
# 115        0.49    0.70     -0.22        30.74
# 579        0.02    0.02     -0.01        31.01
# 258        0.18    0.26     -0.08        31.05
# 665        0.49    0.71     -0.22        31.12
# 453        0.02    0.02     -0.01        31.18
# 108        0.03    0.02      0.01        31.22
# 572        0.03    0.02      0.01        32.26
# 158        0.49    0.72     -0.23        32.37
# 667        0.05    0.04      0.01        32.43
# 31         0.03    0.02      0.01        32.76
# 534        0.03    0.02      0.01        32.77
# 430        0.02    0.02     -0.01        32.81
# 242        0.43    0.32      0.11        33.01
# 476        0.49    0.73     -0.24        33.10
# 486        0.59    0.88     -0.29        33.15
# 618        0.64    0.48      0.16        33.16
# 261        0.11    0.08      0.03        33.21
# 394        0.55    0.82     -0.27        33.32
# 557        0.26    0.19      0.06        33.56
# 238        0.49    0.73     -0.25        33.57
# 243        0.49    0.36      0.12        33.72
# 619        0.03    0.02      0.01        33.88
# 34         0.49    0.36      0.12        33.96
# 268        0.01    0.02     -0.01        34.05
# 409        0.49    0.36      0.12        34.20
# 363        0.02    0.02     -0.01        34.28
# 51         0.03    0.05     -0.02        34.77
# 310        0.01    0.02     -0.01        34.96
# 461        0.49    0.36      0.13        34.96
# 219        1.06    0.79      0.28        34.98
# 456        0.04    0.03      0.01        35.18
# 560        0.49    0.75     -0.27        35.58
# 149        0.49    0.76     -0.27        35.69
# 647        0.03    0.02      0.01        35.79
# 384        0.49    0.76     -0.28        36.18
# 577        0.28    0.21      0.07        36.30
# 236        0.11    0.17     -0.06        36.50
# 631        0.30    0.47     -0.17        36.66
# 345        0.49    0.77     -0.29        37.10
# 98         0.03    0.02      0.01        37.93
# 654        0.03    0.02      0.01        38.26
# 578        0.49    0.79     -0.30        38.29
# 536        0.05    0.03      0.01        38.33
# 383        0.49    0.80     -0.31        39.10
# 283        0.49    0.80     -0.31        39.15
# 426        0.49    0.80     -0.31        39.20
# 316        0.01    0.02     -0.01        39.28
# 140        0.01    0.02     -0.01        39.31
# 165        0.27    0.45     -0.18        39.73
# 68         0.16    0.26     -0.10        39.73
# 360        0.03    0.02      0.01        39.77
# 312        0.03    0.02      0.01        39.79
# 169        0.29    0.48     -0.19        40.14
# 56         0.49    0.81     -0.33        40.17
# 177        0.49    0.35      0.14        40.24
# 220        0.49    0.81     -0.33        40.27
# 434        0.02    0.04     -0.02        40.29
# 293        0.49    0.81     -0.33        40.31
# 170        0.49    0.82     -0.33        40.60
# 623        0.49    0.82     -0.34        40.93
# 643        0.01    0.02     -0.01        40.95
# 582        0.03    0.02      0.01        41.04
# 291        0.49    0.83     -0.34        41.16
# 609        0.49    0.83     -0.34        41.21
# 315        0.03    0.04     -0.02        41.22
# 435        0.49    0.83     -0.35        41.53
# 185        0.49    0.34      0.14        42.38
# 223        0.49    0.85     -0.36        42.61
# 321        0.49    0.85     -0.36        42.65
# 58         0.49    0.34      0.15        42.93
# 565        0.71    0.49      0.21        43.27
# 444        0.03    0.02      0.01        43.35
# 353        0.49    0.34      0.15        43.47
# 80         0.06    0.04      0.02        43.55
# 119        0.49    0.86     -0.38        43.74
# 431        0.49    0.87     -0.39        44.32
# 666        0.49    0.88     -0.39        44.44
# 371        0.01    0.02     -0.01        44.66
# 206        0.49    0.89     -0.40        45.09
# 186        0.02    0.04     -0.02        45.25
# 509        0.49    0.33      0.15        45.43
# 205        0.49    0.89     -0.41        45.57
# 490        0.03    0.02      0.01        45.60
# 571        0.49    0.89     -0.41        45.65
# 77         0.51    0.94     -0.43        45.93
# 303        0.03    0.06     -0.03        46.25
# 54         0.03    0.05     -0.02        46.27
# 377        0.49    0.91     -0.42        46.28
# 179        0.49    0.91     -0.42        46.32
# 550        0.49    0.91     -0.42        46.47
# 233        0.49    0.91     -0.42        46.62
# 290        0.02    0.04     -0.02        46.64
# 462        0.49    0.91     -0.43        46.70
# 221        0.03    0.02      0.01        46.83
# 74         0.04    0.03      0.01        47.10
# 503        0.03    0.02      0.01        47.13
# 114        0.47    0.88     -0.42        47.28
# 192        0.01    0.03     -0.01        47.30
# 120        0.03    0.02      0.01        47.49
# 601        0.02    0.04     -0.02        48.03
# 151        0.49    0.94     -0.45        48.03
# 548        0.03    0.02      0.01        48.25
# 514        0.49    0.94     -0.45        48.32
# 61         0.49    0.95     -0.46        48.68
# 532        0.03    0.02      0.01        48.85
# 420        0.15    0.10      0.05        49.11
# 652        0.01    0.02     -0.01        50.15
# 432        0.48    0.32      0.16        50.35
# 559        0.19    0.38     -0.19        50.55
# 29         0.01    0.02     -0.01        50.59
# 675        0.03    0.02      0.01        50.69
# 269        0.03    0.02      0.01        50.78
# 202        0.96    0.63      0.32        50.81
# 489        0.06    0.04      0.02        50.84
# 324        0.48    0.99     -0.50        50.91
# 257        0.02    0.03     -0.02        51.33
# 354        0.03    0.02      0.01        51.37
# 118        0.49    0.32      0.17        51.63
# 508        0.01    0.02     -0.01        51.85
# 265        0.03    0.02      0.01        52.27
# 568        0.03    0.02      0.01        52.46
# 398        0.49    0.32      0.17        52.56
# 593        0.47    0.99     -0.52        52.76
# 533        0.02    0.04     -0.02        52.86
# 566        0.49    0.32      0.17        52.87
# 524        0.01    0.02     -0.01        52.89
# 47         0.23    0.49     -0.26        53.23
# 253        0.49    0.32      0.17        53.50
# 81         0.03    0.02      0.01        54.09
# 232        0.01    0.02     -0.01        54.16
# 234        0.04    0.03      0.02        54.22
# 317        0.02    0.05     -0.03        54.34
# 637        0.04    0.02      0.01        54.40
# 340        0.03    0.02      0.01        54.44
# 190        0.32    0.70     -0.38        54.78
# 142        0.03    0.07     -0.04        55.42
# 488        0.04    0.02      0.01        55.86
# 212        0.35    0.80     -0.45        55.97
# 313        0.04    0.02      0.01        56.22
# 7          0.39    0.25      0.14        56.82
# 589        0.10    0.24     -0.14        57.27
# 650        0.04    0.02      0.01        57.66
# 450        0.10    0.24     -0.14        57.84
# 211        0.01    0.02     -0.01        57.92
# 404        0.32    0.77     -0.45        58.13
# 648        0.30    0.19      0.11        58.26
# 332        0.05    0.03      0.02        59.80
# 309        0.01    0.02     -0.01        60.67
# 584        0.25    0.67     -0.42        62.14
# 73         0.01    0.02     -0.01        62.20
# 610        0.02    0.05     -0.03        62.29
# 519        0.14    0.38     -0.24        62.77
# 627        0.01    0.03     -0.02        63.21
# 361        0.04    0.02      0.01        63.48
# 370        0.49    0.30      0.19        63.58
# 20         0.01    0.03     -0.02        63.58
# 302        0.01    0.02     -0.01        63.87
# 25         0.04    0.02      0.01        64.98
# 348        0.01    0.03     -0.02        65.08
# 83         0.32    0.92     -0.60        65.24
# 606        0.04    0.02      0.02        65.57
# 342        0.04    0.02      0.01        65.63
# 328        0.01    0.02     -0.01        65.94
# 362        0.01    0.02     -0.01        65.96
# 101        0.49    0.29      0.19        66.87
# 573        0.01    0.04     -0.02        67.22
# 159        0.32    0.98     -0.66        67.34
# 672        0.04    0.02      0.02        67.37
# 327        0.05    0.03      0.02        69.02
# 166        0.04    0.02      0.02        69.14
# 204        0.37    0.22      0.15        70.17
# 638        0.04    0.02      0.02        70.36
# 97         0.05    0.18     -0.13        70.45
# 397        0.01    0.04     -0.03        71.12
# 136        0.01    0.02     -0.02        71.91
# 252        0.04    0.02      0.02        72.56
# 23         0.01    0.02     -0.02        72.71
# 525        0.01    0.04     -0.03        72.94
# 545        0.49    0.28      0.21        74.67
# 495        0.01    0.01      0.01        74.71
# 591        0.05    0.22     -0.16        75.21
# 154        0.49    0.28      0.21        76.32
# 255        0.04    0.02      0.02        76.81
# 483        0.04    0.02      0.02        77.10
# 215        0.04    0.02      0.02        77.41
# 630        0.04    0.02      0.02        77.95
# 463        0.49    0.27      0.21        78.42
# 276        0.04    0.20     -0.16        78.64
# 636        0.02    0.08     -0.06        78.89
# 374        0.01    0.06     -0.04        79.53
# 622        0.01    0.03     -0.02        80.52
# 419        0.49    0.27      0.22        80.58
# 191        0.00    0.02     -0.02        80.72
# 479        0.18    0.98     -0.80        81.73
# 52         0.01    0.03     -0.03        83.14
# 168        0.49    0.26      0.22        84.14
# 172        0.02    0.01      0.01        84.30
# 543        0.43    0.23      0.20        85.06
# 48         0.00    0.02     -0.02        85.69
# 346        0.04    0.30     -0.26        85.76
# 551        0.01    0.04     -0.03        85.88
# 617        0.02    0.14     -0.12        86.48
# 131        0.04    0.02      0.02        86.84
# 523        0.07    0.03      0.03        87.30
# 264        0.00    0.02     -0.02        87.32
# 671        0.00    0.02     -0.02        87.63
# 28         0.04    0.02      0.02        87.78
# 530        0.49    0.26      0.23        88.79
# 37         0.04    0.02      0.02        89.08
# 300        0.04    0.02      0.02        89.20
# 467        0.09    0.05      0.04        90.12
# 266        0.04    0.02      0.02        90.98
# 2          0.03    0.39     -0.36        91.37
# 304        0.06    0.71     -0.65        91.83
# 428        0.08    0.04      0.04        92.09
# 575        0.04    0.02      0.02        92.15
# 448        0.49    0.25      0.23        92.19
# 403        0.49    0.25      0.23        92.69
# 14         0.03    0.35     -0.33        92.82
# 437        0.04    0.02      0.02        92.93
# 674        0.04    0.02      0.02        93.56
# 639        0.22    0.12      0.11        93.62
# 511        0.88    0.45      0.43        93.77
# 182        0.01    0.22     -0.20        93.80
# 325        0.05    0.84     -0.79        93.83
# 139        0.00    0.02     -0.02        94.96
# 621        0.79    0.40      0.39        95.32
# 6          0.00    0.02     -0.02        96.36
# 278        0.00    0.02     -0.02        97.04
# 72         0.04    0.02      0.02        98.56
# 24         0.05    0.02      0.02        99.93
# 351        0.01    0.01      0.01       100.01
# 382        0.03    0.01      0.01       100.30
# 334        0.09    0.04      0.04       100.40
# 141        0.04    0.02      0.02       101.11
# 41         0.05    0.02      0.02       103.36
# 174        0.05    0.02      0.02       103.60
# 275       -0.00    0.02     -0.02       107.64
# 71         0.49    0.23      0.25       108.26
# 194       -0.00    0.02     -0.02       109.04
# 199        0.05    0.02      0.03       112.24
# 5          0.05    0.02      0.03       113.15
# 657        0.06    0.03      0.03       114.79
# 544        0.06    0.03      0.03       115.16
# 440        0.05    0.02      0.03       120.94
# 84         0.54    0.25      0.30       121.43
# 70         0.06    0.03      0.03       122.08
# 279        0.05    0.02      0.03       122.86
# 10         0.49    0.22      0.27       123.86
# 42         0.05    0.02      0.03       125.06
# 529        0.05    0.02      0.03       125.17
# 381        0.05    0.02      0.03       125.74
# 433        0.05    0.02      0.03       125.98
# 62         0.06    0.02      0.03       128.31
# 226        0.05    0.02      0.03       130.02
# 76         0.05    0.02      0.03       130.54
# 307        0.23    0.10      0.13       136.30
# 446       -0.01    0.02     -0.03       137.20
# 338        0.49    0.20      0.28       138.14
# 555        0.49    0.20      0.28       141.21
# 216        0.07    0.03      0.04       143.68
# 515        0.06    0.02      0.03       144.96
# 239        0.49    0.20      0.29       145.17
# 326        0.05    0.02      0.03       145.29
# 295        0.11    0.04      0.07       147.69
# 341        0.49    0.19      0.29       150.09
# 368        0.05    0.02      0.03       150.56
# 528        0.04    0.02      0.03       154.34
# 271        0.20    0.08      0.12       158.28
# 297       -0.01    0.02     -0.02       158.61
# 673        0.49    0.19      0.30       158.75
# 592        0.06    0.02      0.03       158.82
# 256        0.04    0.01      0.02       167.12
# 244        0.49    0.18      0.31       172.93
# 183        0.49    0.18      0.31       174.94
# 60         0.49    0.18      0.31       176.98
# 100        0.08    0.03      0.05       178.30
# 561        0.12    0.04      0.08       180.02
# 493        0.49    0.17      0.31       180.09
# 152        0.03    0.01      0.02       180.41
# 438        0.04    0.01      0.02       181.48
# 376        0.06    0.02      0.04       181.82
# 429        0.49    0.17      0.31       183.28
# 40         0.05    0.02      0.03       185.85
# 286       -0.01    0.01     -0.02       186.53
# 103        0.09    0.03      0.06       186.60
# 614        0.08    0.03      0.05       187.52
# 393        0.07    0.02      0.04       187.83
# 69         0.04    0.01      0.03       189.74
# 263        0.10    0.04      0.07       190.44
# 301        0.04    0.02      0.03       191.42
# 330        0.49    0.17      0.32       193.29
# 605        0.06    0.02      0.04       196.42
# 603        0.04    0.01      0.02       198.83
# 498        0.13    0.04      0.08       206.63
# 227        0.03    0.01      0.02       208.45
# 250        0.09    0.03      0.06       209.39
# 17         0.10    0.03      0.07       215.11
# 105        0.07    0.02      0.05       217.15
# 367        0.02    0.01      0.02       222.74
# 247        0.07    0.02      0.05       226.18
# 207        0.05    0.02      0.04       231.29
# 475        0.07    0.02      0.05       232.57
# 82         0.20    0.06      0.14       236.51
# 408        0.29    0.09      0.21       237.10
# 93         0.08    0.02      0.06       241.53
# 625        0.05    0.01      0.04       249.81
# 208        0.04    0.01      0.03       253.55
# 231        0.49    0.14      0.35       256.21
# 531        0.49    0.14      0.35       257.92
# 477        0.49    0.13      0.35       261.38
# 505        0.04    0.01      0.03       262.09
# 522        0.07    0.02      0.05       264.11
# 576        0.49    0.13      0.36       275.93
# 552        0.04    0.01      0.03       279.40
# 468        0.49    0.13      0.36       281.69
# 387        0.20    0.05      0.14       282.12
# 30         0.05    0.01      0.03       282.98
# 506        0.02    0.01      0.01       286.91
# 355        0.04    0.01      0.03       289.27
# 85         0.09    0.02      0.07       290.31
# 564        0.03    0.01      0.02       292.23
# 225        0.16    0.04      0.12       296.85
# 439        0.08    0.02      0.06       307.30
# 580        0.09    0.02      0.07       310.72
# 281        0.03    0.01      0.03       311.69
# 350        0.05    0.01      0.04       321.36
# 126        0.03    0.01      0.03       321.66
# 418        0.03    0.01      0.03       321.83
# 542        0.03    0.01      0.03       322.03
# 410        0.18    0.04      0.14       339.10
# 299        0.49    0.11      0.38       340.16
# 357        0.04    0.01      0.03       341.76
# 157        0.09    0.02      0.07       342.64
# 92         0.04    0.01      0.03       344.62
# 628        0.17    0.04      0.13       351.68
# 111        0.04    0.01      0.03       367.65
# 401        0.04    0.01      0.03       379.33
# 189        0.34    0.07      0.27       379.66
# 129        0.49    0.10      0.38       379.72
# 15         0.04    0.01      0.03       388.01
# 333        0.49    0.10      0.39       389.15
# 96         0.12    0.02      0.09       389.62
# 513        0.04    0.01      0.03       390.78
# 218        0.49    0.10      0.39       405.70
# 358        0.04    0.01      0.03       415.61
# 274        0.05    0.01      0.04       450.71
# 547        0.05    0.01      0.04       453.71
# 79         0.05    0.01      0.04       461.67
# 134        0.06    0.01      0.05       464.05
# 400        0.04    0.01      0.03       481.71
# 110        0.30    0.05      0.25       499.80
# 343        0.14    0.02      0.12       509.31
# 485        0.04    0.01      0.04       509.88
# 19         0.05    0.01      0.04       510.20
# 581        0.14    0.02      0.12       526.89
# 436        0.33    0.05      0.28       579.24
# 8          0.06    0.01      0.05       582.66
# 480        0.10    0.01      0.09       595.70
# 123        0.22    0.03      0.19       600.18
# 146        0.49    0.07      0.42       627.19
# 512        0.11    0.01      0.09       635.01
# 406        0.06    0.01      0.05       636.12
# 329        0.06    0.01      0.05       638.65
# 642        0.27    0.03      0.24       701.57
# 415        0.49    0.06      0.43       723.36
# 390        0.12    0.01      0.11       806.50
# 629        0.07    0.01      0.06       822.70
# 616        0.21    0.02      0.19       871.60
# 45         0.49    0.05      0.44       899.61
# 241        0.23    0.02      0.21       915.47
# 127        0.73    0.07      0.66       934.08
# 296        0.22    0.02      0.20       952.02
# 359        0.49    0.05      0.44       956.13
# 416        0.17    0.02      0.15       978.01
# 122        0.11    0.01      0.10       994.96
# 378        0.49    0.04      0.44      1002.91
# 458        0.09    0.01      0.08      1005.21
# 337        0.26    0.02      0.24      1010.61
# 417        0.21    0.02      0.19      1094.70
# 375        0.38    0.03      0.35      1103.77
# 49         0.11    0.01      0.10      1190.92
# 386        0.49    0.04      0.45      1216.71
# 137        0.24    0.02      0.22      1280.02
# 447        0.17    0.01      0.15      1367.61
# 655        0.49    0.03      0.45      1402.01
# 507        0.69    0.04      0.65      1464.17
# 454        0.74    0.05      0.70      1470.67
# 596        0.13    0.01      0.13      1525.48
# 298        0.48    0.02      0.46      1864.84
# 455        0.26    0.01      0.26      3107.72
# 203        0.38    0.01      0.37      4536.42
# 344        0.71    0.01      0.70      8522.95

# %% [markdown]
# # Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_hat_test)
print('R2 (testing) = {}'.format(r2_test))
# Out:
# R2 (testing) = 0.770674499327363

# %%
print(np.sqrt(mean_squared_error(y_test,y_hat_test)))
# Out:
# 0.1734028530024294
