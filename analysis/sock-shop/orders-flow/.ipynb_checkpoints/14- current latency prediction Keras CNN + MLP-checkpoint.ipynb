# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from keras.models import Sequential
from keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from keras.callbacks import EarlyStopping , ReduceLROnPlateau , ModelCheckpoint
from keras.models import load_model
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.2f}'.format

import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
epochs=600
batch_size=1000

learning_rate = 1e-3
decay = learning_rate / epochs

patience=80

test_split = 0.1
validation_split = 0.2

select_features=True

SCALE_TARGET = True
SCALE_FEATURES = True

RUN_MODEL = True

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'
models_dir = home_dir + "/models/"

data_file = 'orders_flow_data.csv'   # raw data as is
#data_file = 'order_flow_cleanup_data.csv'
#data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, True)
data = data.reset_index(drop=True)
data.head(5)
# Out:
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0               0.03            0.01               0.01          0.01
# 1               0.06            0.02               0.02          0.02
# 2               0.07            0.03               0.02          0.03
# 3               0.07            0.03               0.02          0.02
# 4               0.07            0.02               0.01          0.02
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0             0.01              0.01             0.01           0.03
# 1             0.02              0.01             0.01           0.18
# 2             0.02              0.01             0.01           0.44
# 3             0.02              0.01             0.01           0.23
# 4             0.02              0.01             0.01           0.24
#
#    carts-db_cpu_use  front-end_pods  orders_pods  user_pods  shipping_pods  \
# 0              0.07            1.00         1.00       1.00           1.00
# 1              0.18            1.00         1.00       1.00           1.00
# 2              0.20            1.00         1.00       1.00           1.00
# 3              0.17            1.00         1.00       1.00           1.00
# 4              0.14            1.00         1.00       1.00           1.00
#
#    payment_pods  carts_pods  nodes_cpu_use  orders_req  orders_ltcy
# 0          1.00        1.00           2.50        0.15         0.24
# 1          1.00        1.00           1.89        0.15         0.24
# 2          1.00        1.00           1.35        0.15         0.24
# 3          1.00        1.00           1.26        0.13         0.24
# 4          1.00        1.00           1.28        0.36         0.24

# %%
data.shape
# Out:
# (6766, 18)

# %% [markdown]
# # clear noice from outliers

# %%
df = data

# %%
df.describe(include="all")
# Out:
#        front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# count           6,766.00        6,766.00           6,766.00      6,766.00
# mean                0.83            0.21               0.02          0.20
# std                 0.62            0.13               0.00          0.13
# min                 0.01            0.01               0.01          0.01
# 25%                 0.19            0.08               0.02          0.05
# 50%                 0.84            0.22               0.02          0.20
# 75%                 1.29            0.30               0.02          0.30
# max                 2.73            0.91               0.04          0.64
#
#        user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# count         6,766.00          6,766.00         6,766.00       6,766.00
# mean              0.12              0.05             0.03           0.53
# std               0.08              0.04             0.01           0.58
# min               0.01              0.01             0.01           0.03
# 25%               0.03              0.04             0.02           0.12
# 50%               0.12              0.05             0.03           0.32
# 75%               0.18              0.06             0.04           0.58
# max               0.34              0.63             0.10           2.53
#
#        carts-db_cpu_use  front-end_pods  orders_pods  user_pods  \
# count          6,766.00        6,766.00     6,766.00   6,766.00
# mean               1.83            2.76         2.76       2.76
# std                1.99            1.10         1.09       1.09
# min                0.01            0.50         1.00       1.00
# 25%                0.02            2.00         2.00       2.00
# 50%                1.15            3.00         3.00       3.00
# 75%                3.28            4.00         4.00       4.00
# max                6.58            4.00         4.00       4.00
#
#        shipping_pods  payment_pods  carts_pods  nodes_cpu_use  orders_req  \
# count       6,766.00      6,766.00    6,766.00       6,766.00    6,766.00
# mean            2.76          2.76        2.76           4.10        5.03
# std             1.09          1.09        1.09           2.08        4.20
# min             1.00          1.00        1.00           1.10        0.00
# 25%             2.00          2.00        2.00           1.92        0.49
# 50%             3.00          3.00        3.00           4.21        5.14
# 75%             4.00          4.00        4.00           5.78        8.20
# max             4.00          4.00        4.00           9.66       20.13
#
#        orders_ltcy
# count     6,766.00
# mean          2.97
# std           3.51
# min           0.02
# 25%           0.24
# 50%           0.49
# 75%           5.81
# max           9.75

# %%
df = data
print('shape before {}'.format(df.shape))
if 1 == 1:
    minq = df['orders_ltcy'].quantile(0.3)
    maxq = df['orders_ltcy'].quantile(0.99)
    print('latency quantiles min {} max {}'.format(maxq, minq))
    df = df[df['orders_ltcy'] > minq]
    df = df[df['orders_ltcy'] < maxq]
    sns.distplot(df['orders_ltcy'])
print('shape after {}'.format(df.shape))
# Out:
# shape before (6766, 18)
# latency quantiles min 9.65 max 0.24
# shape after (4233, 18)

# %%
data = df
data.shape
# Out:
# (4233, 18)

# %% [markdown]
# # Shuffle the data

# %%
# shuffle the data
from sklearn.utils import shuffle
data = shuffle(data, random_state=365)
print('shape {}'.format(data.shape))
data.head(5)
# Out:
# shape (4233, 18)
#       front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 6357               1.34            0.24               0.03          0.26
# 6688               2.26            0.44               0.02          0.55
# 5171               0.04            0.05               0.02          0.04
# 555                0.88            0.26               0.03          0.26
# 674                0.83            0.23               0.01          0.23
#
#       user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 6357             0.20              0.08             0.04           0.38
# 6688             0.27              0.05             0.04           2.03
# 5171             0.02              0.05             0.04           0.05
# 555              0.21              0.05             0.02           0.42
# 674              0.17              0.02             0.01           0.35
#
#       carts-db_cpu_use  front-end_pods  orders_pods  user_pods  shipping_pods  \
# 6357              5.77            4.00         4.00       4.00           4.00
# 6688              0.34            4.00         4.00       4.00           4.00
# 5171              0.02            4.00         4.00       4.00           4.00
# 555               5.73            1.00         1.00       1.00           1.00
# 674               0.21            1.00         1.00       1.00           1.00
#
#       payment_pods  carts_pods  nodes_cpu_use  orders_req  orders_ltcy
# 6357          4.00        4.00           7.59        6.62         7.06
# 6688          4.00        4.00           5.80       12.33         7.55
# 5171          4.00        4.00           1.36        0.00         4.00
# 555           1.00        1.00           6.92        8.96         2.09
# 674           1.00        1.00           3.64        7.02         8.86

# %%
x_data = data.drop(['orders_ltcy'], axis=1)
x_data = x_data.values
print("Shape x_data: ", x_data.shape)
print("type x_data: ", type(x_data))

y_data = data['orders_ltcy'].values
y_data = y_data.reshape(-1,1)

print("Shape y_data: ", y_data.shape)
print("type y_data: ", type(y_data))

num_data = len(x_data)
print("There are {} sample data".format(num_data))
# Out:
# Shape x_data:  (4233, 17)
# type x_data:  <class 'numpy.ndarray'>
# Shape y_data:  (4233, 1)
# type y_data:  <class 'numpy.ndarray'>
# There are 4233 sample data

# %% [markdown]
# # Scale Target

# %%
if SCALE_TARGET:
    y_scaler =  MinMaxScaler() # StandardScaler() or MinMaxScaler()
    y_data = y_scaler.fit_transform(y_data)

# %%
pd.DataFrame(y_data).describe(include="all")
# Out:
#              0
# count 4,233.00
# mean      0.45
# std       0.37
# min       0.00
# 25%       0.05
# 50%       0.41
# 75%       0.86
# max       1.00

# %%
 sns.distplot(y_data)

# %%
x_dataset = np.expand_dims(x_data, axis=2)
n_depth = x_dataset.shape[1]
n_width = x_dataset.shape[2]
x_dataset.shape
# Out:
# (4233, 17, 1)

# %%
y_dataset = y_data.reshape(y_data.shape[0])
n_targets = y_data.shape[1]
y_dataset.shape
# Out:
# (4233,)

# %%
print('Experiment has {} number of features and {} number of target(s)'.format(n_depth,n_targets))
# Out:
# Experiment has 17 number of features and 1 number of target(s)

# %%
validate_split = 0.1
test_split = 0.1
train_split = 1 - (test_split + validate_split)

num_data = len(x_dataset)

num_test = int(test_split * num_data)
num_validate = int(validate_split * num_data)
num_train = num_data - (num_test + num_validate)
print('Data splitted to training {} , validation {} and testing {}'.format(num_train, num_validate, num_test))
# Out:
# Data splitted to training 3387 , validation 423 and testing 423

# %%
x_train = x_dataset[:num_train]
x_validate = x_dataset[num_train:num_train+num_validate]
x_test = x_dataset[num_train+num_validate:]

print("x_train {} , x_validate {} , x_test {}".format(x_train.shape, x_validate.shape, x_test.shape))

len(x_train) + len(x_validate) + len(x_test)
# Out:
# x_train (3387, 17, 1) , x_validate (423, 17, 1) , x_test (423, 17, 1)
# 4233

# %%
y_train = y_dataset[:num_train]
y_validate = y_dataset[num_train:num_train+num_validate]
y_test = y_dataset[num_train+num_validate:]

print("y_train {} , y_validate {} , y_test {}".format(y_train.shape, y_validate.shape, y_test.shape))

len(y_train) + len(y_validate) + len(y_test)
# Out:
# y_train (3387,) , y_validate (423,) , y_test (423,)
# 4233

# %% [markdown]
# # Scaling Features

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

if SCALE_FEATURES:
    x_scaler = StandardScaler()  # StandardScaler() or MinMaxScaler()
    
    dim_z, dim_x, dim_y = x_train.shape[0], x_train.shape[1], x_train.shape[2]
    x_train = x_train.reshape(dim_z, dim_x)    
    x_train = x_scaler.fit_transform(x_train)
    x_train = x_train.reshape(dim_z, dim_x, dim_y)
    
    dim_z, dim_x, dim_y = x_test.shape[0], x_test.shape[1], x_test.shape[2]
    x_test = x_test.reshape(dim_z, dim_x)    
    x_test = x_scaler.transform(x_test)
    x_test = x_test.reshape(dim_z, dim_x, dim_y)

# %%
print('y_test shape {}'.format(y_test.shape))
y_test[0:10]
# Out:
# y_test shape (423,)
# array([0.22394529, 0.54738018, 0.7428731 , 0.78197168, 0.04583972,
#        0.01635864, 0.46453289, 0.00464862, 0.013165  , 0.93399809])

# %%
# data batch generator
def batch_generator(batch_size, sequence_length=n_depth, n_features=n_width):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, n_features)
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        #y_shape = (batch_size, sequence_length, num_y_signals)
        #y_batch = np.zeros(shape=y_shape, dtype=np.float16)
        y_batch = []

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(num_train - sequence_length)
            
            # Copy the sequences of data starting at this index.
            x_batch[i] = x_train[idx]
            y_batch.append(y_train[idx])
        
        yield (x_batch, np.array(y_batch))

# %%
generator = batch_generator(batch_size)

# %%
# test the batch generator
if 1 == 1:
    x_batch, y_batch = next(generator)
    print(x_batch.shape)
    print(y_batch.shape)
# Out:
# (1000, 17, 1)
# (1000,)

# %%
# test and validate tuples
test_data = (x_test, y_test)
validate_data = (x_validate, y_validate)

# %% [markdown]
# # Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling1D
from keras.optimizers import RMSprop, Adam
from keras import models
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau

# %%
# 1-D CONV CNN for feature recognition
model = Sequential()
model.add(Conv1D(filters=4, kernel_size=2, kernel_initializer='normal', activation='relu', input_shape=(n_depth,n_width)))
model.add(Conv1D(filters=4, kernel_size=2, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(11, kernel_initializer='normal', activation='relu'))
model.add(Dense(8, kernel_initializer='normal', activation='relu'))
model.add(Dense(4, kernel_initializer='normal', activation='relu'))
model.add(Dense(n_targets, kernel_initializer='normal', activation='linear'))

adam = Adam(lr=learning_rate, decay=decay)
# or loss= 'mean_absolute_percentage_error'
model.compile(loss='mean_squared_error', optimizer=adam, metrics=['mse'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_192 (Conv1D)          (None, 16, 4)             12
# _________________________________________________________________
# conv1d_193 (Conv1D)          (None, 15, 4)             36
# _________________________________________________________________
# dropout_101 (Dropout)        (None, 15, 4)             0
# _________________________________________________________________
# max_pooling1d_101 (MaxPoolin (None, 7, 4)              0
# _________________________________________________________________
# flatten_98 (Flatten)         (None, 28)                0
# _________________________________________________________________
# dense_380 (Dense)            (None, 11)                319
# _________________________________________________________________
# dense_381 (Dense)            (None, 8)                 96
# _________________________________________________________________
# dense_382 (Dense)            (None, 4)                 36
# _________________________________________________________________
# dense_383 (Dense)            (None, 1)                 5
# =================================================================
# Total params: 504
# Trainable params: 504
# Non-trainable params: 0
# _________________________________________________________________

# %%
# call backs
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=patience)

# save the best model only
path_model = models_dir + 'best_mlp_model.h5'
mc = ModelCheckpoint(path_model
                     , monitor='val_loss'
                     , mode='min' 
                     , verbose=1
                     #, save_weights_only=True
                     , save_best_only=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.1,
                                       min_lr=1e-4,
                                       patience=0,
                                       verbose=1)

callbacks = [es, mc, reduce_lr]

# %%
# %%time
steps_per_epoch = math.ceil(num_train / batch_size)   # = total number of training data points divided by the batch size
print('steps_per_epoch {}'.format(steps_per_epoch))

if RUN_MODEL:
    history = model.fit_generator(generator=generator, epochs=epochs
                                  , steps_per_epoch=steps_per_epoch
                                  , validation_data=validate_data
                                  , callbacks=callbacks, verbose=1, shuffle=False)
    #history = model.fit(x_train, y_train, epochs=epochs
                        #, verbose=1,callbacks=callbacks,shuffle=True,validation_data=validate_data)
# Out:
# steps_per_epoch 4
# Epoch 1/600
# 4/4 [==============================] - 17s 4s/step - loss: 0.3424 - mean_squared_error: 0.3424 - val_loss: 0.3467 - val_mean_squared_error: 0.3467
#
# Epoch 00001: val_loss improved from inf to 0.34671, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 2/600
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3408 - mean_squared_error: 0.3408 - val_loss: 0.3431 - val_mean_squared_error: 0.3431
#
# Epoch 00002: val_loss improved from 0.34671 to 0.34311, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 3/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.3324 - mean_squared_error: 0.3324 - val_loss: 0.3395 - val_mean_squared_error: 0.3395
#
# Epoch 00003: val_loss improved from 0.34311 to 0.33953, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 4/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.3335 - mean_squared_error: 0.3335 - val_loss: 0.3360 - val_mean_squared_error: 0.3360
#
# Epoch 00004: val_loss improved from 0.33953 to 0.33598, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 5/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.3317 - mean_squared_error: 0.3317 - val_loss: 0.3325 - val_mean_squared_error: 0.3325
#
# Epoch 00005: val_loss improved from 0.33598 to 0.33248, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 6/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3266 - mean_squared_error: 0.3266 - val_loss: 0.3290 - val_mean_squared_error: 0.3290
#
# Epoch 00006: val_loss improved from 0.33248 to 0.32901, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 7/600
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3236 - mean_squared_error: 0.3236 - val_loss: 0.3256 - val_mean_squared_error: 0.3256
#
# Epoch 00007: val_loss improved from 0.32901 to 0.32558, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 8/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.3114 - mean_squared_error: 0.3114 - val_loss: 0.3222 - val_mean_squared_error: 0.3222
#
# Epoch 00008: val_loss improved from 0.32558 to 0.32220, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 9/600
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3118 - mean_squared_error: 0.3118 - val_loss: 0.3189 - val_mean_squared_error: 0.3189
#
# Epoch 00009: val_loss improved from 0.32220 to 0.31886, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 10/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.3143 - mean_squared_error: 0.3143 - val_loss: 0.3156 - val_mean_squared_error: 0.3156
#
# Epoch 00010: val_loss improved from 0.31886 to 0.31556, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 11/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3099 - mean_squared_error: 0.3099 - val_loss: 0.3123 - val_mean_squared_error: 0.3123
#
# Epoch 00011: val_loss improved from 0.31556 to 0.31231, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 12/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.3068 - mean_squared_error: 0.3068 - val_loss: 0.3091 - val_mean_squared_error: 0.3091
#
# Epoch 00012: val_loss improved from 0.31231 to 0.30912, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 13/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3021 - mean_squared_error: 0.3021 - val_loss: 0.3060 - val_mean_squared_error: 0.3060
#
# Epoch 00013: val_loss improved from 0.30912 to 0.30596, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 14/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2987 - mean_squared_error: 0.2987 - val_loss: 0.3029 - val_mean_squared_error: 0.3029
#
# Epoch 00014: val_loss improved from 0.30596 to 0.30285, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 15/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2939 - mean_squared_error: 0.2939 - val_loss: 0.2998 - val_mean_squared_error: 0.2998
#
# Epoch 00015: val_loss improved from 0.30285 to 0.29980, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 16/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.3059 - mean_squared_error: 0.3059 - val_loss: 0.2968 - val_mean_squared_error: 0.2968
#
# Epoch 00016: val_loss improved from 0.29980 to 0.29677, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 17/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2855 - mean_squared_error: 0.2855 - val_loss: 0.2938 - val_mean_squared_error: 0.2938
#
# Epoch 00017: val_loss improved from 0.29677 to 0.29377, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 18/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2846 - mean_squared_error: 0.2846 - val_loss: 0.2908 - val_mean_squared_error: 0.2908
#
# Epoch 00018: val_loss improved from 0.29377 to 0.29085, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 19/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2826 - mean_squared_error: 0.2826 - val_loss: 0.2880 - val_mean_squared_error: 0.2880
#
# Epoch 00019: val_loss improved from 0.29085 to 0.28797, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 20/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2848 - mean_squared_error: 0.2848 - val_loss: 0.2851 - val_mean_squared_error: 0.2851
#
# Epoch 00020: val_loss improved from 0.28797 to 0.28512, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 21/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.2753 - mean_squared_error: 0.2753 - val_loss: 0.2823 - val_mean_squared_error: 0.2823
#
# Epoch 00021: val_loss improved from 0.28512 to 0.28233, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 22/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2714 - mean_squared_error: 0.2714 - val_loss: 0.2796 - val_mean_squared_error: 0.2796
#
# Epoch 00022: val_loss improved from 0.28233 to 0.27958, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 23/600
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2767 - mean_squared_error: 0.2767 - val_loss: 0.2769 - val_mean_squared_error: 0.2769
#
# Epoch 00023: val_loss improved from 0.27958 to 0.27686, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 24/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2748 - mean_squared_error: 0.2748 - val_loss: 0.2742 - val_mean_squared_error: 0.2742
#
# Epoch 00024: val_loss improved from 0.27686 to 0.27417, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 25/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2684 - mean_squared_error: 0.2684 - val_loss: 0.2715 - val_mean_squared_error: 0.2715
#
# Epoch 00025: val_loss improved from 0.27417 to 0.27152, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 26/600
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2613 - mean_squared_error: 0.2613 - val_loss: 0.2689 - val_mean_squared_error: 0.2689
#
# Epoch 00026: val_loss improved from 0.27152 to 0.26892, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 27/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.2654 - mean_squared_error: 0.2654 - val_loss: 0.2663 - val_mean_squared_error: 0.2663
#
# Epoch 00027: val_loss improved from 0.26892 to 0.26635, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 28/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2641 - mean_squared_error: 0.2641 - val_loss: 0.2638 - val_mean_squared_error: 0.2638
#
# Epoch 00028: val_loss improved from 0.26635 to 0.26382, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 29/600
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2609 - mean_squared_error: 0.2609 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
#
# Epoch 00029: val_loss improved from 0.26382 to 0.26131, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 30/600
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2552 - mean_squared_error: 0.2552 - val_loss: 0.2589 - val_mean_squared_error: 0.2589
#
# Epoch 00030: val_loss improved from 0.26131 to 0.25886, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 31/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2563 - mean_squared_error: 0.2563 - val_loss: 0.2564 - val_mean_squared_error: 0.2564
#
# Epoch 00031: val_loss improved from 0.25886 to 0.25645, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 32/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2482 - mean_squared_error: 0.2482 - val_loss: 0.2541 - val_mean_squared_error: 0.2541
#
# Epoch 00032: val_loss improved from 0.25645 to 0.25408, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 33/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2447 - mean_squared_error: 0.2447 - val_loss: 0.2518 - val_mean_squared_error: 0.2518
#
# Epoch 00033: val_loss improved from 0.25408 to 0.25176, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 34/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.2448 - mean_squared_error: 0.2448 - val_loss: 0.2495 - val_mean_squared_error: 0.2495
#
# Epoch 00034: val_loss improved from 0.25176 to 0.24948, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 35/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2531 - mean_squared_error: 0.2531 - val_loss: 0.2472 - val_mean_squared_error: 0.2472
#
# Epoch 00035: val_loss improved from 0.24948 to 0.24721, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 36/600
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2376 - mean_squared_error: 0.2376 - val_loss: 0.2450 - val_mean_squared_error: 0.2450
#
# Epoch 00036: val_loss improved from 0.24721 to 0.24498, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 37/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2377 - mean_squared_error: 0.2377 - val_loss: 0.2428 - val_mean_squared_error: 0.2428
#
# Epoch 00037: val_loss improved from 0.24498 to 0.24281, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 38/600
# 4/4 [==============================] - 0s 47ms/step - loss: 0.2312 - mean_squared_error: 0.2312 - val_loss: 0.2407 - val_mean_squared_error: 0.2407
#
# Epoch 00038: val_loss improved from 0.24281 to 0.24068, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 39/600
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2415 - mean_squared_error: 0.2415 - val_loss: 0.2386 - val_mean_squared_error: 0.2386
#
# Epoch 00039: val_loss improved from 0.24068 to 0.23857, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 40/600
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2307 - mean_squared_error: 0.2307 - val_loss: 0.2365 - val_mean_squared_error: 0.2365
#
# Epoch 00040: val_loss improved from 0.23857 to 0.23650, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 41/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.2413 - mean_squared_error: 0.2413 - val_loss: 0.2344 - val_mean_squared_error: 0.2344
#
# Epoch 00041: val_loss improved from 0.23650 to 0.23445, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 42/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.2296 - mean_squared_error: 0.2296 - val_loss: 0.2324 - val_mean_squared_error: 0.2324
#
# Epoch 00042: val_loss improved from 0.23445 to 0.23242, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 43/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2286 - mean_squared_error: 0.2286 - val_loss: 0.2304 - val_mean_squared_error: 0.2304
#
# Epoch 00043: val_loss improved from 0.23242 to 0.23044, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 44/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2285 - val_mean_squared_error: 0.2285
#
# Epoch 00044: val_loss improved from 0.23044 to 0.22850, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 45/600
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2266 - val_mean_squared_error: 0.2266
#
# Epoch 00045: val_loss improved from 0.22850 to 0.22661, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 46/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2243 - mean_squared_error: 0.2243 - val_loss: 0.2247 - val_mean_squared_error: 0.2247
#
# Epoch 00046: val_loss improved from 0.22661 to 0.22474, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 47/600
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2188 - mean_squared_error: 0.2188 - val_loss: 0.2229 - val_mean_squared_error: 0.2229
#
# Epoch 00047: val_loss improved from 0.22474 to 0.22291, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 48/600
# 4/4 [==============================] - 0s 47ms/step - loss: 0.2161 - mean_squared_error: 0.2161 - val_loss: 0.2211 - val_mean_squared_error: 0.2211
#
# Epoch 00048: val_loss improved from 0.22291 to 0.22112, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 49/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.2132 - mean_squared_error: 0.2132 - val_loss: 0.2194 - val_mean_squared_error: 0.2194
#
# Epoch 00049: val_loss improved from 0.22112 to 0.21935, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 50/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2214 - mean_squared_error: 0.2214 - val_loss: 0.2176 - val_mean_squared_error: 0.2176
#
# Epoch 00050: val_loss improved from 0.21935 to 0.21761, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 51/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.2118 - mean_squared_error: 0.2118 - val_loss: 0.2159 - val_mean_squared_error: 0.2159
#
# Epoch 00051: val_loss improved from 0.21761 to 0.21589, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 52/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2071 - mean_squared_error: 0.2071 - val_loss: 0.2142 - val_mean_squared_error: 0.2142
#
# Epoch 00052: val_loss improved from 0.21589 to 0.21419, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 53/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2160 - mean_squared_error: 0.2160 - val_loss: 0.2125 - val_mean_squared_error: 0.2125
#
# Epoch 00053: val_loss improved from 0.21419 to 0.21252, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 54/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.2066 - mean_squared_error: 0.2066 - val_loss: 0.2109 - val_mean_squared_error: 0.2109
#
# Epoch 00054: val_loss improved from 0.21252 to 0.21087, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 55/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.2038 - mean_squared_error: 0.2038 - val_loss: 0.2093 - val_mean_squared_error: 0.2093
#
# Epoch 00055: val_loss improved from 0.21087 to 0.20927, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 56/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2075 - mean_squared_error: 0.2075 - val_loss: 0.2077 - val_mean_squared_error: 0.2077
#
# Epoch 00056: val_loss improved from 0.20927 to 0.20770, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 57/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.2080 - mean_squared_error: 0.2080 - val_loss: 0.2062 - val_mean_squared_error: 0.2062
#
# Epoch 00057: val_loss improved from 0.20770 to 0.20616, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 58/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2041 - mean_squared_error: 0.2041 - val_loss: 0.2046 - val_mean_squared_error: 0.2046
#
# Epoch 00058: val_loss improved from 0.20616 to 0.20463, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 59/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1922 - mean_squared_error: 0.1922 - val_loss: 0.2032 - val_mean_squared_error: 0.2032
#
# Epoch 00059: val_loss improved from 0.20463 to 0.20315, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 60/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1994 - mean_squared_error: 0.1994 - val_loss: 0.2017 - val_mean_squared_error: 0.2017
#
# Epoch 00060: val_loss improved from 0.20315 to 0.20171, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 61/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.2005 - mean_squared_error: 0.2005 - val_loss: 0.2003 - val_mean_squared_error: 0.2003
#
# Epoch 00061: val_loss improved from 0.20171 to 0.20028, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 62/600
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1924 - mean_squared_error: 0.1924 - val_loss: 0.1989 - val_mean_squared_error: 0.1989
#
# Epoch 00062: val_loss improved from 0.20028 to 0.19889, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 63/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1926 - mean_squared_error: 0.1926 - val_loss: 0.1975 - val_mean_squared_error: 0.1975
#
# Epoch 00063: val_loss improved from 0.19889 to 0.19753, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 64/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1959 - mean_squared_error: 0.1959 - val_loss: 0.1962 - val_mean_squared_error: 0.1962
#
# Epoch 00064: val_loss improved from 0.19753 to 0.19618, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 65/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1954 - mean_squared_error: 0.1954 - val_loss: 0.1948 - val_mean_squared_error: 0.1948
#
# Epoch 00065: val_loss improved from 0.19618 to 0.19484, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 66/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1895 - mean_squared_error: 0.1895 - val_loss: 0.1935 - val_mean_squared_error: 0.1935
#
# Epoch 00066: val_loss improved from 0.19484 to 0.19355, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 67/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1919 - mean_squared_error: 0.1919 - val_loss: 0.1923 - val_mean_squared_error: 0.1923
#
# Epoch 00067: val_loss improved from 0.19355 to 0.19228, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 68/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1820 - mean_squared_error: 0.1820 - val_loss: 0.1911 - val_mean_squared_error: 0.1911
#
# Epoch 00068: val_loss improved from 0.19228 to 0.19105, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 69/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1839 - mean_squared_error: 0.1839 - val_loss: 0.1898 - val_mean_squared_error: 0.1898
#
# Epoch 00069: val_loss improved from 0.19105 to 0.18985, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 70/600
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1836 - mean_squared_error: 0.1836 - val_loss: 0.1887 - val_mean_squared_error: 0.1887
#
# Epoch 00070: val_loss improved from 0.18985 to 0.18867, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 71/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1829 - mean_squared_error: 0.1829 - val_loss: 0.1875 - val_mean_squared_error: 0.1875
#
# Epoch 00071: val_loss improved from 0.18867 to 0.18752, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 72/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1868 - mean_squared_error: 0.1868 - val_loss: 0.1864 - val_mean_squared_error: 0.1864
#
# Epoch 00072: val_loss improved from 0.18752 to 0.18639, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 73/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1830 - mean_squared_error: 0.1830 - val_loss: 0.1853 - val_mean_squared_error: 0.1853
#
# Epoch 00073: val_loss improved from 0.18639 to 0.18527, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 74/600
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1790 - mean_squared_error: 0.1790 - val_loss: 0.1842 - val_mean_squared_error: 0.1842
#
# Epoch 00074: val_loss improved from 0.18527 to 0.18417, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 75/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1826 - mean_squared_error: 0.1826 - val_loss: 0.1831 - val_mean_squared_error: 0.1831
#
# Epoch 00075: val_loss improved from 0.18417 to 0.18309, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 76/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1764 - mean_squared_error: 0.1764 - val_loss: 0.1820 - val_mean_squared_error: 0.1820
#
# Epoch 00076: val_loss improved from 0.18309 to 0.18202, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 77/600
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1814 - mean_squared_error: 0.1814 - val_loss: 0.1810 - val_mean_squared_error: 0.1810
#
# Epoch 00077: val_loss improved from 0.18202 to 0.18098, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 78/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1768 - mean_squared_error: 0.1768 - val_loss: 0.1800 - val_mean_squared_error: 0.1800
#
# Epoch 00078: val_loss improved from 0.18098 to 0.17995, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 79/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1686 - mean_squared_error: 0.1686 - val_loss: 0.1790 - val_mean_squared_error: 0.1790
#
# Epoch 00079: val_loss improved from 0.17995 to 0.17896, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 80/600
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1770 - mean_squared_error: 0.1770 - val_loss: 0.1780 - val_mean_squared_error: 0.1780
#
# Epoch 00080: val_loss improved from 0.17896 to 0.17800, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 81/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1781 - mean_squared_error: 0.1781 - val_loss: 0.1770 - val_mean_squared_error: 0.1770
#
# Epoch 00081: val_loss improved from 0.17800 to 0.17703, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 82/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1761 - mean_squared_error: 0.1761 - val_loss: 0.1761 - val_mean_squared_error: 0.1761
#
# Epoch 00082: val_loss improved from 0.17703 to 0.17608, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 83/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1678 - mean_squared_error: 0.1678 - val_loss: 0.1752 - val_mean_squared_error: 0.1752
#
# Epoch 00083: val_loss improved from 0.17608 to 0.17515, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 84/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1709 - mean_squared_error: 0.1709 - val_loss: 0.1743 - val_mean_squared_error: 0.1743
#
# Epoch 00084: val_loss improved from 0.17515 to 0.17426, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 85/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1666 - mean_squared_error: 0.1666 - val_loss: 0.1734 - val_mean_squared_error: 0.1734
#
# Epoch 00085: val_loss improved from 0.17426 to 0.17339, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 86/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1640 - mean_squared_error: 0.1640 - val_loss: 0.1726 - val_mean_squared_error: 0.1726
#
# Epoch 00086: val_loss improved from 0.17339 to 0.17256, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 87/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1711 - mean_squared_error: 0.1711 - val_loss: 0.1717 - val_mean_squared_error: 0.1717
#
# Epoch 00087: val_loss improved from 0.17256 to 0.17174, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 88/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1676 - mean_squared_error: 0.1676 - val_loss: 0.1709 - val_mean_squared_error: 0.1709
#
# Epoch 00088: val_loss improved from 0.17174 to 0.17092, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 89/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1628 - mean_squared_error: 0.1628 - val_loss: 0.1701 - val_mean_squared_error: 0.1701
#
# Epoch 00089: val_loss improved from 0.17092 to 0.17014, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 90/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1698 - mean_squared_error: 0.1698 - val_loss: 0.1694 - val_mean_squared_error: 0.1694
#
# Epoch 00090: val_loss improved from 0.17014 to 0.16936, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 91/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1682 - mean_squared_error: 0.1682 - val_loss: 0.1686 - val_mean_squared_error: 0.1686
#
# Epoch 00091: val_loss improved from 0.16936 to 0.16860, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 92/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1682 - mean_squared_error: 0.1682 - val_loss: 0.1678 - val_mean_squared_error: 0.1678
#
# Epoch 00092: val_loss improved from 0.16860 to 0.16784, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 93/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1610 - mean_squared_error: 0.1610 - val_loss: 0.1671 - val_mean_squared_error: 0.1671
#
# Epoch 00093: val_loss improved from 0.16784 to 0.16711, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 94/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1583 - mean_squared_error: 0.1583 - val_loss: 0.1664 - val_mean_squared_error: 0.1664
#
# Epoch 00094: val_loss improved from 0.16711 to 0.16641, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 95/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1637 - mean_squared_error: 0.1637 - val_loss: 0.1657 - val_mean_squared_error: 0.1657
#
# Epoch 00095: val_loss improved from 0.16641 to 0.16572, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 96/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1640 - mean_squared_error: 0.1640 - val_loss: 0.1650 - val_mean_squared_error: 0.1650
#
# Epoch 00096: val_loss improved from 0.16572 to 0.16504, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 97/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1602 - mean_squared_error: 0.1602 - val_loss: 0.1644 - val_mean_squared_error: 0.1644
#
# Epoch 00097: val_loss improved from 0.16504 to 0.16438, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 98/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1585 - mean_squared_error: 0.1585 - val_loss: 0.1637 - val_mean_squared_error: 0.1637
#
# Epoch 00098: val_loss improved from 0.16438 to 0.16373, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 99/600
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1566 - mean_squared_error: 0.1566 - val_loss: 0.1631 - val_mean_squared_error: 0.1631
#
# Epoch 00099: val_loss improved from 0.16373 to 0.16309, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 100/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1607 - mean_squared_error: 0.1607 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
#
# Epoch 00100: val_loss improved from 0.16309 to 0.16248, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 101/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1580 - mean_squared_error: 0.1580 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
#
# Epoch 00101: val_loss improved from 0.16248 to 0.16188, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 102/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1614 - mean_squared_error: 0.1614 - val_loss: 0.1613 - val_mean_squared_error: 0.1613
#
# Epoch 00102: val_loss improved from 0.16188 to 0.16128, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 103/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1570 - mean_squared_error: 0.1570 - val_loss: 0.1607 - val_mean_squared_error: 0.1607
#
# Epoch 00103: val_loss improved from 0.16128 to 0.16070, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 104/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1614 - mean_squared_error: 0.1614 - val_loss: 0.1601 - val_mean_squared_error: 0.1601
#
# Epoch 00104: val_loss improved from 0.16070 to 0.16013, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 105/600
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1553 - mean_squared_error: 0.1553 - val_loss: 0.1596 - val_mean_squared_error: 0.1596
#
# Epoch 00105: val_loss improved from 0.16013 to 0.15957, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 106/600
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1544 - mean_squared_error: 0.1544 - val_loss: 0.1590 - val_mean_squared_error: 0.1590
#
# Epoch 00106: val_loss improved from 0.15957 to 0.15903, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 107/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1547 - mean_squared_error: 0.1547 - val_loss: 0.1585 - val_mean_squared_error: 0.1585
#
# Epoch 00107: val_loss improved from 0.15903 to 0.15850, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 108/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1526 - mean_squared_error: 0.1526 - val_loss: 0.1580 - val_mean_squared_error: 0.1580
#
# Epoch 00108: val_loss improved from 0.15850 to 0.15798, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 109/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1588 - mean_squared_error: 0.1588 - val_loss: 0.1575 - val_mean_squared_error: 0.1575
#
# Epoch 00109: val_loss improved from 0.15798 to 0.15748, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 110/600
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1595 - mean_squared_error: 0.1595 - val_loss: 0.1570 - val_mean_squared_error: 0.1570
#
# Epoch 00110: val_loss improved from 0.15748 to 0.15698, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 111/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1568 - mean_squared_error: 0.1568 - val_loss: 0.1565 - val_mean_squared_error: 0.1565
#
# Epoch 00111: val_loss improved from 0.15698 to 0.15649, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 112/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1528 - mean_squared_error: 0.1528 - val_loss: 0.1560 - val_mean_squared_error: 0.1560
#
# Epoch 00112: val_loss improved from 0.15649 to 0.15601, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 113/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1550 - mean_squared_error: 0.1550 - val_loss: 0.1555 - val_mean_squared_error: 0.1555
#
# Epoch 00113: val_loss improved from 0.15601 to 0.15554, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 114/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1541 - mean_squared_error: 0.1541 - val_loss: 0.1551 - val_mean_squared_error: 0.1551
#
# Epoch 00114: val_loss improved from 0.15554 to 0.15509, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 115/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1528 - mean_squared_error: 0.1528 - val_loss: 0.1547 - val_mean_squared_error: 0.1547
#
# Epoch 00115: val_loss improved from 0.15509 to 0.15465, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 116/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1516 - mean_squared_error: 0.1516 - val_loss: 0.1542 - val_mean_squared_error: 0.1542
#
# Epoch 00116: val_loss improved from 0.15465 to 0.15423, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 117/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1480 - mean_squared_error: 0.1480 - val_loss: 0.1538 - val_mean_squared_error: 0.1538
#
# Epoch 00117: val_loss improved from 0.15423 to 0.15383, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 118/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1525 - mean_squared_error: 0.1525 - val_loss: 0.1534 - val_mean_squared_error: 0.1534
#
# Epoch 00118: val_loss improved from 0.15383 to 0.15344, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 119/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1516 - mean_squared_error: 0.1516 - val_loss: 0.1531 - val_mean_squared_error: 0.1531
#
# Epoch 00119: val_loss improved from 0.15344 to 0.15306, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 120/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1531 - mean_squared_error: 0.1531 - val_loss: 0.1527 - val_mean_squared_error: 0.1527
#
# Epoch 00120: val_loss improved from 0.15306 to 0.15268, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 121/600
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1511 - mean_squared_error: 0.1511 - val_loss: 0.1523 - val_mean_squared_error: 0.1523
#
# Epoch 00121: val_loss improved from 0.15268 to 0.15230, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 122/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1490 - mean_squared_error: 0.1490 - val_loss: 0.1519 - val_mean_squared_error: 0.1519
#
# Epoch 00122: val_loss improved from 0.15230 to 0.15194, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 123/600
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1474 - mean_squared_error: 0.1474 - val_loss: 0.1516 - val_mean_squared_error: 0.1516
#
# Epoch 00123: val_loss improved from 0.15194 to 0.15159, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 124/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1498 - mean_squared_error: 0.1498 - val_loss: 0.1512 - val_mean_squared_error: 0.1512
#
# Epoch 00124: val_loss improved from 0.15159 to 0.15125, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 125/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1465 - mean_squared_error: 0.1465 - val_loss: 0.1509 - val_mean_squared_error: 0.1509
#
# Epoch 00125: val_loss improved from 0.15125 to 0.15092, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 126/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1490 - mean_squared_error: 0.1490 - val_loss: 0.1506 - val_mean_squared_error: 0.1506
#
# Epoch 00126: val_loss improved from 0.15092 to 0.15060, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 127/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1481 - mean_squared_error: 0.1481 - val_loss: 0.1503 - val_mean_squared_error: 0.1503
#
# Epoch 00127: val_loss improved from 0.15060 to 0.15029, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 128/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1464 - mean_squared_error: 0.1464 - val_loss: 0.1500 - val_mean_squared_error: 0.1500
#
# Epoch 00128: val_loss improved from 0.15029 to 0.14999, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 129/600
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1462 - mean_squared_error: 0.1462 - val_loss: 0.1497 - val_mean_squared_error: 0.1497
#
# Epoch 00129: val_loss improved from 0.14999 to 0.14969, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 130/600
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1481 - mean_squared_error: 0.1481 - val_loss: 0.1494 - val_mean_squared_error: 0.1494
#
# Epoch 00130: val_loss improved from 0.14969 to 0.14940, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 131/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1480 - mean_squared_error: 0.1480 - val_loss: 0.1491 - val_mean_squared_error: 0.1491
#
# Epoch 00131: val_loss improved from 0.14940 to 0.14911, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 132/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1458 - mean_squared_error: 0.1458 - val_loss: 0.1488 - val_mean_squared_error: 0.1488
#
# Epoch 00132: val_loss improved from 0.14911 to 0.14884, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 133/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1436 - mean_squared_error: 0.1436 - val_loss: 0.1486 - val_mean_squared_error: 0.1486
#
# Epoch 00133: val_loss improved from 0.14884 to 0.14859, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 134/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1467 - mean_squared_error: 0.1467 - val_loss: 0.1483 - val_mean_squared_error: 0.1483
#
# Epoch 00134: val_loss improved from 0.14859 to 0.14834, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 135/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1496 - mean_squared_error: 0.1496 - val_loss: 0.1481 - val_mean_squared_error: 0.1481
#
# Epoch 00135: val_loss improved from 0.14834 to 0.14808, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 136/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1452 - mean_squared_error: 0.1452 - val_loss: 0.1478 - val_mean_squared_error: 0.1478
#
# Epoch 00136: val_loss improved from 0.14808 to 0.14783, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 137/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1427 - mean_squared_error: 0.1427 - val_loss: 0.1476 - val_mean_squared_error: 0.1476
#
# Epoch 00137: val_loss improved from 0.14783 to 0.14759, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 138/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1459 - mean_squared_error: 0.1459 - val_loss: 0.1474 - val_mean_squared_error: 0.1474
#
# Epoch 00138: val_loss improved from 0.14759 to 0.14737, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 139/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1437 - mean_squared_error: 0.1437 - val_loss: 0.1471 - val_mean_squared_error: 0.1471
#
# Epoch 00139: val_loss improved from 0.14737 to 0.14715, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 140/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1423 - mean_squared_error: 0.1423 - val_loss: 0.1469 - val_mean_squared_error: 0.1469
#
# Epoch 00140: val_loss improved from 0.14715 to 0.14694, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 141/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1454 - mean_squared_error: 0.1454 - val_loss: 0.1467 - val_mean_squared_error: 0.1467
#
# Epoch 00141: val_loss improved from 0.14694 to 0.14674, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 142/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1471 - mean_squared_error: 0.1471 - val_loss: 0.1465 - val_mean_squared_error: 0.1465
#
# Epoch 00142: val_loss improved from 0.14674 to 0.14653, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 143/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1434 - mean_squared_error: 0.1434 - val_loss: 0.1463 - val_mean_squared_error: 0.1463
#
# Epoch 00143: val_loss improved from 0.14653 to 0.14633, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 144/600
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1440 - mean_squared_error: 0.1440 - val_loss: 0.1461 - val_mean_squared_error: 0.1461
#
# Epoch 00144: val_loss improved from 0.14633 to 0.14614, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 145/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1451 - mean_squared_error: 0.1451 - val_loss: 0.1460 - val_mean_squared_error: 0.1460
#
# Epoch 00145: val_loss improved from 0.14614 to 0.14596, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 146/600
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1462 - mean_squared_error: 0.1462 - val_loss: 0.1458 - val_mean_squared_error: 0.1458
#
# Epoch 00146: val_loss improved from 0.14596 to 0.14577, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 147/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1446 - mean_squared_error: 0.1446 - val_loss: 0.1456 - val_mean_squared_error: 0.1456
#
# Epoch 00147: val_loss improved from 0.14577 to 0.14558, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 148/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1429 - mean_squared_error: 0.1429 - val_loss: 0.1454 - val_mean_squared_error: 0.1454
#
# Epoch 00148: val_loss improved from 0.14558 to 0.14540, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 149/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1453 - mean_squared_error: 0.1453 - val_loss: 0.1452 - val_mean_squared_error: 0.1452
#
# Epoch 00149: val_loss improved from 0.14540 to 0.14522, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 150/600
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1427 - mean_squared_error: 0.1427 - val_loss: 0.1451 - val_mean_squared_error: 0.1451
#
# Epoch 00150: val_loss improved from 0.14522 to 0.14505, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 151/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1435 - mean_squared_error: 0.1435 - val_loss: 0.1449 - val_mean_squared_error: 0.1449
#
# Epoch 00151: val_loss improved from 0.14505 to 0.14489, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 152/600
# ...
#
# Epoch 00178: val_loss improved from 0.14280 to 0.14279, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 179/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1405 - mean_squared_error: 0.1405 - val_loss: 0.1428 - val_mean_squared_error: 0.1428
#
# Epoch 00179: val_loss improved from 0.14279 to 0.14278, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 180/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1432 - mean_squared_error: 0.1432 - val_loss: 0.1428 - val_mean_squared_error: 0.1428
#
# Epoch 00180: val_loss improved from 0.14278 to 0.14277, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 181/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1418 - mean_squared_error: 0.1418 - val_loss: 0.1428 - val_mean_squared_error: 0.1428
#
# Epoch 00181: val_loss improved from 0.14277 to 0.14276, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 182/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1411 - mean_squared_error: 0.1411 - val_loss: 0.1428 - val_mean_squared_error: 0.1428
#
# Epoch 00182: val_loss improved from 0.14276 to 0.14275, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 183/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1406 - mean_squared_error: 0.1406 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00183: val_loss improved from 0.14275 to 0.14274, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 184/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1410 - mean_squared_error: 0.1410 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00184: val_loss improved from 0.14274 to 0.14273, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 185/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1415 - mean_squared_error: 0.1415 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00185: val_loss improved from 0.14273 to 0.14272, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 186/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1404 - mean_squared_error: 0.1404 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00186: val_loss improved from 0.14272 to 0.14272, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 187/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1395 - mean_squared_error: 0.1395 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00187: val_loss improved from 0.14272 to 0.14271, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 188/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1405 - mean_squared_error: 0.1405 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00188: val_loss improved from 0.14271 to 0.14270, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 189/600
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1399 - mean_squared_error: 0.1399 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00189: val_loss improved from 0.14270 to 0.14269, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 190/600
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1396 - mean_squared_error: 0.1396 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00190: val_loss improved from 0.14269 to 0.14268, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 191/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1401 - mean_squared_error: 0.1401 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00191: val_loss improved from 0.14268 to 0.14267, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 192/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1383 - mean_squared_error: 0.1383 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00192: val_loss improved from 0.14267 to 0.14267, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 193/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1405 - mean_squared_error: 0.1405 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00193: val_loss improved from 0.14267 to 0.14266, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 194/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1422 - mean_squared_error: 0.1422 - val_loss: 0.1427 - val_mean_squared_error: 0.1427
#
# Epoch 00194: val_loss improved from 0.14266 to 0.14265, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 195/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1368 - mean_squared_error: 0.1368 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00195: val_loss improved from 0.14265 to 0.14264, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 196/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1420 - mean_squared_error: 0.1420 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00196: val_loss improved from 0.14264 to 0.14263, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 197/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1411 - mean_squared_error: 0.1411 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00197: val_loss improved from 0.14263 to 0.14262, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 198/600
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1414 - mean_squared_error: 0.1414 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00198: val_loss improved from 0.14262 to 0.14262, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 199/600
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1433 - mean_squared_error: 0.1433 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00199: val_loss improved from 0.14262 to 0.14261, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 200/600
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1396 - mean_squared_error: 0.1396 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00200: val_loss improved from 0.14261 to 0.14260, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 201/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1446 - mean_squared_error: 0.1446 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00201: val_loss improved from 0.14260 to 0.14259, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 202/600
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1431 - mean_squared_error: 0.1431 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00202: val_loss improved from 0.14259 to 0.14258, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 203/600
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1414 - mean_squared_error: 0.1414 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00203: val_loss improved from 0.14258 to 0.14257, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 204/600
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1442 - mean_squared_error: 0.1442 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
#
# Epoch 00204: val_loss improved from 0.14257 to 0.14256, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 205/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1382 - mean_squared_error: 0.1382 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00205: val_loss improved from 0.14256 to 0.14255, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 206/600
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1388 - mean_squared_error: 0.1388 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00206: val_loss improved from 0.14255 to 0.14254, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 207/600
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1397 - mean_squared_error: 0.1397 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00207: val_loss improved from 0.14254 to 0.14253, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 208/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1425 - mean_squared_error: 0.1425 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00208: val_loss improved from 0.14253 to 0.14252, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 209/600
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1413 - mean_squared_error: 0.1413 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00209: val_loss improved from 0.14252 to 0.14251, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 210/600
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1423 - mean_squared_error: 0.1423 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00210: val_loss improved from 0.14251 to 0.14251, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 211/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1416 - mean_squared_error: 0.1416 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00211: val_loss improved from 0.14251 to 0.14250, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 212/600
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1406 - mean_squared_error: 0.1406 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00212: val_loss improved from 0.14250 to 0.14249, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 213/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1368 - mean_squared_error: 0.1368 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00213: val_loss improved from 0.14249 to 0.14248, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 214/600
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1412 - mean_squared_error: 0.1412 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00214: val_loss improved from 0.14248 to 0.14247, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 215/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1402 - mean_squared_error: 0.1402 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00215: val_loss improved from 0.14247 to 0.14246, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 216/600
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1405 - mean_squared_error: 0.1405 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00216: val_loss improved from 0.14246 to 0.14245, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 217/600
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1400 - mean_squared_error: 0.1400 - val_loss: 0.1424 - val_mean_squared_error: 0.1424
#
# Epoch 00217: val_loss improved from 0.14245 to 0.14245, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 218/600
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1312, in time
#     exec(code, glob, local_ns)
#   File "<timed exec>", line 8, in <module>
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/keras/engine/training.py", line 1418, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/keras/engine/training_generator.py", line 217, in fit_generator
#     class_weight=class_weight)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/keras/engine/training.py", line 1217, in train_on_batch
#     outputs = self.train_function(ins)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py", line 2715, in __call__
#     return self._call(inputs)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py", line 2675, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1472, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/opt/anaconda3/envs/infs890/lib/python3.7/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %%
# plot history
if RUN_MODEL:
    plt.figure(figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
val_loss = history.history['val_loss']
val_loss_df = pd.DataFrame(val_loss)

print("Model Validation MSE mean: %.2f  std: (%.2f)" % \
      (val_loss_df.mean(), val_loss_df.std()))
# Out:
# Model Validation MSE mean: 0.17  std: (0.06)

# %%
# Load the best saved model
try:
    model = models.load_model(path_model)
except Exception as error:
    print("Error trying to load model.")
    print(error)

# %% [markdown]
# # Plot Prediction

# %%
def y_comparison(start_idx, length=100, target_scaled=False, data_set='train'):
    """
    Obtain predicted and true output-signals.
    
    :param start_idx: Start-index for the time-series.
    :param length: Sequence-length to process and plot.
    :param train: Boolean whether to use training- or test-set.
    """
    
    if data_set == 'train':
        # Use training-data.
        x = x_train
        y_true = y_train
    elif data_set == 'validate':
        x = x_validate
        y_true = y_validate
    else:
        # Use test-data.
        x = x_test
        y_true = y_test
    
    # End-index for the sequences.
    end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
    #x = np.expand_dims(x, axis=0)

    # Use the model to predict the output-signals.
    y_pred = model.predict(x)
    
    y_true = y_true.reshape(y_true.shape[0], 1)
    
    if target_scaled:
        # The output of the model is scaled.
        # Do an inverse map to get it back to the scale
        # of the original data-set.
        y_true = y_scaler.inverse_transform(y_true)
        y_pred = y_scaler.inverse_transform(y_pred)
       
    y_true = y_true.reshape(y_true.shape[0])
    y_pred = y_pred.reshape(y_pred.shape[0])
    
    print("shape y_pred: %", y_pred.shape)
    print("shape y_true: %", y_true.shape)
    
    return y_true, y_pred


#This helper-function plots the predicted and true output-signals.
def plot_comparison(signal_true, signal_pred):
    """
    Plot the predicted and true output-signals.
    """

    # Make the plotting-canvas bigger.
    plt.figure(figsize=(15,5))
        
    # Plot and compare the two signals.
    plt.plot(signal_true, label='true')
    plt.plot(signal_pred, label='pred')
        
    # Plot grey box for warmup-period.
    p = plt.axvspan(0, warmup_steps, facecolor='black', alpha=0.15)
        
    # Plot labels etc.
    plt.ylabel('ltcy')
    plt.legend()
    plt.show()

# %% [markdown]
# # Check on Some Training Data

# %% [markdown]
# Let us start with an example from the training-data. This is data that the model has seen during training so it should perform reasonably well on this data.

# %%
print("total number of training targets {}".format(num_train))
train_true, train_pred = y_comparison(start_idx=0, length=num_train, data_set='train')


stack = np.stack((train_true[0:10], train_pred[0:10]), axis=-1)
stack

# %%
plot_comparison(train_true[10:110], train_pred[10:110])

# %%
import math
# calculate RMSE
mse = math.sqrt(mean_squared_error(train_true, train_pred))
print('Train MSE: %.3f' % mse)

# %%
plt.scatter(train_true, train_pred, alpha=0.2)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show

# %%
ax = sns.regplot(x=train_true[10:110], y=train_pred[10:110], color='g')

# %%
r2_train = metrics.r2_score(train_true, train_pred)
print('R2 (training) = {}'.format(r2_train))

# %% [markdown]
# # Evaluate Model

# %%
print("total number of testing targets {}".format(num_test))
test_true, test_pred = y_comparison(start_idx=0, length=num_test, data_set='test')


stack = np.stack((test_true[0:10], test_pred[0:10]), axis=-1)
stack

# %%
plot_comparison(test_true[10:110], test_pred[10:110])

# %% [markdown]
# # *** R2

# %%
r2_test = metrics.r2_score(test_true, test_pred)
print('R2 (testing) = {}'.format(r2_test))

# %%
sns.distplot(test_true - test_pred)
plt.title('Residual PDF', size=18)

# %%
ax = sns.regplot(x=test_true[10:110], y=test_pred[10:110], color='g')

# %%
plt.scatter(test_true[10:110], test_pred[10:110], alpha=0.6)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show

# %%
print('shape y test {}'.format(test_true.shape))
print('shape y predicted {}'.format(test_pred.shape))

#print ("Actual test values: \n {}".format(test_signal_true[:20]))
#print ("Predicted test values: \n {}".format(test_signal_pred[:20]))

print("")
# calculate RMSE
mse = math.sqrt(mean_squared_error(test_true, test_pred))
print('Test MSE: %.3f' % mse)

# %%
true_df = round(pd.DataFrame(test_true, columns=['actual']),2)
pred_df = round(pd.DataFrame(test_pred, columns=['predicted']),2)


compare_df = pd.concat([true_df,pred_df], axis=1, sort=False)

# testing mean_absolute_percentage_error
compare_df['residual'] = round(compare_df['actual'] - compare_df['predicted'], 2)
compare_df['difference%'] = round(np.absolute(compare_df['residual']* 100 / compare_df['actual']),2)

compare_df.head(5)

# %%
compare_df.describe()

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
compare_df.sort_values(by = ['difference%'])

# %%
print("... FINISH ....")
