# %% [markdown]
# # Decision Tree
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import seaborn as sns
from sklearn import preprocessing, metrics, feature_selection, tree
from datetime import datetime
from scipy import stats
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import RFECV

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# Set this flag to True if you're using reduction feature using FCA, otherwise set it to False

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'

#data_file = 'order_flow_cleanup_data.csv'
data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'



test_split = 0.1

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, True)
data = data.reset_index(drop=True)
data.head(5)
# Out:
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0             0.0700          0.0200             0.0100        0.0200
# 1             0.0600          0.0300             0.0100        0.0200
# 2             0.0600          0.0300             0.0100        0.0200
# 3             0.0900          0.0300             0.0100        0.0200
# 4             0.1100          0.0400             0.0100        0.0300
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0           0.0200            0.0100           0.0100         0.1200
# 1           0.0200            0.0100           0.0100         0.1400
# 2           0.0200            0.0100           0.0100         0.1500
# 3           0.0200            0.0100           0.0100         0.0600
# 4           0.0300            0.0100           0.0100         0.1100
#
#    carts-db_cpu_use  front-end_pods  orders_pods  user_pods  shipping_pods  \
# 0            0.1600          1.0000       1.0000     1.0000         1.0000
# 1            0.1700          1.0000       1.0000     1.0000         1.0000
# 2            0.1400          1.0000       1.0000     1.0000         1.0000
# 3            0.1900          1.0000       1.0000     1.0000         1.0000
# 4            0.3200          1.0000       1.0000     1.0000         1.0000
#
#    payment_pods  carts_pods  nodes_cpu_use  orders_req  orders_ltcy
# 0        1.0000      1.0000         1.1800      0.4000       0.6325
# 1        1.0000      1.0000         1.1800      0.4400       0.6245
# 2        1.0000      1.0000         1.1500      0.3600       0.6164
# 3        1.0000      1.0000         1.5400      0.4000       0.5568
# 4        1.0000      1.0000         2.3500      0.7800       0.5292

# %%
data.shape
# Out:
# (1499, 18)

# %%
targets = data['orders_ltcy']

inputs = data.drop(['orders_ltcy'], axis=1)
#inputs = inputs.drop(['date'], axis=1)

n_features = inputs.values.shape[1]

#inputs_scaled = scaler.fit_transform(inputs)
#x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=test_split, shuffle=False, random_state=365)

# for better convergence and result scale target to values between 0 - 1
y_train_max = y_train.max()
y_test_max = y_test.max()

y_train = y_train / y_train_max
y_test = y_test / y_test_max

print("there are {} features".format(n_features))
# Out:
# there are 17 features

# %%
#plt.scatter(data['orders_cpu_use'], data['orders_ltcy'])
#plt.xlabel('orders_cpu_use', size=18)
#plt.ylabel("orders_ltcy", size=18)
#plt.show()

# plot cpu vs latency 
plt.plot(data['orders_cpu_use'][:100], label='orders_cpu_use')
plt.plot(data['orders_ltcy'][:100], label='orders_ltcy')
plt.legend()
plt.show()

#ax = sns.regplot(x=data['orders_cpu_use'], y=data['orders_ltcy'], color='g')

# %% [markdown]
# # Model

# %%
# start:  search grid

reg = tree.DecisionTreeRegressor() 

# standardize the features
scaler = StandardScaler()
#scaler.fit(x_train.values.reshape(-1,n_features))

#model = LassoCV(fit_intercept=False,n_jobs=-1,random_state=0,selection='random',positive=False,cv=10)
model = RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=20)
sfm = SelectFromModel(model)


pipe = Pipeline(steps=[
    ('selector', sfm),
    ('scaler', scaler), 
    ('reg', reg)
])

kfold = KFold(n_splits=10, shuffle=True)

param_grid = {
    #'selector__threshold': [0.1, 0.05, 0.02, 0.001]  # with lasso
    'selector__threshold': ['1*mean', '0.8*mean', '0.6*mean', '0.3*mean', '0.1*mean','0.05*mean', '0.02*mean', '0.01*mean', '0.001*mean'] # with tree
    , 'reg__min_samples_leaf': [5]
}

search = GridSearchCV(pipe, param_grid, scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=1, n_jobs=-1)

#scores = cross_val_score(pipe, x_train, y_train, cv=kfold, n_jobs=-1
        #, verbose=3, scoring='neg_mean_squared_error')

# %%
import sklearn 
print(sklearn.__version__)

search.fit(x_train, y_train)
# Out:
# 0.22.2.post1
# Fitting 10 folds for each of 9 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:    7.0s finished
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('selector',
#                                         SelectFromModel(estimator=RandomForestRegressor(bootstrap=True,
#                                                                                         ccp_alpha=0.0,
#                                                                                         criterion='mse',
#                                                                                         max_depth=10,
#                                                                                         max_features='auto',
#                                                                                         max_leaf_nodes=None,
#                                                                                         max_samples=None,
#                                                                                         min_impurity_decrease=0.0,
#                                                                                         min_impurity_split=None,
#                                                                                         min_s...
#                                                               presort='deprecated',
#                                                               random_state=None,
#                                                               splitter='best'))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'reg__min_samples_leaf': [5],
#                          'selector__threshold': ['1*mean', '0.8*mean',
#                                                  '0.6*mean', '0.3*mean',
#                                                  '0.1*mean', '0.05*mean',
#                                                  '0.02*mean', '0.01*mean',
#                                                  '0.001*mean']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=1)

# %% [markdown]
# # Best Model

# %%
estimator = search.best_estimator_

score = search.best_score_
print("Best CV test score = %0.4f:" % score)

params = search.best_params_
print("Best CV params = {}".format(params))

print("")
all_training_scores = search.cv_results_
#print("\ncross_validation:\n", all_training_scores , "\n")

print('mean train scores')
print(all_training_scores['mean_train_score'])

print('mean test scores')
print(all_training_scores['mean_test_score'])
# Out:
# Best CV test score = -0.0163:
# Best CV params = {'reg__min_samples_leaf': 5, 'selector__threshold': '0.8*mean'}
#
# mean train scores
# [-0.00902347 -0.00705019 -0.00587385 -0.00551281 -0.00538174 -0.00535552
#  -0.00528623 -0.00528623 -0.00528688]
# mean test scores
# [-0.01714387 -0.01627993 -0.01683055 -0.01658485 -0.01685937 -0.01673372
#  -0.01664714 -0.01661985 -0.01665859]

# %% [markdown]
# # Features Selected

# %%
best_threshold = params['selector__threshold']

print('best selector threshold {}'.format(best_threshold))

#sfm = SelectFromModel(clf,threshold=best_threshold)

sfm = pipe['selector']
sfm.threshold = best_threshold

selectedFeatures = sfm.fit(x_train, y_train).transform(x_train)
print('{} features selected'.format(selectedFeatures[1].shape[0]))

feature_list = x_train.columns[sfm.get_support()]
features = ''
features = ', '.join(feature_list)
#features

reduced_x_train = x_train[feature_list]
#reduced_x_train.head(2)
print('')
for feature in reduced_x_train.columns.values:
    print(feature)
# Out:
# best selector threshold 0.8*mean
# 5 features selected
#
# user_cpu_use
# user-db_cpu_use
# carts_cpu_use
# carts-db_cpu_use
# orders_req

# %%
pdf = pd.DataFrame(all_training_scores['mean_train_score'], columns=['training mse'])
pdf.plot()

# %% [markdown]
# # Training R2

# %%
y_hat = estimator.predict(x_train)

r2_train = metrics.r2_score(y_train, y_hat)
print('R2 (training) = {}'.format(r2_train))

#print("score ", search.score(x_test, y_test))
# or also R-Squared could be obtain via
#pline.score(x_train, y_train)
# Out:
# R2 (training) = 0.8651187952195327

# %%
print('Score (training) = {}'.format(search.score(x_train,y_train)))
# Out:
# Score (training) = -0.0064252878972860875

# %%
# validation mean_absolute_percentage_error
train_error =  np.abs(y_train - y_hat)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)


print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.05 (0.06) 0.00 0.48 MSE

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
#plt.xlim(-2,3)
#plt.ylim(-3,1)
plt.show()

# %%
sns.distplot(y_train - y_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %% [markdown]
# # Testing

# %%
y_hat_test = estimator.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_hat_test, color='g')

# %%
perf = pd.DataFrame(np.exp(y_hat_test), columns=['prediction'])
y_test = y_test.reset_index(drop=True)
perf['target'] = np.exp(y_test)
perf.head()
# Out:
#    prediction  target
# 0      1.2477  1.2048
# 1      1.2187  1.2467
# 2      1.2706  1.2658
# 3      1.2417  1.2840
# 4      1.3330  1.2840

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0        1.2477  1.2048    0.0429       3.5570
# 1        1.2187  1.2467   -0.0280       2.2432
# 2        1.2706  1.2658    0.0048       0.3793
# 3        1.2417  1.2840   -0.0423       3.2967
# 4        1.3330  1.2840    0.0489       3.8118
# ..          ...     ...       ...          ...
# 145      1.8283  2.1268   -0.2985      14.0344
# 146      2.1328  2.7126   -0.5798      21.3731
# 147      2.3157  2.5009   -0.1853       7.4078
# 148      1.9134  2.6881   -0.7747      28.8209
# 149      2.5995  2.6692   -0.0697       2.6116
#
# [150 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction   target  residual  difference%
# count    150.0000 150.0000  150.0000     150.0000
# mean       1.7683   1.7858   -0.0175      11.0411
# std        0.3794   0.4596    0.2763       9.6763
# min        1.2049   1.2048   -0.8589       0.1123
# 25%        1.3394   1.2981   -0.1711       3.1080
# 50%        1.8329   1.7370    0.0097       7.4360
# 75%        2.1139   2.2090    0.1254      17.3808
# max        2.5995   2.7183    0.6518      41.9858

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 25         1.29    1.29      0.00         0.11
# 21         1.23    1.23     -0.00         0.16
# 120        2.29    2.28      0.01         0.29
# 2          1.27    1.27      0.00         0.38
# 130        1.72    1.73     -0.01         0.57
# 53         1.23    1.24     -0.01         0.59
# 86         2.11    2.13     -0.01         0.61
# 23         1.28    1.27      0.01         0.76
# 30         1.21    1.20      0.01         0.81
# 12         1.41    1.42     -0.01         0.86
# 137        2.40    2.43     -0.03         1.37
# 17         1.23    1.25     -0.02         1.44
# 85         2.11    2.08      0.03         1.55
# 126        2.32    2.28      0.04         1.66
# 70         2.32    2.28      0.04         1.74
# 19         1.23    1.25     -0.02         1.75
# 139        2.14    2.18     -0.04         1.85
# 43         1.23    1.20      0.02         1.98
# 28         1.23    1.20      0.02         1.98
# 40         1.23    1.20      0.02         1.98
# 42         1.23    1.20      0.02         1.98
# 7          1.27    1.30     -0.03         2.05
# 26         1.24    1.27     -0.03         2.06
# 1          1.22    1.25     -0.03         2.24
# 136        1.83    1.79      0.04         2.28
# 39         1.23    1.26     -0.03         2.35
# 41         1.24    1.20      0.03         2.52
# 16         1.27    1.24      0.03         2.57
# 149        2.60    2.67     -0.07         2.61
# 111        2.24    2.18      0.06         2.64
# 31         1.23    1.26     -0.03         2.72
# 15         1.20    1.24     -0.03         2.73
# 46         1.26    1.23      0.03         2.85
# 45         1.26    1.23      0.03         2.85
# 27         1.24    1.20      0.03         2.89
# 119        2.32    2.25      0.07         2.96
# 29         1.24    1.20      0.04         3.06
# 6          1.26    1.30     -0.04         3.11
# 110        2.22    2.29     -0.07         3.11
# 5          1.33    1.29      0.04         3.24
# 3          1.24    1.28     -0.04         3.30
# 20         1.28    1.23      0.04         3.30
# 118        1.83    1.77      0.06         3.52
# 0          1.25    1.20      0.04         3.56
# 13         1.26    1.21      0.04         3.63
# 4          1.33    1.28      0.05         3.81
# 73         1.79    1.72      0.07         3.84
# 74         1.83    1.76      0.07         4.04
# 128        2.32    2.42     -0.10         4.13
# 112        2.13    2.23     -0.10         4.35
# 129        2.13    2.04      0.09         4.40
# 131        2.32    2.21      0.10         4.58
# 75         1.87    1.79      0.08         4.62
# 37         1.31    1.38     -0.07         4.76
# 59         1.70    1.62      0.08         4.83
# 100        1.83    1.74      0.09         5.07
# 44         1.29    1.23      0.07         5.39
# 22         1.27    1.20      0.07         5.46
# 144        2.32    2.45     -0.14         5.55
# 33         1.31    1.39     -0.08         5.57
# 64         2.32    2.19      0.12         5.69
# 68         1.83    1.73      0.10         5.87
# 90         2.32    2.19      0.13         5.87
# 143        2.40    2.55     -0.15         5.99
# 94         2.11    2.25     -0.14         6.01
# 141        1.83    1.95     -0.12         6.09
# 18         1.33    1.25      0.08         6.39
# 97         2.13    2.00      0.13         6.63
# 91         2.32    2.49     -0.17         6.84
# 51         1.49    1.40      0.10         6.95
# 95         2.11    2.27     -0.16         6.96
# 117        1.92    1.79      0.13         7.04
# 133        2.10    2.27     -0.17         7.34
# 101        1.83    1.71      0.13         7.36
# 147        2.32    2.50     -0.19         7.41
# 92         2.13    2.30     -0.17         7.46
# 132        1.79    1.94     -0.15         7.55
# 93         2.11    2.30     -0.18         7.90
# 66         1.31    1.43     -0.11         8.03
# 127        2.11    2.30     -0.19         8.05
# 38         1.26    1.37     -0.11         8.26
# 32         1.41    1.29      0.11         8.67
# 114        2.12    1.95      0.17         8.82
# 49         1.73    1.59      0.14         8.88
# 87         1.87    2.06     -0.19         9.18
# 138        2.14    2.37     -0.23         9.65
# 140        2.22    2.46     -0.24         9.66
# 9          1.59    1.44      0.15        10.22
# 89         2.24    2.02      0.21        10.53
# 63         1.72    1.93     -0.21        10.77
# 77         2.06    2.32     -0.27        11.42
# 58         1.83    1.64      0.19        11.49
# 88         1.83    2.08     -0.24        11.77
# 123        1.44    1.64     -0.20        12.13
# 78         1.83    2.10     -0.27        12.68
# 122        2.32    2.66     -0.34        12.81
# 102        1.83    2.10     -0.27        12.84
# 11         1.36    1.56     -0.21        13.13
# 14         1.41    1.24      0.17        13.53
# 57         1.87    1.65      0.22        13.54
# 62         1.90    1.67      0.23        13.64
# 145        1.83    2.13     -0.30        14.03
# 105        2.11    1.85      0.26        14.07
# 60         1.70    1.48      0.22        14.55
# 134        1.52    1.78     -0.26        14.62
# 98         2.32    2.72     -0.40        14.81
# 80         1.83    2.15     -0.32        14.82
# 35         1.73    1.50      0.23        15.31
# 48         1.70    1.47      0.23        15.36
# 124        1.79    2.12     -0.33        15.70
# 125        1.87    2.25     -0.37        16.51
# 10         1.87    1.60      0.27        17.01
# 84         1.83    2.22     -0.39        17.50
# 121        1.91    2.33     -0.41        17.80
# 52         1.49    1.27      0.23        17.92
# 99         1.66    2.02     -0.36        17.98
# 81         1.83    2.24     -0.40        18.07
# 135        1.72    2.13     -0.41        19.05
# 65         1.83    2.29     -0.45        19.80
# 55         1.73    1.44      0.29        20.19
# 104        1.66    2.09     -0.43        20.63
# 56         1.87    1.55      0.33        21.01
# 146        2.13    2.71     -0.58        21.37
# 8          1.64    1.35      0.29        21.65
# 61         1.73    1.42      0.31        21.83
# 50         1.92    1.57      0.35        22.08
# 82         1.78    2.29     -0.51        22.13
# 24         1.59    1.29      0.29        22.67
# 109        2.40    1.94      0.45        23.25
# 72         1.79    1.45      0.34        23.39
# 83         1.73    2.26     -0.53        23.40
# 103        1.70    2.22     -0.52        23.46
# 71         1.76    1.42      0.34        23.80
# 142        1.94    2.57     -0.63        24.51
# 69         2.32    1.86      0.46        24.54
# 115        1.65    2.19     -0.54        24.67
# 67         2.11    1.68      0.43        25.62
# 76         1.44    1.95     -0.51        26.14
# 113        1.83    2.50     -0.67        26.76
# 34         1.92    1.51      0.41        26.88
# 107        2.29    1.79      0.49        27.59
# 106        2.29    1.78      0.51        28.36
# 36         1.87    1.46      0.42        28.68
# 148        1.91    2.69     -0.77        28.82
# 116        1.83    2.69     -0.86        31.91
# 79         2.12    1.59      0.53        32.97
# 54         1.92    1.39      0.53        37.73
# 47         1.73    1.25      0.47        37.98
# 96         2.24    1.58      0.65        41.17
# 108        2.06    1.45      0.61        41.99

# %% [markdown]
# # *** Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_hat_test)
print('R2 (testing) = {}'.format(r2_test))

# also: R-Squared could obtain with
# pline.score(x_test, y_test)
# Out:
# R2 (testing) = 0.6877657234655615

# %%
print(np.sqrt(mean_squared_error(y_test,y_hat_test)))
# Out:
# 0.14440916784599325
