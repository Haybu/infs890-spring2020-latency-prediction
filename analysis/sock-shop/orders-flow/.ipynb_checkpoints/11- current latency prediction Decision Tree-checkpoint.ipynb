# %% [markdown]
# # Decision Tree
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectKBest
import seaborn as sns
from sklearn import preprocessing, metrics, feature_selection, tree
from datetime import datetime
from scipy import stats
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler , MinMaxScaler
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import RFECV
from sklearn.decomposition import PCA

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# Set this flag to True if you're using reduction feature using FCA, otherwise set it to False

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'

#data_file = 'orders_flow_data.csv'   # raw data as is
#data_file = 'order_flow_cleanup_data.csv'
data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'


SCALE_TARGETS = True

test_split = 0.1

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, True)
data = data.reset_index(drop=True)
data.head(5)
# Out:
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0             0.0700          0.0200             0.0100        0.0200
# 1             0.0600          0.0300             0.0100        0.0200
# 2             0.2100          0.0600             0.0200        0.0500
# 3             0.2200          0.0600             0.0200        0.0600
# 4             0.2100          0.0600             0.0100        0.0500
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0           0.0200            0.0100           0.0100         0.1200
# 1           0.0200            0.0100           0.0100         0.1400
# 2           0.0300            0.0200           0.0100         0.2400
# 3           0.0400            0.0200           0.0100         0.2100
# 4           0.0400            0.0200           0.0100         0.1500
#
#    carts-db_cpu_use  front-end_pods  ...  user-db_net_use  shipping_net_use  \
# 0            0.1600          1.0000  ...           9.1583            4.2628
# 1            0.1700          1.0000  ...           8.2344            4.8656
# 2            0.6600          1.0000  ...          25.5465            3.1148
# 3            0.6600          1.0000  ...          26.4822            7.2076
# 4            0.6600          1.0000  ...          18.6872            6.8741
#
#    payment_net_use  carts_net_use  carts-db_net_use  nodes_cpu_use  \
# 0           3.3626         6.9149            5.5572         1.1800
# 1           3.1404         9.7259            7.1883         1.1800
# 2           4.4254        29.5804            7.4301         1.8400
# 3           4.4523        25.2584           15.2118         1.8300
# 4           6.0157        24.1570           16.1607         1.7500
#
#    nodes_disk_io  nodes_net_use  orders_req  orders_ltcy
# 0         0.0000         1.7850      0.4000       0.4000
# 1         0.0000         1.7496      0.4400       0.3900
# 2         0.2600         3.6912      1.5800       0.4200
# 3         0.2600         3.7957      1.5800       0.4100
# 4         0.0000         3.8370      1.4900       0.3900
#
# [5 rows x 29 columns]

# %%
data.shape
# Out:
# (3175, 29)

# %%
targets = data['orders_ltcy']
inputs = data.drop(['orders_ltcy'], axis=1)

n_features = inputs.values.shape[1]
print("there are {} features".format(n_features))
# Out:
# there are 28 features

# %%
# scale targets for better convergence
if SCALE_TARGETS:
    y_scaler =  MinMaxScaler()
    targets = y_scaler.fit_transform(targets.values.reshape(-1,1))

# %%
x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=test_split, shuffle=False, random_state=365)

if 1 == 0:
    # for better convergence and result scale target to values between 0 - 1
    y_train_max = y_train.max()
    y_test_max = y_test.max()

    y_train = y_train / y_train_max
    y_test = y_test / y_test_max

# %%
# plot cpu vs latency 
plt.plot(data['orders_cpu_use'][100:200], label='orders_cpu_use')
plt.plot(data['orders_ltcy'][100:200], label='orders_ltcy')
plt.legend()
plt.show()

#ax = sns.regplot(x=data['orders_cpu_use'], y=data['orders_ltcy'], color='g')

# %% [markdown]
# # Model

# %%
#lasso = LassoCV(fit_intercept=False,n_jobs=-1,random_state=0,selection='random',positive=False,cv=10)
#sfm1 = SelectFromModel(lasso, threshold='0.01*mean')

#rfr = RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=20)
#sfm = SelectFromModel(rfr, threshold='0.01*mean')

#sfm = SelectKBest(k=6)

sfm = PCA(random_state=100)

reg = tree.DecisionTreeRegressor() 

pipe = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('selector', sfm),
    ('reg', reg)
])

kfold = KFold(n_splits=10, shuffle=True)

param_grid = {
    #'selector__threshold': [0.1, 0.05, 0.02, 0.001]  # with lasso
    
    #'selector__threshold': ['1*mean', '0.8*mean', '0.6*mean', '0.3*mean', '0.1*mean','0.05*mean', '0.02*mean', '0.01*mean', '0.001*mean'] # with tree
    #, 'selector__estimator__max_depth' : [10, 15]
    #, 'selector__estimator__n_estimators' : [20, 30, 40]
    
    'selector__n_components' : [10, 15, 20]  # with PCA
    , 'reg__min_samples_leaf': [1,2,3]
}

search = GridSearchCV(pipe, param_grid, scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=1, n_jobs=-1)

#scores = cross_val_score(pipe, x_train, y_train, cv=kfold, n_jobs=-1
        #, verbose=3, scoring='neg_mean_squared_error')

# %%
import sklearn 
print('sklearn version {}'.format(sklearn.__version__))

search.fit(x_train, y_train)
# Out:
# sklearn version 0.22.2.post1
# Fitting 10 folds for each of 9 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done  75 out of  90 | elapsed:    2.0s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:    2.0s finished
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('selector',
#                                         PCA(copy=True, iterated_power='auto',
#                                             n_components=None, random_state=100,
#                                             svd_solver='auto', tol=0.0,
#                                             whiten=False)),
#                                        ('reg',
#                                         DecisionTreeRegressor(ccp_alpha=0...
#                                                               min_samples_leaf=1,
#                                                               min_samples_split=2,
#                                                               min_weight_fraction_leaf=0.0,
#                                                               presort='deprecated',
#                                                               random_state=None,
#                                                               splitter='best'))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'reg__min_samples_leaf': [1, 2, 3],
#                          'selector__n_components': [10, 15, 20]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=1)

# %% [markdown]
# # Best Model

# %%
score = search.best_score_
print("Best CV test score = %0.4f:" % score)

params = search.best_params_
print("Best CV params = {}".format(params))

#print("")
all_training_scores = search.cv_results_
#print("\ncross_validation:\n", all_training_scores , "\n")

#print('mean train scores')
#print(all_training_scores['mean_train_score'])

#print('mean test scores')
#print(all_training_scores['mean_test_score'])
# Out:
# Best CV test score = -0.0728:
# Best CV params = {'reg__min_samples_leaf': 3, 'selector__n_components': 10}

# %% [markdown]
# # Features Selected

# %%
if 1 == 0:
    best_threshold = params['selector__threshold']
    best_max_depth = params['selector__estimator__max_depth']
    best_n_estimators = params['selector__estimator__n_estimators']

    select_model = RandomForestRegressor(n_jobs=-1, max_depth=best_max_depth, n_estimators=best_n_estimators)
    sfm = SelectFromModel(model, threshold=best_threshold)

    selectedFeatures = sfm.fit(x_train, y_train).transform(x_train)
    print('{} features selected'.format(selectedFeatures[1].shape[0]))

    feature_list = x_train.columns[sfm.get_support()]
    features = ''
    features = ', '.join(feature_list)
    #features

    reduced_x_train = x_train[feature_list]
    #reduced_x_train.head(2)
    print('')
    for feature in reduced_x_train.columns.values:
        print(feature)

# %%
pdf = pd.DataFrame(all_training_scores['mean_test_score'], columns=['testing mse'])
pdf.plot()

# %% [markdown]
# # Training R2

# %%
y_train_hat = search.predict(x_train)

r2_train = metrics.r2_score(y_train, y_train_hat)
print('R2 (training) = {}'.format(r2_train))

print('Score (training) = {}'.format(search.score(x_train,y_train)))
# Out:
# R2 (training) = 0.6245210289539946
# Score (training) = -0.044462619822715786

# %%
# validation mean_absolute_percentage_error
train_error =  np.abs(y_train - y_train_hat)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)


print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.36 (0.25) 0.00 1.00 MSE

# %%
plt.scatter(y_train, y_train_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
plt.show()

# %%
sns.distplot(y_train - y_train_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %% [markdown]
# # Testing

# %%
y_test_hat = search.predict(x_test)

# %%
plt.scatter(y_test, y_test_hat)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_test_hat, color='g')

# %%
perf = pd.DataFrame(y_test_hat, columns=['prediction'])
perf['target'] = y_test
perf.head()
# Out:
#    prediction  target
# 0      0.0082  0.0016
# 1      0.7502  0.0071
# 2      0.0034  0.0093
# 3      0.0034  0.0027
# 4      0.8301  0.0016

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0        0.0082  0.0016    0.0066     417.9775
# 1        0.7502  0.0071    0.7431  10,501.1529
# 2        0.0034  0.0093   -0.0059      63.2250
# 3        0.0034  0.0027    0.0007      27.3731
# 4        0.8301  0.0016    0.8285  52,491.0112
# ..          ...     ...       ...          ...
# 313      0.2636  0.9945   -0.7309      73.4897
# 314      0.9698  0.9967   -0.0269       2.7029
# 315      0.2130  0.9945   -0.7815      78.5849
# 316      0.7757  0.9384   -0.1627      17.3417
# 317      0.9280  0.9780   -0.0500       5.1156
#
# [318 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction   target  residual  difference%
# count    318.0000 318.0000  318.0000     318.0000
# mean       0.4387   0.4823   -0.0437   3,156.3145
# std        0.3447   0.3622    0.4095  18,314.2162
# min        0.0005   0.0005   -0.9877       0.0000
# 25%        0.2130   0.1302   -0.2863      23.3488
# 50%        0.3289   0.4585   -0.0185      67.0508
# 75%        0.7693   0.8859    0.1441      99.7545
# max        0.9970   1.0000    0.9896 206,035.1852

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 141        0.31    0.31     -0.00         0.00
# 308        0.99    1.00     -0.00         0.11
# 181        0.21    0.21      0.00         0.13
# 274        0.99    0.99      0.00         0.22
# 286        1.00    0.99      0.00         0.33
# 266        0.99    0.99      0.00         0.33
# 290        0.94    0.95     -0.01         0.64
# 260        1.00    0.99      0.01         0.69
# 300        1.00    0.99      0.01         0.89
# 209        0.97    0.96      0.01         0.97
# 301        0.95    0.96     -0.01         0.97
# 292        1.00    0.99      0.01         1.00
# 201        0.97    0.98     -0.01         1.08
# 280        1.00    0.98      0.01         1.12
# 270        0.98    0.96      0.01         1.25
# 193        0.94    0.96     -0.01         1.34
# 282        0.95    0.97     -0.01         1.42
# 305        0.95    0.97     -0.02         1.75
# 283        0.98    0.96      0.02         1.79
# 244        0.97    0.98     -0.02         1.85
# 289        0.95    0.97     -0.02         1.87
# 240        0.97    0.99     -0.02         1.96
# 295        0.98    0.96      0.02         1.98
# 296        0.99    0.97      0.02         2.29
# 312        0.95    0.98     -0.02         2.53
# 291        0.94    0.97     -0.03         2.67
# 314        0.97    1.00     -0.03         2.70
# 272        0.98    0.95      0.03         2.82
# 176        0.92    0.89      0.03         3.00
# 276        0.94    0.97     -0.03         3.33
# 239        0.97    1.00     -0.03         3.36
# 275        0.94    0.97     -0.03         3.44
# 255        0.92    0.89      0.03         3.76
# 83         0.21    0.21      0.01         3.89
# 285        0.97    0.93      0.04         4.56
# 298        0.95    0.91      0.04         4.66
# 309        0.99    0.94      0.04         4.69
# 210        0.38    0.40     -0.02         4.72
# 279        0.97    0.92      0.05         4.94
# 317        0.93    0.98     -0.05         5.12
# 90         0.81    0.86     -0.05         5.32
# 265        0.93    0.98     -0.05         5.43
# 136        0.81    0.86     -0.05         5.69
# 222        0.97    0.91      0.05         5.70
# 143        0.21    0.20      0.01         6.17
# 226        0.21    0.23     -0.01         6.18
# 281        0.95    0.89      0.06         6.73
# 114        0.38    0.41     -0.03         7.54
# 245        0.71    0.65      0.06         8.66
# 264        0.95    0.88      0.08         8.70
# 294        0.99    0.91      0.08         8.72
# 139        0.31    0.35     -0.03         9.48
# 25         0.00    0.00     -0.00         9.70
# 135        0.94    0.85      0.09        10.46
# 168        0.42    0.47     -0.05        10.60
# 92         0.38    0.42     -0.05        11.13
# 80         0.38    0.42     -0.05        11.13
# 212        0.31    0.36     -0.04        11.98
# 257        0.83    0.95     -0.12        12.26
# 89         0.81    0.93     -0.12        12.49
# 297        0.82    0.72      0.10        13.58
# 172        0.38    0.44     -0.06        14.45
# 126        0.42    0.49     -0.07        15.01
# 238        0.83    0.98     -0.15        15.03
# 137        0.58    0.51      0.08        15.35
# 120        0.94    0.82      0.13        15.36
# 115        0.31    0.37     -0.06        15.61
# 259        0.75    0.89     -0.14        15.71
# 310        0.96    0.83      0.13        15.77
# 293        0.95    0.81      0.14        16.84
# 316        0.78    0.94     -0.16        17.34
# 43         0.02    0.03     -0.01        18.35
# 106        0.31    0.39     -0.08        19.86
# 166        0.38    0.48     -0.10        20.76
# 173        0.38    0.31      0.07        21.17
# 204        0.67    0.85     -0.18        21.44
# 189        0.41    0.52     -0.11        21.73
# 142        0.21    0.28     -0.06        22.66
# 105        0.38    0.49     -0.11        22.90
# 197        0.38    0.49     -0.11        23.24
# 225        0.94    0.76      0.18        23.66
# 170        0.53    0.70     -0.16        23.67
# 288        0.98    0.79      0.19        24.20
# 124        0.38    0.50     -0.13        25.09
# 108        0.31    0.42     -0.11        25.49
# 3          0.00    0.00      0.00        27.37
# 167        0.31    0.44     -0.12        27.93
# 118        0.31    0.44     -0.13        28.82
# 219        0.21    0.30     -0.09        29.93
# 169        0.81    0.62      0.19        30.38
# 162        0.21    0.31     -0.09        30.69
# 198        0.33    0.48     -0.15        30.83
# 229        0.38    0.55     -0.17        31.10
# 253        0.62    0.91     -0.29        31.50
# 146        0.31    0.46     -0.15        31.71
# 112        0.31    0.46     -0.15        31.87
# 147        0.31    0.47     -0.16        33.61
# 186        0.31    0.48     -0.16        34.07
# 111        0.31    0.48     -0.17        34.97
# 87         0.31    0.49     -0.18        36.13
# 199        0.31    0.49     -0.18        36.27
# 171        0.31    0.49     -0.18        36.27
# 246        0.38    0.59     -0.22        36.45
# 34         0.38    0.27      0.10        37.69
# 271        0.56    0.93     -0.37        39.35
# 33         0.42    0.30      0.12        39.79
# 163        0.71    0.50      0.21        41.10
# 248        0.21    0.36     -0.15        41.21
# 69         0.22    0.16      0.07        42.30
# 26         0.00    0.01     -0.00        42.93
# 175        0.42    0.73     -0.32        43.15
# 188        0.38    0.67     -0.30        44.01
# 86         0.38    0.26      0.12        44.04
# 134        0.42    0.75     -0.33        44.32
# 220        0.71    0.49      0.22        44.92
# 206        0.31    0.57     -0.26        45.07
# 79         0.26    0.47     -0.21        45.20
# 258        0.91    0.62      0.28        45.34
# 129        0.31    0.21      0.10        46.56
# 230        0.42    0.79     -0.38        47.48
# 249        0.21    0.41     -0.20        47.85
# 66         0.02    0.04     -0.02        48.64
# 119        0.31    0.61     -0.30        48.71
# 191        0.42    0.82     -0.40        49.10
# 185        0.33    0.22      0.11        52.26
# 242        0.31    0.66     -0.35        52.53
# 113        0.59    0.38      0.20        53.19
# 91         0.31    0.68     -0.36        53.38
# 84         0.33    0.21      0.12        55.43
# 190        0.31    0.71     -0.40        55.83
# 203        0.42    0.95     -0.53        55.85
# 254        0.33    0.75     -0.42        55.91
# 140        0.31    0.20      0.11        56.15
# 196        0.21    0.49     -0.27        56.22
# 217        0.38    0.88     -0.50        57.20
# 123        0.21    0.51     -0.29        57.84
# 85         0.31    0.20      0.12        60.53
# 151        0.67    0.42      0.25        60.57
# 104        0.30    0.77     -0.47        60.77
# 121        0.31    0.81     -0.50        61.16
# 243        0.38    0.97     -0.60        61.26
# 251        0.38    0.98     -0.60        61.43
# 252        0.38    1.00     -0.62        62.07
# 95         0.03    0.07     -0.04        62.40
# 110        0.81    0.50      0.31        62.80
# 207        0.31    0.85     -0.53        62.92
# 214        0.33    0.20      0.13        63.06
# 88         0.31    0.85     -0.54        63.16
# 78         0.81    0.50      0.31        63.16
# 2          0.00    0.01     -0.01        63.22
# 40         0.00    0.01     -0.01        63.22
# 187        0.81    0.50      0.32        64.25
# 101        0.31    0.88     -0.57        64.35
# 218        0.31    0.93     -0.61        65.96
# 247        0.31    0.93     -0.61        66.12
# 234        0.31    0.93     -0.62        66.16
# 233        1.00    0.60      0.40        66.92
# 228        0.31    0.95     -0.64        66.98
# 208        0.31    0.95     -0.64        66.98
# 27         0.00    0.01     -0.01        67.12
# 57         0.02    0.07     -0.05        67.26
# 231        0.31    0.97     -0.66        67.65
# 192        0.31    0.97     -0.66        67.69
# 268        0.21    0.67     -0.45        68.11
# 152        0.67    0.39      0.27        69.52
# 15         0.00    0.01     -0.01        70.61
# 261        0.21    0.73     -0.52        70.85
# 262        0.21    0.73     -0.52        70.89
# 306        0.26    0.92     -0.66        71.44
# 109        0.81    0.47      0.34        72.68
# 122        0.21    0.78     -0.57        72.81
# 130        0.31    0.18      0.13        73.14
# 313        0.26    0.99     -0.73        73.49
# 269        0.21    0.85     -0.63        74.86
# 21         0.00    0.00     -0.00        75.15
# 267        0.21    0.88     -0.66        75.74
# 278        0.21    0.88     -0.66        75.74
# 303        0.21    0.91     -0.70        76.56
# 68         0.03    0.11     -0.08        76.77
# 277        0.21    0.92     -0.71        76.95
# 263        0.21    0.92     -0.71        76.95
# 237        0.21    0.93     -0.72        77.12
# 311        0.21    0.94     -0.73        77.33
# 138        0.11    0.47     -0.36        77.34
# 284        0.21    0.94     -0.73        77.44
# 236        0.21    0.96     -0.75        77.80
# 299        0.21    0.97     -0.75        77.95
# 304        0.21    0.97     -0.75        77.98
# 307        0.21    0.97     -0.76        78.13
# 273        0.21    0.99     -0.78        78.56
# 315        0.21    0.99     -0.78        78.58
# 165        0.11    0.51     -0.40        78.91
# 144        0.04    0.18     -0.15        80.39
# 45         0.02    0.13     -0.11        82.90
# 77         0.81    0.44      0.37        82.93
# 148        0.07    0.44     -0.37        84.16
# 67         0.01    0.06     -0.05        87.05
# 97         0.02    0.21     -0.19        89.21
# 154        0.02    0.22     -0.20        89.69
# 180        0.02    0.23     -0.20        89.94
# 59         0.00    0.04     -0.03        90.99
# 58         0.00    0.04     -0.04        91.25
# 64         0.00    0.05     -0.04        92.51
# 99         0.02    0.31     -0.29        92.62
# 179        0.03    0.37     -0.34        93.07
# 6          0.00    0.01     -0.01        93.23
# 149        0.03    0.39     -0.36        93.41
# 153        0.02    0.35     -0.33        93.44
# 81         0.00    0.06     -0.05        94.08
# 164        0.04    0.61     -0.58        94.11
# 224        0.02    0.41     -0.39        94.41
# 127        0.02    0.46     -0.44        95.02
# 177        0.02    0.84     -0.82        97.29
# 202        0.03    0.99     -0.97        97.44
# 221        0.02    0.89     -0.87        97.44
# 178        0.02    0.65     -0.63        97.47
# 184        0.00    0.14     -0.13        97.53
# 256        0.02    1.00     -0.97        97.71
# 194        0.00    0.15     -0.15        97.73
# 94         0.00    0.05     -0.05        97.77
# 82         0.00    0.17     -0.17        98.02
# 157        0.00    0.18     -0.18        98.09
# 205        0.01    0.51     -0.50        98.39
# 98         0.00    0.23     -0.22        98.50
# 55         0.00    0.09     -0.09        98.69
# 241        0.00    0.31     -0.31        98.91
# 200        0.01    0.87     -0.86        99.06
# 195        0.00    0.41     -0.40        99.16
# 232        0.00    0.44     -0.44        99.23
# 213        0.00    0.45     -0.44        99.24
# 227        0.00    0.58     -0.58        99.41
# 150        0.00    0.26     -0.26        99.53
# 302        0.00    0.90     -0.89        99.62
# 250        0.00    0.91     -0.91        99.63
# 103        0.00    0.93     -0.92        99.63
# 102        0.00    0.96     -0.95        99.64
# 128        0.00    0.36     -0.36        99.66
# 125        0.00    0.48     -0.48        99.75
# 235        0.00    0.99     -0.99        99.76
# 100        0.00    0.52     -0.52        99.77
# 117        0.71    0.35      0.36       101.81
# 133        0.71    0.34      0.37       109.03
# 155        0.48    0.23      0.25       112.19
# 216        1.00    0.46      0.54       117.43
# 211        0.38    0.17      0.21       120.95
# 174        1.00    0.45      0.55       123.63
# 71         0.33    0.14      0.19       131.08
# 116        0.91    0.38      0.52       137.63
# 156        0.55    0.23      0.32       137.83
# 107        0.31    0.13      0.19       143.91
# 16         0.02    0.01      0.01       146.21
# 145        0.99    0.40      0.60       151.07
# 52         0.00    0.00      0.00       153.09
# 63         0.31    0.12      0.20       164.15
# 46         0.31    0.12      0.20       171.67
# 32         0.59    0.20      0.39       192.58
# 287        0.82    0.28      0.54       194.90
# 76         0.91    0.30      0.61       202.18
# 132        0.38    0.12      0.25       202.76
# 8          0.01    0.00      0.01       205.30
# 223        0.71    0.22      0.49       219.03
# 161        0.21    0.07      0.15       220.48
# 35         0.71    0.22      0.49       227.15
# 96         0.71    0.19      0.51       266.31
# 70         0.59    0.15      0.43       282.81
# 215        0.82    0.20      0.62       317.20
# 183        0.31    0.07      0.24       344.53
# 73         0.31    0.07      0.25       381.93
# 93         0.33    0.07      0.26       403.24
# 72         0.42    0.08      0.34       416.69
# 0          0.01    0.00      0.01       417.98
# 182        0.33    0.06      0.27       420.76
# 30         0.03    0.00      0.02       420.85
# 158        0.11    0.02      0.09       426.71
# 75         0.91    0.17      0.74       447.23
# 74         0.31    0.06      0.26       467.92
# 47         0.31    0.05      0.26       479.41
# 159        0.31    0.05      0.26       530.42
# 36         0.71    0.11      0.60       539.85
# 56         0.59    0.09      0.50       580.52
# 62         0.91    0.13      0.78       607.03
# 11         0.00    0.00      0.00       612.35
# 160        0.38    0.05      0.33       639.60
# 7          0.02    0.00      0.02       752.76
# 13         0.02    0.00      0.02       752.76
# 9          0.03    0.00      0.02       848.57
# 44         0.71    0.06      0.64      1018.88
# 61         0.91    0.08      0.83      1085.61
# 29         0.10    0.01      0.09      1116.27
# 131        0.94    0.06      0.88      1364.75
# 12         0.03    0.00      0.02      1509.36
# 54         0.71    0.04      0.66      1529.59
# 49         0.33    0.01      0.32      3069.97
# 50         0.33    0.01      0.32      3445.76
# 60         0.31    0.01      0.31      5169.73
# 41         0.71    0.01      0.70      6058.18
# 42         0.71    0.01      0.70      6058.18
# 28         0.71    0.01      0.70      6710.84
# 17         0.71    0.01      0.70      6710.84
# 53         0.91    0.01      0.89      8624.89
# 39         0.71    0.01      0.70      9885.81
# 38         0.75    0.01      0.74     10469.30
# 1          0.75    0.01      0.74     10501.15
# 65         0.21    0.00      0.21     13392.70
# 5          0.83    0.01      0.82     13789.02
# 23         0.71    0.00      0.70     14388.51
# 24         1.00    0.01      0.99     16557.86
# 18         0.71    0.00      0.70     18605.82
# 51         0.31    0.00      0.31     19853.93
# 10         0.10    0.00      0.10     20666.67
# 31         0.71    0.00      0.71     44667.87
# 19         0.71    0.00      0.71     44667.87
# 37         0.71    0.00      0.71     44667.87
# 4          0.83    0.00      0.83     52491.01
# 48         0.99    0.00      0.99     62435.39
# 14         0.71    0.00      0.71    147468.15
# 20         0.83    0.00      0.83    173255.56
# 22         0.99    0.00      0.99    206035.19

# %% [markdown]
# # *** Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_test_hat)
print('R2 (testing) = {}'.format(r2_test))

# also: R-Squared could obtain with
# pline.score(x_test, y_test)
# Out:
# R2 (testing) = -0.29256843519246156

# %%
print(np.sqrt(mean_squared_error(y_test,y_test_hat)))
# Out:
# 0.4111735150856962
