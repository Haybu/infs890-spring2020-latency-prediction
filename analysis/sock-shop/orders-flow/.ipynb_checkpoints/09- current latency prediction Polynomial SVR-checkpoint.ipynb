# %% [markdown]
# # Polynomial SVR
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectKBest
import seaborn as sns
from sklearn import preprocessing, metrics, feature_selection
from datetime import datetime
from scipy import stats
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler , MinMaxScaler
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import RFECV
from sklearn.decomposition import PCA

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# Set this flag to True if you're using reduction feature using FCA, otherwise set it to False

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'

#data_file = 'orders_flow_data.csv'   # raw data as is
#data_file = 'order_flow_cleanup_data.csv'
data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'


SCALE_TARGETS = True

test_split = 0.1

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, True)
data = data.reset_index(drop=True)
data.head(5)
# Out:
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0             0.0700          0.0200             0.0100        0.0200
# 1             0.0600          0.0300             0.0100        0.0200
# 2             0.2100          0.0600             0.0200        0.0500
# 3             0.2200          0.0600             0.0200        0.0600
# 4             0.2100          0.0600             0.0100        0.0500
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0           0.0200            0.0100           0.0100         0.1200
# 1           0.0200            0.0100           0.0100         0.1400
# 2           0.0300            0.0200           0.0100         0.2400
# 3           0.0400            0.0200           0.0100         0.2100
# 4           0.0400            0.0200           0.0100         0.1500
#
#    carts-db_cpu_use  front-end_pods  orders_pods  user_pods  shipping_pods  \
# 0            0.1600          1.0000       1.0000     1.0000         1.0000
# 1            0.1700          1.0000       1.0000     1.0000         1.0000
# 2            0.6600          1.0000       1.0000     1.0000         1.0000
# 3            0.6600          1.0000       1.0000     1.0000         1.0000
# 4            0.6600          1.0000       1.0000     1.0000         1.0000
#
#    payment_pods  carts_pods  nodes_cpu_use  orders_req  orders_ltcy
# 0        1.0000      1.0000         1.1800      0.4000       0.4000
# 1        1.0000      1.0000         1.1800      0.4400       0.3900
# 2        1.0000      1.0000         1.8400      1.5800       0.4200
# 3        1.0000      1.0000         1.8300      1.5800       0.4100
# 4        1.0000      1.0000         1.7500      1.4900       0.3900

# %%
data.shape
# Out:
# (3175, 18)

# %%
targets = data['orders_ltcy']
inputs = data.drop(['orders_ltcy'], axis=1)

n_features = inputs.values.shape[1]
print("there are {} features".format(n_features))
# Out:
# there are 17 features

# %%
# scale targets for better convergence
if SCALE_TARGETS:
    y_scaler =  MinMaxScaler()
    targets = y_scaler.fit_transform(targets.values.reshape(-1,1))

# %%
x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=test_split, shuffle=False, random_state=365)

if 1 == 0:
    # for better convergence and result scale target to values between 0 - 1
    y_train_max = y_train.max()
    y_test_max = y_test.max()

    y_train = y_train / y_train_max
    y_test = y_test / y_test_max

# %%
# plot cpu vs latency 
plt.plot(data['orders_cpu_use'][100:200], label='orders_cpu_use')
plt.plot(data['orders_ltcy'][100:200], label='orders_ltcy')
plt.legend()
plt.show()

#ax = sns.regplot(x=data['orders_cpu_use'], y=data['orders_ltcy'], color='g')

# %% [markdown]
# # Model

# %%
#lasso = LassoCV(fit_intercept=False,n_jobs=-1,random_state=0,selection='random',positive=False,cv=10)
#sfm1 = SelectFromModel(lasso, threshold='0.01*mean')

rfr = RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=20)
sfm = SelectFromModel(rfr, threshold='0.01*mean')

#sfm = SelectKBest(k=6)

#sfm = PCA(random_state=180)

# SVR
reg = SVR(kernel='poly', C=100, gamma='auto', degree=3, epsilon=.1, coef0=1)

pipe = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('selector', sfm),
    ('reg', reg)
])

kfold = KFold(n_splits=10, shuffle=True)

param_grid = {
    #'selector__threshold': [0.1, 0.05, 0.02, 0.001]  # with lasso
    
    'selector__threshold': ['0.05*mean', '0.02*mean', '0.01*mean'] # with tree
    , 'selector__estimator__max_depth' : [20]
    , 'selector__estimator__n_estimators' : [40]
    
    #'selector__n_components' : [2,3,4]   # with PCA
    ,'reg__C': [100]
    ,'reg__degree': [2, 3]
    ,'reg__epsilon': [0.1]
}

search = GridSearchCV(pipe, param_grid, scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=1, n_jobs=-1)

#scores = cross_val_score(pipe, x_train, y_train, cv=kfold, n_jobs=-1
        #, verbose=3, scoring='neg_mean_squared_error')

# %%
import sklearn 
print('sklearn version {}'.format(sklearn.__version__))

search.fit(x_train, y_train)
# Out:
# sklearn version 0.22.2.post1
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  6.6min finished
# /opt/anaconda3/envs/infs890/lib/python3.7/site-packages/sklearn/feature_selection/_from_model.py:222: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X, y, **fit_params)
# /opt/anaconda3/envs/infs890/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('selector',
#                                         SelectFromModel(estimator=RandomForestRegressor(bootstrap=True,
#                                                                                         ccp_alpha=0.0,
#                                                                                         criterion='mse',
#                                                                                         max_depth=10,
#                                                                                         max_features='auto',
#                                                                                         max_leaf_nodes=None,
#                                                                                         max_sa...
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'reg__C': [100], 'reg__degree': [2, 3],
#                          'reg__epsilon': [0.1],
#                          'selector__estimator__max_depth': [20],
#                          'selector__estimator__n_estimators': [40],
#                          'selector__threshold': ['0.05*mean', '0.02*mean',
#                                                  '0.01*mean']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=1)

# %% [markdown]
# # Best Model

# %%
score = search.best_score_
print("Best CV test score = %0.4f:" % score)

params = search.best_params_
print("Best CV params = {}".format(params))

#print("")
all_training_scores = search.cv_results_
#print("\ncross_validation:\n", all_training_scores , "\n")

#print('mean train scores')
#print(all_training_scores['mean_train_score'])

#print('mean test scores')
#print(all_training_scores['mean_test_score'])
# Out:
# Best CV test score = -0.0568:
# Best CV params = {'reg__C': 100, 'reg__degree': 2, 'reg__epsilon': 0.1, 'selector__estimator__max_depth': 20, 'selector__estimator__n_estimators': 40, 'selector__threshold': '0.05*mean'}

# %% [markdown]
# # Features Selected

# %%
if 1 == 0:
    best_threshold = params['selector__threshold']
    best_max_depth = params['selector__estimator__max_depth']
    best_n_estimators = params['selector__estimator__n_estimators']

    select_model = RandomForestRegressor(n_jobs=-1, max_depth=best_max_depth, n_estimators=best_n_estimators)
    sfm = SelectFromModel(model, threshold=best_threshold)

    selectedFeatures = sfm.fit(x_train, y_train).transform(x_train)
    print('{} features selected'.format(selectedFeatures[1].shape[0]))

    feature_list = x_train.columns[sfm.get_support()]
    features = ''
    features = ', '.join(feature_list)
    #features

    reduced_x_train = x_train[feature_list]
    #reduced_x_train.head(2)
    print('')
    for feature in reduced_x_train.columns.values:
        print(feature)

# %%
pdf = pd.DataFrame(all_training_scores['mean_test_score'], columns=['testing mse'])
pdf.plot()

# %% [markdown]
# # Training R2

# %%
y_train_hat = search.predict(x_train)

r2_train = metrics.r2_score(y_train, y_train_hat)
print('R2 (training) = {}'.format(r2_train))

print('Score (training) = {}'.format(search.score(x_train,y_train)))
# Out:
# R2 (training) = 0.5355820410309236
# Score (training) = -0.05499439580054038

# %%
# validation mean_absolute_percentage_error
train_error =  np.abs(y_train - y_train_hat)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)


print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.36 (0.24) 0.00 1.31 MSE

# %%
plt.scatter(y_train, y_train_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
plt.show()

# %%
sns.distplot(y_train - y_train_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %% [markdown]
# # Testing

# %%
y_test_hat = search.predict(x_test)

# %%
plt.scatter(y_test, y_test_hat)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_test_hat, color='g')

# %%
perf = pd.DataFrame(y_test_hat, columns=['prediction'])
perf['target'] = y_test
perf.head()
# Out:
#    prediction  target
# 0     -0.1240  0.0016
# 1     -0.2486  0.0071
# 2     -0.2359  0.0093
# 3     -0.1263  0.0027
# 4     -0.2248  0.0016

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0       -0.1240  0.0016   -0.1256   7,958.0423
# 1       -0.2486  0.0071   -0.2556   3,612.6387
# 2       -0.2359  0.0093   -0.2452   2,643.3391
# 3       -0.1263  0.0027   -0.1289   4,814.8366
# 4       -0.2248  0.0016   -0.2264  14,343.7607
# ..          ...     ...       ...          ...
# 313      0.4455  0.9945   -0.5490      55.2034
# 314      0.7567  0.9967   -0.2400      24.0775
# 315      0.6418  0.9945   -0.3527      35.4624
# 316      0.4276  0.9384   -0.5108      54.4300
# 317      0.6352  0.9780   -0.3428      35.0486
#
# [318 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction   target  residual  difference%
# count    318.0000 318.0000  318.0000     318.0000
# mean       0.2823   0.4823   -0.2000   1,443.6972
# std        0.3382   0.3622    0.2154   6,059.9252
# min       -0.5735   0.0005   -0.8348       0.1988
# 25%        0.0055   0.1302   -0.3457      29.7761
# 50%        0.2973   0.4585   -0.1928      53.7961
# 75%        0.5403   0.8859   -0.0418     131.6004
# max        1.1071   1.0000    0.4391  56,414.8720

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 147        0.47    0.47     -0.00         0.20
# 227        0.58    0.58     -0.00         0.22
# 87         0.49    0.49     -0.00         0.25
# 280        0.98    0.98     -0.00         0.34
# 146        0.46    0.46     -0.00         0.40
# 115        0.37    0.37     -0.00         0.64
# 86         0.27    0.26      0.00         1.13
# 179        0.36    0.37     -0.00         1.21
# 186        0.47    0.48     -0.01         1.31
# 153        0.34    0.35     -0.01         1.69
# 150        0.25    0.26     -0.00         1.77
# 55         0.09    0.09     -0.00         2.03
# 286        0.96    0.99     -0.03         2.83
# 98         0.23    0.23      0.01         3.08
# 278        0.91    0.88      0.03         3.45
# 269        0.81    0.85     -0.03         3.88
# 260        1.03    0.99      0.04         4.00
# 279        0.88    0.92     -0.04         4.31
# 164        0.59    0.61     -0.03         4.43
# 188        0.64    0.67     -0.03         4.72
# 111        0.46    0.48     -0.02         5.07
# 259        0.84    0.89     -0.05         5.22
# 123        0.54    0.51      0.03         6.60
# 169        0.67    0.62      0.04         6.94
# 216        0.49    0.46      0.03         7.12
# 298        0.84    0.91     -0.07         7.52
# 288        0.85    0.79      0.06         7.55
# 258        0.57    0.62     -0.05         7.70
# 84         0.19    0.21     -0.02         7.90
# 177        0.77    0.84     -0.07         8.46
# 89         0.85    0.93     -0.08         8.84
# 77         0.40    0.44     -0.04         9.04
# 226        0.20    0.23     -0.02        10.01
# 243        0.88    0.97     -0.10        10.10
# 112        0.41    0.46     -0.05        10.42
# 110        0.55    0.50      0.05        10.79
# 270        1.07    0.96      0.10        10.85
# 190        0.64    0.71     -0.08        10.91
# 244        0.87    0.98     -0.11        11.37
# 135        0.75    0.85     -0.10        12.00
# 151        0.47    0.42      0.05        12.43
# 124        0.57    0.50      0.06        12.48
# 262        0.83    0.73      0.10        13.33
# 165        0.43    0.51     -0.07        14.58
# 207        0.72    0.85     -0.13        15.19
# 304        0.81    0.97     -0.15        15.74
# 63         0.10    0.12     -0.02        16.27
# 290        0.79    0.95     -0.15        16.32
# 119        0.72    0.61      0.10        16.53
# 97         0.18    0.21     -0.04        16.87
# 176        0.74    0.89     -0.15        17.08
# 285        0.76    0.93     -0.17        17.85
# 90         0.70    0.86     -0.16        18.29
# 291        0.79    0.97     -0.18        18.47
# 121        0.66    0.81     -0.15        18.55
# 292        0.80    0.99     -0.19        19.32
# 137        0.41    0.51     -0.10        19.53
# 206        0.46    0.57     -0.12        20.44
# 118        0.54    0.44      0.09        21.13
# 239        0.79    1.00     -0.21        21.26
# 253        0.71    0.91     -0.19        21.42
# 296        0.76    0.97     -0.21        21.69
# 171        0.39    0.49     -0.11        21.70
# 299        0.75    0.97     -0.21        22.09
# 67         0.08    0.06      0.01        22.10
# 208        0.74    0.95     -0.21        22.53
# 238        0.75    0.98     -0.23        23.28
# 197        0.37    0.49     -0.12        23.99
# 314        0.76    1.00     -0.24        24.08
# 88         0.65    0.85     -0.21        24.32
# 108        0.32    0.42     -0.10        24.45
# 109        0.35    0.47     -0.12        24.94
# 284        0.71    0.94     -0.24        25.06
# 261        0.92    0.73      0.19        25.80
# 297        0.53    0.72     -0.19        26.56
# 257        0.69    0.95     -0.25        26.56
# 220        0.36    0.49     -0.13        26.77
# 311        0.67    0.94     -0.27        28.25
# 79         0.33    0.47     -0.14        29.20
# 120        0.57    0.82     -0.24        29.77
# 96         0.14    0.19     -0.06        29.81
# 263        0.64    0.92     -0.28        30.48
# 256        0.69    1.00     -0.31        30.70
# 300        0.68    0.99     -0.30        30.71
# 125        0.33    0.48     -0.15        31.00
# 307        0.67    0.97     -0.30        31.20
# 174        0.31    0.45     -0.14        31.40
# 272        0.65    0.95     -0.30        31.50
# 168        0.32    0.47     -0.15        31.78
# 275        0.66    0.97     -0.31        31.91
# 78         0.33    0.50     -0.16        32.87
# 293        0.54    0.81     -0.27        33.28
# 152        0.26    0.39     -0.14        34.48
# 305        0.64    0.97     -0.34        34.53
# 303        0.59    0.91     -0.31        34.62
# 252        0.65    1.00     -0.35        34.97
# 317        0.64    0.98     -0.34        35.05
# 221        0.58    0.89     -0.31        35.22
# 246        0.80    0.59      0.21        35.25
# 175        0.48    0.73     -0.26        35.27
# 315        0.64    0.99     -0.35        35.46
# 172        0.28    0.44     -0.16        35.69
# 155        0.31    0.23      0.08        35.77
# 219        0.19    0.30     -0.11        35.97
# 193        0.61    0.96     -0.35        36.14
# 294        0.58    0.91     -0.33        36.16
# 241        0.20    0.31     -0.11        36.49
# 282        0.61    0.97     -0.35        36.52
# 203        0.60    0.95     -0.35        36.52
# 185        0.30    0.22      0.08        36.74
# 281        0.56    0.89     -0.33        37.38
# 312        0.61    0.98     -0.37        37.75
# 73         0.09    0.07      0.02        37.78
# 103        0.57    0.93     -0.35        38.01
# 273        0.61    0.99     -0.38        38.40
# 104        0.47    0.77     -0.30        38.83
# 122        0.48    0.78     -0.31        39.25
# 264        0.53    0.88     -0.35        39.46
# 35         0.30    0.22      0.09        40.20
# 187        0.70    0.50      0.20        40.84
# 127        0.27    0.46     -0.19        41.08
# 234        0.54    0.93     -0.39        41.45
# 247        0.54    0.93     -0.39        41.81
# 202        0.58    0.99     -0.42        42.12
# 301        0.55    0.96     -0.41        42.46
# 306        0.53    0.92     -0.40        43.00
# 230        0.45    0.79     -0.34        43.03
# 100        0.29    0.52     -0.23        43.34
# 310        0.47    0.83     -0.36        43.66
# 113        0.22    0.38     -0.17        43.72
# 217        0.50    0.88     -0.39        43.87
# 102        0.53    0.96     -0.42        44.18
# 114        0.59    0.41      0.18        44.37
# 235        0.55    0.99     -0.44        44.67
# 40         0.01    0.01     -0.00        44.90
# 133        0.49    0.34      0.15        45.71
# 224        0.22    0.41     -0.19        46.08
# 308        0.53    1.00     -0.46        46.38
# 201        0.52    0.98     -0.45        46.47
# 309        0.50    0.94     -0.44        46.49
# 265        0.52    0.98     -0.46        46.55
# 289        0.52    0.97     -0.45        46.61
# 205        0.27    0.51     -0.24        47.38
# 251        0.51    0.98     -0.47        48.01
# 255        0.46    0.89     -0.43        48.03
# 204        0.44    0.85     -0.41        48.26
# 228        0.49    0.95     -0.46        48.27
# 32         0.30    0.20      0.10        48.81
# 192        0.50    0.97     -0.48        48.88
# 85         0.29    0.20      0.10        49.60
# 62         0.06    0.13     -0.06        50.16
# 68         0.05    0.11     -0.06        50.65
# 245        0.32    0.65     -0.33        51.19
# 134        0.36    0.75     -0.39        52.26
# 302        0.43    0.90     -0.47        52.33
# 231        0.46    0.97     -0.52        52.96
# 159        0.02    0.05     -0.03        53.20
# 295        0.45    0.96     -0.52        53.56
# 249        0.19    0.41     -0.22        53.59
# 196        0.22    0.49     -0.26        54.00
# 191        0.38    0.82     -0.44        54.06
# 148        0.20    0.44     -0.24        54.43
# 316        0.43    0.94     -0.51        54.43
# 198        0.22    0.48     -0.26        54.46
# 138        0.21    0.47     -0.26        54.48
# 237        0.42    0.93     -0.51        54.69
# 274        0.44    0.99     -0.55        55.12
# 313        0.45    0.99     -0.55        55.20
# 126        0.22    0.49     -0.27        55.31
# 271        0.41    0.93     -0.52        55.95
# 200        0.38    0.87     -0.49        56.24
# 240        0.43    0.99     -0.56        56.44
# 218        0.40    0.93     -0.53        56.82
# 99         0.13    0.31     -0.18        56.86
# 101        0.38    0.88     -0.51        57.45
# 283        0.41    0.96     -0.55        57.49
# 154        0.35    0.22      0.13        57.92
# 189        0.22    0.52     -0.31        58.73
# 166        0.20    0.48     -0.28        59.00
# 173        0.50    0.31      0.19        59.55
# 209        0.39    0.96     -0.57        59.57
# 76         0.48    0.30      0.18        59.73
# 144        0.30    0.18      0.11        61.07
# 248        0.14    0.36     -0.22        61.45
# 136        0.33    0.86     -0.53        61.54
# 242        0.24    0.66     -0.42        63.94
# 236        0.35    0.96     -0.61        64.02
# 34         0.45    0.27      0.18        64.09
# 225        0.26    0.76     -0.50        65.33
# 277        0.32    0.92     -0.60        65.43
# 268        1.11    0.67      0.44        65.75
# 170        0.24    0.70     -0.46        66.06
# 254        0.25    0.75     -0.50        66.93
# 139        0.11    0.35     -0.23        67.15
# 250        0.30    0.91     -0.61        67.33
# 178        0.21    0.65     -0.45        68.44
# 36         0.19    0.11      0.08        68.86
# 163        0.16    0.50     -0.34        68.87
# 199        0.15    0.49     -0.34        69.04
# 267        0.27    0.88     -0.61        69.23
# 91         0.21    0.68     -0.47        69.24
# 117        0.60    0.35      0.25        70.51
# 83         0.35    0.21      0.15        72.17
# 105        0.13    0.49     -0.36        72.52
# 131        0.11    0.06      0.05        72.84
# 70         0.04    0.15     -0.11        73.35
# 128        0.09    0.36     -0.27        74.09
# 80         0.10    0.42     -0.32        75.52
# 69         0.04    0.16     -0.12        76.35
# 276        0.21    0.97     -0.77        78.69
# 167        0.08    0.44     -0.35        80.91
# 266        0.18    0.99     -0.81        81.71
# 214        0.03    0.20     -0.17        83.28
# 145        0.06    0.40     -0.34        85.05
# 45         0.02    0.13     -0.12        86.86
# 162        0.04    0.31     -0.27        87.30
# 222        0.09    0.91     -0.83        90.36
# 106        0.03    0.39     -0.36        91.75
# 33         0.57    0.30      0.27        91.88
# 213        0.03    0.45     -0.41        92.55
# 184        0.01    0.14     -0.13        94.29
# 212        0.02    0.36     -0.34        94.56
# 194        0.01    0.15     -0.14        95.65
# 232        0.02    0.44     -0.42        96.16
# 92         0.00    0.42     -0.42        99.94
# 287        0.56    0.28      0.28       101.45
# 156       -0.00    0.23     -0.23       101.57
# 56        -0.00    0.09     -0.09       102.44
# 211       -0.00    0.17     -0.18       102.48
# 233       -0.02    0.60     -0.62       103.17
# 130       -0.01    0.18     -0.19       103.87
# 142       -0.02    0.28     -0.29       106.48
# 149       -0.03    0.39     -0.42       107.87
# 71        -0.03    0.14     -0.17       119.17
# 210       -0.08    0.40     -0.47       119.37
# 161        0.15    0.07      0.08       123.78
# 107        0.29    0.13      0.16       127.45
# 75        -0.05    0.17     -0.21       128.65
# 141       -0.10    0.31     -0.42       132.59
# 116       -0.17    0.38     -0.55       143.49
# 229       -0.29    0.55     -0.83       152.32
# 223       -0.12    0.22     -0.34       152.64
# 129       -0.12    0.21     -0.33       154.84
# 132        0.32    0.12      0.19       155.87
# 82        -0.10    0.17     -0.27       158.69
# 44        -0.04    0.06     -0.10       160.62
# 195       -0.25    0.41     -0.66       160.91
# 64        -0.03    0.05     -0.07       164.03
# 215       -0.13    0.20     -0.32       164.69
# 140       -0.14    0.20     -0.34       167.30
# 72         0.22    0.08      0.14       173.48
# 58        -0.03    0.04     -0.07       174.44
# 183       -0.05    0.07     -0.12       175.12
# 181       -0.17    0.21     -0.38       180.28
# 143       -0.16    0.20     -0.36       181.08
# 158       -0.02    0.02     -0.04       185.71
# 61         0.22    0.08      0.14       188.99
# 74         0.16    0.06      0.11       191.47
# 180       -0.22    0.23     -0.44       195.87
# 53         0.03    0.01      0.02       202.37
# 182       -0.07    0.06     -0.13       203.05
# 66         0.14    0.04      0.10       218.32
# 160        0.16    0.05      0.11       222.69
# 46        -0.15    0.12     -0.27       229.75
# 43        -0.04    0.03     -0.07       258.13
# 157       -0.29    0.18     -0.46       260.20
# 93        -0.11    0.07     -0.18       274.54
# 81        -0.10    0.06     -0.16       278.28
# 94        -0.11    0.05     -0.17       310.26
# 59        -0.08    0.04     -0.12       313.52
# 95        -0.15    0.07     -0.22       319.51
# 47         0.24    0.05      0.19       343.65
# 57        -0.37    0.07     -0.44       625.73
# 5         -0.05    0.01     -0.05       878.08
# 54        -0.35    0.04     -0.39       902.36
# 65        -0.02    0.00     -0.02      1349.86
# 29        -0.11    0.01     -0.12      1440.30
# 17        -0.16    0.01     -0.17      1616.91
# 50        -0.14    0.01     -0.15      1656.88
# 38        -0.11    0.01     -0.12      1665.74
# 19        -0.03    0.00     -0.03      1740.47
# 16        -0.16    0.01     -0.17      1841.88
# 6         -0.13    0.01     -0.14      1926.50
# 41        -0.23    0.01     -0.24      2095.61
# 49        -0.21    0.01     -0.22      2154.08
# 12         0.04    0.00      0.03      2189.19
# 42        -0.27    0.01     -0.28      2440.11
# 2         -0.24    0.01     -0.25      2643.34
# 15        -0.23    0.01     -0.23      2855.23
# 27        -0.33    0.01     -0.34      3289.07
# 39        -0.23    0.01     -0.24      3371.78
# 1         -0.25    0.01     -0.26      3612.64
# 26        -0.22    0.01     -0.22      3724.49
# 28        -0.38    0.01     -0.39      3789.69
# 21        -0.19    0.00     -0.19      3980.66
# 30        -0.20    0.00     -0.21      4224.88
# 9         -0.11    0.00     -0.12      4346.06
# 31         0.07    0.00      0.07      4493.23
# 3         -0.13    0.00     -0.13      4814.84
# 23        -0.25    0.00     -0.25      5153.43
# 24        -0.33    0.01     -0.34      5614.62
# 13        -0.18    0.00     -0.18      6797.17
# 0         -0.12    0.00     -0.13      7958.04
# 7         -0.23    0.00     -0.23      8506.26
# 48        -0.15    0.00     -0.15      9404.30
# 25        -0.36    0.00     -0.36      9645.81
# 60        -0.57    0.01     -0.58      9696.05
# 8         -0.29    0.00     -0.29     10780.73
# 18        -0.44    0.00     -0.45     11828.61
# 37        -0.19    0.00     -0.19     12040.21
# 4         -0.22    0.00     -0.23     14343.76
# 51         0.33    0.00      0.32     20539.39
# 22         0.10    0.00      0.10     21250.98
# 10        -0.14    0.00     -0.14     28955.10
# 20        -0.17    0.00     -0.17     35158.20
# 14        -0.22    0.00     -0.22     45883.52
# 52        -0.25    0.00     -0.25     52201.63
# 11        -0.27    0.00     -0.27     56414.87

# %% [markdown]
# # *** Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_test_hat)
print('R2 (testing) = {}'.format(r2_test))

# also: R-Squared could obtain with
# pline.score(x_test, y_test)
# Out:
# R2 (testing) = 0.34045798764386936

# %%
print(np.sqrt(mean_squared_error(y_test,y_test_hat)))
# Out:
# 0.2937105808234938
