# %% [markdown]
# # Linear Regression
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import seaborn as sns
from sklearn import preprocessing, metrics, feature_selection
from datetime import datetime
from scipy import stats
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.3f}'.format

# %% [markdown]
# Set this flag to True if you're using reduction feature using FCA, otherwise set it to False

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'

data_file = 'order_flow_cleanup_data.csv'
#data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'



test_split = 0.1

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, False)
data.head(5)
# Out:
#                   date  front-end_cpu_use  orders_cpu_use  user_cpu_use  \
# 0  2020-03-27 00:00:22              -1.29           -0.33         -1.29
# 1  2020-03-27 00:00:37              -1.27           -0.25         -1.29
# 2  2020-03-27 00:00:52              -1.24           -0.98         -1.22
# 3  2020-03-27 00:01:07              -1.17           -0.91         -1.22
# 4  2020-03-27 00:01:22              -1.15           -0.25         -1.15
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0            -1.18             14.71            -1.45           0.01
# 1            -1.30             14.71            -1.45           0.03
# 2            -1.18             12.09            -1.45           0.13
# 3            -1.18              6.56            -1.45           0.11
# 4            -1.18              1.03            -1.45          -0.07
#
#    carts-db_cpu_use  nodes_cpu_use  orders_req  orders_ltcy
# 0             -0.91          -1.07       -1.21         0.24
# 1             -0.91          -1.05       -1.21         0.24
# 2             -0.87          -1.12       -1.21         0.24
# 3             -0.81          -1.09       -1.21         0.24
# 4             -0.80          -1.18       -1.20         0.24

# %%
data.shape
# Out:
# (5711, 12)

# %%
targets = data['orders_ltcy']

inputs = data.drop(['orders_ltcy'], axis=1)
inputs = inputs.drop(['date'], axis=1)

n_features = inputs.values.shape[1]

#inputs_scaled = scaler.fit_transform(inputs)
#x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=test_split, shuffle=False, random_state=365)

# for better convergence and result scale target to values between 0 - 1
y_train_max = y_train.max()
y_test_max = y_test.max()

y_train = y_train / y_train_max
y_test = y_test / y_test_max

print("there are {} features".format(n_features))
# Out:
# there are 10 features

# %%
#plt.scatter(data['orders_cpu_use'], data['orders_ltcy'])
#plt.xlabel('orders_cpu_use', size=18)
#plt.ylabel("orders_ltcy", size=18)
#plt.show()

# plot cpu vs latency 
plt.plot(data['orders_cpu_use'][:100], label='orders_cpu_use')
plt.plot(data['orders_ltcy'][:100], label='orders_ltcy')
plt.legend()
plt.show()

#ax = sns.regplot(x=data['orders_cpu_use'], y=data['orders_ltcy'], color='g')

# %% [markdown]
# # Regression with Feature Selection

# %%
# -- trying features selection 1
#selector = feature_selection.SelectKBest(feature_selection.f_regression).fit(x_train, y_train)
#selectedFeatures = selector.transform(x_train)
#print('{} features selected'.format(selectedFeatures[1].shape[0]))

# %%
# -- trying features selection 2
#clf = LassoCV()
#sfm = SelectFromModel(clf) #(clf, threshold=0.01)
#selectedFeatures = sfm.fit(x_train, y_train).transform(x_train)
#print('{} features selected'.format(selectedFeatures[1].shape[0]))

# %%
# -- trying features selection 3
clf = RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15)
sfm = SelectFromModel(clf,threshold='0.8*mean')

# %%
# start:  search grid

reg = LinearRegression(normalize=False) # normalize false bacause we are going to use the scaler

# standardize the features
scaler = StandardScaler()
#scaler.fit(x_train.values.reshape(-1,n_features))

pipe = Pipeline(steps=[
    ('scaler', scaler),
    ('selector', sfm), 
    ('clf', reg)
])

kfold = KFold(n_splits=10, shuffle=False)

param_grid = {
    'selector__threshold': ['.1*mean', '.08*mean', '.05*mean', '.02*mean', '.01*mean']
    ,'clf__normalize': [False, True]
}

search = GridSearchCV(pipe, param_grid,scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=0, n_jobs=-1)

search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('selector',
#                                         SelectFromModel(estimator=RandomForestRegressor(bootstrap=True,
#                                                                                         ccp_alpha=0.0,
#                                                                                         criterion='mse',
#                                                                                         max_depth=10,
#                                                                                         max_features='auto',
#                                                                                         max_leaf_nodes=None,
#                                                                                         max_s...
#                                        ('clf',
#                                         LinearRegression(copy_X=True,
#                                                          fit_intercept=True,
#                                                          n_jobs=None,
#                                                          normalize=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'clf__normalize': [False, True],
#                          'selector__threshold': ['.1*mean', '.08*mean',
#                                                  '.05*mean', '.02*mean',
#                                                  '.01*mean']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
estimator = search.best_estimator_
params = search.best_params_
score = search.best_score_

print("Best CV score = %0.3f:" % score)
print("Best CV params = {}".format(params))

print("")
all_training_scores = search.cv_results_
#print("\ncross_validation:\n", all_training_scores , "\n")
print(all_training_scores['mean_train_score'])
# Out:
# Best CV score = -0.099:
# Best CV params = {'clf__normalize': True, 'selector__threshold': '.01*mean'}
#
# [-0.08388398 -0.08402187 -0.08215019 -0.08213215 -0.0755279  -0.08432077
#  -0.08355872 -0.08312748 -0.0813703  -0.0755279 ]

# %%
pdf = pd.DataFrame(all_training_scores['mean_train_score'], columns=['training mse'])
pdf.plot()

# %% [markdown]
# # Training R2

# %%
y_hat = estimator.predict(x_train)

r2_train = metrics.r2_score(y_train, y_hat)
print('R2 (training) = {}'.format(r2_train))

#print("score ", search.score(x_test, y_test))
# or also R-Squared could be obtain via
#pline.score(x_train, y_train)
# Out:
# R2 (training) = 0.40600139037663363

# %%
print('Score (training) = {}'.format(search.score(x_train,y_train)))
# Out:
# Score (training) = -0.07657610297717415

# %%
estimator.fit(x_train, y_train)

estimator.named_steps.clf.intercept_
# Out:
# 0.3191755299481821

# %%
estimator.named_steps.clf.coef_
# Out:
# array([-0.4226004 , -0.02440317,  0.04619235, -0.21326669,  0.27978558,
#        -0.06375969,  0.09559349,  0.47418211,  0.12654454, -0.06291234,
#         0.01418212])

# %%
# validation mean_absolute_percentage_error
train_error =  np.abs(y_train - y_hat)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)


print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.22 (0.17) 0.00 1.05 MSE

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
#plt.xlim(-2,3)
#plt.ylim(-3,1)
plt.show()

# %%
sns.distplot(y_train - y_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %% [markdown]
# # Testing

# %%
y_hat_test = estimator.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_hat_test, color='g')

# %%
perf = pd.DataFrame(np.exp(y_hat_test), columns=['prediction'])
y_test = y_test.reset_index(drop=True)
perf['target'] = np.exp(y_test)
perf.head()
# Out:
#    prediction  target
# 0       1.036   1.047
# 1       0.934   1.047
# 2       1.290   1.049
# 3       1.089   1.052
# 4       0.944   1.052

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0         1.036   1.047    -0.012        1.127
# 1         0.934   1.047    -0.113       10.785
# 2         1.290   1.049     0.240       22.907
# 3         1.089   1.052     0.037        3.561
# 4         0.944   1.052    -0.107       10.221
# ..          ...     ...       ...          ...
# 567       3.969   2.690     1.279       47.526
# 568       4.724   2.690     2.034       75.584
# 569       5.948   2.685     3.263      121.540
# 570       5.530   2.693     2.836      105.311
# 571       3.965   2.702     1.263       46.750
#
# [572 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction  target  residual  difference%
# count     572.000 572.000   572.000      572.000
# mean        2.659   1.918     0.740       51.302
# std         1.793   0.673     1.451       54.308
# min         0.833   1.016    -1.430        0.002
# 25%         1.354   1.187    -0.170       12.178
# 50%         1.797   2.060     0.194       30.291
# 75%         3.799   2.618     1.407       78.114
# max         8.667   2.718     7.374      570.312

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 521        2.60    2.60     -0.00         0.00
# 165        1.65    1.65      0.00         0.01
# 181        1.20    1.21     -0.00         0.15
# 62         1.21    1.20      0.00         0.23
# 7          1.18    1.18      0.00         0.40
# 105        1.61    1.60      0.01         0.54
# 68         1.22    1.21      0.01         0.65
# 306        2.38    2.36      0.02         0.71
# 33         1.12    1.13     -0.01         0.73
# 352        2.05    2.06     -0.02         0.73
# 133        1.27    1.26      0.01         0.83
# 197        1.66    1.65      0.02         0.97
# 0          1.04    1.05     -0.01         1.13
# 27         1.04    1.03      0.01         1.16
# 36         1.09    1.08      0.01         1.19
# 139        1.62    1.60      0.02         1.32
# 196        1.62    1.64     -0.02         1.36
# 141        1.55    1.57     -0.02         1.40
# 488        2.40    2.36      0.03         1.48
# 63         1.18    1.20     -0.02         1.59
# 126        1.40    1.43     -0.02         1.59
# 92         1.37    1.39     -0.02         1.60
# 106        1.46    1.49     -0.03         1.82
# 262        1.51    1.54     -0.03         1.94
# 236        1.31    1.29      0.03         2.00
# 71         1.62    1.66     -0.04         2.27
# 116        1.71    1.67      0.04         2.30
# 293        2.73    2.66      0.06         2.34
# 104        1.68    1.64      0.04         2.41
# 159        1.71    1.67      0.04         2.57
# 218        1.29    1.26      0.03         2.70
# 274        1.76    1.71      0.05         3.10
# 193        1.44    1.40      0.04         3.11
# 235        1.63    1.58      0.05         3.16
# 130        1.72    1.67      0.05         3.27
# 158        1.78    1.85     -0.06         3.30
# 146        1.39    1.44     -0.05         3.37
# 472        2.38    2.47     -0.08         3.37
# 464        2.56    2.65     -0.09         3.41
# 15         1.00    1.04     -0.04         3.43
# 12         1.07    1.03      0.04         3.51
# 3          1.09    1.05      0.04         3.56
# 98         1.59    1.64     -0.06         3.59
# 8          1.12    1.16     -0.04         3.64
# 167        1.44    1.39      0.05         3.65
# 61         1.11    1.15     -0.04         3.65
# 135        1.40    1.35      0.05         3.85
# 50         1.00    1.04     -0.04         3.85
# 183        1.32    1.27      0.05         3.93
# 180        1.26    1.22      0.05         3.94
# 463        2.68    2.58      0.10         4.00
# 28         0.98    1.03     -0.04         4.00
# 34         1.16    1.11      0.05         4.09
# 25         0.98    1.03     -0.04         4.12
# 103        1.59    1.66     -0.07         4.28
# 213        1.27    1.22      0.05         4.33
# 86         1.06    1.11     -0.05         4.34
# 44         1.07    1.03      0.04         4.35
# 21         1.00    1.04     -0.05         4.37
# 20         1.07    1.03      0.05         4.40
# 136        1.20    1.25     -0.06         4.65
# 466        2.42    2.53     -0.12         4.66
# 178        1.16    1.10      0.05         4.76
# 58         1.08    1.03      0.05         4.77
# 122        1.21    1.27     -0.06         5.03
# 16         1.09    1.04      0.05         5.03
# 60         1.16    1.10      0.06         5.04
# 166        1.49    1.57     -0.08         5.14
# 132        1.37    1.44     -0.07         5.14
# 542        2.50    2.64     -0.14         5.15
# 450        2.68    2.55      0.13         5.22
# 156        1.31    1.39     -0.07         5.27
# 489        2.04    2.16     -0.11         5.29
# 70         1.49    1.58     -0.08         5.38
# 57         0.97    1.03     -0.06         5.55
# 110        1.52    1.44      0.08         5.61
# 32         1.20    1.13      0.06         5.64
# 6          1.04    1.10     -0.06         5.72
# 87         1.03    1.09     -0.06         5.77
# 173        1.38    1.47     -0.09         6.02
# 565        2.75    2.60      0.16         6.04
# 134        1.31    1.40     -0.09         6.27
# 145        1.41    1.50     -0.09         6.29
# 79         1.24    1.33     -0.08         6.35
# 402        2.08    2.22     -0.14         6.35
# 69         1.47    1.38      0.09         6.52
# 300        2.68    2.51      0.17         6.62
# 64         1.11    1.19     -0.08         6.79
# 186        1.82    1.95     -0.14         6.95
# 301        2.23    2.40     -0.17         7.05
# 97         1.99    2.14     -0.15         7.09
# 537        0.95    1.02     -0.07         7.24
# 182        1.27    1.18      0.09         7.25
# 72         1.73    1.62      0.12         7.30
# 101        1.43    1.54     -0.12         7.48
# 107        1.41    1.52     -0.11         7.50
# 396        2.22    2.06      0.16         7.62
# 229        1.79    1.66      0.13         7.64
# 39         1.10    1.03      0.08         7.67
# 216        1.71    1.59      0.12         7.68
# 121        1.34    1.46     -0.11         7.81
# 564        2.30    2.50     -0.20         8.16
# 187        1.56    1.70     -0.14         8.21
# 29         1.13    1.04      0.09         8.23
# 123        1.34    1.23      0.10         8.42
# 421        2.48    2.28      0.20         8.76
# 38         1.13    1.04      0.09         8.91
# 351        2.78    2.55      0.23         8.96
# 111        1.43    1.57     -0.14         8.96
# 37         0.95    1.05     -0.09         9.08
# 150        1.40    1.28      0.12         9.12
# 131        1.47    1.62     -0.15         9.16
# 163        1.69    1.86     -0.17         9.27
# 102        1.47    1.62     -0.15         9.33
# 194        1.09    1.20     -0.11         9.35
# 140        1.77    1.62      0.15         9.46
# 425        1.85    2.04     -0.19         9.52
# 287        2.42    2.68     -0.26         9.73
# 292        2.36    2.62     -0.26         9.92
# 19         1.13    1.03      0.10         9.93
# 275        1.31    1.46     -0.15        10.04
# 268        2.23    2.48     -0.25        10.18
# 4          0.94    1.05     -0.11        10.22
# 175        1.14    1.27     -0.13        10.27
# 108        1.63    1.47      0.15        10.30
# 215        1.42    1.58     -0.16        10.35
# 185        1.82    1.65      0.17        10.36
# 100        1.30    1.17      0.12        10.49
# 554        2.97    2.69      0.29        10.66
# 96         2.21    2.47     -0.26        10.68
# 144        1.37    1.54     -0.16        10.73
# 117        1.49    1.67     -0.18        10.73
# 1          0.93    1.05     -0.11        10.79
# 357        2.13    2.39     -0.26        10.80
# 247        2.36    2.65     -0.29        10.82
# 327        2.95    2.66      0.29        11.04
# 75         1.36    1.22      0.14        11.37
# 225        1.22    1.38     -0.16        11.58
# 248        2.72    2.44      0.29        11.70
# 223        2.00    2.28     -0.27        11.93
# 18         1.16    1.03      0.12        12.00
# 522        2.99    2.67      0.32        12.05
# 511        1.94    2.20     -0.27        12.12
# 30         1.18    1.05      0.13        12.20
# 281        2.13    2.43     -0.30        12.23
# 99         1.32    1.50     -0.19        12.35
# 137        1.39    1.24      0.15        12.36
# 184        1.42    1.63     -0.20        12.44
# 533        1.98    2.27     -0.28        12.45
# 143        1.16    1.33     -0.17        12.67
# 88         0.97    1.11     -0.14        12.72
# 151        1.07    1.23     -0.16        12.79
# 290        1.62    1.86     -0.24        12.97
# 319        2.81    2.49      0.33        13.10
# 276        1.32    1.52     -0.21        13.47
# 273        2.01    2.33     -0.32        13.64
# 211        1.74    2.01     -0.28        13.67
# 114        1.92    2.22     -0.30        13.72
# 13         1.18    1.03      0.14        13.72
# 160        1.40    1.62     -0.23        13.91
# 23         1.20    1.05      0.15        13.94
# 162        1.38    1.61     -0.23        13.99
# 206        1.53    1.78     -0.25        14.00
# 168        1.35    1.58     -0.22        14.15
# 345        3.01    2.63      0.38        14.40
# 73         1.32    1.55     -0.22        14.51
# 544        2.29    2.68     -0.39        14.72
# 496        1.85    2.17     -0.32        14.78
# 22         1.21    1.05      0.16        14.80
# 5          1.23    1.07      0.16        14.93
# 124        1.27    1.10      0.17        15.08
# 214        1.23    1.45     -0.22        15.34
# 234        1.92    1.66      0.26        15.64
# 179        1.29    1.11      0.18        16.03
# 212        1.26    1.51     -0.24        16.14
# 224        1.37    1.64     -0.27        16.19
# 26         1.19    1.03      0.17        16.27
# 10         1.19    1.02      0.17        16.43
# 83         1.94    2.32     -0.38        16.44
# 78         1.46    1.25      0.21        16.69
# 14         1.21    1.03      0.17        16.70
# 31         0.90    1.08     -0.18        16.76
# 74         1.28    1.10      0.18        16.78
# 66         1.29    1.11      0.19        16.81
# 198        1.35    1.62     -0.27        16.89
# 45         1.20    1.03      0.17        16.89
# 360        7.01    2.70      4.30       159.09
# 383        6.93    2.67      4.26       159.35
# 362        7.06    2.66      4.40       165.57
# 317        7.10    2.65      4.45       167.47
# 434        7.22    2.68      4.54       169.67
# 316        7.31    2.67      4.64       174.00
# 384        7.41    2.70      4.72       174.93
# 314        6.34    2.30      4.04       175.87
# 526        7.53    2.71      4.81       177.40
# 435        7.55    2.70      4.84       179.30
# 385        7.58    2.71      4.87       179.36
# 386        7.58    2.69      4.89       181.40
# 412        7.68    2.70      4.97       183.86
# 361        7.74    2.70      5.03       186.07
# 411        7.83    2.69      5.14       190.87
# 376        2.97    1.02      1.95       192.10
# 302        2.99    1.02      1.97       192.88
# 540        3.00    1.02      1.97       193.24
# 502        8.06    2.71      5.35       197.64
# 334        7.74    2.59      5.15       199.16
# 541        3.22    1.02      2.20       215.36
# 311        7.89    2.36      5.53       233.93
# 313        6.61    1.94      4.67       240.26
# 312        8.67    1.29      7.37       570.31

# %% [markdown]
# # Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_hat_test)
print('R2 (testing) = {}'.format(r2_test))

# also: R-Squared could obtain with
# pline.score(x_test, y_test)
# Out:
# R2 (testing) = -0.6599442692969377

# %%
print(np.sqrt(mean_squared_error(y_test,y_hat_test)))
# Out:
# 0.4962044223817762

# %% [markdown]
# # What features selected

# %%
x_train.shape
# Out:
# (5139, 11)

# %%
#clf = LassoCV()
#sfm = SelectFromModel(clf, threshold=0.001)

threshold_selected = params['selector__threshold']

sfm = SelectFromModel(
                RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15),
                threshold=threshold_selected)

selectedFeatures = sfm.fit(inputs, targets).transform(inputs)
print('{} features selected'.format(selectedFeatures[1].shape[0]))

feature_list = x_train.columns[sfm.get_support()]
features = ''
features = ', '.join(feature_list)
#features

reduced_x_train = x_train[feature_list]
reduced_x_train.head(2)
# Out:
# 11 features selected
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0               0.02            0.17               0.01          0.02
# 1               0.03            0.18               0.01          0.02
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0             0.02              0.56             0.02           0.57
# 1             0.01              0.56             0.02           0.58
#
#    carts-db_cpu_use  nodes_cpu_use  orders_req
# 0              0.01           1.84        0.00
# 1              0.01           1.89        0.00

# %% [markdown]
# # Trying with Polynomial features

# %%
if True:
    from sklearn.preprocessing import PolynomialFeatures

    # covert input data to polynomial form of some degree
    inputs_poly = PolynomialFeatures(degree=2).fit_transform(inputs).astype(float)

    x_train, x_test, y_train, y_test = \
        train_test_split(inputs_poly, targets, test_size=test_split, shuffle=False, random_state=365)

    # for better convergence and result scale target to values between 0 - 1
    y_train_max = y_train.max()
    y_test_max = y_test.max()

    y_train = y_train / y_train_max
    y_test = y_test / y_test_max


    reg = LinearRegression(normalize=False) # normalize false bacause we are going to use the scaler

    scaler = StandardScaler()

    pipe = Pipeline(steps=[
        ('scaler', scaler),
        ('selector', sfm), 
        ('clf', reg)
    ])

    kfold = KFold(n_splits=10, shuffle=False)

    param_grid = {
        'selector__threshold': ['.1*mean', '.08*mean', '.05*mean', '.02*mean', '.001*mean']
    }

    search = GridSearchCV(pipe, param_grid,scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=0, n_jobs=-1)

    search.fit(x_train, y_train)

    y_hat_test = search.predict(x_test)

    r2_test = metrics.r2_score(y_test, y_hat_test)
    print('R2 (testing) = {}'.format(r2_test))
# Out:
# R2 (testing) = -0.15129778891000112

# %% [markdown]
# # Robust Linear Model

# %%
# RANSAC is an iterative algorithm for the robust estimation of parameters from a subset 
# of inliers from the complete data set.
# you can use this with all dataset including outliers
if False:    
    from sklearn.linear_model import RANSACRegressor

    ransac = RANSACRegressor(estimator)
    ransac.fit(x_train, y_train)
    inlier_mask = ransac.inlier_mask_
    outlier_mask = np.logical_not(inlier_mask)

    y_hat_test = ransac.predict(x_test)

    r2_test = metrics.r2_score(y_test, y_hat_test)
    print('R2 (testing) = {}'.format(r2_test))
