# %% [markdown]
# # Linear Regression
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import seaborn as sns
from sklearn import preprocessing, metrics, feature_selection
from datetime import datetime
from scipy import stats
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# Set this flag to True if you're using reduction feature using FCA, otherwise set it to False

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'

#data_file = 'order_flow_cleanup_data.csv'
data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'



test_split = 0.1

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, True)
data = data.reset_index(drop=True)
data.head(5)
# Out:
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0               0.07            0.02               0.01          0.02
# 1               0.06            0.03               0.01          0.02
# 2               0.06            0.03               0.01          0.02
# 3               0.09            0.03               0.01          0.02
# 4               0.11            0.04               0.01          0.03
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0             0.02              0.01             0.01           0.12
# 1             0.02              0.01             0.01           0.14
# 2             0.02              0.01             0.01           0.15
# 3             0.02              0.01             0.01           0.06
# 4             0.03              0.01             0.01           0.11
#
#    carts-db_cpu_use  front-end_pods  orders_pods  user_pods  shipping_pods  \
# 0              0.16            1.00         1.00       1.00           1.00
# 1              0.17            1.00         1.00       1.00           1.00
# 2              0.14            1.00         1.00       1.00           1.00
# 3              0.19            1.00         1.00       1.00           1.00
# 4              0.32            1.00         1.00       1.00           1.00
#
#    payment_pods  carts_pods  nodes_cpu_use  orders_req  orders_ltcy
# 0          1.00        1.00           1.18        0.40         0.63
# 1          1.00        1.00           1.18        0.44         0.62
# 2          1.00        1.00           1.15        0.36         0.62
# 3          1.00        1.00           1.54        0.40         0.56
# 4          1.00        1.00           2.35        0.78         0.53

# %%
data.shape
# Out:
# (1499, 18)

# %%
targets = data['orders_ltcy']

inputs = data.drop(['orders_ltcy'], axis=1)
#inputs = inputs.drop(['date'], axis=1)

n_features = inputs.values.shape[1]

#inputs_scaled = scaler.fit_transform(inputs)
#x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=test_split, shuffle=False, random_state=365)

# for better convergence and result scale target to values between 0 - 1
y_train_max = y_train.max()
y_test_max = y_test.max()

y_train = y_train / y_train_max
y_test = y_test / y_test_max

print("there are {} features".format(n_features))
# Out:
# there are 17 features

# %%
#plt.scatter(data['orders_cpu_use'], data['orders_ltcy'])
#plt.xlabel('orders_cpu_use', size=18)
#plt.ylabel("orders_ltcy", size=18)
#plt.show()

# plot cpu vs latency 
plt.plot(data['orders_cpu_use'][:100], label='orders_cpu_use')
plt.plot(data['orders_ltcy'][:100], label='orders_ltcy')
plt.legend()
plt.show()

#ax = sns.regplot(x=data['orders_cpu_use'], y=data['orders_ltcy'], color='g')

# %% [markdown]
# # Regression with Feature Selection

# %%
# -- trying features selection 1
#selector = feature_selection.SelectKBest(feature_selection.f_regression).fit(x_train, y_train)
#selectedFeatures = selector.transform(x_train)
#print('{} features selected'.format(selectedFeatures[1].shape[0]))

# %%
# -- trying features selection 2
#clf = LassoCV()
#sfm = SelectFromModel(clf) #(clf, threshold=0.01)
#selectedFeatures = sfm.fit(x_train, y_train).transform(x_train)
#print('{} features selected'.format(selectedFeatures[1].shape[0]))

# %%
# -- trying features selection 3
clf = RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15)
sfm = SelectFromModel(clf,threshold='0.8*mean')

# %%
# start:  search grid

reg = LinearRegression(normalize=False) # normalize false bacause we are going to use the scaler

# standardize the features
scaler = StandardScaler()
#scaler.fit(x_train.values.reshape(-1,n_features))

pipe = Pipeline(steps=[
    ('scaler', scaler),
    ('selector', sfm), 
    ('clf', reg)
])

kfold = KFold(n_splits=10, shuffle=False)

param_grid = {
    'selector__threshold': ['.1*mean', '.08*mean', '.05*mean', '.02*mean', '.01*mean']
    ,'clf__normalize': [False, True]
}

search = GridSearchCV(pipe, param_grid,scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=0, n_jobs=-1)

search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('selector',
#                                         SelectFromModel(estimator=RandomForestRegressor(bootstrap=True,
#                                                                                         ccp_alpha=0.0,
#                                                                                         criterion='mse',
#                                                                                         max_depth=10,
#                                                                                         max_features='auto',
#                                                                                         max_leaf_nodes=None,
#                                                                                         max_s...
#                                        ('clf',
#                                         LinearRegression(copy_X=True,
#                                                          fit_intercept=True,
#                                                          n_jobs=None,
#                                                          normalize=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'clf__normalize': [False, True],
#                          'selector__threshold': ['.1*mean', '.08*mean',
#                                                  '.05*mean', '.02*mean',
#                                                  '.01*mean']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
estimator = search.best_estimator_
params = search.best_params_
score = search.best_score_

print("Best CV score = %0.3f:" % score)
print("Best CV params = {}".format(params))

print("")
all_training_scores = search.cv_results_
#print("\ncross_validation:\n", all_training_scores , "\n")
print(all_training_scores['mean_train_score'])
# Out:
# Best CV score = -0.028:
# Best CV params = {'clf__normalize': True, 'selector__threshold': '.01*mean'}
#
# [-0.02228282 -0.02227833 -0.02197007 -0.0209919  -0.02105874 -0.02225837
#  -0.02220428 -0.02175607 -0.02111541 -0.02098681]

# %%
pdf = pd.DataFrame(all_training_scores['mean_train_score'], columns=['training mse'])
pdf.plot()

# %% [markdown]
# # Training R2

# %%
y_hat = estimator.predict(x_train)

r2_train = metrics.r2_score(y_train, y_hat)
print('R2 (training) = {}'.format(r2_train))

#print("score ", search.score(x_test, y_test))
# or also R-Squared could be obtain via
#pline.score(x_train, y_train)
# Out:
# R2 (training) = 0.5535815735297815

# %%
print('Score (training) = {}'.format(search.score(x_train,y_train)))
# Out:
# Score (training) = -0.021265875533905187

# %%
estimator.fit(x_train, y_train)

estimator.named_steps.clf.intercept_
# Out:
# 0.35687400825098364

# %%
estimator.named_steps.clf.coef_
# Out:
# array([-0.03891725,  0.00635344,  0.01073013, -0.05681167,  0.12754497,
#        -0.05179901, -0.00172244,  0.11167618,  0.17401069,  0.70835174,
#        -0.13108189, -0.13108189, -0.13108189, -0.13108189, -0.13108189,
#        -0.00677587, -0.12062306])

# %%
# validation mean_absolute_percentage_error
train_error =  np.abs(y_train - y_hat)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)


print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.11 (0.10) 0.00 0.72 MSE

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
#plt.xlim(-2,3)
#plt.ylim(-3,1)
plt.show()

# %%
sns.distplot(y_train - y_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %% [markdown]
# # Testing

# %%
y_hat_test = estimator.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_hat_test, color='g')

# %%
perf = pd.DataFrame(np.exp(y_hat_test), columns=['prediction'])
y_test = y_test.reset_index(drop=True)
perf['target'] = np.exp(y_test)
perf.head()
# Out:
#    prediction  target
# 0        1.39    1.20
# 1        1.47    1.25
# 2        1.43    1.27
# 3        1.42    1.28
# 4        1.38    1.28

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0          1.39    1.20      0.18        15.19
# 1          1.47    1.25      0.22        17.92
# 2          1.43    1.27      0.17        13.33
# 3          1.42    1.28      0.14        10.77
# 4          1.38    1.28      0.09         7.23
# ..          ...     ...       ...          ...
# 145        1.88    2.13     -0.25        11.66
# 146        1.91    2.71     -0.80        29.63
# 147        2.49    2.50     -0.02         0.64
# 148        4.62    2.69      1.93        71.69
# 149        2.83    2.67      0.16         6.12
#
# [150 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction  target  residual  difference%
# count      150.00  150.00    150.00       150.00
# mean         1.73    1.79     -0.05        13.09
# std          0.34    0.46      0.32         8.90
# min          1.28    1.20     -0.85         0.02
# 25%          1.49    1.30     -0.27         6.36
# 50%          1.71    1.74      0.03        12.14
# 75%          1.90    2.21      0.16        17.91
# max          4.62    2.72      1.93        71.69

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 130        1.73    1.73      0.00         0.02
# 59         1.63    1.62      0.01         0.39
# 147        2.49    2.50     -0.02         0.64
# 74         1.77    1.76      0.01         0.66
# 123        1.62    1.64     -0.01         0.84
# 67         1.71    1.68      0.02         1.33
# 114        1.98    1.95      0.03         1.33
# 63         1.90    1.93     -0.03         1.47
# 136        1.76    1.79     -0.04         2.05
# 89         1.98    2.02     -0.04         2.11
# 36         1.43    1.46     -0.03         2.18
# 68         1.77    1.73      0.04         2.48
# 10         1.64    1.60      0.04         2.49
# 7          1.33    1.30      0.03         2.61
# 141        1.90    1.95     -0.05         2.65
# 105        1.91    1.85      0.05         2.80
# 71         1.46    1.42      0.04         2.90
# 62         1.72    1.67      0.05         2.97
# 73         1.67    1.72     -0.05         3.04
# 97         1.94    2.00     -0.06         3.24
# 33         1.44    1.39      0.05         3.90
# 69         1.94    1.86      0.08         4.18
# 58         1.71    1.64      0.07         4.19
# 107        1.88    1.79      0.09         4.76
# 109        1.85    1.94     -0.10         5.02
# 11         1.49    1.56     -0.08         5.03
# 106        1.87    1.78      0.09         5.12
# 56         1.63    1.55      0.08         5.26
# 15         1.30    1.24      0.07         5.27
# 57         1.74    1.65      0.09         5.34
# 35         1.58    1.50      0.08         5.51
# 50         1.66    1.57      0.09         5.78
# 51         1.48    1.40      0.08         6.01
# 149        2.83    2.67      0.16         6.12
# 132        1.82    1.94     -0.12         6.26
# 90         2.05    2.19     -0.14         6.28
# 72         1.54    1.45      0.09         6.34
# 30         1.28    1.20      0.08         6.36
# 12         1.51    1.42      0.09         6.38
# 4          1.38    1.28      0.09         7.23
# 120        2.11    2.28     -0.17         7.37
# 6          1.40    1.30      0.10         7.52
# 5          1.39    1.29      0.10         7.65
# 75         1.65    1.79     -0.14         7.67
# 18         1.34    1.25      0.10         7.75
# 17         1.34    1.25      0.10         7.81
# 118        1.92    1.77      0.14         8.16
# 49         1.72    1.59      0.13         8.41
# 38         1.49    1.37      0.12         8.45
# 87         1.89    2.06     -0.18         8.51
# 86         1.94    2.13     -0.18         8.69
# 64         2.00    2.19     -0.19         8.71
# 101        1.86    1.71      0.15         8.90
# 131        2.02    2.21     -0.20         8.91
# 9          1.58    1.44      0.14         9.57
# 85         1.88    2.08     -0.20         9.74
# 39         1.38    1.26      0.12         9.90
# 100        1.57    1.74     -0.18        10.06
# 70         2.04    2.28     -0.23        10.16
# 81         2.01    2.24     -0.23        10.23
# 14         1.37    1.24      0.13        10.48
# 3          1.42    1.28      0.14        10.77
# 129        1.81    2.04     -0.22        10.95
# 93         2.04    2.30     -0.25        10.99
# 80         1.91    2.15     -0.24        11.20
# 144        2.17    2.45     -0.28        11.34
# 133        2.01    2.27     -0.26        11.45
# 66         1.59    1.43      0.16        11.51
# 145        1.88    2.13     -0.25        11.66
# 37         1.54    1.38      0.16        11.81
# 34         1.69    1.51      0.18        11.92
# 137        2.14    2.43     -0.29        11.93
# 102        1.85    2.10     -0.25        11.93
# 119        1.98    2.25     -0.27        11.97
# 25         1.45    1.29      0.15        11.99
# 27         1.35    1.20      0.15        12.29
# 134        1.56    1.78     -0.22        12.30
# 117        1.57    1.79     -0.22        12.42
# 21         1.39    1.23      0.16        12.89
# 115        1.91    2.19     -0.28        12.92
# 76         1.69    1.95     -0.25        13.08
# 112        1.94    2.23     -0.29        13.10
# 79         1.80    1.59      0.21        13.24
# 2          1.43    1.27      0.17        13.33
# 8          1.53    1.35      0.18        13.46
# 92         1.98    2.30     -0.32        14.00
# 23         1.45    1.27      0.18        14.28
# 60         1.70    1.48      0.21        14.47
# 128        2.06    2.42     -0.35        14.65
# 16         1.42    1.24      0.18        14.68
# 32         1.49    1.29      0.19        14.73
# 99         1.72    2.02     -0.30        14.84
# 24         1.49    1.29      0.19        14.86
# 111        1.85    2.18     -0.33        15.02
# 31         1.45    1.26      0.19        15.15
# 0          1.39    1.20      0.18        15.19
# 135        1.80    2.13     -0.32        15.27
# 84         1.88    2.22     -0.34        15.33
# 53         1.43    1.24      0.19        15.40
# 94         1.90    2.25     -0.35        15.58
# 65         1.92    2.29     -0.36        15.94
# 77         1.95    2.32     -0.37        16.02
# 126        1.91    2.28     -0.37        16.18
# 48         1.73    1.47      0.25        17.17
# 103        1.84    2.22     -0.38        17.20
# 82         1.89    2.29     -0.39        17.25
# 22         1.41    1.20      0.21        17.40
# 91         2.05    2.49     -0.43        17.45
# 95         1.87    2.27     -0.40        17.71
# 55         1.70    1.44      0.26        17.74
# 108        1.71    1.45      0.26        17.76
# 47         1.47    1.25      0.22        17.89
# 1          1.47    1.25      0.22        17.92
# 26         1.50    1.27      0.23        18.11
# 19         1.48    1.25      0.23        18.11
# 125        1.83    2.25     -0.41        18.41
# 29         1.43    1.20      0.23        18.73
# 83         1.83    2.26     -0.43        18.90
# 61         1.69    1.42      0.27        19.16
# 96         1.89    1.58      0.30        19.21
# 113        2.02    2.50     -0.48        19.24
# 40         1.44    1.20      0.23        19.25
# 139        1.76    2.18     -0.42        19.36
# 78         1.69    2.10     -0.41        19.44
# 110        1.83    2.29     -0.46        19.89
# 127        1.83    2.30     -0.47        20.28
# 88         1.66    2.08     -0.42        20.30
# 52         1.53    1.27      0.26        20.54
# 20         1.49    1.23      0.26        20.95
# 41         1.47    1.20      0.27        22.11
# 54         1.70    1.39      0.31        22.13
# 122        2.07    2.66     -0.59        22.19
# 42         1.47    1.20      0.27        22.37
# 104        1.61    2.09     -0.48        22.94
# 28         1.49    1.20      0.28        23.55
# 43         1.49    1.20      0.29        23.67
# 46         1.53    1.23      0.30        24.43
# 45         1.53    1.23      0.30        24.50
# 143        1.92    2.55     -0.62        24.51
# 124        1.60    2.12     -0.52        24.54
# 13         1.53    1.21      0.31        25.77
# 44         1.54    1.23      0.32        25.96
# 116        1.99    2.69     -0.70        26.15
# 142        1.89    2.57     -0.69        26.65
# 98         1.97    2.72     -0.75        27.64
# 140        1.77    2.46     -0.68        27.85
# 121        1.66    2.33     -0.67        28.69
# 146        1.91    2.71     -0.80        29.63
# 138        1.52    2.37     -0.85        35.83
# 148        4.62    2.69      1.93        71.69

# %% [markdown]
# # *** Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_hat_test)
print('R2 (testing) = {}'.format(r2_test))

# also: R-Squared could obtain with
# pline.score(x_test, y_test)
# Out:
# R2 (testing) = 0.6222671347353071

# %%
print(np.sqrt(mean_squared_error(y_test,y_hat_test)))
# Out:
# 0.15883523984379522

# %% [markdown]
# # What features selected

# %%
x_train.shape
# Out:
# (1349, 17)

# %%
#clf = LassoCV()
#sfm = SelectFromModel(clf, threshold=0.001)

threshold_selected = params['selector__threshold']

sfm = SelectFromModel(
                RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15),
                threshold=threshold_selected)

selectedFeatures = sfm.fit(inputs, targets).transform(inputs)
print('{} features selected'.format(selectedFeatures[1].shape[0]))

feature_list = x_train.columns[sfm.get_support()]
features = ''
features = ', '.join(feature_list)
#features

reduced_x_train = x_train[feature_list]
reduced_x_train.head(2)
# Out:
# 17 features selected
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0               0.07            0.02               0.01          0.02
# 1               0.06            0.03               0.01          0.02
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0             0.02              0.01             0.01           0.12
# 1             0.02              0.01             0.01           0.14
#
#    carts-db_cpu_use  front-end_pods  orders_pods  user_pods  shipping_pods  \
# 0              0.16            1.00         1.00       1.00           1.00
# 1              0.17            1.00         1.00       1.00           1.00
#
#    payment_pods  carts_pods  nodes_cpu_use  orders_req
# 0          1.00        1.00           1.18        0.40
# 1          1.00        1.00           1.18        0.44

# %% [markdown]
# # Trying with Polynomial features

# %%
if True:
    from sklearn.preprocessing import PolynomialFeatures
    
    degree = 2

    # covert input data to polynomial form of some degree
    inputs_poly = PolynomialFeatures(degree=degree).fit_transform(inputs).astype(float)

    x_train, x_test, y_train, y_test = \
        train_test_split(inputs_poly, targets, test_size=test_split, shuffle=False, random_state=365)

    # for better convergence and result scale target to values between 0 - 1
    y_train_max = y_train.max()
    y_test_max = y_test.max()

    y_train = y_train / y_train_max
    y_test = y_test / y_test_max


    reg = LinearRegression(normalize=False) # normalize false bacause we are going to use the scaler

    scaler = StandardScaler()

    pipe = Pipeline(steps=[
        ('scaler', scaler),
        ('selector', sfm), 
        ('clf', reg)
    ])

    kfold = KFold(n_splits=10, shuffle=False)

    param_grid = {
        'selector__threshold': ['.1*mean', '.08*mean', '.05*mean', '.02*mean', '.001*mean']
        ,'clf__normalize': [False, True]
    }

    search = GridSearchCV(pipe, param_grid,scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=0, n_jobs=-1)

    search.fit(x_train, y_train)

    y_hat_test = search.predict(x_test)

    r2_test = metrics.r2_score(y_test, y_hat_test)
    print('R2 (testing) = {}'.format(r2_test))
# Out:
# R2 (testing) = 0.6858722859967321

# %% [markdown]
# # Robust Linear Model

# %%
# RANSAC is an iterative algorithm for the robust estimation of parameters from a subset 
# of inliners from the complete data set.
# you can use this with all dataset including outliers
if False:    
    from sklearn.linear_model import RANSACRegressor

    ransac = RANSACRegressor(estimator)
    ransac.fit(x_train, y_train)
    inlier_mask = ransac.inlier_mask_
    outlier_mask = np.logical_not(inlier_mask)

    y_hat_test = ransac.predict(x_test)

    r2_test = metrics.r2_score(y_test, y_hat_test)
    print('R2 (testing) = {}'.format(r2_test))
# Out:
# R2 (testing) = -1.2985037643256274
