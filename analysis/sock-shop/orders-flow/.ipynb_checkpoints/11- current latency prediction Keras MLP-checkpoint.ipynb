# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from keras.models import Sequential
from keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from keras.callbacks import EarlyStopping , ReduceLROnPlateau , ModelCheckpoint
from keras.models import load_model
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.2f}'.format

import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
# network structure. 
# not to include the input layer
#net_layers = (8, 5)  # (11,9,8,4)

epochs=1000
batch_size=300

learning_rate = 1e-3
decay = learning_rate / epochs

patience=80

test_split = 0.1
validation_split = 0.2

select_features = False

TRAIN_MODEL = True

# trials
# 11 R2-> -0.12
# 11,16,8,4 R2-> 0.37
# 11,11,6 R2-> -0.2
# 11,8,6 R2->   0.316
# 11,11,8,4 R2->  0.37
# 11, 6 R2-> 0.37

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'
models_dir = home_dir + "/models/"

data_file = 'orders_flow_data.csv'   # raw data as is
#data_file = 'order_flow_cleanup_data.csv'
#data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, True)
data = data.reset_index(drop=True)
data.head(5)
# Out:
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0               0.03            0.01               0.01          0.01
# 1               0.06            0.02               0.02          0.02
# 2               0.07            0.03               0.02          0.03
# 3               0.07            0.03               0.02          0.02
# 4               0.07            0.02               0.01          0.02
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0             0.01              0.01             0.01           0.03
# 1             0.02              0.01             0.01           0.18
# 2             0.02              0.01             0.01           0.44
# 3             0.02              0.01             0.01           0.23
# 4             0.02              0.01             0.01           0.24
#
#    carts-db_cpu_use  front-end_pods  orders_pods  user_pods  shipping_pods  \
# 0              0.07            1.00         1.00       1.00           1.00
# 1              0.18            1.00         1.00       1.00           1.00
# 2              0.20            1.00         1.00       1.00           1.00
# 3              0.17            1.00         1.00       1.00           1.00
# 4              0.14            1.00         1.00       1.00           1.00
#
#    payment_pods  carts_pods  nodes_cpu_use  orders_req  orders_ltcy
# 0          1.00        1.00           2.50        0.15         0.24
# 1          1.00        1.00           1.89        0.15         0.24
# 2          1.00        1.00           1.35        0.15         0.24
# 3          1.00        1.00           1.26        0.13         0.24
# 4          1.00        1.00           1.28        0.36         0.24

# %%
data.shape
# Out:
# (6766, 18)

# %% [markdown]
# # Eliminate outlier noice

# %%
df = data

# %%
df.describe(include="all")
# Out:
#        front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# count           6,766.00        6,766.00           6,766.00      6,766.00
# mean                0.83            0.21               0.02          0.20
# std                 0.62            0.13               0.00          0.13
# min                 0.01            0.01               0.01          0.01
# 25%                 0.19            0.08               0.02          0.05
# 50%                 0.84            0.22               0.02          0.20
# 75%                 1.29            0.30               0.02          0.30
# max                 2.73            0.91               0.04          0.64
#
#        user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# count         6,766.00          6,766.00         6,766.00       6,766.00
# mean              0.12              0.05             0.03           0.53
# std               0.08              0.04             0.01           0.58
# min               0.01              0.01             0.01           0.03
# 25%               0.03              0.04             0.02           0.12
# 50%               0.12              0.05             0.03           0.32
# 75%               0.18              0.06             0.04           0.58
# max               0.34              0.63             0.10           2.53
#
#        carts-db_cpu_use  front-end_pods  orders_pods  user_pods  \
# count          6,766.00        6,766.00     6,766.00   6,766.00
# mean               1.83            2.76         2.76       2.76
# std                1.99            1.10         1.09       1.09
# min                0.01            0.50         1.00       1.00
# 25%                0.02            2.00         2.00       2.00
# 50%                1.15            3.00         3.00       3.00
# 75%                3.28            4.00         4.00       4.00
# max                6.58            4.00         4.00       4.00
#
#        shipping_pods  payment_pods  carts_pods  nodes_cpu_use  orders_req  \
# count       6,766.00      6,766.00    6,766.00       6,766.00    6,766.00
# mean            2.76          2.76        2.76           4.10        5.03
# std             1.09          1.09        1.09           2.08        4.20
# min             1.00          1.00        1.00           1.10        0.00
# 25%             2.00          2.00        2.00           1.92        0.49
# 50%             3.00          3.00        3.00           4.21        5.14
# 75%             4.00          4.00        4.00           5.78        8.20
# max             4.00          4.00        4.00           9.66       20.13
#
#        orders_ltcy
# count     6,766.00
# mean          2.97
# std           3.51
# min           0.02
# 25%           0.24
# 50%           0.49
# 75%           5.81
# max           9.75

# %%
df = data
print('shape before {}'.format(df.shape))
if 1 == 1:
    minq = df['orders_ltcy'].quantile(0.3)
    maxq = df['orders_ltcy'].quantile(0.99)
    print('latency quantiles min {} max {}'.format(maxq, minq))
    df = df[df['orders_ltcy'] > minq]
    df = df[df['orders_ltcy'] < maxq]
    sns.distplot(df['orders_ltcy'])
print('shape after {}'.format(df.shape))
# Out:
# shape before (6766, 18)
# latency quantiles min 9.65 max 0.24
# shape after (4233, 18)

# %%
data = df

# %% [markdown]
# # Shuffle

# %%
# shuffle the data
from sklearn.utils import shuffle
data = shuffle(data, random_state=0)
print('shape {}'.format(data.shape))
data.head(5)
# Out:
# shape (4233, 18)
#       front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 5616               0.04            0.05               0.02          0.04
# 2380               1.34            0.26               0.01          0.35
# 2693               1.37            0.37               0.02          0.39
# 2532               1.48            0.25               0.02          0.31
# 1052               0.08            0.08               0.01          0.03
#
#       user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 5616             0.02              0.05             0.04           0.05
# 2380             0.19              0.02             0.02           0.99
# 2693             0.22              0.04             0.02           1.10
# 2532             0.21              0.03             0.02           1.08
# 1052             0.02              0.03             0.02           0.07
#
#       carts-db_cpu_use  front-end_pods  orders_pods  user_pods  shipping_pods  \
# 5616              0.02            4.00         4.00       4.00           4.00
# 2380              0.17            2.00         2.00       2.00           2.00
# 2693              1.86            2.00         2.00       2.00           2.00
# 2532              1.24            2.00         2.00       2.00           2.00
# 1052              0.18            2.00         2.00       2.00           2.00
#
#       payment_pods  carts_pods  nodes_cpu_use  orders_req  orders_ltcy
# 5616          4.00        4.00           1.36        0.00         1.18
# 2380          2.00        2.00           3.80       10.42         8.89
# 2693          2.00        2.00           4.76        9.07         8.91
# 2532          2.00        2.00           4.50       10.31         9.22
# 1052          2.00        2.00           1.26        0.33         0.28

# %%
targets = data['orders_ltcy']
inputs = data.drop(['orders_ltcy'], axis=1)

n_features = inputs.values.shape[1]
print("there are {} features".format(n_features))
# Out:
# there are 17 features

# %%
# scale targets for better convergence
y_scaler =  MinMaxScaler()
targets = y_scaler.fit_transform(targets.values.reshape(-1,1))

# %% [markdown]
# # Feature Selection

# %%
feature_list = inputs.columns.values
if select_features:
    sfm = SelectFromModel(
                RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=15),
                threshold='0.02*mean')

    selectedFeatures = sfm.fit(inputs, targets).transform(inputs)
    print('{} features selected'.format(selectedFeatures[1].shape[0]))

    feature_list = inputs.columns[sfm.get_support()]
    features = ''
    features = ', '.join(feature_list)
    
    print("columns selected are {}".format(features))

    inputs = inputs[feature_list]
    inputs.head(2)

# %%
n_inputs = len(feature_list)
n_inputs
# Out:
# 17

# %%
#net_layers = (11, 8, 5, 2)  # (11,9,8,4)
net_layers = (13, 9)

# %%
x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=test_split, shuffle=True, random_state=365)

print("y_train {} , y_test {}".format(y_train.shape, y_test.shape))

# for better convergence and result scale target to values between 0 - 1
if 1 == 0:
    y_train_max = y_train.max()
    y_test_max = y_test.max()

    y_train = y_train / y_train_max
    y_test = y_test / y_test_max
# Out:
# y_train (3809, 1) , y_test (424, 1)

# %% [markdown]
# # Scaling

# %%
x_scaler = StandardScaler()
x_train = x_scaler.fit_transform(x_train)  # fit on training data only
x_test = x_scaler.transform(x_test)

# %%
if 1 == 0:
    y_scaler =  MinMaxScaler()

    y_train = y_train.values.reshape(-1, 1)
    y_test = y_test.values.reshape(-1, 1)

    y_train = y_scaler.fit_transform(y_train)
    y_test = y_scaler.transform(y_test)

    y_train = y_train.reshape(-1)
    y_test = y_test.reshape(-1)

# %% [markdown]
# ## Function to build a model

# %%
def build_keras_model(nodes = net_layers):   # this does not work with KerasRegressor. interesting
    # create model
    model = Sequential()  
    
    if isinstance(nodes, int) or not nodes:
        model.add(Dense(1, input_dim=n_inputs, kernel_initializer='normal'))
    
    else:
        model.add(Dense(nodes[1], input_dim=n_inputs, kernel_initializer='normal', activation='relu'))
    
        layer = 0
        while layer < len(nodes):
            model.add(Dense(nodes[layer], kernel_initializer='normal', activation='relu'))
            layer = layer + 1
        
        #model.add(Dense(1, kernel_initializer='normal', activation='linear')) 
        model.add(Dense(1, kernel_initializer='normal', activation='linear'))  
    
    adam = Adam(lr=learning_rate, decay=decay)
    
    # or loss= 'mean_absolute_percentage_error'
    model.compile(loss='mean_squared_error', optimizer=adam, metrics=['mse'])
    
    return model

# %%
model = build_keras_model()

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=patience)

# save the best model only
mc = ModelCheckpoint(models_dir + 'best_mlp_model.h5'
                     , monitor='val_loss'
                     , mode='min' 
                     , verbose=1
                     #, save_weights_only=True
                     , save_best_only=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.1,
                                       min_lr=1e-4,
                                       patience=0,
                                       verbose=1)

callbacks = [es, mc, reduce_lr]

if TRAIN_MODEL:
    history = model.fit(x_train, y_train
                    , epochs=epochs
                    , batch_size=batch_size
                    , verbose=1
                    , validation_split=validation_split
                    , shuffle=False
                    , callbacks=callbacks)

print ("Done..!")
# Out:
# Train on 3047 samples, validate on 762 samples
# Epoch 1/1000
# 3047/3047 [==============================] - 4s 1ms/step - loss: 0.3327 - mean_squared_error: 0.3327 - val_loss: 0.3428 - val_mean_squared_error: 0.3428
#
# Epoch 00001: val_loss improved from inf to 0.34283, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 2/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.3204 - mean_squared_error: 0.3204 - val_loss: 0.3291 - val_mean_squared_error: 0.3291
#
# Epoch 00002: val_loss improved from 0.34283 to 0.32908, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 3/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.3062 - mean_squared_error: 0.3062 - val_loss: 0.3128 - val_mean_squared_error: 0.3128
#
# Epoch 00003: val_loss improved from 0.32908 to 0.31285, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 4/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.2887 - mean_squared_error: 0.2887 - val_loss: 0.2913 - val_mean_squared_error: 0.2913
#
# Epoch 00004: val_loss improved from 0.31285 to 0.29131, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 5/1000
# 3047/3047 [==============================] - 0s 17us/step - loss: 0.2645 - mean_squared_error: 0.2645 - val_loss: 0.2605 - val_mean_squared_error: 0.2605
#
# Epoch 00005: val_loss improved from 0.29131 to 0.26053, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 6/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.2302 - mean_squared_error: 0.2302 - val_loss: 0.2187 - val_mean_squared_error: 0.2187
#
# Epoch 00006: val_loss improved from 0.26053 to 0.21874, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 7/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.1878 - mean_squared_error: 0.1878 - val_loss: 0.1748 - val_mean_squared_error: 0.1748
#
# Epoch 00007: val_loss improved from 0.21874 to 0.17481, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 8/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.1528 - mean_squared_error: 0.1528 - val_loss: 0.1479 - val_mean_squared_error: 0.1479
#
# Epoch 00008: val_loss improved from 0.17481 to 0.14788, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 9/1000
# 3047/3047 [==============================] - 0s 17us/step - loss: 0.1338 - mean_squared_error: 0.1338 - val_loss: 0.1272 - val_mean_squared_error: 0.1272
#
# Epoch 00009: val_loss improved from 0.14788 to 0.12720, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 10/1000
# 3047/3047 [==============================] - 0s 18us/step - loss: 0.1160 - mean_squared_error: 0.1160 - val_loss: 0.1087 - val_mean_squared_error: 0.1087
#
# Epoch 00010: val_loss improved from 0.12720 to 0.10872, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 11/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.1019 - mean_squared_error: 0.1019 - val_loss: 0.0965 - val_mean_squared_error: 0.0965
#
# Epoch 00011: val_loss improved from 0.10872 to 0.09648, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 12/1000
# 3047/3047 [==============================] - 0s 18us/step - loss: 0.0927 - mean_squared_error: 0.0927 - val_loss: 0.0892 - val_mean_squared_error: 0.0892
#
# Epoch 00012: val_loss improved from 0.09648 to 0.08916, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 13/1000
# 3047/3047 [==============================] - 0s 21us/step - loss: 0.0869 - mean_squared_error: 0.0869 - val_loss: 0.0848 - val_mean_squared_error: 0.0848
#
# Epoch 00013: val_loss improved from 0.08916 to 0.08484, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 14/1000
# 3047/3047 [==============================] - 0s 17us/step - loss: 0.0830 - mean_squared_error: 0.0830 - val_loss: 0.0823 - val_mean_squared_error: 0.0823
#
# Epoch 00014: val_loss improved from 0.08484 to 0.08228, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 15/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0806 - mean_squared_error: 0.0806 - val_loss: 0.0805 - val_mean_squared_error: 0.0805
#
# Epoch 00015: val_loss improved from 0.08228 to 0.08054, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 16/1000
# 3047/3047 [==============================] - 0s 17us/step - loss: 0.0788 - mean_squared_error: 0.0788 - val_loss: 0.0791 - val_mean_squared_error: 0.0791
#
# Epoch 00016: val_loss improved from 0.08054 to 0.07906, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 17/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0772 - mean_squared_error: 0.0772 - val_loss: 0.0776 - val_mean_squared_error: 0.0776
#
# Epoch 00017: val_loss improved from 0.07906 to 0.07762, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 18/1000
# 3047/3047 [==============================] - 0s 18us/step - loss: 0.0757 - mean_squared_error: 0.0757 - val_loss: 0.0762 - val_mean_squared_error: 0.0762
#
# Epoch 00018: val_loss improved from 0.07762 to 0.07620, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 19/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0743 - mean_squared_error: 0.0743 - val_loss: 0.0748 - val_mean_squared_error: 0.0748
#
# Epoch 00019: val_loss improved from 0.07620 to 0.07477, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 20/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0728 - mean_squared_error: 0.0728 - val_loss: 0.0733 - val_mean_squared_error: 0.0733
#
# Epoch 00020: val_loss improved from 0.07477 to 0.07334, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 21/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0714 - mean_squared_error: 0.0714 - val_loss: 0.0719 - val_mean_squared_error: 0.0719
#
# Epoch 00021: val_loss improved from 0.07334 to 0.07191, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 22/1000
# 3047/3047 [==============================] - 0s 17us/step - loss: 0.0699 - mean_squared_error: 0.0699 - val_loss: 0.0705 - val_mean_squared_error: 0.0705
#
# Epoch 00022: val_loss improved from 0.07191 to 0.07051, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 23/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0685 - mean_squared_error: 0.0685 - val_loss: 0.0691 - val_mean_squared_error: 0.0691
#
# Epoch 00023: val_loss improved from 0.07051 to 0.06908, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 24/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0671 - mean_squared_error: 0.0671 - val_loss: 0.0676 - val_mean_squared_error: 0.0676
#
# Epoch 00024: val_loss improved from 0.06908 to 0.06763, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 25/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0657 - mean_squared_error: 0.0657 - val_loss: 0.0662 - val_mean_squared_error: 0.0662
#
# Epoch 00025: val_loss improved from 0.06763 to 0.06622, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 26/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0643 - mean_squared_error: 0.0643 - val_loss: 0.0648 - val_mean_squared_error: 0.0648
#
# Epoch 00026: val_loss improved from 0.06622 to 0.06477, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 27/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0629 - mean_squared_error: 0.0629 - val_loss: 0.0634 - val_mean_squared_error: 0.0634
#
# Epoch 00027: val_loss improved from 0.06477 to 0.06336, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 28/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0616 - mean_squared_error: 0.0616 - val_loss: 0.0620 - val_mean_squared_error: 0.0620
#
# Epoch 00028: val_loss improved from 0.06336 to 0.06200, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 29/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0603 - mean_squared_error: 0.0603 - val_loss: 0.0607 - val_mean_squared_error: 0.0607
#
# Epoch 00029: val_loss improved from 0.06200 to 0.06069, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 30/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0591 - mean_squared_error: 0.0591 - val_loss: 0.0594 - val_mean_squared_error: 0.0594
#
# Epoch 00030: val_loss improved from 0.06069 to 0.05942, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 31/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0579 - mean_squared_error: 0.0579 - val_loss: 0.0582 - val_mean_squared_error: 0.0582
#
# Epoch 00031: val_loss improved from 0.05942 to 0.05821, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 32/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0569 - mean_squared_error: 0.0569 - val_loss: 0.0571 - val_mean_squared_error: 0.0571
#
# Epoch 00032: val_loss improved from 0.05821 to 0.05708, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 33/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0560 - mean_squared_error: 0.0560 - val_loss: 0.0561 - val_mean_squared_error: 0.0561
#
# Epoch 00033: val_loss improved from 0.05708 to 0.05607, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 34/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0551 - mean_squared_error: 0.0551 - val_loss: 0.0552 - val_mean_squared_error: 0.0552
#
# Epoch 00034: val_loss improved from 0.05607 to 0.05517, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 35/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0544 - mean_squared_error: 0.0544 - val_loss: 0.0544 - val_mean_squared_error: 0.0544
#
# Epoch 00035: val_loss improved from 0.05517 to 0.05440, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 36/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0538 - mean_squared_error: 0.0538 - val_loss: 0.0537 - val_mean_squared_error: 0.0537
#
# Epoch 00036: val_loss improved from 0.05440 to 0.05368, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 37/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0532 - mean_squared_error: 0.0532 - val_loss: 0.0531 - val_mean_squared_error: 0.0531
#
# Epoch 00037: val_loss improved from 0.05368 to 0.05314, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 38/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0528 - mean_squared_error: 0.0528 - val_loss: 0.0526 - val_mean_squared_error: 0.0526
#
# Epoch 00038: val_loss improved from 0.05314 to 0.05263, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 39/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0524 - mean_squared_error: 0.0524 - val_loss: 0.0523 - val_mean_squared_error: 0.0523
#
# Epoch 00039: val_loss improved from 0.05263 to 0.05226, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 40/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0521 - mean_squared_error: 0.0521 - val_loss: 0.0518 - val_mean_squared_error: 0.0518
#
# Epoch 00040: val_loss improved from 0.05226 to 0.05183, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 41/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0518 - mean_squared_error: 0.0518 - val_loss: 0.0516 - val_mean_squared_error: 0.0516
#
# Epoch 00041: val_loss improved from 0.05183 to 0.05155, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 42/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0515 - mean_squared_error: 0.0515 - val_loss: 0.0512 - val_mean_squared_error: 0.0512
#
# Epoch 00042: val_loss improved from 0.05155 to 0.05123, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 43/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0513 - mean_squared_error: 0.0513 - val_loss: 0.0511 - val_mean_squared_error: 0.0511
#
# Epoch 00043: val_loss improved from 0.05123 to 0.05109, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 44/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0511 - mean_squared_error: 0.0511 - val_loss: 0.0508 - val_mean_squared_error: 0.0508
#
# Epoch 00044: val_loss improved from 0.05109 to 0.05078, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 45/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0509 - mean_squared_error: 0.0509 - val_loss: 0.0506 - val_mean_squared_error: 0.0506
#
# Epoch 00045: val_loss improved from 0.05078 to 0.05062, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 46/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0507 - mean_squared_error: 0.0507 - val_loss: 0.0504 - val_mean_squared_error: 0.0504
#
# Epoch 00046: val_loss improved from 0.05062 to 0.05038, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 47/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0505 - mean_squared_error: 0.0505 - val_loss: 0.0502 - val_mean_squared_error: 0.0502
#
# Epoch 00047: val_loss improved from 0.05038 to 0.05025, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 48/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0504 - mean_squared_error: 0.0504 - val_loss: 0.0501 - val_mean_squared_error: 0.0501
#
# Epoch 00048: val_loss improved from 0.05025 to 0.05009, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 49/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0502 - mean_squared_error: 0.0502 - val_loss: 0.0500 - val_mean_squared_error: 0.0500
#
# Epoch 00049: val_loss improved from 0.05009 to 0.04997, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 50/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0501 - mean_squared_error: 0.0501 - val_loss: 0.0498 - val_mean_squared_error: 0.0498
#
# Epoch 00050: val_loss improved from 0.04997 to 0.04984, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 51/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.0497 - val_mean_squared_error: 0.0497
#
# Epoch 00051: val_loss improved from 0.04984 to 0.04972, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 52/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0499 - mean_squared_error: 0.0499 - val_loss: 0.0496 - val_mean_squared_error: 0.0496
#
# Epoch 00052: val_loss improved from 0.04972 to 0.04962, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 53/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0498 - mean_squared_error: 0.0498 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00053: val_loss improved from 0.04962 to 0.04953, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 54/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00054: val_loss improved from 0.04953 to 0.04952, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 55/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00055: val_loss improved from 0.04952 to 0.04952, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 56/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00056: val_loss improved from 0.04952 to 0.04952, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 57/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00057: val_loss improved from 0.04952 to 0.04952, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 58/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00058: val_loss improved from 0.04952 to 0.04951, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 59/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00059: val_loss improved from 0.04951 to 0.04950, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 60/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00060: val_loss improved from 0.04950 to 0.04949, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 61/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00061: val_loss improved from 0.04949 to 0.04949, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 62/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00062: val_loss improved from 0.04949 to 0.04948, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 63/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00063: val_loss improved from 0.04948 to 0.04947, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 64/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00064: val_loss improved from 0.04947 to 0.04946, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 65/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
#
# Epoch 00065: val_loss improved from 0.04946 to 0.04946, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 66/1000
# 3047/3047 [==============================] - 0s 17us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00066: val_loss improved from 0.04946 to 0.04945, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 67/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00067: val_loss improved from 0.04945 to 0.04944, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 68/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00068: val_loss improved from 0.04944 to 0.04943, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 69/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00069: val_loss improved from 0.04943 to 0.04942, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 70/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00070: val_loss improved from 0.04942 to 0.04942, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 71/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00071: val_loss improved from 0.04942 to 0.04941, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 72/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00072: val_loss improved from 0.04941 to 0.04941, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 73/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00073: val_loss improved from 0.04941 to 0.04940, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 74/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00074: val_loss improved from 0.04940 to 0.04939, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 75/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00075: val_loss improved from 0.04939 to 0.04938, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 76/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00076: val_loss improved from 0.04938 to 0.04938, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 77/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00077: val_loss improved from 0.04938 to 0.04937, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 78/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00078: val_loss improved from 0.04937 to 0.04936, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 79/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
#
# Epoch 00079: val_loss improved from 0.04936 to 0.04936, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 80/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00080: val_loss improved from 0.04936 to 0.04935, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 81/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00081: val_loss improved from 0.04935 to 0.04934, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 82/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00082: val_loss improved from 0.04934 to 0.04933, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 83/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00083: val_loss improved from 0.04933 to 0.04932, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 84/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00084: val_loss improved from 0.04932 to 0.04932, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 85/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00085: val_loss improved from 0.04932 to 0.04931, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 86/1000
# 3047/3047 [==============================] - 0s 17us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00086: val_loss improved from 0.04931 to 0.04930, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 87/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00087: val_loss improved from 0.04930 to 0.04929, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 88/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00088: val_loss improved from 0.04929 to 0.04929, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 89/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00089: val_loss improved from 0.04929 to 0.04928, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 90/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00090: val_loss improved from 0.04928 to 0.04927, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 91/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00091: val_loss improved from 0.04927 to 0.04927, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 92/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00092: val_loss improved from 0.04927 to 0.04926, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 93/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
#
# Epoch 00093: val_loss improved from 0.04926 to 0.04925, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 94/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00094: val_loss improved from 0.04925 to 0.04924, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 95/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00095: val_loss improved from 0.04924 to 0.04924, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 96/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00096: val_loss improved from 0.04924 to 0.04923, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 97/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00097: val_loss improved from 0.04923 to 0.04922, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 98/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00098: val_loss improved from 0.04922 to 0.04922, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 99/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00099: val_loss improved from 0.04922 to 0.04921, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 100/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00100: val_loss improved from 0.04921 to 0.04920, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 101/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00101: val_loss improved from 0.04920 to 0.04920, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 102/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00102: val_loss improved from 0.04920 to 0.04919, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 103/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00103: val_loss improved from 0.04919 to 0.04918, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 104/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00104: val_loss improved from 0.04918 to 0.04918, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 105/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00105: val_loss improved from 0.04918 to 0.04917, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 106/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00106: val_loss improved from 0.04917 to 0.04916, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 107/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
#
# Epoch 00107: val_loss improved from 0.04916 to 0.04916, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 108/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00108: val_loss improved from 0.04916 to 0.04915, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 109/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00109: val_loss improved from 0.04915 to 0.04914, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 110/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00110: val_loss improved from 0.04914 to 0.04914, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 111/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00111: val_loss improved from 0.04914 to 0.04913, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 112/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00112: val_loss improved from 0.04913 to 0.04912, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 113/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00113: val_loss improved from 0.04912 to 0.04912, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 114/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00114: val_loss improved from 0.04912 to 0.04911, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 115/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00115: val_loss improved from 0.04911 to 0.04911, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 116/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00116: val_loss improved from 0.04911 to 0.04910, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 117/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00117: val_loss improved from 0.04910 to 0.04909, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 118/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00118: val_loss improved from 0.04909 to 0.04909, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 119/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00119: val_loss improved from 0.04909 to 0.04908, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 120/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00120: val_loss improved from 0.04908 to 0.04907, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 121/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00121: val_loss improved from 0.04907 to 0.04907, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 122/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00122: val_loss improved from 0.04907 to 0.04906, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 123/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
#
# Epoch 00123: val_loss improved from 0.04906 to 0.04905, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 124/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00124: val_loss improved from 0.04905 to 0.04905, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 125/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00125: val_loss improved from 0.04905 to 0.04904, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 126/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00126: val_loss improved from 0.04904 to 0.04903, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 127/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00127: val_loss improved from 0.04903 to 0.04903, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 128/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00128: val_loss improved from 0.04903 to 0.04902, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 129/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00129: val_loss improved from 0.04902 to 0.04901, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 130/1000
# 3047/3047 [==============================] - 0s 17us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00130: val_loss improved from 0.04901 to 0.04901, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 131/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00131: val_loss improved from 0.04901 to 0.04900, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 132/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00132: val_loss improved from 0.04900 to 0.04900, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 133/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00133: val_loss improved from 0.04900 to 0.04899, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 134/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00134: val_loss improved from 0.04899 to 0.04898, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 135/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00135: val_loss improved from 0.04898 to 0.04898, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 136/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00136: val_loss improved from 0.04898 to 0.04897, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 137/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00137: val_loss improved from 0.04897 to 0.04897, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 138/1000
# 3047/3047 [==============================] - 0s 13us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00138: val_loss improved from 0.04897 to 0.04896, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 139/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
#
# Epoch 00139: val_loss improved from 0.04896 to 0.04896, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 140/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
#
# Epoch 00140: val_loss improved from 0.04896 to 0.04895, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 141/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
#
# Epoch 00141: val_loss improved from 0.04895 to 0.04894, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 142/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
#
# Epoch 00142: val_loss improved from 0.04894 to 0.04894, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 143/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
#
# Epoch 00143: val_loss improved from 0.04894 to 0.04893, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 144/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0488 - mean_squared_error: 0.0488 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
#
# Epoch 00144: val_loss improved from 0.04893 to 0.04893, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 145/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0488 - mean_squared_error: 0.0488 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
#
# Epoch 00145: val_loss improved from 0.04893 to 0.04892, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 146/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0488 - mean_squared_error: 0.0488 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
#
# Epoch 00146: val_loss improved from 0.04892 to 0.04892, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 147/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0488 - mean_squared_error: 0.0488 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
#
# Epoch 00147: val_loss improved from 0.04892 to 0.04891, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 148/1000
# ...
# Epoch 951/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00951: val_loss improved from 0.04463 to 0.04463, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 952/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00952: val_loss improved from 0.04463 to 0.04462, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 953/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00953: val_loss improved from 0.04462 to 0.04462, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 954/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00954: val_loss improved from 0.04462 to 0.04462, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 955/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00955: val_loss improved from 0.04462 to 0.04461, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 956/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00956: val_loss did not improve from 0.04461
# Epoch 957/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00957: val_loss improved from 0.04461 to 0.04461, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 958/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00958: val_loss improved from 0.04461 to 0.04461, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 959/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00959: val_loss improved from 0.04461 to 0.04461, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 960/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00960: val_loss improved from 0.04461 to 0.04460, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 961/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00961: val_loss improved from 0.04460 to 0.04460, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 962/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00962: val_loss improved from 0.04460 to 0.04460, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 963/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00963: val_loss improved from 0.04460 to 0.04460, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 964/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00964: val_loss improved from 0.04460 to 0.04459, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 965/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00965: val_loss improved from 0.04459 to 0.04459, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 966/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00966: val_loss improved from 0.04459 to 0.04459, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 967/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00967: val_loss improved from 0.04459 to 0.04459, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 968/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00968: val_loss improved from 0.04459 to 0.04458, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 969/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00969: val_loss improved from 0.04458 to 0.04458, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 970/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00970: val_loss improved from 0.04458 to 0.04458, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 971/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00971: val_loss improved from 0.04458 to 0.04458, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 972/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00972: val_loss improved from 0.04458 to 0.04457, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 973/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00973: val_loss improved from 0.04457 to 0.04457, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 974/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00974: val_loss improved from 0.04457 to 0.04456, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 975/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00975: val_loss did not improve from 0.04456
# Epoch 976/1000
# 3047/3047 [==============================] - 0s 17us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00976: val_loss improved from 0.04456 to 0.04456, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 977/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00977: val_loss improved from 0.04456 to 0.04456, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 978/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
#
# Epoch 00978: val_loss improved from 0.04456 to 0.04455, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 979/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00979: val_loss improved from 0.04455 to 0.04455, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 980/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00980: val_loss improved from 0.04455 to 0.04455, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 981/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00981: val_loss improved from 0.04455 to 0.04454, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 982/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00982: val_loss improved from 0.04454 to 0.04454, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 983/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00983: val_loss improved from 0.04454 to 0.04454, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 984/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00984: val_loss improved from 0.04454 to 0.04453, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 985/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00985: val_loss did not improve from 0.04453
# Epoch 986/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00986: val_loss improved from 0.04453 to 0.04453, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 987/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00987: val_loss improved from 0.04453 to 0.04453, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 988/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00988: val_loss improved from 0.04453 to 0.04453, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 989/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00989: val_loss improved from 0.04453 to 0.04452, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 990/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00990: val_loss improved from 0.04452 to 0.04452, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 991/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00991: val_loss improved from 0.04452 to 0.04452, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 992/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00992: val_loss improved from 0.04452 to 0.04452, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 993/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00993: val_loss improved from 0.04452 to 0.04452, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 994/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00994: val_loss improved from 0.04452 to 0.04451, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 995/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00995: val_loss improved from 0.04451 to 0.04451, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 996/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00996: val_loss improved from 0.04451 to 0.04451, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 997/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00997: val_loss improved from 0.04451 to 0.04450, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 998/1000
# 3047/3047 [==============================] - 0s 16us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00998: val_loss improved from 0.04450 to 0.04450, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 999/1000
# 3047/3047 [==============================] - 0s 14us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 00999: val_loss improved from 0.04450 to 0.04450, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Epoch 1000/1000
# 3047/3047 [==============================] - 0s 15us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0445 - val_mean_squared_error: 0.0445
#
# Epoch 01000: val_loss improved from 0.04450 to 0.04450, saving model to /Users/hmohamed/github/data-research-spring2020/sock-shop/models/best_mlp_model.h5
# Done..!

# %%
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
val_loss = history.history['val_loss']
val_loss_df = pd.DataFrame(val_loss)

print("Model Validation MSE mean: %.2f  std: (%.2f)" % \
      (val_loss_df.mean(), val_loss_df.std()))
# Out:
# Model Validation MSE mean: 0.05  std: (0.02)

# %%
# load the saved model
saved_model = load_model(models_dir + 'best_mlp_model.h5')

# %%
# evaluate the model
train_loss, train_mse = saved_model.evaluate(x_train, y_train, verbose=0)
test_loss, test_mse = saved_model.evaluate(x_test, y_test, verbose=0)
print('Train MSE: %.3f, Test MSE: %.3f' % (train_mse, test_mse))
# Out:
# Train MSE: 0.044, Test MSE: 0.044

# %%
#regressor.fit(x_train, y_train)
y_hat = saved_model.predict(x_train)

#y_train = y_scaler.inverse_transform(y_train.reshape(-1,1))
#y_hat = y_scaler.inverse_transform(y_hat.reshape(-1,1))

# %%
y_train = y_train.reshape(-1)

# %%
y_train_together = pd.DataFrame(y_train, columns=['y_train_true'])
y_train_together['y_train_pred'] = y_hat
#y_train_together = y_train_together.reshape(-1,2)
y_train_together.head(5)
# Out:
#    y_train_true  y_train_pred
# 0          0.97          0.89
# 1          0.77          0.48
# 2          0.91          0.48
# 3          1.00          0.98
# 4          0.99          0.93

# %%
r2_train = metrics.r2_score(y_train, y_hat)
print('R2 (training) = {}'.format(r2_train))
# Out:
# R2 (training) = 0.6860697250883696

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
#plt.xlim(-2,3)
#plt.ylim(-3,1)
plt.show()

# %%
#y_train = y_train.values
sns.distplot(y_train - y_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %%
# evaluation mean_absolute_percentage_error
train_error =  y_train - y_hat
train_error

mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)

print("Train Residual mean: %.2f std: %.2f  min; %.2f max: %.2f" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Train Residual mean: -0.00 std: 0.48  min; -1.16 max: 1.03

# %% [markdown]
# ### Testing

# %%
y_hat_test = saved_model.predict(x_test)

#y_test = y_scaler.inverse_transform(y_test.reshape(-1,1))
#y_hat_test = y_scaler.inverse_transform(y_hat_test.reshape(-1,1))

# %%
y_test = y_test.reshape(-1)

# %%
y_test_together = pd.DataFrame(y_test, columns=['y_test_true'])
y_test_together['y_test_pred'] = y_hat_test
y_test_together.head(5)
# Out:
#    y_test_true  y_test_pred
# 0         0.96         0.87
# 1         0.01         0.18
# 2         0.93         0.84
# 3         0.20         0.27
# 4         0.00         0.08

# %%
plt.scatter(y_test, y_hat_test)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_hat_test, color='g')

# %%
perf = pd.DataFrame(np.exp(y_hat_test), columns=['prediction'])
#y_test = y_test.reset_index(drop=True)
perf['target'] = np.exp(y_test)
perf.head()
# Out:
#    prediction  target
# 0        2.38    2.60
# 1        1.19    1.01
# 2        2.31    2.53
# 3        1.31    1.23
# 4        1.08    1.00

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0          2.38    2.60     -0.23         8.82
# 1          1.19    1.01      0.18        18.20
# 2          2.31    2.53     -0.22         8.67
# 3          1.31    1.23      0.08         6.74
# 4          1.08    1.00      0.08         7.96
# ..          ...     ...       ...          ...
# 419        1.62    2.36     -0.74        31.34
# 420        2.72    2.70      0.03         0.98
# 421        1.62    1.88     -0.26        14.00
# 422        1.62    1.34      0.28        20.71
# 423        2.37    2.58     -0.21         8.14
#
# [424 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction  target  residual  difference%
# count      424.00  424.00    424.00       424.00
# mean         1.66    1.69     -0.04        15.54
# std          0.54    0.64      0.36        15.20
# min          0.97    1.00     -1.23         0.02
# 25%          1.19    1.05     -0.21         3.22
# 50%          1.62    1.52      0.00        10.17
# 75%          1.88    2.38      0.18        23.65
# max          3.03    2.72      0.92        89.71

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 285        2.63    2.63     -0.00         0.02
# 103        1.00    1.00     -0.00         0.07
# 30         1.00    1.00      0.00         0.08
# 106        1.00    1.00     -0.00         0.09
# 101        1.06    1.06      0.00         0.18
# 73         1.02    1.02     -0.00         0.18
# 146        1.02    1.02     -0.00         0.19
# 307        1.62    1.61      0.00         0.22
# 113        1.03    1.02      0.00         0.24
# 327        1.01    1.01      0.00         0.24
# 412        1.62    1.61      0.00         0.29
# 267        2.57    2.57      0.01         0.30
# 120        1.62    1.62     -0.01         0.32
# 318        2.64    2.64      0.01         0.34
# 95         2.60    2.60     -0.01         0.35
# 406        1.00    1.00     -0.00         0.39
# 170        2.71    2.70      0.01         0.41
# 352        2.66    2.68     -0.01         0.42
# 115        2.58    2.57      0.01         0.43
# 252        1.66    1.66      0.01         0.47
# 283        1.02    1.02      0.00         0.49
# 348        1.26    1.27     -0.01         0.52
# 243        1.01    1.02     -0.01         0.60
# 96         1.01    1.00      0.01         0.61
# 122        2.53    2.51      0.02         0.62
# 77         1.01    1.00      0.01         0.63
# 145        1.01    1.00      0.01         0.68
# 232        0.99    1.00     -0.01         0.75
# 409        1.06    1.05      0.01         0.84
# 310        1.02    1.02      0.01         0.89
# 343        1.01    1.02     -0.01         0.95
# 420        2.72    2.70      0.03         0.98
# 97         1.50    1.48      0.01         1.00
# 269        1.01    1.00      0.01         1.10
# 110        1.04    1.02      0.01         1.11
# 334        2.60    2.62     -0.03         1.11
# 214        1.00    1.01     -0.01         1.14
# 94         1.01    1.00      0.01         1.20
# 335        2.63    2.60      0.03         1.24
# 18         1.00    1.01     -0.01         1.25
# 10         1.01    1.02     -0.01         1.25
# 291        1.01    1.00      0.01         1.28
# 404        1.07    1.06      0.01         1.30
# 35         2.75    2.72      0.04         1.31
# 42         2.34    2.37     -0.03         1.32
# 174        1.02    1.01      0.01         1.37
# 186        1.00    1.01     -0.01         1.42
# 373        1.00    1.01     -0.01         1.47
# 292        0.99    1.01     -0.01         1.47
# 31         2.58    2.62     -0.04         1.53
# 328        2.70    2.66      0.04         1.57
# 137        1.08    1.06      0.02         1.58
# 133        1.09    1.10     -0.02         1.64
# 75         1.62    1.65     -0.03         1.65
# 157        1.62    1.59      0.03         1.72
# 164        0.99    1.01     -0.02         1.72
# 309        0.98    1.00     -0.02         1.75
# 47         1.62    1.59      0.03         1.79
# 248        0.98    1.00     -0.02         1.79
# 190        2.52    2.57     -0.05         1.80
# 64         0.98    1.00     -0.02         1.85
# 392        1.28    1.26      0.02         1.85
# 92         1.48    1.45      0.03         1.88
# 336        1.62    1.65     -0.03         1.92
# 124        0.98    1.00     -0.02         1.98
# 179        0.98    1.00     -0.02         2.08
# 367        2.62    2.56      0.05         2.09
# 320        1.08    1.06      0.02         2.11
# 237        0.99    1.01     -0.02         2.13
# 276        1.13    1.16     -0.02         2.13
# 233        1.82    1.86     -0.04         2.14
# 413        1.03    1.00      0.02         2.15
# 6          1.02    1.04     -0.02         2.16
# 205        1.03    1.01      0.02         2.17
# 408        2.74    2.68      0.06         2.22
# 383        0.98    1.00     -0.02         2.24
# 366        1.22    1.25     -0.03         2.28
# 71         2.21    2.16      0.05         2.30
# 119        0.98    1.00     -0.02         2.31
# 188        2.54    2.48      0.06         2.32
# 165        2.62    2.69     -0.06         2.34
# 281        1.03    1.01      0.02         2.36
# 135        1.00    1.03     -0.02         2.40
# 46         1.02    1.00      0.02         2.43
# 398        0.98    1.00     -0.02         2.45
# 184        1.62    1.58      0.04         2.47
# 203        0.99    1.02     -0.03         2.52
# 353        1.04    1.02      0.03         2.54
# 218        2.58    2.65     -0.07         2.59
# 241        2.58    2.65     -0.07         2.64
# 302        0.99    1.02     -0.03         2.64
# 345        0.98    1.00     -0.03         2.67
# 274        0.99    1.02     -0.03         2.71
# 111        0.99    1.02     -0.03         2.81
# 397        1.04    1.01      0.03         2.82
# 415        1.03    1.00      0.03         2.83
# 17         0.98    1.01     -0.03         2.96
# 177        1.04    1.01      0.03         2.98
# 43         1.62    1.57      0.05         3.03
# 201        1.03    1.00      0.03         3.04
# 153        0.99    1.02     -0.03         3.04
# 354        1.17    1.21     -0.04         3.05
# 247        1.62    1.67     -0.05         3.10
# 28         2.42    2.34      0.07         3.17
# 351        2.09    2.16     -0.07         3.19
# 61         1.04    1.01      0.03         3.22
# 197        1.32    1.36     -0.04         3.23
# 400        0.97    1.00     -0.03         3.23
# 126        0.98    1.01     -0.03         3.25
# 79         0.99    1.02     -0.03         3.30
# 148        1.05    1.01      0.03         3.35
# 136        1.62    1.67     -0.06         3.36
# 49         1.04    1.01      0.03         3.39
# 187        1.62    1.56      0.05         3.52
# 410        1.62    1.68     -0.06         3.56
# 162        0.98    1.01     -0.04         3.71
# 387        0.98    1.02     -0.04         3.74
# 236        0.98    1.02     -0.04         3.90
# 45         1.62    1.69     -0.07         4.01
# 215        2.54    2.65     -0.11         4.06
# 263        2.47    2.57     -0.10         4.07
# 213        1.05    1.01      0.04         4.17
# 282        2.60    2.71     -0.12         4.28
# 52         1.62    1.55      0.07         4.57
# 161        1.07    1.02      0.05         4.58
# 418        2.40    2.30      0.11         4.67
# 99         2.77    2.64      0.13         4.91
# 361        2.83    2.69      0.13         4.95
# 98         2.50    2.63     -0.13         4.99
# 340        1.05    1.00      0.05         5.02
# 257        1.62    1.71     -0.09         5.11
# 166        1.06    1.00      0.05         5.17
# 272        1.06    1.00      0.05         5.26
# 223        1.62    1.54      0.08         5.27
# 358        0.97    1.03     -0.05         5.29
# 258        1.05    1.00      0.05         5.34
# 403        1.21    1.15      0.06         5.39
# 405        1.06    1.01      0.06         5.49
# 208        2.21    2.34     -0.13         5.55
# 55         1.62    1.71     -0.10         5.55
# 196        2.34    2.48     -0.14         5.63
# 121        2.28    2.16      0.12         5.65
# 109        1.62    1.72     -0.10         5.68
# 100        1.06    1.01      0.06         5.74
# 176        2.40    2.55     -0.15         5.76
# 83         2.35    2.50     -0.15         5.84
# 191        2.56    2.72     -0.16         5.84
# 255        1.62    1.53      0.09         5.99
# 59         2.73    2.57      0.16         6.03
# 209        1.35    1.27      0.08         6.09
# 204        2.44    2.60     -0.16         6.10
# 194        2.46    2.62     -0.16         6.12
# 20         1.19    1.26     -0.08         6.21
# 297        2.41    2.57     -0.16         6.28
# 56         2.49    2.66     -0.17         6.36
# 317        1.62    1.52      0.10         6.42
# 244        1.12    1.05      0.07         6.44
# 338        2.44    2.61     -0.17         6.53
# 13         2.87    2.70      0.18         6.65
# 3          1.31    1.23      0.08         6.74
# 211        2.36    2.53     -0.17         6.75
# 11         1.07    1.00      0.07         6.75
# 128        1.31    1.22      0.08         6.81
# 330        2.86    2.68      0.18         6.84
# 81         1.33    1.25      0.09         6.85
# 91         1.62    1.74     -0.12         6.94
# 298        2.40    2.58     -0.18         7.09
# 16         2.91    2.72      0.19         7.16
# 266        2.45    2.64     -0.19         7.23
# 417        2.85    2.66      0.19         7.26
# 169        1.62    1.51      0.11         7.28
# 89         2.47    2.67     -0.20         7.32
# 70         2.46    2.66     -0.20         7.35
# 154        1.10    1.02      0.08         7.35
# 130        2.91    2.71      0.20         7.37
# 379        1.09    1.02      0.08         7.48
# 78         2.58    2.40      0.18         7.54
# 363        2.69    2.50      0.19         7.56
# 362        1.34    1.25      0.10         7.79
# 4          1.08    1.00      0.08         7.96
# 234        1.62    1.76     -0.14         8.00
# 220        2.30    2.13      0.17         8.09
# 112        2.13    2.32     -0.19         8.12
# 423        2.37    2.58     -0.21         8.14
# 370        1.87    1.73      0.14         8.25
# 304        2.92    2.69      0.23         8.49
# 86         1.62    1.77     -0.15         8.50
# 389        1.62    1.49      0.13         8.59
# 172        2.39    2.20      0.19         8.63
# 63         1.15    1.05      0.09         8.64
# 2          2.31    2.53     -0.22         8.67
# 246        1.62    1.49      0.13         8.74
# 224        2.34    2.57     -0.22         8.74
# 163        1.10    1.01      0.09         8.82
# 0          2.38    2.60     -0.23         8.82
# 382        2.41    2.65     -0.24         8.96
# 251        1.11    1.02      0.09         9.06
# 250        2.92    2.67      0.24         9.14
# 294        2.48    2.26      0.21         9.40
# 350        2.95    2.70      0.26         9.49
# 24         1.40    1.55     -0.15         9.59
# 9          2.36    2.61     -0.25         9.60
# 129        2.40    2.66     -0.26         9.68
# 7          2.31    2.56     -0.25         9.72
# 279        2.39    2.65     -0.26         9.73
# 290        2.25    2.50     -0.24         9.77
# 333        1.62    1.79     -0.18         9.78
# 225        1.08    1.20     -0.12         9.84
# 308        2.39    2.66     -0.26         9.94
# 156        1.62    1.80     -0.18         9.97
# 107        2.23    2.48     -0.25        10.12
# 58         2.35    2.61     -0.27        10.16
# 289        2.39    2.66     -0.27        10.18
# 355        2.39    2.68     -0.28        10.61
# 296        1.12    1.01      0.11        10.79
# 388        1.62    1.82     -0.20        10.99
# 242        2.88    2.59      0.29        11.23
# 123        1.46    1.64     -0.19        11.31
# 313        1.13    1.28     -0.15        11.53
# 34         2.29    2.59     -0.30        11.59
# 275        2.20    2.49     -0.29        11.60
# 376        3.03    2.71      0.32        11.72
# 374        3.00    2.69      0.32        11.77
# 25         1.79    1.60      0.19        11.78
# 138        1.62    1.84     -0.22        12.01
# 90         1.40    1.59     -0.19        12.07
# 326        2.32    2.64     -0.32        12.09
# 386        1.62    1.84     -0.23        12.24
# 69         1.62    1.44      0.18        12.46
# 142        2.51    2.23      0.28        12.47
# 168        1.62    1.85     -0.23        12.54
# 271        1.62    1.44      0.18        12.54
# 76         2.13    2.44     -0.31        12.58
# 380        1.16    1.03      0.13        12.64
# 342        1.62    1.44      0.18        12.69
# 394        1.05    1.21     -0.15        12.76
# 254        2.28    2.61     -0.33        12.77
# 202        1.62    1.44      0.18        12.77
# 264        1.13    1.00      0.13        12.93
# 393        1.32    1.52     -0.20        12.93
# 117        1.25    1.11      0.14        13.00
# 332        1.62    1.86     -0.24        13.07
# 57         1.62    1.43      0.19        13.22
# 259        1.31    1.51     -0.20        13.28
# 84         1.62    1.87     -0.25        13.48
# 199        1.18    1.04      0.14        13.62
# 85         1.31    1.52     -0.21        13.65
# 72         1.62    1.42      0.20        13.76
# 421        1.62    1.88     -0.26        14.00
# 235        3.02    2.65      0.37        14.05
# 180        1.62    1.88     -0.27        14.12
# 29         1.14    1.00      0.14        14.19
# 219        1.08    1.26     -0.18        14.22
# 260        1.62    1.42      0.20        14.30
# 300        1.62    1.89     -0.27        14.41
# 368        2.28    2.67     -0.39        14.46
# 195        1.17    1.02      0.15        14.60
# 185        1.62    1.90     -0.28        14.64
# 268        1.15    1.01      0.15        14.66
# 23         1.89    1.64      0.24        14.75
# 411        1.62    1.41      0.21        14.76
# 396        1.43    1.68     -0.25        14.77
# 321        1.62    1.41      0.21        14.92
# 359        1.75    1.52      0.23        14.92
# 175        1.62    1.91     -0.29        15.21
# 319        2.30    2.72     -0.42        15.29
# 93         1.62    1.91     -0.30        15.44
# 344        1.17    1.01      0.16        15.49
# 114        1.17    1.02      0.16        15.58
# 87         1.62    1.92     -0.30        15.72
# 183        1.62    1.92     -0.31        15.89
# 14         1.62    1.93     -0.31        16.01
# 125        1.47    1.26      0.20        16.06
# 256        1.88    1.61      0.27        16.52
# 249        1.62    1.95     -0.33        16.85
# 210        1.22    1.04      0.18        17.32
# 284        1.69    1.44      0.25        17.32
# 74         1.21    1.03      0.18        17.39
# 8          1.62    1.96     -0.34        17.52
# 54         1.62    1.38      0.24        17.58
# 402        1.62    1.97     -0.35        17.74
# 68         1.23    1.50     -0.27        17.88
# 1          1.19    1.01      0.18        18.20
# 371        2.15    2.63     -0.48        18.24
# 381        1.28    1.08      0.20        18.31
# 341        1.22    1.03      0.19        18.32
# 200        1.19    1.01      0.19        18.40
# 181        1.62    1.99     -0.37        18.52
# 67         1.94    2.38     -0.45        18.68
# 127        1.19    1.00      0.19        18.79
# 182        2.56    2.16      0.41        18.79
# 159        2.12    2.61     -0.49        18.80
# 212        1.32    1.64     -0.32        19.29
# 198        1.71    1.43      0.28        19.51
# 278        1.26    1.56     -0.31        19.64
# 221        1.23    1.53     -0.30        19.67
# 401        1.20    1.01      0.20        19.78
# 27         1.62    1.35      0.27        19.98
# 147        2.24    1.87      0.38        20.12
# 36         1.62    2.03     -0.41        20.20
# 357        1.62    1.34      0.27        20.39
# 40         1.64    2.07     -0.42        20.49
# 37         1.62    2.04     -0.42        20.52
# 422        1.62    1.34      0.28        20.71
# 414        1.23    1.55     -0.32        20.79
# 324        1.62    2.05     -0.43        20.90
# 375        1.62    2.07     -0.45        21.64
# 65         1.62    2.07     -0.45        21.75
# 80         1.53    1.26      0.28        21.99
# 104        1.62    2.08     -0.46        22.27
# 384        1.62    2.09     -0.47        22.48
# 144        1.22    1.57     -0.35        22.56
# 66         1.62    2.10     -0.48        22.90
# 231        1.62    2.10     -0.48        22.95
# 347        1.62    2.10     -0.49        23.11
# 5          0.99    1.29     -0.30        23.16
# 216        1.97    2.57     -0.60        23.45
# 270        1.62    2.12     -0.50        23.57
# 377        1.62    2.13     -0.51        23.88
# 39         1.62    2.14     -0.52        24.29
# 60         1.62    1.30      0.32        24.35
# 331        1.62    2.14     -0.52        24.39
# 315        1.62    2.14     -0.53        24.54
# 286        1.62    2.15     -0.53        24.80
# 160        1.62    1.30      0.32        24.94
# 44         1.49    1.20      0.30        25.07
# 19         1.62    2.17     -0.55        25.25
# 143        1.62    1.29      0.33        25.36
# 364        1.62    2.18     -0.56        25.65
# 152        1.62    2.18     -0.56        25.75
# 316        1.62    1.29      0.33        25.87
# 346        1.62    1.29      0.33        25.95
# 134        1.62    2.19     -0.57        26.05
# 32         1.62    2.20     -0.58        26.45
# 139        1.62    1.28      0.34        26.55
# 151        1.91    2.61     -0.70        26.68
# 82         1.27    1.00      0.27        26.79
# 53         1.62    2.21     -0.59        26.80
# 360        1.84    2.53     -0.68        27.07
# 118        1.62    1.27      0.35        27.32
# 238        1.62    2.23     -0.61        27.53
# 311        1.02    1.41     -0.39        27.54
# 192        2.12    1.65      0.47        28.28
# 240        1.62    2.26     -0.64        28.36
# 140        1.30    1.01      0.29        28.65
# 314        1.62    1.26      0.36        28.70
# 88         1.62    1.26      0.36        28.78
# 245        1.68    1.30      0.38        29.06
# 132        1.54    1.19      0.35        29.25
# 50         1.62    1.25      0.37        29.57
# 167        1.62    2.30     -0.68        29.60
# 102        1.42    1.09      0.33        30.31
# 227        1.85    2.67     -0.82        30.59
# 390        1.62    1.24      0.38        30.88
# 295        1.62    1.24      0.38        30.97
# 419        1.62    2.36     -0.74        31.34
# 21         1.62    2.37     -0.75        31.80
# 273        1.62    1.23      0.39        31.86
# 265        1.62    2.38     -0.76        31.94
# 312        1.62    2.38     -0.76        32.03
# 226        1.62    2.39     -0.77        32.17
# 12         1.62    2.39     -0.77        32.26
# 322        1.62    2.40     -0.78        32.53
# 62         1.62    2.42     -0.80        33.12
# 305        1.62    1.21      0.41        33.38
# 22         1.62    1.21      0.41        33.74
# 228        1.62    2.46     -0.84        34.28
# 178        1.62    2.46     -0.85        34.33
# 299        1.43    1.06      0.37        34.44
# 206        1.62    2.48     -0.86        34.68
# 149        1.62    2.49     -0.87        34.99
# 306        1.62    1.20      0.42        35.01
# 171        1.62    2.50     -0.88        35.25
# 391        1.62    1.19      0.42        35.46
# 33         1.62    1.19      0.42        35.55
# 385        1.62    1.18      0.43        36.75
# 189        1.62    1.18      0.44        36.84
# 51         1.62    2.57     -0.95        37.06
# 26         1.62    2.57     -0.95        37.10
# 222        1.62    2.58     -0.96        37.23
# 277        1.62    2.59     -0.97        37.40
# 239        1.62    1.18      0.44        37.58
# 369        1.62    1.18      0.44        37.67
# 395        1.62    2.60     -0.98        37.73
# 48         1.62    1.17      0.44        37.86
# 301        1.83    1.32      0.50        38.03
# 288        1.62    1.17      0.45        38.14
# 141        1.62    1.17      0.45        38.70
# 329        1.62    1.17      0.45        38.79
# 365        2.14    1.54      0.60        39.31
# 293        1.53    2.55     -1.02        40.05
# 287        1.53    2.62     -1.10        41.74
# 173        1.43    2.47     -1.05        42.37
# 253        1.62    1.14      0.48        42.49
# 131        1.40    2.50     -1.10        44.09
# 378        1.62    1.12      0.50        44.32
# 399        1.62    1.12      0.50        45.10
# 339        1.47    2.70     -1.23        45.65
# 38         1.62    1.11      0.51        46.09
# 407        1.42    2.64     -1.22        46.28
# 356        1.62    1.11      0.51        46.28
# 261        1.62    1.10      0.52        46.97
# 217        1.62    1.09      0.52        47.97
# 323        1.29    2.51     -1.22        48.57
# 105        1.62    1.09      0.53        48.67
# 303        1.50    1.01      0.50        49.12
# 158        1.91    1.28      0.64        49.82
# 150        1.62    1.08      0.54        50.38
# 262        1.62    1.07      0.55        51.60
# 230        1.62    1.06      0.56        53.14
# 41         1.62    1.05      0.56        53.45
# 155        1.62    1.05      0.57        53.66
# 416        1.62    1.05      0.57        53.87
# 15         2.59    1.67      0.92        55.39
# 207        1.59    1.02      0.57        56.20
# 116        1.62    1.03      0.58        56.38
# 325        1.62    1.03      0.59        56.69
# 280        1.62    1.03      0.59        57.01
# 108        1.62    1.03      0.59        57.54
# 349        1.62    1.02      0.60        58.29
# 372        2.29    1.44      0.85        59.20
# 193        2.42    1.51      0.91        60.42
# 337        2.14    1.28      0.86        67.10
# 229        1.92    1.01      0.91        89.71

# %% [markdown]
# # Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_hat_test)
print('R2 (testing) = {}'.format(r2_test))
# Out:
# R2 (testing) = 0.68463696349176

# %%
print(np.sqrt(mean_squared_error(y_test,y_hat_test)))
# Out:
# 0.21081282893745307
