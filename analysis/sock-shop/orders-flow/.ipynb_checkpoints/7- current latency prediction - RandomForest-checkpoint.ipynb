# %% [markdown]
# # RandomForest Regressor
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import seaborn as sns
from sklearn import preprocessing, metrics, feature_selection
from datetime import datetime
from scipy import stats
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# Set this flag to True if you're using reduction feature using FCA, otherwise set it to False

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'


#data_file = 'order_flow_cleanup_data.csv'
data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'


test_split = 0.1

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, True)
data = data.reset_index(drop=True)
data.head(5)
# Out:
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0               0.07            0.02               0.01          0.02
# 1               0.06            0.03               0.01          0.02
# 2               0.06            0.03               0.01          0.02
# 3               0.09            0.03               0.01          0.02
# 4               0.11            0.04               0.01          0.03
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0             0.02              0.01             0.01           0.12
# 1             0.02              0.01             0.01           0.14
# 2             0.02              0.01             0.01           0.15
# 3             0.02              0.01             0.01           0.06
# 4             0.03              0.01             0.01           0.11
#
#    carts-db_cpu_use  front-end_pods  orders_pods  user_pods  shipping_pods  \
# 0              0.16            1.00         1.00       1.00           1.00
# 1              0.17            1.00         1.00       1.00           1.00
# 2              0.14            1.00         1.00       1.00           1.00
# 3              0.19            1.00         1.00       1.00           1.00
# 4              0.32            1.00         1.00       1.00           1.00
#
#    payment_pods  carts_pods  nodes_cpu_use  orders_req  orders_ltcy
# 0          1.00        1.00           1.18        0.40         0.63
# 1          1.00        1.00           1.18        0.44         0.62
# 2          1.00        1.00           1.15        0.36         0.62
# 3          1.00        1.00           1.54        0.40         0.56
# 4          1.00        1.00           2.35        0.78         0.53

# %%
data.shape
# Out:
# (1499, 18)

# %%
targets = data['orders_ltcy']
inputs = data.drop(['orders_ltcy'], axis=1)

n_features = inputs.values.shape[1]

x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=test_split, shuffle=False, random_state=365)

# for better convergence and result scale target to values between 0 - 1
y_train_max = y_train.max()
y_test_max = y_test.max()

y_train = y_train / y_train_max
y_test = y_test / y_test_max

print("there are {} features".format(n_features))
# Out:
# there are 17 features

# %%
# Regression

# start:  search grid

randforest = RandomForestRegressor() #(n_estimators=tree_n_estimators, max_features=tree_n_features)

# standardize the features
scaler = StandardScaler()

# no feastures selection needed for RandomTree Regressor
pipe = Pipeline(steps=[
    ('scaler', scaler),
    ('clf', randforest)
])

kfold = KFold(n_splits=10, shuffle=False)

param_grid = {
    'clf__max_features': [11, 9, 7, 5, 3]   # The maximum number of features to consider
    ,'clf__n_estimators': [10, 8, 6, 4, 2, 1]  # The number of trees in the forest 
}


search = GridSearchCV(pipe
                      , param_grid
                      , scoring='neg_mean_squared_error'
                      , return_train_score= True
                      , cv=kfold
                      , verbose=0
                      , n_jobs=-1)

search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('clf',
#                                         RandomForestRegressor(bootstrap=True,
#                                                               ccp_alpha=0.0,
#                                                               criterion='mse',
#                                                               max_depth=None,
#                                                               max_features='auto',
#                                                               max_leaf_nodes=None,
#                                                               max_samples=None,
#                                                               min_impurity_decr...
#                                                               min_samples_split=2,
#                                                               min_weight_fraction_leaf=0.0,
#                                                               n_estimators=100,
#                                                               n_jobs=None,
#                                                               oob_score=False,
#                                                               random_state=None,
#                                                               verbose=0,
#                                                               warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'clf__max_features': [11, 9, 7, 5, 3],
#                          'clf__n_estimators': [10, 8, 6, 4, 2, 1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %% [markdown]
# # Best Model

# %%
estimator = search.best_estimator_
params = search.best_params_
score = search.best_score_

print("Best CV score = %0.3f:" % score)
print("Best CV params = {}".format(params))

print("")
all_training_scores = search.cv_results_
#print("\ncross_validation:\n", all_training_scores , "\n")
print(all_training_scores['mean_train_score'])

print("")
print('Model training Score = {}'.format(search.score(x_train,y_train)))
# Out:
# Best CV score = -0.017:
# Best CV params = {'clf__max_features': 9, 'clf__n_estimators': 10}
#
# [-0.00222483 -0.00224635 -0.00259053 -0.00326167 -0.00495943 -0.00881234
#  -0.00220535 -0.00232153 -0.00257073 -0.00334315 -0.00511535 -0.008463
#  -0.00217882 -0.00239108 -0.00262794 -0.00319269 -0.00495966 -0.00854461
#  -0.00223228 -0.002455   -0.0027394  -0.00340388 -0.00507575 -0.00940256
#  -0.00229882 -0.00244821 -0.00272597 -0.00352559 -0.0054575  -0.0090415 ]
#
# Model training Score = -0.0020842077547847063

# %%
pdf = pd.DataFrame(all_training_scores['mean_train_score'], columns=['training mse'])
pdf.plot()

# %% [markdown]
# # Training R2

# %%
score = search.score(x_train, y_train)
score
# Out:
# -0.0020842077547847063

# %%
#scaler.fit(x_train.values.reshape(-1,n_features))
#x_train = scaler.transform(x_train)

y_hat = search.predict(x_train)

r2_train = metrics.r2_score(y_train, y_hat)
print('R2 (training) = {}'.format(r2_train))
# Out:
# R2 (training) = 0.9562478043829143

# %%
# validation mean_absolute_percentage_error
train_error =  np.abs(y_train - y_hat)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)


print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.03 (0.04) 0.00 0.39 MSE

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
#plt.xlim(-2,3)
#plt.ylim(-3,1)
plt.show()

# %%
sns.distplot(y_train - y_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %% [markdown]
# # Testing

# %%
y_hat_test = search.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_hat_test, color='g')

# %%
perf = pd.DataFrame(np.exp(y_hat_test), columns=['prediction'])
y_test = y_test.reset_index(drop=True)
perf['target'] = np.exp(y_test)
perf.head()
# Out:
#    prediction  target
# 0        1.22    1.20
# 1        1.28    1.25
# 2        1.26    1.27
# 3        1.27    1.28
# 4        1.35    1.28

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0          1.22    1.20      0.02         1.27
# 1          1.28    1.25      0.03         2.30
# 2          1.26    1.27     -0.01         0.79
# 3          1.27    1.28     -0.01         0.82
# 4          1.35    1.28      0.06         5.05
# ..          ...     ...       ...          ...
# 145        1.72    2.13     -0.41        19.30
# 146        2.06    2.71     -0.65        24.14
# 147        2.04    2.50     -0.46        18.36
# 148        1.99    2.69     -0.70        26.03
# 149        1.91    2.67     -0.76        28.39
#
# [150 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction  target  residual  difference%
# count      150.00  150.00    150.00       150.00
# mean         1.72    1.79     -0.06        11.26
# std          0.30    0.46      0.28         8.55
# min          1.21    1.20     -0.83         0.11
# 25%          1.45    1.30     -0.23         3.68
# 50%          1.79    1.74      0.01         9.79
# 75%          1.98    2.21      0.10        17.43
# max          2.28    2.72      0.53        37.77

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 100        1.74    1.74      0.00         0.11
# 16         1.24    1.24     -0.00         0.20
# 38         1.38    1.37      0.01         0.56
# 19         1.24    1.25     -0.01         0.61
# 101        1.70    1.71     -0.01         0.68
# 2          1.26    1.27     -0.01         0.79
# 3          1.27    1.28     -0.01         0.82
# 23         1.25    1.27     -0.01         0.97
# 21         1.24    1.23      0.01         1.01
# 7          1.31    1.30      0.01         1.04
# 136        1.81    1.79      0.02         1.18
# 0          1.22    1.20      0.02         1.27
# 17         1.26    1.25      0.02         1.27
# 118        1.79    1.77      0.02         1.36
# 92         2.26    2.30     -0.04         1.58
# 30         1.22    1.20      0.02         1.60
# 109        1.98    1.94      0.03         1.71
# 93         2.26    2.30     -0.04         1.72
# 94         2.21    2.25     -0.04         1.89
# 85         2.04    2.08     -0.04         1.96
# 89         2.07    2.02      0.04         2.19
# 9          1.47    1.44      0.03         2.24
# 1          1.28    1.25      0.03         2.30
# 5          1.32    1.29      0.03         2.34
# 15         1.21    1.24     -0.03         2.61
# 13         1.25    1.21      0.03         2.63
# 39         1.29    1.26      0.03         2.65
# 43         1.24    1.20      0.03         2.81
# 97         1.94    2.00     -0.06         2.82
# 20         1.27    1.23      0.03         2.83
# 27         1.24    1.20      0.03         2.89
# 6          1.34    1.30      0.04         3.06
# 26         1.31    1.27      0.04         3.32
# 87         1.99    2.06     -0.07         3.49
# 117        1.85    1.79      0.06         3.50
# 66         1.48    1.43      0.05         3.59
# 18         1.29    1.25      0.05         3.65
# 49         1.65    1.59      0.06         3.66
# 29         1.25    1.20      0.05         3.76
# 75         1.86    1.79      0.07         4.00
# 67         1.75    1.68      0.07         4.22
# 130        1.81    1.73      0.07         4.27
# 71         1.48    1.42      0.06         4.54
# 64         2.08    2.19     -0.11         4.85
# 90         2.08    2.19     -0.11         4.87
# 4          1.35    1.28      0.06         5.05
# 35         1.57    1.50      0.08         5.18
# 131        2.10    2.21     -0.12         5.25
# 32         1.36    1.29      0.07         5.37
# 10         1.51    1.60     -0.09         5.48
# 44         1.30    1.23      0.07         6.01
# 86         2.00    2.13     -0.13         6.12
# 28         1.28    1.20      0.08         6.26
# 59         1.72    1.62      0.10         6.32
# 12         1.32    1.42     -0.10         6.86
# 144        2.28    2.45     -0.17         7.01
# 129        1.89    2.04     -0.14         7.01
# 114        2.09    1.95      0.14         7.02
# 60         1.59    1.48      0.10         7.03
# 63         1.79    1.93     -0.14         7.17
# 119        2.09    2.25     -0.16         7.26
# 40         1.29    1.20      0.09         7.32
# 141        1.81    1.95     -0.14         7.37
# 70         2.11    2.28     -0.17         7.46
# 80         1.99    2.15     -0.16         7.63
# 127        2.12    2.30     -0.18         7.78
# 25         1.39    1.29      0.10         7.91
# 42         1.30    1.20      0.10         7.99
# 102        1.93    2.10     -0.17         8.05
# 53         1.34    1.24      0.10         8.30
# 137        2.22    2.43     -0.21         8.74
# 78         1.91    2.10     -0.19         9.24
# 123        1.48    1.64     -0.15         9.33
# 45         1.34    1.23      0.12         9.60
# 126        2.06    2.28     -0.22         9.76
# 81         2.02    2.24     -0.22         9.82
# 8          1.48    1.35      0.13         9.85
# 120        2.05    2.28     -0.23         9.97
# 112        2.00    2.23     -0.23        10.13
# 99         1.81    2.02     -0.21        10.27
# 133        2.03    2.27     -0.24        10.54
# 95         2.02    2.27     -0.25        10.89
# 111        1.94    2.18     -0.24        10.90
# 96         1.76    1.58      0.18        11.06
# 88         1.84    2.08     -0.23        11.23
# 134        1.57    1.78     -0.21        11.67
# 22         1.35    1.20      0.14        11.80
# 65         2.01    2.29     -0.28        12.04
# 108        1.63    1.45      0.18        12.34
# 107        2.01    1.79      0.22        12.36
# 48         1.66    1.47      0.18        12.37
# 68         1.95    1.73      0.22        12.56
# 124        1.85    2.12     -0.27        12.85
# 50         1.77    1.57      0.20        12.94
# 73         1.95    1.72      0.22        13.04
# 105        2.10    1.85      0.24        13.06
# 14         1.40    1.24      0.16        13.26
# 132        1.67    1.94     -0.27        13.95
# 84         1.91    2.22     -0.31        14.01
# 139        1.87    2.18     -0.31        14.20
# 24         1.48    1.29      0.18        14.23
# 62         1.91    1.67      0.24        14.30
# 31         1.44    1.26      0.18        14.30
# 104        1.79    2.09     -0.30        14.38
# 69         2.13    1.86      0.27        14.58
# 77         1.98    2.32     -0.34        14.63
# 37         1.58    1.38      0.20        14.84
# 135        1.80    2.13     -0.33        15.30
# 61         1.65    1.42      0.23        16.37
# 79         1.85    1.59      0.26        16.45
# 46         1.44    1.23      0.21        17.20
# 36         1.71    1.46      0.25        17.30
# 58         1.93    1.64      0.29        17.48
# 51         1.64    1.40      0.25        17.86
# 110        1.88    2.29     -0.41        18.01
# 56         1.83    1.55      0.28        18.05
# 91         2.03    2.49     -0.45        18.19
# 125        1.83    2.25     -0.41        18.28
# 106        2.11    1.78      0.33        18.35
# 147        2.04    2.50     -0.46        18.36
# 11         1.27    1.56     -0.29        18.48
# 145        1.72    2.13     -0.41        19.30
# 122        2.13    2.66     -0.53        19.81
# 143        2.04    2.55     -0.51        20.11
# 82         1.82    2.29     -0.47        20.42
# 128        1.92    2.42     -0.49        20.45
# 140        1.95    2.46     -0.50        20.55
# 52         1.53    1.27      0.26        20.66
# 74         2.15    1.76      0.39        21.97
# 33         1.70    1.39      0.31        22.11
# 57         2.02    1.65      0.37        22.16
# 76         1.51    1.95     -0.44        22.37
# 103        1.72    2.22     -0.50        22.42
# 115        1.70    2.19     -0.49        22.48
# 83         1.75    2.26     -0.51        22.51
# 113        1.91    2.50     -0.59        23.52
# 146        2.06    2.71     -0.65        24.14
# 98         2.04    2.72     -0.68        25.06
# 34         1.90    1.51      0.39        25.48
# 148        1.99    2.69     -0.70        26.03
# 142        1.90    2.57     -0.67        26.20
# 138        1.72    2.37     -0.66        27.62
# 55         1.85    1.44      0.41        28.21
# 149        1.91    2.67     -0.76        28.39
# 121        1.64    2.33     -0.69        29.43
# 72         1.89    1.45      0.44        30.03
# 116        1.86    2.69     -0.83        30.73
# 47         1.64    1.25      0.39        31.27
# 41         1.59    1.20      0.39        32.13
# 54         1.92    1.39      0.53        37.77

# %% [markdown]
# # Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_hat_test)
print('R2 (testing) = {}'.format(r2_test))

# also: R-Squared could obtain with
# pline.score(x_test, y_test)
# Out:
# R2 (testing) = 0.6826970621232824

# %%
print(np.sqrt(mean_squared_error(y_test,y_hat_test)))
# Out:
# 0.14557658365256576

# %% [markdown]
# # Features Selected

# %%
threshold_selected = params['selector__threshold']
sfm = pipe['selector']

selectedFeatures = sfm.fit(inputs, targets).transform(inputs)
print('{} features selected'.format(selectedFeatures[1].shape[0]))

feature_list = x_train.columns[sfm.get_support()]
features = ''
features = ', '.join(feature_list)
#features

reduced_x_train = x_train[feature_list]
reduced_x_train.head(2)
