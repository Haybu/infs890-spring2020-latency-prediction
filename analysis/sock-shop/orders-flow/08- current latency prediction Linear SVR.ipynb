# %% [markdown]
# # Linear SVR
# Haytham Mohamed
#
# INFS 890 - Spring 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVR
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectKBest
import seaborn as sns
from sklearn import preprocessing, metrics, feature_selection
from datetime import datetime
from scipy import stats
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler , MinMaxScaler
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import RFECV
from sklearn.decomposition import PCA

sns.set()
sns.set(color_codes=True)
#sns.set_color_codes()

pd.options.display.max_rows = 15
pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# Set this flag to True if you're using reduction feature using FCA, otherwise set it to False

# %%
# 1- read data file
# 1- read processed file
home_dir = '/Users/hmohamed/github/data-research-spring2020/sock-shop'
file_dir = home_dir + '/processed-data/'

#data_file = 'orders_flow_data.csv'   # raw data as is
#data_file = 'order_flow_cleanup_data.csv'
data_file = 'order_flow_normalized_data.csv'
#data_file = 'order_flow_standardized_data.csv'
#data_file = 'order_flow_factored_data.csv'


SCALE_TARGETS = True

test_split = 0.1

# %%
def read_df(file_dir, data_file, timeseries=True):
    df = pd.read_csv(file_dir + data_file)
    if timeseries:
        df = to_time_series(df)
    return df

def to_time_series(df, index_col_name='date'):
    df[index_col_name] = pd.to_datetime(df[index_col_name])
    df.set_index(index_col_name, inplace=True)
    df.sort_index(inplace=True)
    return df

def merge(df, series):
    return pd.merge_asof(df, series, left_index=True, right_index=True, tolerance=pd.Timedelta('1 second')).bfill()

# %%
data = read_df(file_dir, data_file, True)
data = data.reset_index(drop=True)
data.head(5)
# Out:
#    front-end_cpu_use  orders_cpu_use  orders-db_cpu_use  user_cpu_use  \
# 0             0.0700          0.0200             0.0100        0.0200
# 1             0.0600          0.0300             0.0100        0.0200
# 2             0.2100          0.0600             0.0200        0.0500
# 3             0.2200          0.0600             0.0200        0.0600
# 4             0.2100          0.0600             0.0100        0.0500
#
#    user-db_cpu_use  shipping_cpu_use  payment_cpu_use  carts_cpu_use  \
# 0           0.0200            0.0100           0.0100         0.1200
# 1           0.0200            0.0100           0.0100         0.1400
# 2           0.0300            0.0200           0.0100         0.2400
# 3           0.0400            0.0200           0.0100         0.2100
# 4           0.0400            0.0200           0.0100         0.1500
#
#    carts-db_cpu_use  front-end_pods  ...  user-db_net_use  shipping_net_use  \
# 0            0.1600          1.0000  ...           9.1583            4.2628
# 1            0.1700          1.0000  ...           8.2344            4.8656
# 2            0.6600          1.0000  ...          25.5465            3.1148
# 3            0.6600          1.0000  ...          26.4822            7.2076
# 4            0.6600          1.0000  ...          18.6872            6.8741
#
#    payment_net_use  carts_net_use  carts-db_net_use  nodes_cpu_use  \
# 0           3.3626         6.9149            5.5572         1.1800
# 1           3.1404         9.7259            7.1883         1.1800
# 2           4.4254        29.5804            7.4301         1.8400
# 3           4.4523        25.2584           15.2118         1.8300
# 4           6.0157        24.1570           16.1607         1.7500
#
#    nodes_disk_io  nodes_net_use  orders_req  orders_ltcy
# 0         0.0000         1.7850      0.4000       0.4000
# 1         0.0000         1.7496      0.4400       0.3900
# 2         0.2600         3.6912      1.5800       0.4200
# 3         0.2600         3.7957      1.5800       0.4100
# 4         0.0000         3.8370      1.4900       0.3900
#
# [5 rows x 29 columns]

# %%
data.shape
# Out:
# (3175, 29)

# %%
targets = data['orders_ltcy']
inputs = data.drop(['orders_ltcy'], axis=1)

n_features = inputs.values.shape[1]
print("there are {} features".format(n_features))
# Out:
# there are 28 features

# %%
# scale targets for better convergence
if SCALE_TARGETS:
    y_scaler =  MinMaxScaler()
    targets = y_scaler.fit_transform(targets.values.reshape(-1,1))

# %%
x_train, x_test, y_train, y_test = \
    train_test_split(inputs, targets, test_size=test_split, shuffle=False, random_state=365)

if 1 == 0:
    # for better convergence and result scale target to values between 0 - 1
    y_train_max = y_train.max()
    y_test_max = y_test.max()

    y_train = y_train / y_train_max
    y_test = y_test / y_test_max

# %%
# plot cpu vs latency 
plt.plot(data['orders_cpu_use'][100:200], label='orders_cpu_use')
plt.plot(data['orders_ltcy'][100:200], label='orders_ltcy')
plt.legend()
plt.show()

#ax = sns.regplot(x=data['orders_cpu_use'], y=data['orders_ltcy'], color='g')

# %% [markdown]
# # Model

# %%
#lasso = LassoCV(fit_intercept=False,n_jobs=-1,random_state=0,selection='random',positive=False,cv=10)
#sfm1 = SelectFromModel(lasso, threshold='0.01*mean')

#rfr = RandomForestRegressor(n_jobs=-1, max_depth=10, n_estimators=20)
#sfm = SelectFromModel(rfr, threshold='0.01*mean')

#sfm = SelectKBest(k=6)

sfm = PCA(random_state=100)

# SVR
#reg = LinearSVR(random_state=365, verbose=0)   #(C=0.1, random_state=365, verbose=0)
reg = SVR(kernel='linear', C=100, gamma='auto')

pipe = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('selector', sfm),
    ('reg', reg)
])

kfold = KFold(n_splits=10, shuffle=True)

param_grid = {
    #'selector__threshold': [0.1, 0.05, 0.02, 0.001]  # with lasso
    
    #'selector__threshold': ['0.05*mean', '0.02*mean', '0.01*mean'] # with tree
    #, 'selector__estimator__max_depth' : [20]
    #, 'selector__estimator__n_estimators' : [40]
    
     'selector__n_components' : [10, 15, 20]   # with PCA
    #,'reg__C': [.01, .05, .1]
    
    ,'reg__C': [100]
    ,'reg__gamma' : ['auto']
}

search = GridSearchCV(pipe, param_grid, scoring='neg_mean_squared_error'
                      , return_train_score= True, cv=kfold, verbose=1, n_jobs=-1)

#scores = cross_val_score(pipe, x_train, y_train, cv=kfold, n_jobs=-1
        #, verbose=3, scoring='neg_mean_squared_error')

# %%
import sklearn 
print('sklearn version {}'.format(sklearn.__version__))

search.fit(x_train, y_train.ravel())
# Out:
# sklearn version 0.22.2.post1
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  4.7min finished
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('selector',
#                                         PCA(copy=True, iterated_power='auto',
#                                             n_components=None, random_state=100,
#                                             svd_solver='auto', tol=0.0,
#                                             whiten=False)),
#                                        ('reg',
#                                         SVR(C=100, cache_size=200, coef0=0.0,
#                                             degree=3, epsilon=0.1, gamma='auto',
#                                             kernel='linear', max_iter=-1,
#                                             shrinking=True, tol=0.001,
#                                             verbose=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'reg__C': [100], 'reg__gamma': ['auto'],
#                          'selector__n_components': [10, 15, 20]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=1)

# %% [markdown]
# # Best Model

# %%
score = search.best_score_
print("Best CV test score = %0.4f:" % score)

params = search.best_params_
print("Best CV params = {}".format(params))

#print("")
all_training_scores = search.cv_results_
#print("\ncross_validation:\n", all_training_scores , "\n")

#print('mean train scores')
#print(all_training_scores['mean_train_score'])

#print('mean test scores')
#print(all_training_scores['mean_test_score'])
# Out:
# Best CV test score = -0.0681:
# Best CV params = {'reg__C': 100, 'reg__gamma': 'auto', 'selector__n_components': 20}

# %% [markdown]
# # Features Selected

# %%
if 1 == 0:
    best_threshold = params['selector__threshold']
    best_max_depth = params['selector__estimator__max_depth']
    best_n_estimators = params['selector__estimator__n_estimators']

    select_model = RandomForestRegressor(n_jobs=-1, max_depth=best_max_depth, n_estimators=best_n_estimators)
    sfm = SelectFromModel(model, threshold=best_threshold)

    selectedFeatures = sfm.fit(x_train, y_train).transform(x_train)
    print('{} features selected'.format(selectedFeatures[1].shape[0]))

    feature_list = x_train.columns[sfm.get_support()]
    features = ''
    features = ', '.join(feature_list)
    #features

    reduced_x_train = x_train[feature_list]
    #reduced_x_train.head(2)
    print('')
    for feature in reduced_x_train.columns.values:
        print(feature)

# %%
pdf = pd.DataFrame(all_training_scores['mean_test_score'], columns=['testing mse'])
pdf.plot()

# %% [markdown]
# # Training R2

# %%
y_train_hat = search.predict(x_train)

r2_train = metrics.r2_score(y_train, y_train_hat)
print('R2 (training) = {}'.format(r2_train))

print('Score (training) = {}'.format(search.score(x_train,y_train)))
# Out:
# R2 (training) = 0.43278715382239474
# Score (training) = -0.06716692833129499

# %%
# validation mean_absolute_percentage_error
train_error =  np.abs(y_train - y_train_hat)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)


print("Model Result (mean - std of error - min - max): %.2f (%.2f) %.2f %.2f MSE" \
      % (mean_error, std_error, min_error, max_error))
# Out:
# Model Result (mean - std of error - min - max): 0.35 (0.23) 0.00 1.54 MSE

# %%
plt.scatter(y_train, y_train_hat)
plt.xlabel('Latency', size=18)
plt.ylabel("predicted Latency", size=18)
plt.show()

# %%
sns.distplot(y_train - y_train_hat)
plt.title('Residual PDF', size=18)
# Out:
# Text(0.5, 1.0, 'Residual PDF')

# %% [markdown]
# # Testing

# %%
y_test_hat = search.predict(x_test)

# %%
plt.scatter(y_test, y_test_hat)
plt.xlabel('Latency', size=18)
plt.ylabel('Predicted Latency', size=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = sns.regplot(x=y_test, y=y_test_hat, color='g')

# %%
perf = pd.DataFrame(y_test_hat, columns=['prediction'])
perf['target'] = y_test
perf.head()
# Out:
#    prediction  target
# 0      0.1246  0.0016
# 1      0.0879  0.0071
# 2     -0.0038  0.0093
# 3      0.0745  0.0027
# 4      0.2323  0.0016

# %%
# testing mean_absolute_percentage_error
perf['residual'] = perf['prediction'] - perf['target']
perf['difference%'] = np.absolute(perf['residual'] * 100 / perf['target'])
perf
# Out:
#      prediction  target  residual  difference%
# 0        0.1246  0.0016    0.1231   7,796.9959
# 1        0.0879  0.0071    0.0808   1,142.4083
# 2       -0.0038  0.0093   -0.0131     141.3877
# 3        0.0745  0.0027    0.0718   2,680.5458
# 4        0.2323  0.0016    0.2307  14,615.7360
# ..          ...     ...       ...          ...
# 313      1.5376  0.9945    0.5431      54.6061
# 314      1.8104  0.9967    0.8137      81.6388
# 315      1.6954  0.9945    0.7009      70.4807
# 316      1.3318  0.9384    0.3933      41.9144
# 317      1.4062  0.9780    0.4282      43.7832
#
# [318 rows x 4 columns]

# %%
perf.describe()
# Out:
#        prediction   target  residual  difference%
# count    318.0000 318.0000  318.0000     318.0000
# mean       0.6372   0.4823    0.1549   1,793.2702
# std        0.4635   0.3622    0.3179   7,635.8455
# min       -0.0477   0.0005   -0.5861       0.5454
# 25%        0.3384   0.1302   -0.0688      26.1970
# 50%        0.4975   0.4585    0.1423      54.9549
# 75%        0.6865   0.8859    0.3516     183.6755
# max        2.0947   1.0000    1.3272  87,659.2122

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
perf.sort_values(by = ['difference%'])
# Out:
#      prediction  target  residual  difference%
# 149        0.39    0.39      0.00         0.55
# 241        0.31    0.31      0.00         0.95
# 179        0.37    0.37      0.00         1.10
# 180        0.23    0.23      0.00         1.50
# 138        0.48    0.47      0.01         1.83
# 210        0.39    0.40     -0.01         2.02
# 246        0.61    0.59      0.01         2.25
# 166        0.49    0.48      0.01         2.62
# 162        0.30    0.31     -0.01         3.28
# 181        0.21    0.21     -0.01         3.55
# 224        0.43    0.41      0.02         4.54
# 116        0.40    0.38      0.02         4.74
# 105        0.52    0.49      0.03         6.14
# 260        1.07    0.99      0.08         7.63
# 135        0.79    0.85     -0.07         7.86
# 175        0.67    0.73     -0.06         8.03
# 259        0.82    0.89     -0.07         8.13
# 100        0.48    0.52     -0.05         8.67
# 170        0.62    0.70     -0.07        10.28
# 99         0.34    0.31      0.03        10.69
# 123        0.45    0.51     -0.06        11.13
# 126        0.43    0.49     -0.06        11.47
# 119        0.69    0.61      0.07        11.94
# 198        0.42    0.48     -0.06        12.10
# 244        0.86    0.98     -0.12        12.28
# 148        0.49    0.44      0.05        12.53
# 128        0.41    0.36      0.05        12.76
# 189        0.45    0.52     -0.07        13.04
# 167        0.50    0.44      0.06        13.27
# 152        0.45    0.39      0.05        13.45
# 91         0.58    0.68     -0.09        13.58
# 243        0.84    0.97     -0.13        13.63
# 188        0.77    0.67      0.10        14.29
# 125        0.41    0.48     -0.07        14.46
# 213        0.38    0.45     -0.06        14.47
# 90         0.73    0.86     -0.12        14.52
# 197        0.56    0.49      0.07        14.53
# 153        0.40    0.35      0.05        14.65
# 206        0.49    0.57     -0.08        14.69
# 169        0.72    0.62      0.09        15.06
# 196        0.56    0.49      0.07        15.06
# 89         0.79    0.93     -0.14        15.41
# 252        0.84    1.00     -0.15        15.54
# 127        0.39    0.46     -0.07        15.68
# 209        0.81    0.96     -0.15        15.74
# 106        0.46    0.39      0.07        16.62
# 163        0.42    0.50     -0.08        16.97
# 208        0.79    0.95     -0.17        17.63
# 190        0.59    0.71     -0.13        17.88
# 218        0.75    0.93     -0.18        19.08
# 207        0.69    0.85     -0.16        19.16
# 111        0.58    0.48      0.09        19.32
# 186        0.58    0.48      0.10        20.44
# 258        0.50    0.62     -0.13        20.46
# 92         0.34    0.42     -0.09        20.48
# 88         0.68    0.85     -0.18        20.65
# 136        0.68    0.86     -0.18        20.76
# 220        0.38    0.49     -0.10        21.05
# 193        0.75    0.96     -0.20        21.12
# 247        0.73    0.93     -0.20        21.72
# 146        0.56    0.46      0.10        21.81
# 164        0.75    0.61      0.13        21.82
# 191        0.64    0.82     -0.18        22.15
# 165        0.62    0.51      0.11        22.28
# 112        0.57    0.46      0.10        22.32
# 120        0.63    0.82     -0.19        23.08
# 87         0.61    0.49      0.11        23.29
# 177        0.65    0.84     -0.20        23.35
# 147        0.59    0.47      0.11        23.98
# 151        0.52    0.42      0.10        24.03
# 277        1.15    0.92      0.22        24.27
# 79         0.59    0.47      0.12        24.60
# 80         0.32    0.42     -0.10        24.69
# 217        0.66    0.88     -0.22        24.73
# 124        0.38    0.50     -0.13        24.81
# 199        0.37    0.49     -0.12        24.87
# 157        0.22    0.18      0.04        25.06
# 98         0.17    0.23     -0.06        25.13
# 137        0.63    0.51      0.13        25.29
# 242        0.49    0.66     -0.17        26.16
# 145        0.50    0.40      0.10        26.32
# 251        0.72    0.98     -0.26        26.76
# 97         0.15    0.21     -0.06        26.84
# 174        0.57    0.45      0.12        26.99
# 230        0.58    0.79     -0.22        27.16
# 176        0.65    0.89     -0.24        27.19
# 312        1.25    0.98      0.27        27.37
# 266        1.26    0.99      0.27        27.42
# 109        0.60    0.47      0.13        27.88
# 142        0.20    0.28     -0.08        27.93
# 178        0.47    0.65     -0.18        28.16
# 234        0.65    0.93     -0.28        29.94
# 192        0.68    0.97     -0.29        29.96
# 172        0.58    0.44      0.14        30.93
# 168        0.61    0.47      0.14        31.04
# 240        0.68    0.99     -0.31        31.11
# 253        0.62    0.91     -0.28        31.20
# 121        0.56    0.81     -0.25        31.37
# 104        0.52    0.77     -0.25        32.55
# 102        0.65    0.96     -0.31        32.61
# 134        0.50    0.75     -0.25        33.28
# 222        0.61    0.91     -0.30        33.30
# 228        0.63    0.95     -0.32        33.51
# 171        0.66    0.49      0.17        33.62
# 216        0.61    0.46      0.16        34.30
# 195        0.27    0.41     -0.14        34.43
# 226        0.15    0.23     -0.08        34.91
# 225        0.50    0.76     -0.27        35.10
# 282        1.31    0.97      0.34        35.31
# 129        0.29    0.21      0.08        35.63
# 113        0.52    0.38      0.14        35.91
# 256        0.63    1.00     -0.37        37.05
# 103        0.58    0.93     -0.35        37.25
# 78         0.69    0.50      0.19        37.41
# 239        0.63    1.00     -0.37        37.47
# 57         0.04    0.07     -0.03        37.71
# 305        1.34    0.97      0.37        37.98
# 257        0.59    0.95     -0.36        38.13
# 110        0.69    0.50      0.19        38.24
# 203        0.58    0.95     -0.36        38.27
# 231        0.60    0.97     -0.38        38.78
# 245        0.40    0.65     -0.25        38.86
# 54         0.03    0.04     -0.02        38.90
# 202        0.61    0.99     -0.39        39.03
# 139        0.49    0.35      0.14        39.92
# 271        1.30    0.93      0.37        39.99
# 201        0.58    0.98     -0.39        40.14
# 233        0.35    0.60     -0.24        40.84
# 108        0.60    0.42      0.17        40.87
# 316        1.33    0.94      0.39        41.91
# 82         0.24    0.17      0.07        42.23
# 255        0.51    0.89     -0.38        42.32
# 212        0.51    0.36      0.15        42.75
# 227        0.33    0.58     -0.25        42.91
# 306        1.32    0.92      0.40        43.17
# 248        0.21    0.36     -0.16        43.19
# 317        1.41    0.98      0.43        43.78
# 101        0.50    0.88     -0.39        43.89
# 154        0.32    0.22      0.10        44.02
# 122        0.42    0.78     -0.36        45.77
# 238        0.53    0.98     -0.45        45.79
# 221        0.48    0.89     -0.41        46.24
# 204        0.45    0.85     -0.40        47.04
# 273        1.46    0.99      0.47        47.21
# 114        0.60    0.41      0.19        47.27
# 307        1.44    0.97      0.46        47.57
# 254        0.39    0.75     -0.36        48.02
# 232        0.23    0.44     -0.21        48.23
# 96         0.29    0.19      0.09        48.24
# 140        0.30    0.20      0.10        48.80
# 118        0.66    0.44      0.22        48.85
# 249        0.20    0.41     -0.21        50.65
# 265        1.48    0.98      0.50        51.10
# 250        0.44    0.91     -0.47        51.45
# 301        1.46    0.96      0.50        51.97
# 298        1.38    0.91      0.47        52.22
# 235        0.47    0.99     -0.52        52.62
# 77         0.69    0.44      0.24        54.31
# 313        1.54    0.99      0.54        54.61
# 200        0.39    0.87     -0.48        55.30
# 215        0.31    0.20      0.11        55.72
# 311        1.47    0.94      0.53        56.08
# 237        0.41    0.93     -0.52        56.26
# 285        1.45    0.93      0.52        56.29
# 143        0.08    0.20     -0.12        58.78
# 294        1.45    0.91      0.54        58.93
# 229        0.22    0.55     -0.33        60.03
# 219        0.49    0.30      0.18        60.64
# 236        0.37    0.96     -0.59        61.09
# 278        1.41    0.88      0.54        61.11
# 288        1.28    0.79      0.49        61.37
# 281        1.44    0.89      0.55        61.76
# 223        0.08    0.22     -0.14        62.04
# 299        1.57    0.97      0.61        62.84
# 300        1.61    0.99      0.62        62.93
# 205        0.19    0.51     -0.32        63.03
# 303        1.48    0.91      0.58        63.36
# 296        1.59    0.97      0.63        64.60
# 263        1.52    0.92      0.60        64.93
# 279        1.53    0.92      0.61        65.60
# 289        1.61    0.97      0.64        65.74
# 290        1.58    0.95      0.63        66.93
# 286        1.66    0.99      0.67        67.74
# 310        1.39    0.83      0.57        68.26
# 267        1.49    0.88      0.61        69.36
# 264        1.49    0.88      0.62        70.26
# 315        1.70    0.99      0.70        70.48
# 304        1.65    0.97      0.68        70.79
# 274        1.70    0.99      0.71        71.41
# 293        1.40    0.81      0.58        71.68
# 269        1.46    0.85      0.61        72.25
# 280        1.70    0.98      0.71        72.57
# 308        1.72    1.00      0.73        72.90
# 309        1.65    0.94      0.71        75.00
# 284        1.66    0.94      0.72        75.79
# 150        0.46    0.26      0.20        76.79
# 133        0.60    0.34      0.26        76.99
# 141        0.56    0.31      0.24        77.16
# 276        1.73    0.97      0.76        77.90
# 295        1.72    0.96      0.76        78.45
# 117        0.63    0.35      0.28        79.55
# 173        0.57    0.31      0.25        81.41
# 314        1.81    1.00      0.81        81.64
# 292        1.80    0.99      0.82        82.74
# 115        0.68    0.37      0.31        83.26
# 155        0.42    0.23      0.19        84.49
# 302        1.66    0.90      0.77        85.48
# 297        1.34    0.72      0.62        85.51
# 291        1.81    0.97      0.85        87.44
# 272        1.78    0.95      0.84        88.00
# 270        1.82    0.96      0.85        88.13
# 261        1.37    0.73      0.64        88.20
# 156        0.44    0.23      0.21        92.80
# 283        1.87    0.96      0.90        94.03
# 187        0.97    0.50      0.48        96.19
# 76         0.59    0.30      0.29        97.80
# 83         0.41    0.21      0.21       100.80
# 84         0.43    0.21      0.22       101.76
# 194        0.31    0.15      0.16       106.51
# 33         0.62    0.30      0.32       108.72
# 185        0.45    0.22      0.24       108.96
# 262        1.55    0.73      0.82       111.74
# 275        2.09    0.97      1.12       114.91
# 86         0.56    0.26      0.30       115.07
# 130        0.40    0.18      0.22       118.59
# 268        1.49    0.67      0.82       122.60
# 94         0.12    0.05      0.07       123.27
# 214        0.46    0.20      0.26       127.58
# 2         -0.00    0.01     -0.01       141.39
# 34         0.69    0.27      0.42       151.36
# 35         0.57    0.22      0.35       163.76
# 46         0.31    0.12      0.19       165.64
# 71         0.38    0.14      0.24       169.95
# 75         0.45    0.17      0.29       172.90
# 45         0.37    0.13      0.23       174.24
# 32         0.55    0.20      0.35       175.87
# 58         0.11    0.04      0.07       176.67
# 81         0.16    0.06      0.11       183.47
# 69         0.44    0.16      0.29       183.74
# 70         0.44    0.15      0.29       188.68
# 211        0.53    0.17      0.36       207.88
# 85         0.60    0.20      0.41       208.07
# 68         0.35    0.11      0.24       221.86
# 184        0.48    0.14      0.34       245.76
# 95         0.24    0.07      0.18       260.46
# 93         0.24    0.07      0.18       268.90
# 107        0.48    0.13      0.35       272.18
# 144        0.69    0.18      0.51       276.36
# 36         0.43    0.11      0.32       292.82
# 56         0.34    0.09      0.25       293.93
# 55         0.38    0.09      0.29       311.03
# 132        0.51    0.12      0.39       311.12
# 161        0.27    0.07      0.21       311.79
# 63         0.52    0.12      0.40       336.25
# 44         0.28    0.06      0.22       347.92
# 62         0.58    0.13      0.45       353.29
# 73         0.31    0.07      0.24       374.49
# 18         0.02    0.00      0.02       405.81
# 67         0.33    0.06      0.27       426.49
# 59         0.20    0.04      0.16       429.76
# 287        1.60    0.28      1.33       478.15
# 72         0.47    0.08      0.39       488.12
# 182        0.41    0.06      0.35       556.71
# 27        -0.05    0.01     -0.06       559.89
# 183        0.48    0.07      0.41       577.90
# 66         0.31    0.04      0.26       591.49
# 61         0.58    0.08      0.51       665.82
# 64         0.35    0.05      0.30       669.03
# 47         0.43    0.05      0.37       687.82
# 74         0.46    0.06      0.40       724.85
# 131        0.56    0.06      0.50       774.67
# 43         0.25    0.03      0.22       799.66
# 160        0.53    0.05      0.47       928.88
# 159        0.53    0.05      0.48       965.00
# 1          0.09    0.01      0.08      1142.41
# 28         0.13    0.01      0.12      1164.10
# 41         0.15    0.01      0.14      1179.02
# 42         0.17    0.01      0.15      1346.66
# 26         0.09    0.01      0.08      1359.68
# 17         0.16    0.01      0.15      1469.47
# 29         0.15    0.01      0.14      1709.71
# 60         0.11    0.01      0.10      1745.74
# 158        0.43    0.02      0.41      2040.14
# 53         0.23    0.01      0.22      2079.76
# 40         0.23    0.01      0.22      2332.65
# 15         0.21    0.01      0.20      2481.12
# 39         0.18    0.01      0.18      2497.19
# 3          0.07    0.00      0.07      2680.55
# 16         0.29    0.01      0.28      2980.94
# 25         0.12    0.00      0.12      3085.89
# 24         0.21    0.01      0.21      3432.05
# 23         0.20    0.00      0.20      4036.12
# 6          0.31    0.01      0.30      4218.25
# 50         0.40    0.01      0.39      4224.83
# 49         0.46    0.01      0.45      4300.54
# 21         0.24    0.00      0.23      4800.69
# 5          0.31    0.01      0.31      5125.50
# 38         0.38    0.01      0.37      5225.63
# 13         0.18    0.00      0.17      6484.07
# 8          0.18    0.00      0.18      6624.29
# 30         0.35    0.00      0.34      7048.20
# 0          0.12    0.00      0.12      7797.00
# 9          0.24    0.00      0.24      8850.44
# 7          0.25    0.00      0.25      9205.92
# 11         0.07    0.00      0.07     14423.42
# 4          0.23    0.00      0.23     14615.74
# 19         0.24    0.00      0.24     15255.16
# 37         0.26    0.00      0.26     16662.41
# 10         0.09    0.00      0.09     18707.43
# 65         0.31    0.00      0.31     19718.57
# 12         0.32    0.00      0.32     19967.97
# 48         0.41    0.00      0.40     25636.79
# 51         0.41    0.00      0.41     26144.46
# 31         0.44    0.00      0.44     28015.40
# 14         0.18    0.00      0.18     38454.14
# 20         0.23    0.00      0.23     47411.24
# 52         0.28    0.00      0.28     57481.58
# 22         0.42    0.00      0.42     87659.21

# %% [markdown]
# # *** Prediction Accuracy

# %%
r2_test = metrics.r2_score(y_test, y_test_hat)
print('R2 (testing) = {}'.format(r2_test))

# also: R-Squared could obtain with
# pline.score(x_test, y_test)
# Out:
# R2 (testing) = 0.04655585199000589

# %%
print(np.sqrt(mean_squared_error(y_test,y_test_hat)))
# Out:
# 0.35313924840654415
