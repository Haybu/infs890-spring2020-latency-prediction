# %% [markdown]
# # Predict future latency using LTSM
# Haytham Mohamed - INFS890 - Spring 2020

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import tensorflow as tf
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.metrics import mean_squared_error

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
file_dir = '../../data/processed-data-timeseries/'
data_file = 'raw_timeseries_data.csv'

df = pd.read_csv(file_dir + data_file)

target = 'svc_ltcy_200'

# move target column (err) to the end 
cols = df.columns.tolist()
cols.insert(len(cols)-1, cols.pop(cols.index(target)))
df = data_df.reindex(columns= cols)

df.date = pd.to_datetime(df.date)
df.set_index('date', inplace=True)
df.sort_index()

df.head()
# Out:
#                      svc_req_rate  svc_cpu_use  svc_cpu_sat  svc_net_use  \
# date
# 2020-02-17 08:36:51          0.64         0.16         0.06     53544.44
# 2020-02-17 08:37:06          0.64         0.07        -0.02     18535.60
# 2020-02-17 08:37:21          0.56        -0.01         0.01      7652.47
# 2020-02-17 08:37:36         -0.05         0.02        -0.01       172.34
# 2020-02-17 08:37:51          0.09        -0.02         0.01      9270.24
#
#                      svc_disk_use  system_cpu_use  system_cpu_sat  \
# date
# 2020-02-17 08:36:51        787.34            0.18            0.59
# 2020-02-17 08:37:06        885.38            0.10            0.41
# 2020-02-17 08:37:21       -742.25           -0.03           -5.33
# 2020-02-17 08:37:36      10578.40           -0.06            8.17
# 2020-02-17 08:37:51       6293.83           -0.02            4.16
#
#                      system_net_use  svc_req_size  svc_resp_size  svc_pods  \
# date
# 2020-02-17 08:36:51       526675.55       1046.39        7048.01       0.0
# 2020-02-17 08:37:06       362572.58       1046.39        7048.01       0.0
# 2020-02-17 08:37:21        36011.78        832.21        5735.02       0.0
# 2020-02-17 08:37:36       -77753.13       -217.00       -1925.54      -1.0
# 2020-02-17 08:37:51       -66192.56        103.55         675.50      -3.0
#
#                      svc_ltcy_200
# date
# 2020-02-17 08:36:51          0.05
# 2020-02-17 08:37:06          0.05
# 2020-02-17 08:37:21          0.06
# 2020-02-17 08:37:36          0.02
# 2020-02-17 08:37:51          0.01

# %%
values = df.values
columns = df.columns

# specify columns to plot
number_of_features = len(columns) - 1

i = 1
## plot each column
plt.figure(figsize=(20, 40), dpi=80, facecolor='w', edgecolor='k')
for group in range(number_of_features):
    plt.subplot(number_of_features, 1, i)
    plt.plot(values[:, group])
    plt.title(df.columns[group], y=0.5, loc='right')
    i += 1
plt.show()
# Out:
# 12

# %% [markdown]
# ## Multivariate LSTM Forecast Model
#
# We need to model:
# a forecasting model that can predict set of metrics given past observed metrics. I will fit an LSTM model to the collected metrics data. First we need to transfer the time series dataset into a supervised learning dataset. I will use Pandas shift function to achieve this goal.

# %%
# convert series to supervised learning
def series_to_supervised(data, col_names, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
    data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        col_names: List of feature column names
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('%s(t-%d)' % (col_names[j], i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('%s(t)' % (col_names[j])) for j in range(n_vars)]
        else:
            names += [('%s(t+%d)' % (col_names[j], i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# integer encode direction
#encoder = preprocessing.LabelEncoder()
#values[:,2] = encoder.fit_transform(values[:,2])   # error as target column to encode
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, column_names[1:], 1, 1)
# drop columns we don't want to predict
drop_columns = ['req(t)', 'rmem(t)', 'rcpu(t)', 'rfs(t)', 'dur(t)', 'nett(t)', 'nrr(t)', 'cpu(t)', 'mem(t)', 'nmem(t)', 'ncpu(t)', 'dbops(t)','dbconn(t)']
reframed.drop(drop_columns, axis=1, inplace=True)
reframed.head()
# Out:
#    req(t-1)  err(t-1)  rmem(t-1)  rcpu(t-1)  rfs(t-1)  dur(t-1)  nett(t-1)  \
# 1  0.640444  0.513754   0.484479   0.717147  0.710879  0.524696   0.873522
# 2  0.640799  0.513754   0.505908   0.717147  0.754221  0.504757   0.873522
# 3  0.639911  0.516500   0.475558   0.717049  0.627763  0.463511   0.852609
# 4  0.639911  0.516500   0.475558   0.717049  0.627763  0.463511   0.852609
# 5  0.641243  0.517390   0.501804   0.717116  0.737685  0.677956   0.920153
#
#    nrr(t-1)  cpu(t-1)  mem(t-1)  nmem(t-1)  ncpu(t-1)  dbops(t-1)  \
# 1  0.500289  0.539034  0.511445   0.003994   0.537214    0.523951
# 2  0.501600  0.514829  0.519737   0.003960   0.537281    0.523951
# 3  0.498400  0.520723  0.477903   0.002377   0.537281    0.523951
# 4  0.498400  0.520723  0.477903   0.000795   0.537281    0.523951
# 5  0.501630  0.706292  0.716174   0.006525   0.537281    0.523951
#
#    dbconn(t-1)    err(t)
# 1          0.0  0.513754
# 2          0.0  0.516500
# 3          0.0  0.516500
# 4          0.0  0.517390
# 5          0.0  0.510474

# %%
data = reframed.values

n_train = round(0.7 * data.shape[0])   # take 70% of sample for training
n_valid = round(0.1 * data.shape[0])   # 1% for validation &  2% for testing
train = data[:n_train, :]              
valid = data[n_train:n_train+n_valid, :]
test = data[n_train+n_valid:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
valid_X, valid_y = valid[:, :-1], valid[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
valid_X = valid_X.reshape((valid_X.shape[0], 1, valid_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape, valid_X.shape, valid_y.shape)
# Out:
# (794, 1, 14) (794,) (227, 1, 14) (227,) (113, 1, 14) (113,)

# %% [markdown]
# ## Create and Train Model
#
# Next, define and fit an LSTM model.
#
# I will define the LSTM with 50 neurons in the first hidden layer and 1 neuron in the output layer for predicting pollution.
# The input shape will be 1 time step with 14 features.

# %%
hidden_nodes_number = 50
epochs = 50
batch = 100

# design network
model = Sequential()
model.add(LSTM(hidden_nodes_number, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
#model.compile(loss='mae', optimizer='adam')
model.compile(loss='mean_squared_error', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 794 samples, validate on 227 samples
# Epoch 1/50
#  - 0s - loss: 0.1403 - val_loss: 0.0781
# Epoch 2/50
#  - 0s - loss: 0.0481 - val_loss: 0.0162
# Epoch 3/50
#  - 0s - loss: 0.0072 - val_loss: 3.2445e-04
# Epoch 4/50
#  - 0s - loss: 0.0027 - val_loss: 0.0038
# Epoch 5/50
#  - 0s - loss: 0.0048 - val_loss: 0.0026
# Epoch 6/50
#  - 0s - loss: 0.0025 - val_loss: 4.2328e-04
# Epoch 7/50
#  - 0s - loss: 0.0014 - val_loss: 4.8836e-04
# Epoch 8/50
#  - 0s - loss: 0.0016 - val_loss: 5.3632e-04
# Epoch 9/50
#  - 0s - loss: 0.0014 - val_loss: 3.3320e-04
# Epoch 10/50
#  - 0s - loss: 0.0013 - val_loss: 3.1900e-04
# Epoch 11/50
#  - 0s - loss: 0.0013 - val_loss: 3.2483e-04
# Epoch 12/50
#  - 0s - loss: 0.0013 - val_loss: 3.0855e-04
# Epoch 13/50
#  - 0s - loss: 0.0013 - val_loss: 3.1053e-04
# Epoch 14/50
#  - 0s - loss: 0.0013 - val_loss: 3.0977e-04
# Epoch 15/50
#  - 0s - loss: 0.0013 - val_loss: 3.0798e-04
# Epoch 16/50
#  - 0s - loss: 0.0013 - val_loss: 3.0810e-04
# Epoch 17/50
#  - 0s - loss: 0.0013 - val_loss: 3.0798e-04
# Epoch 18/50
#  - 0s - loss: 0.0013 - val_loss: 3.0807e-04
# Epoch 19/50
#  - 0s - loss: 0.0013 - val_loss: 3.0808e-04
# Epoch 20/50
#  - 0s - loss: 0.0013 - val_loss: 3.0804e-04
# Epoch 21/50
#  - 0s - loss: 0.0013 - val_loss: 3.0807e-04
# Epoch 22/50
#  - 0s - loss: 0.0013 - val_loss: 3.0811e-04
# Epoch 23/50
#  - 0s - loss: 0.0013 - val_loss: 3.0816e-04
# Epoch 24/50
#  - 0s - loss: 0.0013 - val_loss: 3.0820e-04
# Epoch 25/50
#  - 0s - loss: 0.0013 - val_loss: 3.0825e-04
# Epoch 26/50
#  - 0s - loss: 0.0013 - val_loss: 3.0832e-04
# Epoch 27/50
#  - 0s - loss: 0.0013 - val_loss: 3.0838e-04
# Epoch 28/50
#  - 0s - loss: 0.0013 - val_loss: 3.0846e-04
# Epoch 29/50
#  - 0s - loss: 0.0013 - val_loss: 3.0854e-04
# Epoch 30/50
#  - 0s - loss: 0.0013 - val_loss: 3.0863e-04
# Epoch 31/50
#  - 0s - loss: 0.0013 - val_loss: 3.0872e-04
# Epoch 32/50
#  - 0s - loss: 0.0013 - val_loss: 3.0882e-04
# Epoch 33/50
#  - 0s - loss: 0.0013 - val_loss: 3.0893e-04
# Epoch 34/50
#  - 0s - loss: 0.0013 - val_loss: 3.0904e-04
# Epoch 35/50
#  - 0s - loss: 0.0013 - val_loss: 3.0916e-04
# Epoch 36/50
#  - 0s - loss: 0.0013 - val_loss: 3.0929e-04
# Epoch 37/50
#  - 0s - loss: 0.0013 - val_loss: 3.0942e-04
# Epoch 38/50
#  - 0s - loss: 0.0013 - val_loss: 3.0956e-04
# Epoch 39/50
#  - 0s - loss: 0.0013 - val_loss: 3.0970e-04
# Epoch 40/50
#  - 0s - loss: 0.0013 - val_loss: 3.0985e-04
# Epoch 41/50
#  - 0s - loss: 0.0013 - val_loss: 3.1001e-04
# Epoch 42/50
#  - 0s - loss: 0.0013 - val_loss: 3.1017e-04
# Epoch 43/50
#  - 0s - loss: 0.0013 - val_loss: 3.1033e-04
# Epoch 44/50
#  - 0s - loss: 0.0013 - val_loss: 3.1050e-04
# Epoch 45/50
#  - 0s - loss: 0.0013 - val_loss: 3.1068e-04
# Epoch 46/50
#  - 0s - loss: 0.0013 - val_loss: 3.1086e-04
# Epoch 47/50
#  - 0s - loss: 0.0013 - val_loss: 3.1105e-04
# Epoch 48/50
#  - 0s - loss: 0.0013 - val_loss: 3.1124e-04
# Epoch 49/50
#  - 0s - loss: 0.0013 - val_loss: 3.1144e-04
# Epoch 50/50
#  - 0s - loss: 0.0013 - val_loss: 3.1164e-04

# %%
# plot history
plt.figure(figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluate Model

# %%
# make a prediction
yhat = model.predict(valid_X)
valid_X = valid_X.reshape((valid_X.shape[0], valid_X.shape[2]))
# invert scaling for forecast
inv_yhat = np.concatenate((valid_X[:, :-1], yhat), axis=1)


inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

print ("Predicted values: {}".format(inv_yhat[:20]))

# invert scaling for actual
valid_y = valid_y.reshape((len(valid_y), 1))
inv_y = np.concatenate((valid_X[:, :-1], valid_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]

print ("Actual values: {}".format(inv_y[:20]))
# calculate RMSE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Predicted values: [ 87.6838913   87.68370056  87.6835022   87.68331146  87.68309784
#   87.80282593  89.41300964  87.34560394  87.76457977  87.7585144
#   87.7611618   87.83325195  87.77031708  87.76959991  87.76889038
#   87.76817322  87.76746368  87.76674652  87.76602173  87.76963043]
# Actual values: [ 87.86164856  87.86164856  87.86164856  87.86164856  87.86164856
#   88.27774048  87.60903168  87.980896    87.980896    87.980896    87.980896
#   87.81204224  87.81204224  87.81204224  87.81204224  87.81204224
#   87.81204224  87.81204224  87.81204224  87.81204224]
# Test RMSE: 1.805

# %%
# df['f'] = df['d'].rolling(2).sum().shift(-1)

compare_df = pd.DataFrame({'actual':inv_y, 'predicted':inv_yhat})
# referse the diff (stationary)
compare_df['actual'] = compare_df['actual'].rolling(2).sum().shift(-1)
compare_df['predicted'] = compare_df['predicted'].rolling(2).sum().shift(-1)


compare_df.head()
# Out:
#        actual   predicted
# 0  175.723297  175.580193
# 1  175.723297  175.579903
# 2  175.723297  175.579597
# 3  175.723297  175.579277
# 4  176.139389  175.657364
